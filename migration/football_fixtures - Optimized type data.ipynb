# %%
import mysql.connector
# -----------------------------------------------------------------
# CHECK
# -----------------------------------------------------------------
col = 'end_ah_pattern'
# -----------------------------------------------------------------
host="localhost"
user="root"
database="pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
# -----------------------------------------------------------------
query = ' select '
query += col 
query += ' , CHAR_LENGTH(' + col + ') '  
query += ' from football_fixtures '  
query += ' where ' + col + ' is not null ' 
query += ' order by CHAR_LENGTH(' + col + ') desc ' 
query += ' limit 3 ' 
# -----------------------------------------------------------------
mycursor = mydb.cursor() 
mycursor.execute(query)
myresult = mycursor.fetchall()
# -----------------------------------------------------------------
print("Total rows : " + str(len(myresult))) 
# -----------------------------------------------------------------
for x in myresult:  
    # -------------------------------------------------------------
    col_name = str(x[0])
    col_length = str(x[1])
    # -------------------------------------------------------------
    print(col_name + " -- " + col_length )
# Out:
# Total rows : 3
# 2+225+25+3+325+35+375+4+425+H -- 29
# 15_125_1_075_05_0#025+075+1+H -- 29
# 175_15_125_1_075_075+1+125+H -- 28

# %%
import mysql.connector
# -----------------------------------------------------------------
# CHECK
# -----------------------------------------------------------------
col = [
    'pre_match_winner_home', 
    'pre_match_winner_draw', 
    'pre_match_winner_away', 
    'end_match_winner_home', 
    'end_match_winner_draw', 
    'end_match_winner_away', 
    'pre_homeaway_home', 
    'pre_homeaway_away', 
    'end_homeaway_home', 
    'end_homeaway_away',
    'pre_first_half_winner_home',
    'pre_first_half_winner_draw',
    'pre_first_half_winner_away',
    'end_first_half_winner_home',
    'end_first_half_winner_draw',
    'end_first_half_winner_away',
    'pre_second_half_winner_home',
    'pre_second_half_winner_draw',
    'pre_second_half_winner_away',
    'end_second_half_winner_home',
    'end_second_half_winner_draw',
    'end_second_half_winner_away',
    'pre_asian_handicap_home_min_675',
    'pre_asian_handicap_away_min_675',
    'pre_asian_handicap_home_min_65',
    'pre_asian_handicap_away_min_65',
    'pre_asian_handicap_home_min_625',
    'pre_asian_handicap_away_min_625',
    'pre_asian_handicap_home_min_6',
    'pre_asian_handicap_away_min_6',
    'pre_asian_handicap_home_min_575',
    'pre_asian_handicap_away_min_575',
    'pre_asian_handicap_home_min_55',
    'pre_asian_handicap_away_min_55',
    'pre_asian_handicap_home_min_525',
    'pre_asian_handicap_away_min_525',
    'pre_asian_handicap_home_min_5',
    'pre_asian_handicap_away_min_5',
    'pre_asian_handicap_home_min_475',
    'pre_asian_handicap_away_min_475',
    'pre_asian_handicap_home_min_45',
    'pre_asian_handicap_away_min_45',
    'pre_asian_handicap_home_min_425',
    'pre_asian_handicap_away_min_425',
    'pre_asian_handicap_home_min_4',
    'pre_asian_handicap_away_min_4',
    'pre_asian_handicap_home_min_375',
    'pre_asian_handicap_away_min_375',
    'pre_asian_handicap_home_min_35',
    'pre_asian_handicap_away_min_35',
    'pre_asian_handicap_home_min_325',
    'pre_asian_handicap_away_min_325',
    'pre_asian_handicap_home_min_3',
    'pre_asian_handicap_away_min_3',
    'pre_asian_handicap_home_min_275',
    'pre_asian_handicap_away_min_275',
    'pre_asian_handicap_home_min_25',
    'pre_asian_handicap_away_min_25',
    'pre_asian_handicap_home_min_225',
    'pre_asian_handicap_away_min_225',
    'pre_asian_handicap_home_min_2',
    'pre_asian_handicap_away_min_2',
    'pre_asian_handicap_home_min_175',
    'pre_asian_handicap_away_min_175',
    'pre_asian_handicap_home_min_15',
    'pre_asian_handicap_away_min_15',
    'pre_asian_handicap_home_min_125',
    'pre_asian_handicap_away_min_125',
    'pre_asian_handicap_home_min_1',
    'pre_asian_handicap_away_min_1',
    'pre_asian_handicap_home_min_075',
    'pre_asian_handicap_away_min_075',
    'pre_asian_handicap_home_min_05',
    'pre_asian_handicap_away_min_05',
    'pre_asian_handicap_home_min_025',
    'pre_asian_handicap_away_min_025',
    'pre_asian_handicap_home_plus_0',
    'pre_asian_handicap_away_plus_0',
    'pre_asian_handicap_home_plus_025',
    'pre_asian_handicap_away_plus_025',
    'pre_asian_handicap_home_plus_05',
    'pre_asian_handicap_away_plus_05',
    'pre_asian_handicap_home_plus_075',
    'pre_asian_handicap_away_plus_075',
    'pre_asian_handicap_home_plus_1',
    'pre_asian_handicap_away_plus_1',
    'pre_asian_handicap_home_plus_125',
    'pre_asian_handicap_away_plus_125',
    'pre_asian_handicap_home_plus_15',
    'pre_asian_handicap_away_plus_15',
    'pre_asian_handicap_home_plus_175',
    'pre_asian_handicap_away_plus_175',
    'pre_asian_handicap_home_plus_2',
    'pre_asian_handicap_away_plus_2',
    'pre_asian_handicap_home_plus_225',
    'pre_asian_handicap_away_plus_225',
    'pre_asian_handicap_home_plus_25',
    'pre_asian_handicap_away_plus_25',
    'pre_asian_handicap_home_plus_275',
    'pre_asian_handicap_away_plus_275',
    'pre_asian_handicap_home_plus_3',
    'pre_asian_handicap_away_plus_3',
    'pre_asian_handicap_home_plus_325',
    'pre_asian_handicap_away_plus_325',
    'pre_asian_handicap_home_plus_35',
    'pre_asian_handicap_away_plus_35',
    'pre_asian_handicap_home_plus_375',
    'pre_asian_handicap_away_plus_375',
    'pre_asian_handicap_home_plus_4',
    'pre_asian_handicap_away_plus_4',
    'pre_asian_handicap_home_plus_425',
    'pre_asian_handicap_away_plus_425',
    'pre_asian_handicap_home_plus_45',
    'pre_asian_handicap_away_plus_45',
    'pre_asian_handicap_home_plus_475',
    'pre_asian_handicap_away_plus_475',
    'pre_asian_handicap_home_plus_5',
    'pre_asian_handicap_away_plus_5',
    'pre_asian_handicap_home_plus_525',
    'pre_asian_handicap_away_plus_525',
    'pre_asian_handicap_home_plus_55',
    'pre_asian_handicap_away_plus_55',
    'pre_asian_handicap_home_plus_575',
    'pre_asian_handicap_away_plus_575',
    'pre_asian_handicap_home_plus_6',
    'pre_asian_handicap_away_plus_6',
    'pre_asian_handicap_home_plus_625',
    'pre_asian_handicap_away_plus_625',
    'pre_asian_handicap_home_plus_65',
    'pre_asian_handicap_away_plus_65',
    'pre_asian_handicap_home_plus_675',
    'pre_asian_handicap_away_plus_675',
    'end_asian_handicap_home_min_675',
    'end_asian_handicap_away_min_675',
    'end_asian_handicap_home_min_65',
    'end_asian_handicap_away_min_65',
    'end_asian_handicap_home_min_625',
    'end_asian_handicap_away_min_625',
    'end_asian_handicap_home_min_6',
    'end_asian_handicap_away_min_6',
    'end_asian_handicap_home_min_575',
    'end_asian_handicap_away_min_575',
    'end_asian_handicap_home_min_55',
    'end_asian_handicap_away_min_55',
    'end_asian_handicap_home_min_525',
    'end_asian_handicap_away_min_525',
    'end_asian_handicap_home_min_5',
    'end_asian_handicap_away_min_5',
    'end_asian_handicap_home_min_475',
    'end_asian_handicap_away_min_475',
    'end_asian_handicap_home_min_45',
    'end_asian_handicap_away_min_45',
    'end_asian_handicap_home_min_425',
    'end_asian_handicap_away_min_425',
    'end_asian_handicap_home_min_4',
    'end_asian_handicap_away_min_4',
    'end_asian_handicap_home_min_375',
    'end_asian_handicap_away_min_375',
    'end_asian_handicap_home_min_35',
    'end_asian_handicap_away_min_35',
    'end_asian_handicap_home_min_325',
    'end_asian_handicap_away_min_325',
    'end_asian_handicap_home_min_3',
    'end_asian_handicap_away_min_3',
    'end_asian_handicap_home_min_275',
    'end_asian_handicap_away_min_275',
    'end_asian_handicap_home_min_25',
    'end_asian_handicap_away_min_25',
    'end_asian_handicap_home_min_225',
    'end_asian_handicap_away_min_225',
    'end_asian_handicap_home_min_2',
    'end_asian_handicap_away_min_2',
    'end_asian_handicap_home_min_175',
    'end_asian_handicap_away_min_175',
    'end_asian_handicap_home_min_15',
    'end_asian_handicap_away_min_15',
    'end_asian_handicap_home_min_125',
    'end_asian_handicap_away_min_125',
    'end_asian_handicap_home_min_1',
    'end_asian_handicap_away_min_1',
    'end_asian_handicap_home_min_075',
    'end_asian_handicap_away_min_075',
    'end_asian_handicap_home_min_05',
    'end_asian_handicap_away_min_05',
    'end_asian_handicap_home_min_025',
    'end_asian_handicap_away_min_025',
    'end_asian_handicap_home_plus_0',
    'end_asian_handicap_away_plus_0',
    'end_asian_handicap_home_plus_025',
    'end_asian_handicap_away_plus_025',
    'end_asian_handicap_home_plus_05',
    'end_asian_handicap_away_plus_05',
    'end_asian_handicap_home_plus_075',
    'end_asian_handicap_away_plus_075',
    'end_asian_handicap_home_plus_1',
    'end_asian_handicap_away_plus_1',
    'end_asian_handicap_home_plus_125',
    'end_asian_handicap_away_plus_125',
    'end_asian_handicap_home_plus_15',
    'end_asian_handicap_away_plus_15',
    'end_asian_handicap_home_plus_175',
    'end_asian_handicap_away_plus_175',
    'end_asian_handicap_home_plus_2',
    'end_asian_handicap_away_plus_2',
    'end_asian_handicap_home_plus_225',
    'end_asian_handicap_away_plus_225',
    'end_asian_handicap_home_plus_25',
    'end_asian_handicap_away_plus_25',
    'end_asian_handicap_home_plus_275',
    'end_asian_handicap_away_plus_275',
    'end_asian_handicap_home_plus_3',
    'end_asian_handicap_away_plus_3',
    'end_asian_handicap_home_plus_325',
    'end_asian_handicap_away_plus_325',
    'end_asian_handicap_home_plus_35',
    'end_asian_handicap_away_plus_35',
    'end_asian_handicap_home_plus_375',
    'end_asian_handicap_away_plus_375',
    'end_asian_handicap_home_plus_4',
    'end_asian_handicap_away_plus_4',
    'end_asian_handicap_home_plus_425',
    'end_asian_handicap_away_plus_425',
    'end_asian_handicap_home_plus_45',
    'end_asian_handicap_away_plus_45',
    'end_asian_handicap_home_plus_475',
    'end_asian_handicap_away_plus_475',
    'end_asian_handicap_home_plus_5',
    'end_asian_handicap_away_plus_5',
    'end_asian_handicap_home_plus_525',
    'end_asian_handicap_away_plus_525',
    'end_asian_handicap_home_plus_55',
    'end_asian_handicap_away_plus_55',
    'end_asian_handicap_home_plus_575',
    'end_asian_handicap_away_plus_575',
    'end_asian_handicap_home_plus_6',
    'end_asian_handicap_away_plus_6',
    'end_asian_handicap_home_plus_625',
    'end_asian_handicap_away_plus_625',
    'end_asian_handicap_home_plus_65',
    'end_asian_handicap_away_plus_65',
    'end_asian_handicap_home_plus_675',
    'end_asian_handicap_away_plus_675',
    'pre_goals_overunder_over_05',
    'pre_goals_overunder_under_05',
    'pre_goals_overunder_over_075',
    'pre_goals_overunder_under_075',
    'pre_goals_overunder_over_10',
    'pre_goals_overunder_under_10',
    'pre_goals_overunder_over_125',
    'pre_goals_overunder_under_125',
    'pre_goals_overunder_over_15',
    'pre_goals_overunder_under_15',
    'pre_goals_overunder_over_175',
    'pre_goals_overunder_under_175',
    'pre_goals_overunder_over_20',
    'pre_goals_overunder_under_20',
    'pre_goals_overunder_over_225',
    'pre_goals_overunder_under_225',
    'pre_goals_overunder_over_25',
    'pre_goals_overunder_under_25',
    'pre_goals_overunder_over_275',
    'pre_goals_overunder_under_275',
    'pre_goals_overunder_over_30',
    'pre_goals_overunder_under_30',
    'pre_goals_overunder_over_325',
    'pre_goals_overunder_under_325',
    'pre_goals_overunder_over_35',
    'pre_goals_overunder_under_35',
    'pre_goals_overunder_over_375',
    'pre_goals_overunder_under_375',
    'pre_goals_overunder_over_40',
    'pre_goals_overunder_under_40',
    'pre_goals_overunder_over_425',
    'pre_goals_overunder_under_425',
    'pre_goals_overunder_over_45',
    'pre_goals_overunder_under_45',
    'pre_goals_overunder_over_475',
    'pre_goals_overunder_under_475',
    'pre_goals_overunder_over_50',
    'pre_goals_overunder_under_50',
    'pre_goals_overunder_over_525',
    'pre_goals_overunder_under_525',
    'pre_goals_overunder_over_55',
    'pre_goals_overunder_under_55',
    'pre_goals_overunder_over_575',
    'pre_goals_overunder_under_575',
    'pre_goals_overunder_over_60',
    'pre_goals_overunder_under_60',
    'pre_goals_overunder_over_625',
    'pre_goals_overunder_under_625',
    'pre_goals_overunder_over_65',
    'pre_goals_overunder_under_65',
    'pre_goals_overunder_over_675',
    'pre_goals_overunder_under_675',
    'pre_goals_overunder_over_70',
    'pre_goals_overunder_under_70',
    'pre_goals_overunder_over_75',
    'pre_goals_overunder_under_75',
    'pre_goals_overunder_over_85',
    'pre_goals_overunder_under_85',
    'pre_goals_overunder_over_95',
    'pre_goals_overunder_under_95',
    'end_goals_overunder_over_05',
    'end_goals_overunder_under_05',
    'end_goals_overunder_over_075',
    'end_goals_overunder_under_075',
    'end_goals_overunder_over_10',
    'end_goals_overunder_under_10',
    'end_goals_overunder_over_125',
    'end_goals_overunder_under_125',
    'end_goals_overunder_over_15',
    'end_goals_overunder_under_15',
    'end_goals_overunder_over_175',
    'end_goals_overunder_under_175',
    'end_goals_overunder_over_20',
    'end_goals_overunder_under_20',
    'end_goals_overunder_over_225',
    'end_goals_overunder_under_225',
    'end_goals_overunder_over_25',
    'end_goals_overunder_under_25',
    'end_goals_overunder_over_275',
    'end_goals_overunder_under_275',
    'end_goals_overunder_over_30',
    'end_goals_overunder_under_30',
    'end_goals_overunder_over_325',
    'end_goals_overunder_under_325',
    'end_goals_overunder_over_35',
    'end_goals_overunder_under_35',
    'end_goals_overunder_over_375',
    'end_goals_overunder_under_375',
    'end_goals_overunder_over_40',
    'end_goals_overunder_under_40',
    'end_goals_overunder_over_425',
    'end_goals_overunder_under_425',
    'end_goals_overunder_over_45',
    'end_goals_overunder_under_45',
    'end_goals_overunder_over_475',
    'end_goals_overunder_under_475',
    'end_goals_overunder_over_50',
    'end_goals_overunder_under_50',
    'end_goals_overunder_over_525',
    'end_goals_overunder_under_525',
    'end_goals_overunder_over_55',
    'end_goals_overunder_under_55',
    'end_goals_overunder_over_575',
    'end_goals_overunder_under_575',
    'end_goals_overunder_over_60',
    'end_goals_overunder_under_60',
    'end_goals_overunder_over_625',
    'end_goals_overunder_under_625',
    'end_goals_overunder_over_65',
    'end_goals_overunder_under_65',
    'end_goals_overunder_over_675',
    'end_goals_overunder_under_675',
    'end_goals_overunder_over_70',
    'end_goals_overunder_under_70',
    'end_goals_overunder_over_75',
    'end_goals_overunder_under_75',
    'end_goals_overunder_over_85',
    'end_goals_overunder_under_85',
    'end_goals_overunder_over_95',
    'end_goals_overunder_under_95',
    'pre_asian_handicap_first_half_home_min_175',
    'pre_asian_handicap_first_half_away_min_175',
    'pre_asian_handicap_first_half_home_min_15',
    'pre_asian_handicap_first_half_away_min_15',
    'pre_asian_handicap_first_half_home_min_125',
    'pre_asian_handicap_first_half_away_min_125',
    'pre_asian_handicap_first_half_home_min_1',
    'pre_asian_handicap_first_half_away_min_1',
    'pre_asian_handicap_first_half_home_min_075',
    'pre_asian_handicap_first_half_away_min_075',
    'pre_asian_handicap_first_half_home_min_05',
    'pre_asian_handicap_first_half_away_min_05',
    'pre_asian_handicap_first_half_home_min_025',
    'pre_asian_handicap_first_half_away_min_025',
    'pre_asian_handicap_first_half_home_plus_0',
    'pre_asian_handicap_first_half_away_plus_0',
    'pre_asian_handicap_first_half_home_plus_025',
    'pre_asian_handicap_first_half_away_plus_025',
    'pre_asian_handicap_first_half_home_plus_05',
    'pre_asian_handicap_first_half_away_plus_05',
    'pre_asian_handicap_first_half_home_plus_075',
    'pre_asian_handicap_first_half_away_plus_075',
    'pre_asian_handicap_first_half_home_plus_1',
    'pre_asian_handicap_first_half_away_plus_1',
    'pre_asian_handicap_first_half_home_plus_125',
    'pre_asian_handicap_first_half_away_plus_125',
    'pre_asian_handicap_first_half_home_plus_15',
    'pre_asian_handicap_first_half_away_plus_15',
    'pre_asian_handicap_first_half_home_plus_175',
    'pre_asian_handicap_first_half_away_plus_175',
    'end_asian_handicap_first_half_home_min_175',
    'end_asian_handicap_first_half_away_min_175',
    'end_asian_handicap_first_half_home_min_15',
    'end_asian_handicap_first_half_away_min_15',
    'end_asian_handicap_first_half_home_min_125',
    'end_asian_handicap_first_half_away_min_125',
    'end_asian_handicap_first_half_home_min_1',
    'end_asian_handicap_first_half_away_min_1',
    'end_asian_handicap_first_half_home_min_075',
    'end_asian_handicap_first_half_away_min_075',
    'end_asian_handicap_first_half_home_min_05',
    'end_asian_handicap_first_half_away_min_05',
    'end_asian_handicap_first_half_home_min_025',
    'end_asian_handicap_first_half_away_min_025',
    'end_asian_handicap_first_half_home_plus_0',
    'end_asian_handicap_first_half_away_plus_0',
    'end_asian_handicap_first_half_home_plus_025',
    'end_asian_handicap_first_half_away_plus_025',
    'end_asian_handicap_first_half_home_plus_05',
    'end_asian_handicap_first_half_away_plus_05',
    'end_asian_handicap_first_half_home_plus_075',
    'end_asian_handicap_first_half_away_plus_075',
    'end_asian_handicap_first_half_home_plus_1',
    'end_asian_handicap_first_half_away_plus_1',
    'end_asian_handicap_first_half_home_plus_125',
    'end_asian_handicap_first_half_away_plus_125',
    'end_asian_handicap_first_half_home_plus_15',
    'end_asian_handicap_first_half_away_plus_15',
    'end_asian_handicap_first_half_home_plus_175',
    'end_asian_handicap_first_half_away_plus_175',
    'pre_goals_overunder_first_half_over_05',
    'pre_goals_overunder_first_half_under_05',
    'pre_goals_overunder_first_half_over_075',
    'pre_goals_overunder_first_half_under_075',
    'pre_goals_overunder_first_half_over_10',
    'pre_goals_overunder_first_half_under_10',
    'pre_goals_overunder_first_half_over_125',
    'pre_goals_overunder_first_half_under_125',
    'pre_goals_overunder_first_half_over_15',
    'pre_goals_overunder_first_half_under_15',
    'pre_goals_overunder_first_half_over_175',
    'pre_goals_overunder_first_half_under_175',
    'pre_goals_overunder_first_half_over_20',
    'pre_goals_overunder_first_half_under_20',
    'pre_goals_overunder_first_half_over_225',
    'pre_goals_overunder_first_half_under_225',
    'pre_goals_overunder_first_half_over_25',
    'pre_goals_overunder_first_half_under_25',
    'pre_goals_overunder_first_half_over_275',
    'pre_goals_overunder_first_half_under_275',
    'pre_goals_overunder_first_half_over_30',
    'pre_goals_overunder_first_half_under_30',
    'pre_goals_overunder_first_half_over_325',
    'pre_goals_overunder_first_half_under_325',
    'pre_goals_overunder_first_half_over_35',
    'pre_goals_overunder_first_half_under_35',
    'pre_goals_overunder_first_half_over_375',
    'pre_goals_overunder_first_half_under_375',
    'end_goals_overunder_first_half_over_05',
    'end_goals_overunder_first_half_under_05',
    'end_goals_overunder_first_half_over_075',
    'end_goals_overunder_first_half_under_075',
    'end_goals_overunder_first_half_over_10',
    'end_goals_overunder_first_half_under_10',
    'end_goals_overunder_first_half_over_125',
    'end_goals_overunder_first_half_under_125',
    'end_goals_overunder_first_half_over_15',
    'end_goals_overunder_first_half_under_15',
    'end_goals_overunder_first_half_over_175',
    'end_goals_overunder_first_half_under_175',
    'end_goals_overunder_first_half_over_20',
    'end_goals_overunder_first_half_under_20',
    'end_goals_overunder_first_half_over_225',
    'end_goals_overunder_first_half_under_225',
    'end_goals_overunder_first_half_over_25',
    'end_goals_overunder_first_half_under_25',
    'end_goals_overunder_first_half_over_275',
    'end_goals_overunder_first_half_under_275',
    'end_goals_overunder_first_half_over_30',
    'end_goals_overunder_first_half_under_30',
    'end_goals_overunder_first_half_over_325',
    'end_goals_overunder_first_half_under_325',
    'end_goals_overunder_first_half_over_35',
    'end_goals_overunder_first_half_under_35',
    'end_goals_overunder_first_half_over_375',
    'end_goals_overunder_first_half_under_375',
    'pre_goals_overunder__second_half_over_05',
    'pre_goals_overunder__second_half_under_05',
    'pre_goals_overunder__second_half_over_075',
    'pre_goals_overunder__second_half_under_075',
    'pre_goals_overunder__second_half_over_10',
    'pre_goals_overunder__second_half_under_10',
    'pre_goals_overunder__second_half_over_125',
    'pre_goals_overunder__second_half_under_125',
    'pre_goals_overunder__second_half_over_15',
    'pre_goals_overunder__second_half_under_15',
    'pre_goals_overunder__second_half_over_175',
    'pre_goals_overunder__second_half_under_175',
    'pre_goals_overunder__second_half_over_20',
    'pre_goals_overunder__second_half_under_20',
    'pre_goals_overunder__second_half_over_225',
    'pre_goals_overunder__second_half_under_225',
    'pre_goals_overunder__second_half_over_25',
    'pre_goals_overunder__second_half_under_25',
    'pre_goals_overunder__second_half_over_275',
    'pre_goals_overunder__second_half_under_275',
    'pre_goals_overunder__second_half_over_30',
    'pre_goals_overunder__second_half_under_30',
    'pre_goals_overunder__second_half_over_325',
    'pre_goals_overunder__second_half_under_325',
    'pre_goals_overunder__second_half_over_35',
    'pre_goals_overunder__second_half_under_35',
    'pre_goals_overunder__second_half_over_375',
    'pre_goals_overunder__second_half_under_375',
    'end_goals_overunder__second_half_over_05',
    'end_goals_overunder__second_half_under_05',
    'end_goals_overunder__second_half_over_075',
    'end_goals_overunder__second_half_under_075',
    'end_goals_overunder__second_half_over_10',
    'end_goals_overunder__second_half_under_10',
    'end_goals_overunder__second_half_over_125',
    'end_goals_overunder__second_half_under_125',
    'end_goals_overunder__second_half_over_15',
    'end_goals_overunder__second_half_under_15',
    'end_goals_overunder__second_half_over_175',
    'end_goals_overunder__second_half_under_175',
    'end_goals_overunder__second_half_over_20',
    'end_goals_overunder__second_half_under_20',
    'end_goals_overunder__second_half_over_225',
    'end_goals_overunder__second_half_under_225',
    'end_goals_overunder__second_half_over_25',
    'end_goals_overunder__second_half_under_25',
    'end_goals_overunder__second_half_over_275',
    'end_goals_overunder__second_half_under_275',
    'end_goals_overunder__second_half_over_30',
    'end_goals_overunder__second_half_under_30',
    'end_goals_overunder__second_half_over_325',
    'end_goals_overunder__second_half_under_325',
    'end_goals_overunder__second_half_over_35',
    'end_goals_overunder__second_half_under_35',
    'end_goals_overunder__second_half_over_375',
    'end_goals_overunder__second_half_under_375',
    'pre_htft_double_home_home',
    'pre_htft_double_home_draw',
    'pre_htft_double_home_away',
    'pre_htft_double_draw_home',
    'pre_htft_double_draw_draw',
    'pre_htft_double_draw_away',
    'pre_htft_double_away_home',
    'pre_htft_double_away_draw',
    'pre_htft_double_away_away',
    'end_htft_double_home_home',
    'end_htft_double_home_draw',
    'end_htft_double_home_away',
    'end_htft_double_draw_home',
    'end_htft_double_draw_draw',
    'end_htft_double_draw_away',
    'end_htft_double_away_home',
    'end_htft_double_away_draw',
    'end_htft_double_away_away',
    'pre_both_teams_score_yes',
    'pre_both_teams_score_no',
    'end_both_teams_score_yes',
    'end_both_teams_score_no',
    'pre_both_teams_score__first_half_yes',
    'pre_both_teams_score__first_half_no',
    'end_both_teams_score__first_half_yes',
    'end_both_teams_score__first_half_no',
    'pre_both_teams_to_score__second_half_yes',
    'pre_both_teams_to_score__second_half_no',
    'end_both_teams_to_score__second_half_yes',
    'end_both_teams_to_score__second_half_no',
    'pre_results_both_teams_score_home_yes',
    'pre_results_both_teams_score_draw_yes',
    'pre_results_both_teams_score_away_yes',
    'pre_results_both_teams_score_home_no',
    'pre_results_both_teams_score_draw_no',
    'pre_results_both_teams_score_away_no',
    'end_results_both_teams_score_home_yes',
    'end_results_both_teams_score_draw_yes',
    'end_results_both_teams_score_away_yes',
    'end_results_both_teams_score_home_no',
    'end_results_both_teams_score_draw_no',
    'end_results_both_teams_score_away_no',
    'pre_to_score_in_both_halves_by_teams_home',
    'pre_to_score_in_both_halves_by_teams_away',
    'end_to_score_in_both_halves_by_teams_home',
    'end_to_score_in_both_halves_by_teams_away',
    'pre_total_goals_both_teams_to_score_over_yes_25',
    'pre_total_goals_both_teams_to_score_over_no_25',
    'pre_total_goals_both_teams_to_score_under_yes_25',
    'pre_total_goals_both_teams_to_score_under_no_25',
    'end_total_goals_both_teams_to_score_over_yes_25',
    'end_total_goals_both_teams_to_score_over_no_25',
    'end_total_goals_both_teams_to_score_under_yes_25',
    'end_total_goals_both_teams_to_score_under_no_25',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_no',
    'pre_both_teams_to_score_1st_half__2nd_half_no_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_no_no',
    'end_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'end_both_teams_to_score_1st_half__2nd_half_yes_no',
    'end_both_teams_to_score_1st_half__2nd_half_no_yes',
    'end_both_teams_to_score_1st_half__2nd_half_no_no',
    'pre_highest_scoring_half_first',
    'pre_highest_scoring_half_draw',
    'pre_highest_scoring_half_second',
    'end_highest_scoring_half_first',
    'end_highest_scoring_half_draw',
    'end_highest_scoring_half_second',
    'pre_double_chance_home_draw',
    'pre_double_chance_home_away',
    'pre_double_chance_draw_away',
    'end_double_chance_home_draw',
    'end_double_chance_home_away',
    'end_double_chance_draw_away',
    'pre_double_chance__first_half_home_draw',
    'pre_double_chance__first_half_home_away',
    'pre_double_chance__first_half_draw_away',
    'end_double_chance__first_half_home_draw',
    'end_double_chance__first_half_home_away',
    'end_double_chance__first_half_draw_away',
    'pre_oddeven_odd',
    'pre_oddeven_even',
    'end_oddeven_odd',
    'end_oddeven_even',
    'pre_result_total_goals_home_over_35',
    'pre_result_total_goals_draw_over_35',
    'pre_result_total_goals_away_over_35',
    'pre_result_total_goals_home_under_35',
    'pre_result_total_goals_draw_under_35',
    'pre_result_total_goals_away_under_35',
    'pre_result_total_goals_home_over_25',
    'pre_result_total_goals_draw_over_25',
    'pre_result_total_goals_away_over_25',
    'pre_result_total_goals_home_under_25',
    'pre_result_total_goals_draw_under_25',
    'pre_result_total_goals_away_under_25',
    'end_result_total_goals_home_over_35',
    'end_result_total_goals_draw_over_35',
    'end_result_total_goals_away_over_35',
    'end_result_total_goals_home_under_35',
    'end_result_total_goals_draw_under_35',
    'end_result_total_goals_away_under_35',
    'end_result_total_goals_home_over_25',
    'end_result_total_goals_draw_over_25',
    'end_result_total_goals_away_over_25',
    'end_result_total_goals_home_under_25',
    'end_result_total_goals_draw_under_25',
    'end_result_total_goals_away_under_25',
    'pre_clean_sheet__home_yes',
    'pre_clean_sheet__home_no',
    'end_clean_sheet__home_yes',
    'end_clean_sheet__home_no',
    'pre_clean_sheet__away_yes',
    'pre_clean_sheet__away_no',
    'end_clean_sheet__away_yes',
    'end_clean_sheet__away_no',
    'pre_win_both_halves_home',
    'pre_win_both_halves_away',
    'end_win_both_halves_home',
    'end_win_both_halves_away',
    'pre_win_to_nil_home',
    'pre_win_to_nil_away',
    'end_win_to_nil_home',
    'end_win_to_nil_away',
    'pre_to_win_either_half_home',
    'pre_to_win_either_half_away',
    'end_to_win_either_half_home',
    'end_to_win_either_half_away',
    'pre_halftime_result_both_teams_score_home_yes',
    'pre_halftime_result_both_teams_score_draw_yes',
    'pre_halftime_result_both_teams_score_away_yes',
    'pre_halftime_result_both_teams_score_home_no',
    'pre_halftime_result_both_teams_score_draw_no',
    'pre_halftime_result_both_teams_score_away_no',
    'end_halftime_result_both_teams_score_home_yes',
    'end_halftime_result_both_teams_score_draw_yes',
    'end_halftime_result_both_teams_score_away_yes',
    'end_halftime_result_both_teams_score_home_no',
    'end_halftime_result_both_teams_score_draw_no',
    'end_halftime_result_both_teams_score_away_no',
    'pre_exact_goals_number_0',
    'pre_exact_goals_number_1',
    'pre_exact_goals_number_2',
    'pre_exact_goals_number_3',
    'pre_exact_goals_number_4',
    'pre_exact_goals_number_5',
    'pre_exact_goals_number_6',
    'pre_exact_goals_number_more_7',
    'end_exact_goals_number_0',
    'end_exact_goals_number_1',
    'end_exact_goals_number_2',
    'end_exact_goals_number_3',
    'end_exact_goals_number_4',
    'end_exact_goals_number_5',
    'end_exact_goals_number_6',
    'end_exact_goals_number_more_7',
    'pre_exact_goals_number__first_half_0',
    'pre_exact_goals_number__first_half_1',
    'pre_exact_goals_number__first_half_2',
    'pre_exact_goals_number__first_half_3',
    'pre_exact_goals_number__first_half_4',
    'pre_exact_goals_number__first_half_more_5',
    'end_exact_goals_number__first_half_0',
    'end_exact_goals_number__first_half_1',
    'end_exact_goals_number__first_half_2',
    'end_exact_goals_number__first_half_3',
    'end_exact_goals_number__first_half_4',
    'end_exact_goals_number__first_half_more_5',
    'pre_second_half_exact_goals_number_0',
    'pre_second_half_exact_goals_number_1',
    'pre_second_half_exact_goals_number_2',
    'pre_second_half_exact_goals_number_3',
    'pre_second_half_exact_goals_number_4',
    'pre_second_half_exact_goals_number_more_5',
    'end_second_half_exact_goals_number_0',
    'end_second_half_exact_goals_number_1',
    'end_second_half_exact_goals_number_2',
    'end_second_half_exact_goals_number_3',
    'end_second_half_exact_goals_number_4',
    'end_second_half_exact_goals_number_more_5',
    'pre_home_team_exact_goals_number_0',
    'pre_home_team_exact_goals_number_1',
    'pre_home_team_exact_goals_number_2',
    'pre_home_team_exact_goals_number_more_3',
    'end_home_team_exact_goals_number_0',
    'end_home_team_exact_goals_number_1',
    'end_home_team_exact_goals_number_2',
    'end_home_team_exact_goals_number_more_3',
    'pre_away_team_exact_goals_number_0',
    'pre_away_team_exact_goals_number_1',
    'pre_away_team_exact_goals_number_2',
    'pre_away_team_exact_goals_number_more_3',
    'end_away_team_exact_goals_number_0',
    'end_away_team_exact_goals_number_1',
    'end_away_team_exact_goals_number_2',
    'end_away_team_exact_goals_number_more_3',
    'pre_corners_winner_home',
    'pre_corners_winner_draw',
    'pre_corners_winner_away',
    'end_corners_winner_home',
    'end_corners_winner_draw',
    'end_corners_winner_away',
    'pre_10_overunder_over_05',
    'pre_10_overunder_under_05',
    'end_10_overunder_over_05',
    'end_10_overunder_under_05',
    'pre_cards_european_handicap_home_min_2',
    'pre_cards_european_handicap_draw_min_2',
    'pre_cards_european_handicap_away_min_2',
    'pre_cards_european_handicap_home_min_1',
    'pre_cards_european_handicap_draw_min_1',
    'pre_cards_european_handicap_away_min_1',
    'pre_cards_european_handicap_home_plus_0',
    'pre_cards_european_handicap_draw_plus_0',
    'pre_cards_european_handicap_away_plus_0',
    'pre_cards_european_handicap_home_plus_1',
    'pre_cards_european_handicap_draw_plus_1',
    'pre_cards_european_handicap_away_plus_1',
    'pre_cards_european_handicap_home_plus_2',
    'pre_cards_european_handicap_draw_plus_2',
    'pre_cards_european_handicap_away_plus_2',
    'end_cards_european_handicap_home_min_2',
    'end_cards_european_handicap_draw_min_2',
    'end_cards_european_handicap_away_min_2',
    'end_cards_european_handicap_home_min_1',
    'end_cards_european_handicap_draw_min_1',
    'end_cards_european_handicap_away_min_1',
    'end_cards_european_handicap_home_plus_0',
    'end_cards_european_handicap_draw_plus_0',
    'end_cards_european_handicap_away_plus_0',
    'end_cards_european_handicap_home_plus_1',
    'end_cards_european_handicap_draw_plus_1',
    'end_cards_european_handicap_away_plus_1',
    'end_cards_european_handicap_home_plus_2',
    'end_cards_european_handicap_draw_plus_2',
    'end_cards_european_handicap_away_plus_2',
    'pre_rcard_yes',
    'pre_rcard_no',
    'end_rcard_yes',
    'end_rcard_no',

    ]
# -----------------------------------------------------------------
for c in col:  
    # -----------------------------------------------------------------
    host="localhost"
    user="root"
    database="pr_mmbuzz_2022_06" 
    mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
    # -----------------------------------------------------------------
    query = ' select '
    query += c 
    query += ' , CHAR_LENGTH(' + c + ') '  
    query += ' from football_fixtures '  
    query += ' where ' + c + ' is not null ' 
    query += ' order by CHAR_LENGTH(' + c + ') desc ' 
    query += ' limit 3 ' 
    # -----------------------------------------------------------------
    mycursor = mydb.cursor() 
    mycursor.execute(query)
    myresult = mycursor.fetchall()
    # -----------------------------------------------------------------
    print(c + " Total rows : " + str(len(myresult))) 
    # -----------------------------------------------------------------
    for x in myresult:  
        # -------------------------------------------------------------
        col_name = str(x[0])
        col_length = str(x[1])
        # -------------------------------------------------------------
        print("  " + col_name + " -- " + col_length ) 
        # ------------------------------------------------------------- 
    # ----------------------------------------------------------------- 
    print("")
    # -----------------------------------------------------------------
# Out:
# pre_first_half_winner_home Total rows : 3
#   2.25 -- 4
#   2.37 -- 4
#   1.66 -- 4
#
# pre_first_half_winner_draw Total rows : 3
#   2.05 -- 4
#   2.25 -- 4
#   2.05 -- 4
#
# pre_first_half_winner_away Total rows : 3
#   2.87 -- 4
#   2.87 -- 4
#   3.25 -- 4
#
# end_first_half_winner_home Total rows : 3
#   4.75 -- 4
#   2.87 -- 4
#   3.75 -- 4
#
# end_first_half_winner_draw Total rows : 3
#   2.37 -- 4
#   2.05 -- 4
#   3.25 -- 4
#
# end_first_half_winner_away Total rows : 3
#   2.87 -- 4
#   4.33 -- 4
#   2.75 -- 4
#
# pre_second_half_winner_home Total rows : 3
#   1.53 -- 4
#   2.75 -- 4
#   1.57 -- 4
#
# pre_second_half_winner_draw Total rows : 3
#   2.63 -- 4
#   2.75 -- 4
#   3.25 -- 4
#
# pre_second_half_winner_away Total rows : 3
#   2.87 -- 4
#   2.25 -- 4
#   2.38 -- 4
#
# end_second_half_winner_home Total rows : 3
#   3.75 -- 4
#   2.75 -- 4
#   2.88 -- 4
#
# end_second_half_winner_draw Total rows : 3
#   2.63 -- 4
#   2.75 -- 4
#   2.75 -- 4
#
# end_second_half_winner_away Total rows : 3
#   1.66 -- 4
#   1.95 -- 4
#   3.75 -- 4
#
# pre_asian_handicap_home_min_675 Total rows : 0
#
# pre_asian_handicap_away_min_675 Total rows : 0
#
# pre_asian_handicap_home_min_65 Total rows : 2
#   4.15 -- 4
#   4.0 -- 1
#
# pre_asian_handicap_away_min_65 Total rows : 2
#   1.22 -- 4
#   1.2 -- 3
#
# pre_asian_handicap_home_min_625 Total rows : 2
#   3.48 -- 4
#   3.9 -- 3
#
# pre_asian_handicap_away_min_625 Total rows : 2
#   1.26 -- 4
#   1.24 -- 4
#
# pre_asian_handicap_home_min_6 Total rows : 3
#   11.5 -- 4
#   11.5 -- 4
#   4.5 -- 3
#
# pre_asian_handicap_away_min_6 Total rows : 3
#   1.19 -- 4
#   1.01 -- 4
#   1.26 -- 4
#
# pre_asian_handicap_home_min_575 Total rows : 3
#   2.91 -- 4
#   3.01 -- 4
#   4.25 -- 4
#
# pre_asian_handicap_away_min_575 Total rows : 3
#   1.17 -- 4
#   1.33 -- 4
#   1.19 -- 4
#
# pre_asian_handicap_home_min_55 Total rows : 3
#   6.85 -- 4
#   2.57 -- 4
#   5.25 -- 4
#
# pre_asian_handicap_away_min_55 Total rows : 3
#   1.23 -- 4
#   1.02 -- 4
#   1.02 -- 4
#
# pre_asian_handicap_home_min_525 Total rows : 3
#   5.75 -- 4
#   2.41 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_away_min_525 Total rows : 3
#   1.25 -- 4
#   1.15 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_home_min_5 Total rows : 3
#   5.25 -- 4
#   5.25 -- 4
#   3.45 -- 4
#
# pre_asian_handicap_away_min_5 Total rows : 3
#   1.27 -- 4
#   1.16 -- 4
#   1.11 -- 4
#
# pre_asian_handicap_home_min_475 Total rows : 3
#   2.85 -- 4
#   3.45 -- 4
#   5.25 -- 4
#
# pre_asian_handicap_away_min_475 Total rows : 3
#   1.38 -- 4
#   1.13 -- 4
#   1.23 -- 4
#
# pre_asian_handicap_home_min_45 Total rows : 3
#   5.25 -- 4
#   5.75 -- 4
#   13.5 -- 4
#
# pre_asian_handicap_away_min_45 Total rows : 3
#   1.06 -- 4
#   1.16 -- 4
#   1.14 -- 4
#
# pre_asian_handicap_home_min_425 Total rows : 3
#   2.35 -- 4
#   5.25 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_away_min_425 Total rows : 3
#   1.58 -- 4
#   1.16 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_home_min_4 Total rows : 3
#   5.75 -- 4
#   4.65 -- 4
#   6.25 -- 4
#
# pre_asian_handicap_away_min_4 Total rows : 3
#   1.14 -- 4
#   1.18 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_home_min_375 Total rows : 3
#   4.15 -- 4
#   5.75 -- 4
#   3.55 -- 4
#
# pre_asian_handicap_away_min_375 Total rows : 3
#   1.22 -- 4
#   1.13 -- 4
#   1.27 -- 4
#
# pre_asian_handicap_home_min_35 Total rows : 3
#   3.45 -- 4
#   4.65 -- 4
#   2.85 -- 4
#
# pre_asian_handicap_away_min_35 Total rows : 3
#   1.14 -- 4
#   1.18 -- 4
#   1.38 -- 4
#
# pre_asian_handicap_home_min_325 Total rows : 3
#   4.15 -- 4
#   5.25 -- 4
#   4.25 -- 4
#
# pre_asian_handicap_away_min_325 Total rows : 3
#   1.35 -- 4
#   1.22 -- 4
#   1.21 -- 4
#
# pre_asian_handicap_home_min_3 Total rows : 3
#   2.85 -- 4
#   2.35 -- 4
#   2.42 -- 4
#
# pre_asian_handicap_away_min_3 Total rows : 3
#   1.52 -- 4
#   1.58 -- 4
#   1.23 -- 4
#
# pre_asian_handicap_home_min_275 Total rows : 3
#   2.38 -- 4
#   4.65 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_away_min_275 Total rows : 3
#   1.11 -- 4
#   1.55 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_home_min_25 Total rows : 3
#   2.67 -- 4
#   1.96 -- 4
#   4.25 -- 4
#
# pre_asian_handicap_away_min_25 Total rows : 3
#   1.13 -- 4
#   1.06 -- 4
#   1.13 -- 4
#
# pre_asian_handicap_home_min_225 Total rows : 3
#   5.75 -- 4
#   1.98 -- 4
#   3.45 -- 4
#
# pre_asian_handicap_away_min_225 Total rows : 3
#   1.15 -- 4
#   1.14 -- 4
#   1.92 -- 4
#
# pre_asian_handicap_home_min_2 Total rows : 3
#   5.25 -- 4
#   5.25 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_away_min_2 Total rows : 3
#   1.11 -- 4
#   1.16 -- 4
#   1.17 -- 4
#
# pre_asian_handicap_home_min_175 Total rows : 3
#   4.65 -- 4
#   5.75 -- 4
#   3.55 -- 4
#
# pre_asian_handicap_away_min_175 Total rows : 3
#   1.18 -- 4
#   1.14 -- 4
#   1.27 -- 4
#
# pre_asian_handicap_home_min_15 Total rows : 3
#   1.48 -- 4
#   4.15 -- 4
#   2.85 -- 4
#
# pre_asian_handicap_away_min_15 Total rows : 3
#   1.11 -- 4
#   1.26 -- 4
#   1.22 -- 4
#
# pre_asian_handicap_home_min_125 Total rows : 3
#   1.35 -- 4
#   2.42 -- 4
#   1.96 -- 4
#
# pre_asian_handicap_away_min_125 Total rows : 3
#   1.11 -- 4
#   1.32 -- 4
#   1.26 -- 4
#
# pre_asian_handicap_home_min_1 Total rows : 3
#   2.85 -- 4
#   3.45 -- 4
#   2.25 -- 4
#
# pre_asian_handicap_away_min_1 Total rows : 3
#   1.13 -- 4
#   1.15 -- 4
#   1.13 -- 4
#
# pre_asian_handicap_home_min_075 Total rows : 3
#   5.75 -- 4
#   1.97 -- 4
#   3.55 -- 4
#
# pre_asian_handicap_away_min_075 Total rows : 3
#   1.14 -- 4
#   1.24 -- 4
#   1.23 -- 4
#
# pre_asian_handicap_home_min_05 Total rows : 3
#   2.85 -- 4
#   1.17 -- 4
#   2.06 -- 4
#
# pre_asian_handicap_away_min_05 Total rows : 3
#   1.32 -- 4
#   1.35 -- 4
#   1.84 -- 4
#
# pre_asian_handicap_home_min_025 Total rows : 3
#   2.85 -- 4
#   2.67 -- 4
#   1.73 -- 4
#
# pre_asian_handicap_away_min_025 Total rows : 3
#   1.45 -- 4
#   2.08 -- 4
#   1.94 -- 4
#
# pre_asian_handicap_home_plus_0 Total rows : 3
#   2.08 -- 4
#   1.83 -- 4
#   1.48 -- 4
#
# pre_asian_handicap_away_plus_0 Total rows : 3
#   1.35 -- 4
#   3.45 -- 4
#   2.25 -- 4
#
# pre_asian_handicap_home_plus_025 Total rows : 3
#   2.05 -- 4
#   1.94 -- 4
#   1.35 -- 4
#
# pre_asian_handicap_away_plus_025 Total rows : 3
#   1.55 -- 4
#   1.96 -- 4
#   1.85 -- 4
#
# pre_asian_handicap_home_plus_05 Total rows : 3
#   2.05 -- 4
#   1.65 -- 4
#   1.75 -- 4
#
# pre_asian_handicap_away_plus_05 Total rows : 3
#   1.75 -- 4
#   2.38 -- 4
#   3.45 -- 4
#
# pre_asian_handicap_home_plus_075 Total rows : 3
#   1.55 -- 4
#   1.48 -- 4
#   1.19 -- 4
#
# pre_asian_handicap_away_plus_075 Total rows : 3
#   2.06 -- 4
#   3.45 -- 4
#   2.38 -- 4
#
# pre_asian_handicap_home_plus_1 Total rows : 3
#   1.55 -- 4
#   1.23 -- 4
#   1.35 -- 4
#
# pre_asian_handicap_away_plus_1 Total rows : 3
#   2.38 -- 4
#   3.45 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_home_plus_125 Total rows : 3
#   1.43 -- 4
#   1.24 -- 4
#   1.12 -- 4
#
# pre_asian_handicap_away_plus_125 Total rows : 3
#   2.75 -- 4
#   5.75 -- 4
#   3.45 -- 4
#
# pre_asian_handicap_home_plus_15 Total rows : 3
#   1.25 -- 4
#   1.21 -- 4
#   1.11 -- 4
#
# pre_asian_handicap_away_plus_15 Total rows : 3
#   6.25 -- 4
#   4.25 -- 4
#   5.25 -- 4
#
# pre_asian_handicap_home_plus_175 Total rows : 3
#   1.24 -- 4
#   1.13 -- 4
#   1.17 -- 4
#
# pre_asian_handicap_away_plus_175 Total rows : 3
#   2.02 -- 4
#   5.75 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_home_plus_2 Total rows : 3
#   1.14 -- 4
#   1.23 -- 4
#   1.63 -- 4
#
# pre_asian_handicap_away_plus_2 Total rows : 3
#   5.75 -- 4
#   2.25 -- 4
#   1.65 -- 4
#
# pre_asian_handicap_home_plus_225 Total rows : 3
#   1.12 -- 4
#   1.19 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_away_plus_225 Total rows : 3
#   6.25 -- 4
#   5.25 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_home_plus_25 Total rows : 3
#   1.11 -- 4
#   1.17 -- 4
#   1.43 -- 4
#
# pre_asian_handicap_away_plus_25 Total rows : 3
#   2.85 -- 4
#   5.75 -- 4
#   2.75 -- 4
#
# pre_asian_handicap_home_plus_275 Total rows : 3
#   1.11 -- 4
#   1.27 -- 4
#   1.55 -- 4
#
# pre_asian_handicap_away_plus_275 Total rows : 3
#   3.45 -- 4
#   2.38 -- 4
#   3.55 -- 4
#
# pre_asian_handicap_home_plus_3 Total rows : 3
#   1.14 -- 4
#   1.11 -- 4
#   1.18 -- 4
#
# pre_asian_handicap_away_plus_3 Total rows : 3
#   3.18 -- 4
#   2.85 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_home_plus_325 Total rows : 3
#   1.25 -- 4
#   1.32 -- 4
#   1.16 -- 4
#
# pre_asian_handicap_away_plus_325 Total rows : 3
#   4.65 -- 4
#   5.25 -- 4
#   6.25 -- 4
#
# pre_asian_handicap_home_plus_35 Total rows : 3
#   1.21 -- 4
#   1.27 -- 4
#   1.14 -- 4
#
# pre_asian_handicap_away_plus_35 Total rows : 3
#   5.25 -- 4
#   3.55 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_home_plus_375 Total rows : 3
#   1.11 -- 4
#   1.21 -- 4
#   1.14 -- 4
#
# pre_asian_handicap_away_plus_375 Total rows : 3
#   4.54 -- 4
#   4.25 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_home_plus_4 Total rows : 3
#   1.13 -- 4
#   1.11 -- 4
#   1.14 -- 4
#
# pre_asian_handicap_away_plus_4 Total rows : 3
#   6.25 -- 4
#   10.5 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_home_plus_425 Total rows : 3
#   1.13 -- 4
#   1.18 -- 4
#   1.11 -- 4
# pre_asian_handicap_away_plus_425 Total rows : 3
#   5.75 -- 4
#   15.5 -- 4
#   2.94 -- 4
#
# pre_asian_handicap_home_plus_45 Total rows : 3
#   1.06 -- 4
#   1.04 -- 4
#   1.16 -- 4
#
# pre_asian_handicap_away_plus_45 Total rows : 3
#   5.25 -- 4
#   5.25 -- 4
#   11.5 -- 4
#
# pre_asian_handicap_home_plus_475 Total rows : 3
#   1.16 -- 4
#   1.21 -- 4
#   1.13 -- 4
#
# pre_asian_handicap_away_plus_475 Total rows : 3
#   1.82 -- 4
#   3.88 -- 4
#   2.35 -- 4
#
# pre_asian_handicap_home_plus_5 Total rows : 3
#   1.03 -- 4
#   1.38 -- 4
#   1.16 -- 4
#
# pre_asian_handicap_away_plus_5 Total rows : 3
#   1.93 -- 4
#   2.71 -- 4
#   4.34 -- 4
#
# pre_asian_handicap_home_plus_525 Total rows : 3
#   1.14 -- 4
#   1.14 -- 4
#   1.34 -- 4
#
# pre_asian_handicap_away_plus_525 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   2.94 -- 4
#
# pre_asian_handicap_home_plus_55 Total rows : 3
#   1.06 -- 4
#   1.02 -- 4
#   1.05 -- 4
#
# pre_asian_handicap_away_plus_55 Total rows : 3
#   3.18 -- 4
#   2.24 -- 4
#   2.03 -- 4
#
# pre_asian_handicap_home_plus_575 Total rows : 3
#   1.23 -- 4
#   1.57 -- 4
#   1.55 -- 4
#
# pre_asian_handicap_away_plus_575 Total rows : 3
#   2.52 -- 4
#   2.22 -- 4
#   2.38 -- 4
#
# pre_asian_handicap_home_plus_6 Total rows : 2
#   1.16 -- 4
#   1.23 -- 4
#
# pre_asian_handicap_away_plus_6 Total rows : 2
#   5.25 -- 4
#   3.68 -- 4
#
# pre_asian_handicap_home_plus_625 Total rows : 0
#
# pre_asian_handicap_away_plus_625 Total rows : 0
#
# pre_asian_handicap_home_plus_65 Total rows : 1
#   1.18 -- 4
#
# pre_asian_handicap_away_plus_65 Total rows : 1
#   4.3 -- 3
#
# pre_asian_handicap_home_plus_675 Total rows : 0
#
# pre_asian_handicap_away_plus_675 Total rows : 0
#
# end_asian_handicap_home_min_675 Total rows : 3
#   2.66 -- 4
#   4.4 -- 3
#   2.6 -- 3
#
# end_asian_handicap_away_min_675 Total rows : 3
#   1.41 -- 4
#   1.48 -- 4
#   1.2 -- 3
#
# end_asian_handicap_home_min_65 Total rows : 3
#   2.38 -- 4
#   2.35 -- 4
#   3.7 -- 3
#
# end_asian_handicap_away_min_65 Total rows : 3
#   1.26 -- 4
#   1.49 -- 4
#   1.58 -- 4
#
# end_asian_handicap_home_min_625 Total rows : 3
#   3.48 -- 4
#   3.55 -- 4
#   2.22 -- 4
#
# end_asian_handicap_away_min_625 Total rows : 3
#   1.26 -- 4
#   1.28 -- 4
#   1.57 -- 4
#
# end_asian_handicap_home_min_6 Total rows : 3
#   2.06 -- 4
#   11.5 -- 4
#   3.5 -- 3
#
# end_asian_handicap_away_min_6 Total rows : 3
#   1.15 -- 4
#   1.01 -- 4
#   1.26 -- 4
#
# end_asian_handicap_home_min_575 Total rows : 3
#   2.46 -- 4
#   3.46 -- 4
#   2.55 -- 4
#
# end_asian_handicap_away_min_575 Total rows : 3
#   1.15 -- 4
#   1.18 -- 4
#   1.44 -- 4
#
# end_asian_handicap_home_min_55 Total rows : 3
#   2.28 -- 4
#   4.24 -- 4
#   6.75 -- 4
#
# end_asian_handicap_away_min_55 Total rows : 3
#   1.05 -- 4
#   1.02 -- 4
#   1.04 -- 4
#
# end_asian_handicap_home_min_525 Total rows : 3
#   5.25 -- 4
#   4.25 -- 4
#   3.45 -- 4
#
# end_asian_handicap_away_min_525 Total rows : 3
#   1.16 -- 4
#   1.21 -- 4
#   1.22 -- 4
#
# end_asian_handicap_home_min_5 Total rows : 3
#   4.65 -- 4
#   3.74 -- 4
#   3.45 -- 4
#
# end_asian_handicap_away_min_5 Total rows : 3
#   1.13 -- 4
#   1.13 -- 4
#   1.24 -- 4
#
# end_asian_handicap_home_min_475 Total rows : 3
#   2.67 -- 4
#   2.85 -- 4
#   6.25 -- 4
#
# end_asian_handicap_away_min_475 Total rows : 3
#   1.26 -- 4
#   1.13 -- 4
#   1.12 -- 4
#
# end_asian_handicap_home_min_45 Total rows : 3
#   6.25 -- 4
#   6.25 -- 4
#   5.75 -- 4
#
# end_asian_handicap_away_min_45 Total rows : 3
#   1.02 -- 4
#   1.15 -- 4
#   1.12 -- 4
#
# end_asian_handicap_home_min_425 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   5.25 -- 4
#
# end_asian_handicap_away_min_425 Total rows : 3
#   1.13 -- 4
#   1.12 -- 4
#   1.16 -- 4
#
# end_asian_handicap_home_min_4 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   4.65 -- 4
#
# end_asian_handicap_away_min_4 Total rows : 3
#   1.14 -- 4
#   1.03 -- 4
#   1.13 -- 4
#
# end_asian_handicap_home_min_375 Total rows : 3
#   4.25 -- 4
#   4.25 -- 4
#   3.55 -- 4
#
# end_asian_handicap_away_min_375 Total rows : 3
#   1.17 -- 4
#   1.21 -- 4
#   1.27 -- 4
#
# end_asian_handicap_home_min_35 Total rows : 3
#   3.45 -- 4
#   6.45 -- 4
#   3.45 -- 4
#
# end_asian_handicap_away_min_35 Total rows : 3
#   1.13 -- 4
#   1.23 -- 4
#   1.06 -- 4
#
# end_asian_handicap_home_min_325 Total rows : 3
#   6.25 -- 4
#   2.75 -- 4
#   3.45 -- 4
#
# end_asian_handicap_away_min_325 Total rows : 3
#   1.32 -- 4
#   1.11 -- 4
#   1.08 -- 4
#
# end_asian_handicap_home_min_3 Total rows : 3
#   2.85 -- 4
#   2.85 -- 4
#   5.75 -- 4
#
# end_asian_handicap_away_min_3 Total rows : 3
#   1.52 -- 4
#   1.13 -- 4
#   1.09 -- 4
#
# end_asian_handicap_home_min_275 Total rows : 3
#   2.67 -- 4
#   2.38 -- 4
#   4.25 -- 4
#
# end_asian_handicap_away_min_275 Total rows : 3
#   1.18 -- 4
#   1.55 -- 4
#   1.21 -- 4
#
# end_asian_handicap_home_min_25 Total rows : 3
#   6.25 -- 4
#   2.15 -- 4
#   3.34 -- 4
#
# end_asian_handicap_away_min_25 Total rows : 3
#   1.12 -- 4
#   1.68 -- 4
#   1.11 -- 4
#
# end_asian_handicap_home_min_225 Total rows : 3
#   4.25 -- 4
#   1.93 -- 4
#   5.75 -- 4
#
# end_asian_handicap_away_min_225 Total rows : 3
#   1.13 -- 4
#   1.11 -- 4
#   1.32 -- 4
#
# end_asian_handicap_home_min_2 Total rows : 3
#   1.96 -- 4
#   6.25 -- 4
#   2.75 -- 4
#
# end_asian_handicap_away_min_2 Total rows : 3
#   1.15 -- 4
#   1.12 -- 4
#   1.39 -- 4
#
# end_asian_handicap_home_min_175 Total rows : 3
#   5.75 -- 4
#   5.25 -- 4
#   4.15 -- 4
#
# end_asian_handicap_away_min_175 Total rows : 3
#   1.11 -- 4
#   1.16 -- 4
#   1.11 -- 4
#
# end_asian_handicap_home_min_15 Total rows : 3
#   6.25 -- 4
#   4.15 -- 4
#   5.25 -- 4
#
# end_asian_handicap_away_min_15 Total rows : 3
#   1.16 -- 4
#   1.22 -- 4
#   1.24 -- 4
#
# end_asian_handicap_home_min_125 Total rows : 3
#   5.75 -- 4
#   5.25 -- 4
#   3.45 -- 4
#
# end_asian_handicap_away_min_125 Total rows : 3
#   1.38 -- 4
#   1.26 -- 4
#   1.18 -- 4
#
# end_asian_handicap_home_min_1 Total rows : 3
#   5.25 -- 4
#   4.65 -- 4
#   1.23 -- 4
#
# end_asian_handicap_away_min_1 Total rows : 3
#   1.32 -- 4
#   1.35 -- 4
#   1.24 -- 4
#
# end_asian_handicap_home_min_075 Total rows : 3
#   4.25 -- 4
#   2.42 -- 4
#   2.38 -- 4
#
# end_asian_handicap_away_min_075 Total rows : 3
#   1.33 -- 4
#   1.21 -- 4
#   1.52 -- 4
#
# end_asian_handicap_home_min_05 Total rows : 3
#   4.15 -- 4
#   2.38 -- 4
#   2.75 -- 4
#
# end_asian_handicap_away_min_05 Total rows : 3
#   1.22 -- 4
#   1.32 -- 4
#   1.43 -- 4
#
# end_asian_handicap_home_min_025 Total rows : 3
#   2.38 -- 4
#   2.85 -- 4
#   1.87 -- 4
#
# end_asian_handicap_away_min_025 Total rows : 3
#   1.26 -- 4
#   1.55 -- 4
#   2.03 -- 4
#
# end_asian_handicap_home_plus_0 Total rows : 3
#   1.84 -- 4
#   2.42 -- 4
#   1.52 -- 4
#
# end_asian_handicap_away_plus_0 Total rows : 3
#   1.32 -- 4
#   1.52 -- 4
#   2.42 -- 4
#
# end_asian_handicap_home_plus_025 Total rows : 3
#   2.42 -- 4
#   2.04 -- 4
#   1.38 -- 4
#
# end_asian_handicap_away_plus_025 Total rows : 3
#   1.52 -- 4
#   1.86 -- 4
#   2.85 -- 4
#
# end_asian_handicap_home_plus_05 Total rows : 3
#   2.05 -- 4
#   1.73 -- 4
#   1.45 -- 4
#
# end_asian_handicap_away_plus_05 Total rows : 3
#   2.25 -- 4
#   2.08 -- 4
#   3.45 -- 4
#
# end_asian_handicap_home_plus_075 Total rows : 3
#   1.87 -- 4
#   1.52 -- 4
#   1.21 -- 4
#
# end_asian_handicap_away_plus_075 Total rows : 3
#   2.03 -- 4
#   2.42 -- 4
#   4.25 -- 4
#
# end_asian_handicap_home_plus_1 Total rows : 3
#   1.58 -- 4
#   1.32 -- 4
#   1.18 -- 4
#
# end_asian_handicap_away_plus_1 Total rows : 3
#   2.35 -- 4
#   6.25 -- 4
#   4.65 -- 4
#
# end_asian_handicap_home_plus_125 Total rows : 3
#   1.45 -- 4
#   1.27 -- 4
#   1.16 -- 4
#
# end_asian_handicap_away_plus_125 Total rows : 3
#   2.67 -- 4
#   3.55 -- 4
#   5.25 -- 4
#
# end_asian_handicap_home_plus_15 Total rows : 3
#   1.38 -- 4
#   1.23 -- 4
#   1.24 -- 4
#
# end_asian_handicap_away_plus_15 Total rows : 3
#   2.42 -- 4
#   4.65 -- 4
#   5.75 -- 4
#
# end_asian_handicap_home_plus_175 Total rows : 3
#   1.25 -- 4
#   1.15 -- 4
#   1.16 -- 4
#
# end_asian_handicap_away_plus_175 Total rows : 3
#   5.25 -- 4
#   6.25 -- 4
#   5.75 -- 4
#
# end_asian_handicap_home_plus_2 Total rows : 3
#   1.15 -- 4
#   1.24 -- 4
#   1.89 -- 4
#
# end_asian_handicap_away_plus_2 Total rows : 3
#   4.65 -- 4
#   2.25 -- 4
#   2.04 -- 4
#
# end_asian_handicap_home_plus_225 Total rows : 3
#   1.13 -- 4
#   1.12 -- 4
#   1.55 -- 4
#
# end_asian_handicap_away_plus_225 Total rows : 3
#   5.25 -- 4
#   3.55 -- 4
#   2.38 -- 4
#
# end_asian_handicap_home_plus_25 Total rows : 3
#   1.11 -- 4
#   1.18 -- 4
#   1.48 -- 4
#
# end_asian_handicap_away_plus_25 Total rows : 3
#   5.75 -- 4
#   4.65 -- 4
#   2.42 -- 4
#
# end_asian_handicap_home_plus_275 Total rows : 3
#   1.12 -- 4
#   1.35 -- 4
#   1.11 -- 4
#
# end_asian_handicap_away_plus_275 Total rows : 3
#   6.25 -- 4
#   2.85 -- 4
#   3.45 -- 4
#
# end_asian_handicap_home_plus_3 Total rows : 3
#   1.23 -- 4
#   1.26 -- 4
#   1.13 -- 4
#
# end_asian_handicap_away_plus_3 Total rows : 3
#   10.5 -- 4
#   12.5 -- 4
#   4.44 -- 4
# end_asian_handicap_home_plus_325 Total rows : 3
#   1.14 -- 4
#   1.23 -- 4
#   1.18 -- 4
#
# end_asian_handicap_away_plus_325 Total rows : 3
#   3.45 -- 4
#   4.78 -- 4
#   4.65 -- 4
#
# end_asian_handicap_home_plus_35 Total rows : 3
#   1.18 -- 4
#   1.12 -- 4
#   1.16 -- 4
#
# end_asian_handicap_away_plus_35 Total rows : 3
#   4.65 -- 4
#   4.65 -- 4
#   5.25 -- 4
#
# end_asian_handicap_home_plus_375 Total rows : 3
#   1.11 -- 4
#   1.14 -- 4
#   1.11 -- 4
#
# end_asian_handicap_away_plus_375 Total rows : 3
#   6.25 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# end_asian_handicap_home_plus_4 Total rows : 3
#   1.11 -- 4
#   1.03 -- 4
#   1.13 -- 4
#
# end_asian_handicap_away_plus_4 Total rows : 3
#   4.15 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# end_asian_handicap_home_plus_425 Total rows : 3
#   1.28 -- 4
#   1.13 -- 4
#   1.14 -- 4
#
# end_asian_handicap_away_plus_425 Total rows : 3
#   3.28 -- 4
#   2.94 -- 4
#   5.75 -- 4
#
# end_asian_handicap_home_plus_45 Total rows : 3
#   1.06 -- 4
#   1.13 -- 4
#   1.04 -- 4
#
# end_asian_handicap_away_plus_45 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   4.65 -- 4
#
# end_asian_handicap_home_plus_475 Total rows : 3
#   1.13 -- 4
#   1.13 -- 4
#   1.17 -- 4
#
# end_asian_handicap_away_plus_475 Total rows : 3
#   5.75 -- 4
#   3.88 -- 4
#   3.11 -- 4
#
# end_asian_handicap_home_plus_5 Total rows : 3
#   1.09 -- 4
#   1.15 -- 4
#   1.16 -- 4
#
# end_asian_handicap_away_plus_5 Total rows : 3
#   4.98 -- 4
#   4.54 -- 4
#   4.44 -- 4
#
# end_asian_handicap_home_plus_525 Total rows : 3
#   1.19 -- 4
#   1.16 -- 4
#   1.57 -- 4
#
# end_asian_handicap_away_plus_525 Total rows : 3
#   4.02 -- 4
#   4.06 -- 4
#   2.31 -- 4
#
# end_asian_handicap_home_plus_55 Total rows : 3
#   1.08 -- 4
#   1.05 -- 4
#   1.18 -- 4
#
# end_asian_handicap_away_plus_55 Total rows : 3
#   2.47 -- 4
#   10.5 -- 4
#   6.15 -- 4
#
# end_asian_handicap_home_plus_575 Total rows : 3
#   1.25 -- 4
#   1.54 -- 4
#   1.28 -- 4
#
# end_asian_handicap_away_plus_575 Total rows : 3
#   3.58 -- 4
#   2.34 -- 4
#   3.46 -- 4
#
# end_asian_handicap_home_plus_6 Total rows : 3
#   1.16 -- 4
#   1.31 -- 4
#   2.0 -- 1
#
# end_asian_handicap_away_plus_6 Total rows : 3
#   5.25 -- 4
#   3.04 -- 4
#   1.85 -- 4
#
# end_asian_handicap_home_plus_625 Total rows : 0
#
# end_asian_handicap_away_plus_625 Total rows : 0
#
# end_asian_handicap_home_plus_65 Total rows : 1
#   1.18 -- 4
#
# end_asian_handicap_away_plus_65 Total rows : 1
#   4.2 -- 3
#
# end_asian_handicap_home_plus_675 Total rows : 0
#
# end_asian_handicap_away_plus_675 Total rows : 0
#
# pre_goals_overunder_over_05 Total rows : 3
#   1.05 -- 4
#   1.07 -- 4
#   1.06 -- 4
#
# pre_goals_overunder_under_05 Total rows : 3
#   6.95 -- 4
#   6.45 -- 4
#   6.65 -- 4
#
# pre_goals_overunder_over_075 Total rows : 3
#   1.12 -- 4
#   1.11 -- 4
#   1.16 -- 4
#
# pre_goals_overunder_under_075 Total rows : 3
#   6.25 -- 4
#   6.25 -- 4
#   5.25 -- 4
#
# pre_goals_overunder_over_10 Total rows : 3
#   1.11 -- 4
#   1.11 -- 4
#   1.11 -- 4
#
# pre_goals_overunder_under_10 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   6.25 -- 4
#
# pre_goals_overunder_over_125 Total rows : 3
#   1.16 -- 4
#   1.21 -- 4
#   1.18 -- 4
#
# pre_goals_overunder_under_125 Total rows : 3
#   5.25 -- 4
#   4.25 -- 4
#   4.65 -- 4
#
# pre_goals_overunder_over_15 Total rows : 3
#   1.33 -- 4
#   1.36 -- 4
#   1.29 -- 4
#
# pre_goals_overunder_under_15 Total rows : 3
#   3.75 -- 4
#   2.75 -- 4
#   3.75 -- 4
#
# pre_goals_overunder_over_175 Total rows : 3
#   1.37 -- 4
#   1.32 -- 4
#   1.35 -- 4
#
# pre_goals_overunder_under_175 Total rows : 3
#   2.37 -- 4
#   2.85 -- 4
#   2.67 -- 4
#
# pre_goals_overunder_over_20 Total rows : 3
#   1.45 -- 4
#   1.42 -- 4
#   1.42 -- 4
#
# pre_goals_overunder_under_20 Total rows : 3
#   2.85 -- 4
#   2.67 -- 4
#   2.75 -- 4
#
# pre_goals_overunder_over_225 Total rows : 3
#   1.63 -- 4
#   1.84 -- 4
#   1.67 -- 4
#
# pre_goals_overunder_under_225 Total rows : 3
#   2.07 -- 4
#   2.06 -- 4
#   2.15 -- 4
#
# pre_goals_overunder_over_25 Total rows : 3
#   1.72 -- 4
#   2.37 -- 4
#   1.61 -- 4
#
# pre_goals_overunder_under_25 Total rows : 3
#   1.61 -- 4
#   1.61 -- 4
#   1.73 -- 4
#
# pre_goals_overunder_over_275 Total rows : 3
#   2.25 -- 4
#   2.35 -- 4
#   2.15 -- 4
#
# pre_goals_overunder_under_275 Total rows : 3
#   1.62 -- 4
#   1.57 -- 4
#   1.67 -- 4
#
# pre_goals_overunder_over_30 Total rows : 3
#   2.67 -- 4
#   3.45 -- 4
#   2.42 -- 4
#
# pre_goals_overunder_under_30 Total rows : 3
#   1.45 -- 4
#   1.47 -- 4
#   1.52 -- 4
#
# pre_goals_overunder_over_325 Total rows : 3
#   2.75 -- 4
#   1.57 -- 4
#   2.85 -- 4
#
# pre_goals_overunder_under_325 Total rows : 3
#   1.43 -- 4
#   1.32 -- 4
#   1.37 -- 4
#
# pre_goals_overunder_over_35 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_goals_overunder_under_35 Total rows : 3
#   1.25 -- 4
#   1.28 -- 4
#   1.33 -- 4
#
# pre_goals_overunder_over_375 Total rows : 3
#   4.15 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# pre_goals_overunder_under_375 Total rows : 3
#   1.22 -- 4
#   1.26 -- 4
#   1.23 -- 4
#
# pre_goals_overunder_over_40 Total rows : 3
#   4.15 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# pre_goals_overunder_under_40 Total rows : 3
#   1.16 -- 4
#   1.14 -- 4
#   1.16 -- 4
#
# pre_goals_overunder_over_425 Total rows : 3
#   5.75 -- 4
#   4.65 -- 4
#   2.42 -- 4
#
# pre_goals_overunder_under_425 Total rows : 3
#   1.11 -- 4
#   1.14 -- 4
#   1.12 -- 4
#
# pre_goals_overunder_over_45 Total rows : 3
#   2.62 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_goals_overunder_under_45 Total rows : 3
#   1.12 -- 4
#   1.06 -- 4
#   1.11 -- 4
#
# pre_goals_overunder_over_475 Total rows : 3
#   3.55 -- 4
#   5.75 -- 4
#   5.75 -- 4
#
# pre_goals_overunder_under_475 Total rows : 3
#   1.35 -- 4
#   1.11 -- 4
#   1.14 -- 4
#
# pre_goals_overunder_over_50 Total rows : 3
#   6.25 -- 4
#   6.25 -- 4
#   4.65 -- 4
#
# pre_goals_overunder_under_50 Total rows : 3
#   1.11 -- 4
#   1.19 -- 4
#   1.18 -- 4
#
# pre_goals_overunder_over_525 Total rows : 3
#   4.15 -- 4
#   4.65 -- 4
#   6.25 -- 4
#
# pre_goals_overunder_under_525 Total rows : 3
#   1.17 -- 4
#   1.17 -- 4
#   1.12 -- 4
#
# pre_goals_overunder_over_55 Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   12.5 -- 4
#
# pre_goals_overunder_under_55 Total rows : 3
#   1.04 -- 4
#   1.02 -- 4
#   1.04 -- 4
#
# pre_goals_overunder_over_575 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   4.78 -- 4
#
# pre_goals_overunder_under_575 Total rows : 3
#   1.14 -- 4
#   1.11 -- 4
#   1.13 -- 4
#
# pre_goals_overunder_over_60 Total rows : 3
#   6.25 -- 4
#   5.75 -- 4
#   6.25 -- 4
#
# pre_goals_overunder_under_60 Total rows : 3
#   1.11 -- 4
#   1.07 -- 4
#   1.24 -- 4
#
# pre_goals_overunder_over_625 Total rows : 3
#   6.55 -- 4
#   6.25 -- 4
#   4.15 -- 4
#
# pre_goals_overunder_under_625 Total rows : 3
#   1.11 -- 4
#   1.13 -- 4
#   1.22 -- 4
#
# pre_goals_overunder_over_65 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   10.5 -- 4
#
# pre_goals_overunder_under_65 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# pre_goals_overunder_over_675 Total rows : 3
#   2.59 -- 4
#   2.52 -- 4
#   2.66 -- 4
#
# pre_goals_overunder_under_675 Total rows : 3
#   1.13 -- 4
#   1.11 -- 4
#   1.17 -- 4
#
# pre_goals_overunder_over_70 Total rows : 3
#   2.98 -- 4
#   6.25 -- 4
#   6.85 -- 4
#
# pre_goals_overunder_under_70 Total rows : 3
#   1.11 -- 4
#   1.12 -- 4
#   1.06 -- 4
#
# pre_goals_overunder_over_75 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   10.5 -- 4
#
# pre_goals_overunder_under_75 Total rows : 3
#   1.03 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# pre_goals_overunder_over_85 Total rows : 3
#   4.22 -- 4
#   10.5 -- 4
#   4.24 -- 4
#
# pre_goals_overunder_under_85 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# pre_goals_overunder_over_95 Total rows : 3
#   10.5 -- 4
#   41.0 -- 2
#   41.0 -- 2
#
# pre_goals_overunder_under_95 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.02 -- 4
#
# end_goals_overunder_over_05 Total rows : 3
#   1.07 -- 4
#   1.07 -- 4
#   1.07 -- 4
#
# end_goals_overunder_under_05 Total rows : 3
#   11.25 -- 5
#   14.75 -- 5
#   11.75 -- 5
#
# end_goals_overunder_over_075 Total rows : 3
#   1.11 -- 4
#   1.12 -- 4
#   1.01 -- 4
#
# end_goals_overunder_under_075 Total rows : 3
#   6.25 -- 4
#   5.75 -- 4
#   6.25 -- 4
#
# end_goals_overunder_over_10 Total rows : 3
#   1.15 -- 4
#   1.12 -- 4
#   1.12 -- 4
#
# end_goals_overunder_under_10 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   6.25 -- 4
#
# end_goals_overunder_over_125 Total rows : 3
#   1.12 -- 4
#   1.22 -- 4
#   1.23 -- 4
#
# end_goals_overunder_under_125 Total rows : 3
#   4.65 -- 4
#   4.15 -- 4
#   5.05 -- 4
#
# end_goals_overunder_over_15 Total rows : 3
#   1.14 -- 4
#   1.36 -- 4
#   1.36 -- 4
#
# end_goals_overunder_under_15 Total rows : 3
#   3.75 -- 4
#   2.75 -- 4
#   2.75 -- 4
#
# end_goals_overunder_over_175 Total rows : 3
#   1.28 -- 4
#   1.42 -- 4
#   1.45 -- 4
#
# end_goals_overunder_under_175 Total rows : 3
#   3.28 -- 4
#   2.75 -- 4
#   2.67 -- 4
#
# end_goals_overunder_over_20 Total rows : 3
#   1.45 -- 4
#   1.57 -- 4
#   1.32 -- 4
# end_goals_overunder_under_20 Total rows : 3
#   2.67 -- 4
#   2.35 -- 4
#   2.93 -- 4
#
# end_goals_overunder_over_225 Total rows : 3
#   1.54 -- 4
#   1.89 -- 4
#   1.95 -- 4
#
# end_goals_overunder_under_225 Total rows : 3
#   2.28 -- 4
#   2.01 -- 4
#   1.95 -- 4
#
# end_goals_overunder_over_25 Total rows : 3
#   2.37 -- 4
#   2.37 -- 4
#   1.72 -- 4
#
# end_goals_overunder_under_25 Total rows : 3
#   1.72 -- 4
#   1.66 -- 4
#   1.72 -- 4
#
# end_goals_overunder_over_275 Total rows : 3
#   2.15 -- 4
#   2.37 -- 4
#   1.96 -- 4
#
# end_goals_overunder_under_275 Total rows : 3
#   1.67 -- 4
#   1.55 -- 4
#   1.79 -- 4
#
# end_goals_overunder_over_30 Total rows : 3
#   3.55 -- 4
#   2.75 -- 4
#   2.16 -- 4
#
# end_goals_overunder_under_30 Total rows : 3
#   1.47 -- 4
#   1.37 -- 4
#   1.35 -- 4
#
# end_goals_overunder_over_325 Total rows : 3
#   2.85 -- 4
#   3.45 -- 4
#   3.55 -- 4
#
# end_goals_overunder_under_325 Total rows : 3
#   1.37 -- 4
#   1.44 -- 4
#   1.27 -- 4
#
# end_goals_overunder_over_35 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# end_goals_overunder_under_35 Total rows : 3
#   1.62 -- 4
#   1.28 -- 4
#   1.25 -- 4
#
# end_goals_overunder_over_375 Total rows : 3
#   3.34 -- 4
#   4.65 -- 4
#   4.25 -- 4
#
# end_goals_overunder_under_375 Total rows : 3
#   1.27 -- 4
#   1.18 -- 4
#   1.17 -- 4
#
# end_goals_overunder_over_40 Total rows : 3
#   5.75 -- 4
#   3.55 -- 4
#   4.15 -- 4
#
# end_goals_overunder_under_40 Total rows : 3
#   1.14 -- 4
#   1.15 -- 4
#   1.15 -- 4
#
# end_goals_overunder_over_425 Total rows : 3
#   5.75 -- 4
#   4.82 -- 4
#   5.25 -- 4
#
# end_goals_overunder_under_425 Total rows : 3
#   1.12 -- 4
#   1.14 -- 4
#   1.14 -- 4
#
# end_goals_overunder_over_45 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   2.75 -- 4
#
# end_goals_overunder_under_45 Total rows : 3
#   1.12 -- 4
#   1.11 -- 4
#   1.08 -- 4
#
# end_goals_overunder_over_475 Total rows : 3
#   4.15 -- 4
#   6.25 -- 4
#   6.15 -- 4
#
# end_goals_overunder_under_475 Total rows : 3
#   1.35 -- 4
#   1.12 -- 4
#   1.15 -- 4
#
# end_goals_overunder_over_50 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   5.75 -- 4
#
# end_goals_overunder_under_50 Total rows : 3
#   1.24 -- 4
#   1.02 -- 4
#   1.14 -- 4
#
# end_goals_overunder_over_525 Total rows : 3
#   4.25 -- 4
#   4.65 -- 4
#   4.65 -- 4
#
# end_goals_overunder_under_525 Total rows : 3
#   1.04 -- 4
#   1.18 -- 4
#   1.12 -- 4
#
# end_goals_overunder_over_55 Total rows : 3
#   10.75 -- 5
#   11.5 -- 4
#   4.33 -- 4
#
# end_goals_overunder_under_55 Total rows : 3
#   1.02 -- 4
#   1.02 -- 4
#   1.03 -- 4
#
# end_goals_overunder_over_575 Total rows : 3
#   5.75 -- 4
#   4.78 -- 4
#   5.25 -- 4
#
# end_goals_overunder_under_575 Total rows : 3
#   1.14 -- 4
#   1.11 -- 4
#   1.13 -- 4
#
# end_goals_overunder_over_60 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   6.25 -- 4
#
# end_goals_overunder_under_60 Total rows : 3
#   1.05 -- 4
#   1.11 -- 4
#   1.12 -- 4
#
# end_goals_overunder_over_625 Total rows : 3
#   6.75 -- 4
#   5.25 -- 4
#   6.45 -- 4
#
# end_goals_overunder_under_625 Total rows : 3
#   1.06 -- 4
#   1.15 -- 4
#   1.11 -- 4
#
# end_goals_overunder_over_65 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   4.33 -- 4
#
# end_goals_overunder_under_65 Total rows : 3
#   1.03 -- 4
#   1.01 -- 4
#   1.03 -- 4
#
# end_goals_overunder_over_675 Total rows : 3
#   2.33 -- 4
#   5.25 -- 4
#   3.15 -- 4
#
# end_goals_overunder_under_675 Total rows : 3
#   1.15 -- 4
#   1.17 -- 4
#   1.16 -- 4
#
# end_goals_overunder_over_70 Total rows : 3
#   6.45 -- 4
#   4.44 -- 4
#   6.25 -- 4
#
# end_goals_overunder_under_70 Total rows : 3
#   1.06 -- 4
#   1.04 -- 4
#   1.03 -- 4
#
# end_goals_overunder_over_75 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   10.5 -- 4
#
# end_goals_overunder_under_75 Total rows : 3
#   1.01 -- 4
#   1.03 -- 4
#   1.01 -- 4
#
# end_goals_overunder_over_85 Total rows : 3
#   3.54 -- 4
#   2.34 -- 4
#   2.07 -- 4
#
# end_goals_overunder_under_85 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# end_goals_overunder_over_95 Total rows : 3
#   2.71 -- 4
#   3.8 -- 3
#   51.0 -- 2
#
# end_goals_overunder_under_95 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# pre_asian_handicap_first_half_home_min_175 Total rows : 3
#   5.25 -- 4
#   5.75 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_first_half_away_min_175 Total rows : 3
#   1.15 -- 4
#   1.16 -- 4
#   1.17 -- 4
#
# pre_asian_handicap_first_half_home_min_15 Total rows : 3
#   6.25 -- 4
#   6.25 -- 4
#   6.25 -- 4
#
# pre_asian_handicap_first_half_away_min_15 Total rows : 3
#   1.06 -- 4
#   1.12 -- 4
#   1.25 -- 4
#
# pre_asian_handicap_first_half_home_min_125 Total rows : 3
#   3.45 -- 4
#   5.75 -- 4
#   4.65 -- 4
#
# pre_asian_handicap_first_half_away_min_125 Total rows : 3
#   1.23 -- 4
#   1.14 -- 4
#   1.33 -- 4
#
# pre_asian_handicap_first_half_home_min_1 Total rows : 3
#   2.75 -- 4
#   4.65 -- 4
#   2.75 -- 4
#
# pre_asian_handicap_first_half_away_min_1 Total rows : 3
#   1.11 -- 4
#   1.18 -- 4
#   1.43 -- 4
#
# pre_asian_handicap_first_half_home_min_075 Total rows : 3
#   2.08 -- 4
#   6.25 -- 4
#   4.25 -- 4
#
# pre_asian_handicap_first_half_away_min_075 Total rows : 3
#   1.73 -- 4
#   1.38 -- 4
#   1.21 -- 4
#
# pre_asian_handicap_first_half_home_min_05 Total rows : 3
#   1.75 -- 4
#   2.35 -- 4
#   2.05 -- 4
#
# pre_asian_handicap_first_half_away_min_05 Total rows : 3
#   2.05 -- 4
#   1.58 -- 4
#   1.35 -- 4
#
# pre_asian_handicap_first_half_home_min_025 Total rows : 3
#   1.45 -- 4
#   1.88 -- 4
#   1.53 -- 4
#
# pre_asian_handicap_first_half_away_min_025 Total rows : 3
#   2.68 -- 4
#   1.93 -- 4
#   2.43 -- 4
#
# pre_asian_handicap_first_half_home_plus_0 Total rows : 3
#   1.43 -- 4
#   1.98 -- 4
#   1.23 -- 4
#
# pre_asian_handicap_first_half_away_plus_0 Total rows : 3
#   1.32 -- 4
#   2.75 -- 4
#   1.83 -- 4
#
# pre_asian_handicap_first_half_home_plus_025 Total rows : 3
#   2.03 -- 4
#   1.28 -- 4
#   1.55 -- 4
#
# pre_asian_handicap_first_half_away_plus_025 Total rows : 3
#   1.87 -- 4
#   3.55 -- 4
#   2.38 -- 4
#
# pre_asian_handicap_first_half_home_plus_05 Total rows : 3
#   1.11 -- 4
#   1.45 -- 4
#   1.13 -- 4
#
# pre_asian_handicap_first_half_away_plus_05 Total rows : 3
#   2.67 -- 4
#   4.25 -- 4
#   2.85 -- 4
#
# pre_asian_handicap_first_half_home_plus_075 Total rows : 3
#   1.38 -- 4
#   1.24 -- 4
#   1.27 -- 4
#
# pre_asian_handicap_first_half_away_plus_075 Total rows : 3
#   6.25 -- 4
#   6.25 -- 4
#   3.55 -- 4
#
# pre_asian_handicap_first_half_home_plus_1 Total rows : 3
#   1.18 -- 4
#   1.11 -- 4
#   1.17 -- 4
#
# pre_asian_handicap_first_half_away_plus_1 Total rows : 3
#   4.65 -- 4
#   6.25 -- 4
#   5.75 -- 4
#
# pre_asian_handicap_first_half_home_plus_125 Total rows : 3
#   1.16 -- 4
#   1.25 -- 4
#   1.14 -- 4
#
# pre_asian_handicap_first_half_away_plus_125 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# pre_asian_handicap_first_half_home_plus_15 Total rows : 3
#   1.11 -- 4
#   1.12 -- 4
#   1.13 -- 4
#
# pre_asian_handicap_first_half_away_plus_15 Total rows : 3
#   4.15 -- 4
#   6.25 -- 4
#   6.25 -- 4
#
# pre_asian_handicap_first_half_home_plus_175 Total rows : 3
#   1.12 -- 4
#   1.14 -- 4
#   1.16 -- 4
#
# pre_asian_handicap_first_half_away_plus_175 Total rows : 3
#   6.25 -- 4
#   5.75 -- 4
#   5.25 -- 4
#
# end_asian_handicap_first_half_home_min_175 Total rows : 3
#   4.65 -- 4
#   5.75 -- 4
#   2.85 -- 4
#
# end_asian_handicap_first_half_away_min_175 Total rows : 3
#   1.18 -- 4
#   1.15 -- 4
#   1.35 -- 4
#
# end_asian_handicap_first_half_home_min_15 Total rows : 3
#   5.25 -- 4
#   3.55 -- 4
#   6.25 -- 4
#
# end_asian_handicap_first_half_away_min_15 Total rows : 3
#   1.11 -- 4
#   1.28 -- 4
#   1.12 -- 4
#
# end_asian_handicap_first_half_home_min_125 Total rows : 3
#   6.25 -- 4
#   4.25 -- 4
#   3.45 -- 4
#
# end_asian_handicap_first_half_away_min_125 Total rows : 3
#   1.12 -- 4
#   1.38 -- 4
#   1.15 -- 4
#
# end_asian_handicap_first_half_home_min_1 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   4.65 -- 4
#
# end_asian_handicap_first_half_away_min_1 Total rows : 3
#   1.14 -- 4
#   1.27 -- 4
#   1.18 -- 4
#
# end_asian_handicap_first_half_home_min_075 Total rows : 3
#   5.75 -- 4
#   3.45 -- 4
#   3.55 -- 4
#
# end_asian_handicap_first_half_away_min_075 Total rows : 3
#   1.14 -- 4
#   1.28 -- 4
#   1.19 -- 4
#
# end_asian_handicap_first_half_home_min_05 Total rows : 3
#   1.85 -- 4
#   1.98 -- 4
#   2.68 -- 4
#
# end_asian_handicap_first_half_away_min_05 Total rows : 3
#   1.45 -- 4
#   1.48 -- 4
#   1.33 -- 4
#
# end_asian_handicap_first_half_home_min_025 Total rows : 3
#   1.55 -- 4
#   5.75 -- 4
#   2.68 -- 4
#
# end_asian_handicap_first_half_away_min_025 Total rows : 3
#   1.33 -- 4
#   1.44 -- 4
#   1.45 -- 4
#
# end_asian_handicap_first_half_home_plus_0 Total rows : 3
#   1.91 -- 4
#   1.63 -- 4
#   2.05 -- 4
#
# end_asian_handicap_first_half_away_plus_0 Total rows : 3
#   2.75 -- 4
#   2.25 -- 4
#   1.75 -- 4
#
# end_asian_handicap_first_half_home_plus_025 Total rows : 3
#   1.28 -- 4
#   1.55 -- 4
#   1.19 -- 4
# end_asian_handicap_first_half_away_plus_025 Total rows : 3
#   3.55 -- 4
#   2.85 -- 4
#   2.43 -- 4
#
# end_asian_handicap_first_half_home_plus_05 Total rows : 3
#   1.53 -- 4
#   1.28 -- 4
#   1.43 -- 4
#
# end_asian_handicap_first_half_away_plus_05 Total rows : 3
#   2.43 -- 4
#   3.55 -- 4
#   2.75 -- 4
#
# end_asian_handicap_first_half_home_plus_075 Total rows : 3
#   1.15 -- 4
#   1.17 -- 4
#   1.26 -- 4
#
# end_asian_handicap_first_half_away_plus_075 Total rows : 3
#   2.85 -- 4
#   2.35 -- 4
#   4.15 -- 4
#
# end_asian_handicap_first_half_home_plus_1 Total rows : 3
#   1.16 -- 4
#   1.11 -- 4
#   1.14 -- 4
#
# end_asian_handicap_first_half_away_plus_1 Total rows : 3
#   5.25 -- 4
#   5.75 -- 4
#   3.45 -- 4
#
# end_asian_handicap_first_half_home_plus_125 Total rows : 3
#   1.11 -- 4
#   1.23 -- 4
#   1.11 -- 4
#
# end_asian_handicap_first_half_away_plus_125 Total rows : 3
#   5.75 -- 4
#   6.25 -- 4
#   3.45 -- 4
#
# end_asian_handicap_first_half_home_plus_15 Total rows : 3
#   1.11 -- 4
#   1.11 -- 4
#   1.18 -- 4
#
# end_asian_handicap_first_half_away_plus_15 Total rows : 3
#   6.25 -- 4
#   4.65 -- 4
#   5.25 -- 4
#
# end_asian_handicap_first_half_home_plus_175 Total rows : 3
#   1.15 -- 4
#   1.11 -- 4
#   1.12 -- 4
#
# end_asian_handicap_first_half_away_plus_175 Total rows : 3
#   4.15 -- 4
#   6.25 -- 4
#   5.75 -- 4
#
# pre_goals_overunder_first_half_over_05 Total rows : 3
#   1.36 -- 4
#   1.44 -- 4
#   1.36 -- 4
#
# pre_goals_overunder_first_half_under_05 Total rows : 3
#   2.75 -- 4
#   2.62 -- 4
#   2.75 -- 4
#
# pre_goals_overunder_first_half_over_075 Total rows : 3
#   1.52 -- 4
#   1.62 -- 4
#   1.55 -- 4
#
# pre_goals_overunder_first_half_under_075 Total rows : 3
#   2.42 -- 4
#   2.25 -- 4
#   2.37 -- 4
#
# pre_goals_overunder_first_half_over_10 Total rows : 3
#   1.83 -- 4
#   1.92 -- 4
#   1.87 -- 4
#
# pre_goals_overunder_first_half_under_10 Total rows : 3
#   1.98 -- 4
#   1.92 -- 4
#   1.97 -- 4
#
# pre_goals_overunder_first_half_over_125 Total rows : 3
#   2.37 -- 4
#   2.37 -- 4
#   2.35 -- 4
#
# pre_goals_overunder_first_half_under_125 Total rows : 3
#   1.55 -- 4
#   1.55 -- 4
#   1.57 -- 4
#
# pre_goals_overunder_first_half_over_15 Total rows : 3
#   3.25 -- 4
#   2.75 -- 4
#   2.75 -- 4
#
# pre_goals_overunder_first_half_under_15 Total rows : 3
#   1.36 -- 4
#   1.33 -- 4
#   1.28 -- 4
#
# pre_goals_overunder_first_half_over_175 Total rows : 3
#   2.15 -- 4
#   3.55 -- 4
#   3.55 -- 4
#
# pre_goals_overunder_first_half_under_175 Total rows : 3
#   1.27 -- 4
#   1.23 -- 4
#   1.26 -- 4
#
# pre_goals_overunder_first_half_over_20 Total rows : 3
#   6.25 -- 4
#   2.75 -- 4
#   5.75 -- 4
#
# pre_goals_overunder_first_half_under_20 Total rows : 3
#   1.13 -- 4
#   1.12 -- 4
#   1.13 -- 4
#
# pre_goals_overunder_first_half_over_225 Total rows : 3
#   5.75 -- 4
#   5.75 -- 4
#   6.25 -- 4
#
# pre_goals_overunder_first_half_under_225 Total rows : 3
#   1.32 -- 4
#   1.11 -- 4
#   1.11 -- 4
#
# pre_goals_overunder_first_half_over_25 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# pre_goals_overunder_first_half_under_25 Total rows : 3
#   1.06 -- 4
#   1.07 -- 4
#   1.08 -- 4
#
# pre_goals_overunder_first_half_over_275 Total rows : 3
#   4.65 -- 4
#   5.25 -- 4
#   6.25 -- 4
#
# pre_goals_overunder_first_half_under_275 Total rows : 3
#   1.15 -- 4
#   1.15 -- 4
#   1.12 -- 4
#
# pre_goals_overunder_first_half_over_30 Total rows : 3
#   15.5 -- 4
#   6.85 -- 4
#   5.25 -- 4
#
# pre_goals_overunder_first_half_under_30 Total rows : 3
#   1.01 -- 4
#   1.11 -- 4
#   1.02 -- 4
#
# pre_goals_overunder_first_half_over_325 Total rows : 3
#   5.25 -- 4
#   5.75 -- 4
#   15.5 -- 4
#
# pre_goals_overunder_first_half_under_325 Total rows : 3
#   1.11 -- 4
#   1.16 -- 4
#   1.17 -- 4
#
# pre_goals_overunder_first_half_over_35 Total rows : 3
#   17.5 -- 4
#   16.5 -- 4
#   17.5 -- 4
#
# pre_goals_overunder_first_half_under_35 Total rows : 3
#   1.02 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# pre_goals_overunder_first_half_over_375 Total rows : 3
#   3.45 -- 4
#   6.25 -- 4
#   5.25 -- 4
#
# pre_goals_overunder_first_half_under_375 Total rows : 3
#   1.23 -- 4
#   1.19 -- 4
#   1.16 -- 4
#
# end_goals_overunder_first_half_over_05 Total rows : 3
#   1.25 -- 4
#   1.44 -- 4
#   1.44 -- 4
#
# end_goals_overunder_first_half_under_05 Total rows : 3
#   3.75 -- 4
#   2.62 -- 4
#   2.62 -- 4
#
# end_goals_overunder_first_half_over_075 Total rows : 3
#   1.46 -- 4
#   1.65 -- 4
#   1.67 -- 4
#
# end_goals_overunder_first_half_under_075 Total rows : 3
#   2.37 -- 4
#   2.53 -- 4
#   2.15 -- 4
#
# end_goals_overunder_first_half_over_10 Total rows : 3
#   1.71 -- 4
#   2.12 -- 4
#   2.15 -- 4
#
# end_goals_overunder_first_half_under_10 Total rows : 3
#   1.92 -- 4
#   1.75 -- 4
#   1.72 -- 4
#
# end_goals_overunder_first_half_over_125 Total rows : 3
#   2.37 -- 4
#   2.35 -- 4
#   2.67 -- 4
#
# end_goals_overunder_first_half_under_125 Total rows : 3
#   1.55 -- 4
#   1.47 -- 4
#   1.45 -- 4
#
# end_goals_overunder_first_half_over_15 Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   3.25 -- 4
#
# end_goals_overunder_first_half_under_15 Total rows : 3
#   1.62 -- 4
#   1.33 -- 4
#   1.33 -- 4
#
# end_goals_overunder_first_half_over_175 Total rows : 3
#   3.28 -- 4
#   4.15 -- 4
#   4.25 -- 4
#
# end_goals_overunder_first_half_under_175 Total rows : 3
#   1.29 -- 4
#   1.22 -- 4
#   1.21 -- 4
#
# end_goals_overunder_first_half_over_20 Total rows : 3
#   4.25 -- 4
#   2.75 -- 4
#   5.75 -- 4
#
# end_goals_overunder_first_half_under_20 Total rows : 3
#   1.12 -- 4
#   1.13 -- 4
#   1.11 -- 4
#
# end_goals_overunder_first_half_over_225 Total rows : 3
#   6.25 -- 4
#   5.75 -- 4
#   5.75 -- 4
#
# end_goals_overunder_first_half_under_225 Total rows : 3
#   1.32 -- 4
#   1.14 -- 4
#   1.27 -- 4
#
# end_goals_overunder_first_half_over_25 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# end_goals_overunder_first_half_under_25 Total rows : 3
#   1.17 -- 4
#   1.07 -- 4
#   1.06 -- 4
#
# end_goals_overunder_first_half_over_275 Total rows : 3
#   5.25 -- 4
#   5.25 -- 4
#   5.25 -- 4
#
# end_goals_overunder_first_half_under_275 Total rows : 3
#   1.11 -- 4
#   1.16 -- 4
#   1.12 -- 4
#
# end_goals_overunder_first_half_over_30 Total rows : 3
#   4.25 -- 4
#   6.85 -- 4
#   6.25 -- 4
#
# end_goals_overunder_first_half_under_30 Total rows : 3
#   1.01 -- 4
#   1.01 -- 4
#   1.13 -- 4
#
# end_goals_overunder_first_half_over_325 Total rows : 3
#   15.5 -- 4
#   4.65 -- 4
#   15.5 -- 4
#
# end_goals_overunder_first_half_under_325 Total rows : 3
#   1.11 -- 4
#   1.13 -- 4
#   1.11 -- 4
#
# end_goals_overunder_first_half_over_35 Total rows : 3
#   17.5 -- 4
#   18.5 -- 4
#   16.5 -- 4
#
# end_goals_overunder_first_half_under_35 Total rows : 3
#   1.04 -- 4
#   1.01 -- 4
#   1.01 -- 4
#
# end_goals_overunder_first_half_over_375 Total rows : 3
#   3.45 -- 4
#   2.33 -- 4
#   4.25 -- 4
#
# end_goals_overunder_first_half_under_375 Total rows : 3
#   1.23 -- 4
#   1.19 -- 4
#   1.52 -- 4
#
# pre_goals_overunder__second_half_over_05 Total rows : 3
#   1.25 -- 4
#   1.22 -- 4
#   1.22 -- 4
#
# pre_goals_overunder__second_half_under_05 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_goals_overunder__second_half_over_075 Total rows : 3
#   1.45 -- 4
#   1.38 -- 4
#   1.42 -- 4
#
# pre_goals_overunder__second_half_under_075 Total rows : 3
#   2.56 -- 4
#   2.99 -- 4
#   2.82 -- 4
#
# pre_goals_overunder__second_half_over_10 Total rows : 3
#   1.32 -- 4
#   1.55 -- 4
#   1.62 -- 4
#
# pre_goals_overunder__second_half_under_10 Total rows : 3
#   1.98 -- 4
#   2.42 -- 4
#   2.28 -- 4
#
# pre_goals_overunder__second_half_over_125 Total rows : 3
#   1.61 -- 4
#   1.93 -- 4
#   2.01 -- 4
#
# pre_goals_overunder__second_half_under_125 Total rows : 3
#   2.23 -- 4
#   1.85 -- 4
#   1.78 -- 4
#
# pre_goals_overunder__second_half_over_15 Total rows : 3
#   2.25 -- 4
#   2.37 -- 4
#   2.25 -- 4
#
# pre_goals_overunder__second_half_under_15 Total rows : 3
#   1.73 -- 4
#   1.61 -- 4
#   1.72 -- 4
#
# pre_goals_overunder__second_half_over_175 Total rows : 3
#   2.19 -- 4
#   2.82 -- 4
#   2.99 -- 4
#
# pre_goals_overunder__second_half_under_175 Total rows : 3
#   1.63 -- 4
#   1.42 -- 4
#   1.38 -- 4
#
# pre_goals_overunder__second_half_over_20 Total rows : 3
#   3.96 -- 4
#   3.78 -- 4
#   2.85 -- 4
#
# pre_goals_overunder__second_half_under_20 Total rows : 3
#   1.39 -- 4
#   1.23 -- 4
#   1.22 -- 4
#
# pre_goals_overunder__second_half_over_225 Total rows : 3
#   6.05 -- 4
#   2.08 -- 4
#   3.56 -- 4
#
# pre_goals_overunder__second_half_under_225 Total rows : 3
#   1.13 -- 4
#   1.34 -- 4
#   1.29 -- 4
#
# pre_goals_overunder__second_half_over_25 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_goals_overunder__second_half_under_25 Total rows : 3
#   1.16 -- 4
#   1.16 -- 4
#   1.12 -- 4
#
# pre_goals_overunder__second_half_over_275 Total rows : 3
#   2.81 -- 4
#   3.15 -- 4
#   2.86 -- 4
#
# pre_goals_overunder__second_half_under_275 Total rows : 3
#   1.36 -- 4
#   1.39 -- 4
#   1.33 -- 4
# pre_goals_overunder__second_half_over_30 Total rows : 3
#   4.54 -- 4
#   4.54 -- 4
#   4.44 -- 4
#
# pre_goals_overunder__second_half_under_30 Total rows : 3
#   1.25 -- 4
#   1.16 -- 4
#   1.14 -- 4
#
# pre_goals_overunder__second_half_over_325 Total rows : 3
#   3.46 -- 4
#   11.4 -- 4
#   13.1 -- 4
#
# pre_goals_overunder__second_half_under_325 Total rows : 3
#   1.28 -- 4
#   1.04 -- 4
#   1.02 -- 4
#
# pre_goals_overunder__second_half_over_35 Total rows : 3
#   4.74 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_goals_overunder__second_half_under_35 Total rows : 3
#   1.05 -- 4
#   1.04 -- 4
#   1.05 -- 4
#
# pre_goals_overunder__second_half_over_375 Total rows : 3
#   7.75 -- 4
#   2.72 -- 4
#   9.25 -- 4
#
# pre_goals_overunder__second_half_under_375 Total rows : 3
#   1.04 -- 4
#   1.05 -- 4
#   1.05 -- 4
#
# end_goals_overunder__second_half_over_05 Total rows : 3
#   1.14 -- 4
#   1.25 -- 4
#   1.28 -- 4
#
# end_goals_overunder__second_half_under_05 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_goals_overunder__second_half_over_075 Total rows : 3
#   1.36 -- 4
#   1.37 -- 4
#   1.42 -- 4
#
# end_goals_overunder__second_half_under_075 Total rows : 3
#   3.48 -- 4
#   3.04 -- 4
#   2.82 -- 4
#
# end_goals_overunder__second_half_over_10 Total rows : 3
#   1.36 -- 4
#   1.54 -- 4
#   1.62 -- 4
#
# end_goals_overunder__second_half_under_10 Total rows : 3
#   2.44 -- 4
#   2.28 -- 4
#   2.03 -- 4
#
# end_goals_overunder__second_half_over_125 Total rows : 3
#   1.67 -- 4
#   1.92 -- 4
#   2.03 -- 4
#
# end_goals_overunder__second_half_under_125 Total rows : 3
#   2.08 -- 4
#   1.86 -- 4
#   1.77 -- 4
#
# end_goals_overunder__second_half_over_15 Total rows : 3
#   2.37 -- 4
#   2.37 -- 4
#   2.25 -- 4
#
# end_goals_overunder__second_half_under_15 Total rows : 3
#   1.61 -- 4
#   1.57 -- 4
#   1.61 -- 4
#
# end_goals_overunder__second_half_over_175 Total rows : 3
#   2.34 -- 4
#   2.82 -- 4
#   3.04 -- 4
#
# end_goals_overunder__second_half_under_175 Total rows : 3
#   1.53 -- 4
#   1.42 -- 4
#   1.37 -- 4
#
# end_goals_overunder__second_half_over_20 Total rows : 3
#   3.96 -- 4
#   3.96 -- 4
#   2.94 -- 4
#
# end_goals_overunder__second_half_under_20 Total rows : 3
#   1.32 -- 4
#   1.23 -- 4
#   1.23 -- 4
#
# end_goals_overunder__second_half_over_225 Total rows : 3
#   4.18 -- 4
#   3.38 -- 4
#   3.32 -- 4
#
# end_goals_overunder__second_half_under_225 Total rows : 3
#   1.27 -- 4
#   1.23 -- 4
#   1.31 -- 4
#
# end_goals_overunder__second_half_over_25 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   3.25 -- 4
#
# end_goals_overunder__second_half_under_25 Total rows : 3
#   1.33 -- 4
#   1.16 -- 4
#   1.14 -- 4
#
# end_goals_overunder__second_half_over_275 Total rows : 3
#   3.68 -- 4
#   2.77 -- 4
#   3.36 -- 4
#
# end_goals_overunder__second_half_under_275 Total rows : 3
#   1.45 -- 4
#   1.33 -- 4
#   1.33 -- 4
#
# end_goals_overunder__second_half_over_30 Total rows : 3
#   4.54 -- 4
#   4.44 -- 4
#   4.44 -- 4
#
# end_goals_overunder__second_half_under_30 Total rows : 3
#   1.17 -- 4
#   1.03 -- 4
#   1.03 -- 4
#
# end_goals_overunder__second_half_over_325 Total rows : 3
#   3.46 -- 4
#   13.9 -- 4
#   15.5 -- 4
#
# end_goals_overunder__second_half_under_325 Total rows : 3
#   1.28 -- 4
#   1.02 -- 4
#   1.01 -- 4
#
# end_goals_overunder__second_half_over_35 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# end_goals_overunder__second_half_under_35 Total rows : 3
#   1.11 -- 4
#   1.03 -- 4
#   1.03 -- 4
#
# end_goals_overunder__second_half_over_375 Total rows : 3
#   2.72 -- 4
#   2.32 -- 4
#   2.38 -- 4
#
# end_goals_overunder__second_half_under_375 Total rows : 3
#   1.55 -- 4
#   1.53 -- 4
#   2.15 -- 4
#
# pre_htft_double_home_home Total rows : 3
#   1.83 -- 4
#   2.63 -- 4
#   1.91 -- 4
#
# pre_htft_double_home_draw Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# pre_htft_double_home_away Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# pre_htft_double_draw_home Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# pre_htft_double_draw_draw Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_htft_double_draw_away Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_htft_double_away_home Total rows : 3
#   13.5 -- 4
#   13.5 -- 4
#   13.5 -- 4
#
# pre_htft_double_away_draw Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# pre_htft_double_away_away Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_htft_double_home_home Total rows : 3
#   2.88 -- 4
#   3.25 -- 4
#   1.83 -- 4
#
# end_htft_double_home_draw Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# end_htft_double_home_away Total rows : 3
#   14.5 -- 4
#   13.5 -- 4
#   14.5 -- 4
#
# end_htft_double_draw_home Total rows : 3
#   3.75 -- 4
#   4.75 -- 4
#   3.75 -- 4
#
# end_htft_double_draw_draw Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_htft_double_draw_away Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# end_htft_double_away_home Total rows : 3
#   14.5 -- 4
#   13.5 -- 4
#   14.5 -- 4
#
# end_htft_double_away_draw Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# end_htft_double_away_away Total rows : 3
#   2.88 -- 4
#   4.75 -- 4
#   3.75 -- 4
#
# pre_both_teams_score_yes Total rows : 3
#   1.95 -- 4
#   1.95 -- 4
#   1.75 -- 4
#
# pre_both_teams_score_no Total rows : 3
#   1.96 -- 4
#   1.95 -- 4
#   1.95 -- 4
#
# end_both_teams_score_yes Total rows : 3
#   1.95 -- 4
#   1.95 -- 4
#   1.95 -- 4
#
# end_both_teams_score_no Total rows : 3
#   2.05 -- 4
#   1.95 -- 4
#   2.63 -- 4
#
# pre_both_teams_score__first_half_yes Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_both_teams_score__first_half_no Total rows : 3
#   1.14 -- 4
#   1.14 -- 4
#   1.22 -- 4
#
# end_both_teams_score__first_half_yes Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_both_teams_score__first_half_no Total rows : 3
#   1.19 -- 4
#   1.25 -- 4
#   1.22 -- 4
#
# pre_both_teams_to_score__second_half_yes Total rows : 3
#   4.33 -- 4
#   3.25 -- 4
#   2.75 -- 4
#
# pre_both_teams_to_score__second_half_no Total rows : 3
#   1.22 -- 4
#   1.33 -- 4
#   1.25 -- 4
#
# end_both_teams_to_score__second_half_yes Total rows : 3
#   3.25 -- 4
#   2.63 -- 4
#   2.75 -- 4
#
# end_both_teams_to_score__second_half_no Total rows : 3
#   1.36 -- 4
#   1.44 -- 4
#   1.31 -- 4
#
# pre_results_both_teams_score_home_yes Total rows : 3
#   2.37 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_results_both_teams_score_draw_yes Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_results_both_teams_score_away_yes Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_results_both_teams_score_home_no Total rows : 3
#   2.87 -- 4
#   2.75 -- 4
#   4.75 -- 4
#
# pre_results_both_teams_score_draw_no Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   3.75 -- 4
#
# pre_results_both_teams_score_away_no Total rows : 3
#   2.87 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_results_both_teams_score_home_yes Total rows : 3
#   2.37 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_results_both_teams_score_draw_yes Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_results_both_teams_score_away_yes Total rows : 3
#   4.75 -- 4
#   2.87 -- 4
#   3.75 -- 4
#
# end_results_both_teams_score_home_no Total rows : 3
#   4.33 -- 4
#   2.05 -- 4
#   2.87 -- 4
#
# ...
#   4.75 -- 4
#
# pre_both_teams_to_score_1st_half__2nd_half_yes_yes Total rows : 3
#   9.5 -- 3
#   9.5 -- 3
#   9.5 -- 3
#
# pre_both_teams_to_score_1st_half__2nd_half_yes_no Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.75 -- 4
# pre_both_teams_to_score_1st_half__2nd_half_no_yes Total rows : 3
#   4.75 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_both_teams_to_score_1st_half__2nd_half_no_no Total rows : 3
#   1.44 -- 4
#   1.62 -- 4
#   1.44 -- 4
#
# end_both_teams_to_score_1st_half__2nd_half_yes_yes Total rows : 3
#   9.5 -- 3
#   9.5 -- 3
#   9.5 -- 3
#
# end_both_teams_to_score_1st_half__2nd_half_yes_no Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_both_teams_to_score_1st_half__2nd_half_no_yes Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# end_both_teams_to_score_1st_half__2nd_half_no_no Total rows : 3
#   1.67 -- 4
#   1.73 -- 4
#   1.62 -- 4
#
# pre_highest_scoring_half_first Total rows : 3
#   3.25 -- 4
#   2.88 -- 4
#   3.25 -- 4
#
# pre_highest_scoring_half_draw Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_highest_scoring_half_second Total rows : 3
#   2.05 -- 4
#   1.95 -- 4
#   1.91 -- 4
#
# end_highest_scoring_half_first Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   3.02 -- 4
#
# end_highest_scoring_half_draw Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_highest_scoring_half_second Total rows : 3
#   1.95 -- 4
#   1.91 -- 4
#   1.95 -- 4
#
# pre_double_chance_home_draw Total rows : 3
#   1.57 -- 4
#   1.28 -- 4
#   1.36 -- 4
#
# pre_double_chance_home_away Total rows : 3
#   1.25 -- 4
#   1.33 -- 4
#   1.25 -- 4
#
# pre_double_chance_draw_away Total rows : 3
#   1.33 -- 4
#   1.72 -- 4
#   1.57 -- 4
#
# end_double_chance_home_draw Total rows : 3
#   1.55 -- 4
#   1.66 -- 4
#   1.28 -- 4
#
# end_double_chance_home_away Total rows : 3
#   1.25 -- 4
#   1.28 -- 4
#   1.33 -- 4
#
# end_double_chance_draw_away Total rows : 3
#   1.36 -- 4
#   1.28 -- 4
#   1.66 -- 4
#
# pre_double_chance__first_half_home_draw Total rows : 3
#   1.06 -- 4
#   1.17 -- 4
#   1.57 -- 4
#
# pre_double_chance__first_half_home_away Total rows : 3
#   1.57 -- 4
#   1.57 -- 4
#   1.57 -- 4
#
# pre_double_chance__first_half_draw_away Total rows : 3
#   1.72 -- 4
#   1.57 -- 4
#   1.36 -- 4
#
# end_double_chance__first_half_home_draw Total rows : 3
#   1.53 -- 4
#   1.22 -- 4
#   1.27 -- 4
#
# end_double_chance__first_half_home_away Total rows : 3
#   1.57 -- 4
#   1.53 -- 4
#   1.57 -- 4
#
# end_double_chance__first_half_draw_away Total rows : 3
#   1.22 -- 4
#   1.53 -- 4
#   1.33 -- 4
#
# pre_oddeven_odd Total rows : 3
#   1.95 -- 4
#   1.95 -- 4
#   1.95 -- 4
#
# pre_oddeven_even Total rows : 3
#   1.83 -- 4
#   1.84 -- 4
#   1.81 -- 4
#
# end_oddeven_odd Total rows : 3
#   1.84 -- 4
#   1.95 -- 4
#   1.95 -- 4
#
# end_oddeven_even Total rows : 3
#   1.83 -- 4
#   1.84 -- 4
#   1.82 -- 4
#
# pre_result_total_goals_home_over_35 Total rows : 3
#   2.75 -- 4
#   3.75 -- 4
#   1.95 -- 4
#
# pre_result_total_goals_draw_over_35 Total rows : 3
#   19.5 -- 4
#   13.5 -- 4
#   15.5 -- 4
#
# pre_result_total_goals_away_over_35 Total rows : 3
#   2.37 -- 4
#   2.63 -- 4
#   2.62 -- 4
#
# pre_result_total_goals_home_under_35 Total rows : 3
#   2.62 -- 4
#   2.37 -- 4
#   2.25 -- 4
#
# pre_result_total_goals_draw_under_35 Total rows : 3
#   2.95 -- 4
#   3.25 -- 4
#   3.25 -- 4
#
# pre_result_total_goals_away_under_35 Total rows : 3
#   2.87 -- 4
#   3.25 -- 4
#   2.37 -- 4
#
# pre_result_total_goals_home_over_25 Total rows : 3
#   2.75 -- 4
#   2.87 -- 4
#   2.05 -- 4
#
# pre_result_total_goals_draw_over_25 Total rows : 3
#   19.5 -- 4
#   13.5 -- 4
#   15.5 -- 4
#
# pre_result_total_goals_away_over_25 Total rows : 3
#   2.87 -- 4
#   3.75 -- 4
#   3.25 -- 4
#
# pre_result_total_goals_home_under_25 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_result_total_goals_draw_under_25 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# pre_result_total_goals_away_under_25 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   3.75 -- 4
#
# end_result_total_goals_home_over_35 Total rows : 3
#   2.75 -- 4
#   1.95 -- 4
#   2.37 -- 4
#
# end_result_total_goals_draw_over_35 Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# end_result_total_goals_away_over_35 Total rows : 3
#   2.62 -- 4
#   2.62 -- 4
#   3.75 -- 4
#
# end_result_total_goals_home_under_35 Total rows : 3
#   2.05 -- 4
#   3.75 -- 4
#   2.37 -- 4
#
# end_result_total_goals_draw_under_35 Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   3.25 -- 4
#
# end_result_total_goals_away_under_35 Total rows : 3
#   4.33 -- 4
#   2.37 -- 4
#   2.25 -- 4
#
# end_result_total_goals_home_over_25 Total rows : 3
#   1.95 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_result_total_goals_draw_over_25 Total rows : 3
#   14.5 -- 4
#   14.5 -- 4
#   14.5 -- 4
#
# end_result_total_goals_away_over_25 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   2.37 -- 4
#
# end_result_total_goals_home_under_25 Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# end_result_total_goals_draw_under_25 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_result_total_goals_away_under_25 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   3.75 -- 4
#
# pre_clean_sheet__home_yes Total rows : 3
#   2.37 -- 4
#   4.33 -- 4
#   2.75 -- 4
#
# pre_clean_sheet__home_no Total rows : 3
#   1.18 -- 4
#   1.28 -- 4
#   1.33 -- 4
#
# end_clean_sheet__home_yes Total rows : 3
#   3.75 -- 4
#   2.62 -- 4
#   2.62 -- 4
#
# end_clean_sheet__home_no Total rows : 3
#   1.17 -- 4
#   1.25 -- 4
#   1.44 -- 4
#
# pre_clean_sheet__away_yes Total rows : 3
#   2.37 -- 4
#   2.75 -- 4
#   4.33 -- 4
#
# pre_clean_sheet__away_no Total rows : 3
#   1.53 -- 4
#   1.16 -- 4
#   1.36 -- 4
#
# end_clean_sheet__away_yes Total rows : 3
#   2.62 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_clean_sheet__away_no Total rows : 3
#   1.22 -- 4
#   1.44 -- 4
#   1.25 -- 4
#
# pre_win_both_halves_home Total rows : 3
#   2.62 -- 4
#   4.33 -- 4
#   1.83 -- 4
#
# pre_win_both_halves_away Total rows : 3
#   3.75 -- 4
#   2.62 -- 4
#   2.62 -- 4
#
# end_win_both_halves_home Total rows : 3
#   3.25 -- 4
#   2.25 -- 4
#   3.75 -- 4
#
# end_win_both_halves_away Total rows : 3
#   4.33 -- 4
#   2.62 -- 4
#   2.25 -- 4
#
# pre_win_to_nil_home Total rows : 3
#   2.75 -- 4
#   2.75 -- 4
#   3.75 -- 4
#
# pre_win_to_nil_away Total rows : 3
#   2.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_win_to_nil_home Total rows : 3
#   4.33 -- 4
#   3.25 -- 4
#   4.33 -- 4
#
# end_win_to_nil_away Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   2.62 -- 4
#
# pre_to_win_either_half_home Total rows : 3
#   2.62 -- 4
#   1.57 -- 4
#   1.66 -- 4
#
# pre_to_win_either_half_away Total rows : 3
#   1.44 -- 4
#   1.72 -- 4
#   1.57 -- 4
#
# end_to_win_either_half_home Total rows : 3
#   2.62 -- 4
#   1.66 -- 4
#   1.57 -- 4
#
# end_to_win_either_half_away Total rows : 3
#   1.44 -- 4
#   1.61 -- 4
#   1.62 -- 4
#
# pre_halftime_result_both_teams_score_home_yes Total rows : 3
#   9.5 -- 3
#   9.5 -- 3
#   9.5 -- 3
#
# pre_halftime_result_both_teams_score_draw_yes Total rows : 3
#   9.5 -- 3
#   8.5 -- 3
#   6.5 -- 3
#
# pre_halftime_result_both_teams_score_away_yes Total rows : 3
#   8.5 -- 3
#   8.5 -- 3
#   9.5 -- 3
#
# pre_halftime_result_both_teams_score_home_no Total rows : 3
#   1.95 -- 4
#   2.63 -- 4
#   3.75 -- 4
#
# pre_halftime_result_both_teams_score_draw_no Total rows : 3
#   2.62 -- 4
#   3.25 -- 4
#   2.63 -- 4
#
# pre_halftime_result_both_teams_score_away_no Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   2.87 -- 4
#
# end_halftime_result_both_teams_score_home_yes Total rows : 3
#   9.5 -- 3
#   8.5 -- 3
#   9.5 -- 3
#
# end_halftime_result_both_teams_score_draw_yes Total rows : 3
#   6.5 -- 3
#   8.5 -- 3
#   6.5 -- 3
#
# end_halftime_result_both_teams_score_away_yes Total rows : 3
#   9.5 -- 3
#   7.5 -- 3
#   9.5 -- 3
#
# end_halftime_result_both_teams_score_home_no Total rows : 3
#   4.75 -- 4
#   2.88 -- 4
#   1.95 -- 4
#
# end_halftime_result_both_teams_score_draw_no Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   3.25 -- 4
#
# end_halftime_result_both_teams_score_away_no Total rows : 3
#   2.75 -- 4
#   4.33 -- 4
#   3.25 -- 4
#
# pre_exact_goals_number_0 Total rows : 3
#   9.5 -- 3
#   8.5 -- 3
#   8.5 -- 3
#
# pre_exact_goals_number_1 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_exact_goals_number_2 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   4.75 -- 4
#
# pre_exact_goals_number_3 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_exact_goals_number_4 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_exact_goals_number_5 Total rows : 3
#   8.5 -- 3
#   8.5 -- 3
#   6.5 -- 3
#
# pre_exact_goals_number_6 Total rows : 3
#   9.5 -- 3
#   8.5 -- 3
#   8.5 -- 3
#
# pre_exact_goals_number_more_7 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   10.5 -- 4
#
# end_exact_goals_number_0 Total rows : 3
#   4.75 -- 4
#   8.5 -- 3
#   8.5 -- 3
#
# end_exact_goals_number_1 Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   4.75 -- 4
#
# end_exact_goals_number_2 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# end_exact_goals_number_3 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.75 -- 4
#
# end_exact_goals_number_4 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
# end_exact_goals_number_5 Total rows : 3
#   8.5 -- 3
#   7.5 -- 3
#   8.5 -- 3
#
# end_exact_goals_number_6 Total rows : 3
#   7.5 -- 3
#   9.5 -- 3
#   8.5 -- 3
#
# end_exact_goals_number_more_7 Total rows : 3
#   10.5 -- 4
#   10.5 -- 4
#   10.5 -- 4
#
# pre_exact_goals_number__first_half_0 Total rows : 3
#   2.62 -- 4
#   3.25 -- 4
#   2.63 -- 4
#
# pre_exact_goals_number__first_half_1 Total rows : 3
#   2.63 -- 4
#   2.63 -- 4
#   2.88 -- 4
#
# pre_exact_goals_number__first_half_2 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# pre_exact_goals_number__first_half_3 Total rows : 3
#   9.5 -- 3
#   9.5 -- 3
#   6.5 -- 3
#
# pre_exact_goals_number__first_half_4 Total rows : 3
#   7.5 -- 3
#   9.5 -- 3
#   21.0 -- 2
#
# pre_exact_goals_number__first_half_more_5 Total rows : 3
#   101.0 -- 3
#   101.0 -- 3
#   101.0 -- 3
#
# end_exact_goals_number__first_half_0 Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   2.25 -- 4
#
# end_exact_goals_number__first_half_1 Total rows : 3
#   2.63 -- 4
#   2.63 -- 4
#   2.63 -- 4
#
# end_exact_goals_number__first_half_2 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_exact_goals_number__first_half_3 Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   6.5 -- 3
#
# end_exact_goals_number__first_half_4 Total rows : 3
#   7.5 -- 3
#   9.5 -- 3
#   8.5 -- 3
#
# end_exact_goals_number__first_half_more_5 Total rows : 3
#   101.0 -- 3
#   101.0 -- 3
#   101.0 -- 3
#
# pre_second_half_exact_goals_number_0 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# pre_second_half_exact_goals_number_1 Total rows : 3
#   2.62 -- 4
#   2.88 -- 4
#   2.63 -- 4
#
# pre_second_half_exact_goals_number_2 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# pre_second_half_exact_goals_number_3 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_second_half_exact_goals_number_4 Total rows : 3
#   8.5 -- 3
#   9.5 -- 3
#   9.5 -- 3
#
# pre_second_half_exact_goals_number_more_5 Total rows : 3
#   5.5 -- 3
#   34.0 -- 2
#   21.0 -- 2
#
# end_second_half_exact_goals_number_0 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# end_second_half_exact_goals_number_1 Total rows : 3
#   2.88 -- 4
#   2.75 -- 4
#   2.87 -- 4
#
# end_second_half_exact_goals_number_2 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_second_half_exact_goals_number_3 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# end_second_half_exact_goals_number_4 Total rows : 3
#   7.5 -- 3
#   8.5 -- 3
#   9.5 -- 3
#
# end_second_half_exact_goals_number_more_5 Total rows : 3
#   5.5 -- 3
#   6.5 -- 3
#   5.5 -- 3
#
# pre_home_team_exact_goals_number_0 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# pre_home_team_exact_goals_number_1 Total rows : 3
#   3.75 -- 4
#   2.75 -- 4
#   4.33 -- 4
#
# pre_home_team_exact_goals_number_2 Total rows : 3
#   4.75 -- 4
#   3.25 -- 4
#   3.75 -- 4
#
# pre_home_team_exact_goals_number_more_3 Total rows : 3
#   3.25 -- 4
#   3.25 -- 4
#   3.25 -- 4
#
# end_home_team_exact_goals_number_0 Total rows : 3
#   2.75 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_home_team_exact_goals_number_1 Total rows : 3
#   2.88 -- 4
#   2.75 -- 4
#   2.63 -- 4
#
# end_home_team_exact_goals_number_2 Total rows : 3
#   4.33 -- 4
#   3.25 -- 4
#   3.75 -- 4
#
# end_home_team_exact_goals_number_more_3 Total rows : 3
#   1.91 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# pre_away_team_exact_goals_number_0 Total rows : 3
#   2.75 -- 4
#   1.83 -- 4
#   2.62 -- 4
#
# pre_away_team_exact_goals_number_1 Total rows : 3
#   2.63 -- 4
#   2.62 -- 4
#   2.75 -- 4
#
# pre_away_team_exact_goals_number_2 Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   4.75 -- 4
#
# pre_away_team_exact_goals_number_more_3 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_away_team_exact_goals_number_0 Total rows : 3
#   2.75 -- 4
#   2.75 -- 4
#   4.33 -- 4
#
# end_away_team_exact_goals_number_1 Total rows : 3
#   2.75 -- 4
#   2.88 -- 4
#   2.63 -- 4
#
# end_away_team_exact_goals_number_2 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_away_team_exact_goals_number_more_3 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   2.62 -- 4
#
# pre_corners_winner_home Total rows : 3
#   2.25 -- 4
#   1.61 -- 4
#   1.61 -- 4
#
# pre_corners_winner_draw Total rows : 3
#   14.5 -- 4
#   12.5 -- 4
#   12.5 -- 4
#
# pre_corners_winner_away Total rows : 3
#   1.95 -- 4
#   2.62 -- 4
#   2.75 -- 4
#
# end_corners_winner_home Total rows : 3
#   1.61 -- 4
#   1.61 -- 4
#   1.72 -- 4
#
# end_corners_winner_draw Total rows : 3
#   11.5 -- 4
#   11.5 -- 4
#   10.5 -- 4
#
# end_corners_winner_away Total rows : 3
#   1.95 -- 4
#   2.62 -- 4
#   2.75 -- 4
#
# pre_10_overunder_over_05 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_10_overunder_under_05 Total rows : 3
#   1.18 -- 4
#   1.16 -- 4
#   1.18 -- 4
#
# end_10_overunder_over_05 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# end_10_overunder_under_05 Total rows : 3
#   1.16 -- 4
#   1.18 -- 4
#   1.22 -- 4
#
# pre_cards_european_handicap_home_min_2 Total rows : 3
#   3.75 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_cards_european_handicap_draw_min_2 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_cards_european_handicap_away_min_2 Total rows : 3
#   1.09 -- 4
#   1.16 -- 4
#   1.17 -- 4
#
# pre_cards_european_handicap_home_min_1 Total rows : 3
#   4.33 -- 4
#   3.25 -- 4
#   4.33 -- 4
#
# pre_cards_european_handicap_draw_min_1 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# pre_cards_european_handicap_away_min_1 Total rows : 3
#   1.22 -- 4
#   1.36 -- 4
#   1.44 -- 4
#
# pre_cards_european_handicap_home_plus_0 Total rows : 3
#   2.62 -- 4
#   2.87 -- 4
#   4.75 -- 4
#
# pre_cards_european_handicap_draw_plus_0 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_cards_european_handicap_away_plus_0 Total rows : 3
#   1.66 -- 4
#   1.95 -- 4
#   1.53 -- 4
#
# pre_cards_european_handicap_home_plus_1 Total rows : 3
#   1.72 -- 4
#   1.61 -- 4
#   1.57 -- 4
#
# pre_cards_european_handicap_draw_plus_1 Total rows : 3
#   4.75 -- 4
#   4.33 -- 4
#   4.33 -- 4
#
# pre_cards_european_handicap_away_plus_1 Total rows : 3
#   2.87 -- 4
#   4.33 -- 4
#   3.75 -- 4
#
# pre_cards_european_handicap_home_plus_2 Total rows : 3
#   1.53 -- 4
#   1.33 -- 4
#   1.22 -- 4
#
# pre_cards_european_handicap_draw_plus_2 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.75 -- 4
#
# pre_cards_european_handicap_away_plus_2 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# end_cards_european_handicap_home_min_2 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_cards_european_handicap_draw_min_2 Total rows : 3
#   4.33 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# end_cards_european_handicap_away_min_2 Total rows : 3
#   1.16 -- 4
#   1.11 -- 4
#   1.14 -- 4
#
# end_cards_european_handicap_home_min_1 Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_cards_european_handicap_draw_min_1 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_cards_european_handicap_away_min_1 Total rows : 3
#   1.22 -- 4
#   1.22 -- 4
#   1.36 -- 4
#
# end_cards_european_handicap_home_plus_0 Total rows : 3
#   3.75 -- 4
#   2.25 -- 4
#   2.87 -- 4
#
# end_cards_european_handicap_draw_plus_0 Total rows : 3
#   4.33 -- 4
#   3.75 -- 4
#   4.33 -- 4
#
# end_cards_european_handicap_away_plus_0 Total rows : 3
#   1.66 -- 4
#   2.25 -- 4
#   1.95 -- 4
#
# end_cards_european_handicap_home_plus_1 Total rows : 3
#   1.57 -- 4
#   1.57 -- 4
#   1.72 -- 4
#
# end_cards_european_handicap_draw_plus_1 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.33 -- 4
#
# end_cards_european_handicap_away_plus_1 Total rows : 3
#   3.25 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_cards_european_handicap_home_plus_2 Total rows : 3
#   1.44 -- 4
#   1.44 -- 4
#   1.22 -- 4
#
# end_cards_european_handicap_draw_plus_2 Total rows : 3
#   4.75 -- 4
#   4.75 -- 4
#   4.75 -- 4
#
# end_cards_european_handicap_away_plus_2 Total rows : 3
#   4.33 -- 4
#   4.33 -- 4
#   4.75 -- 4
#
# pre_rcard_yes Total rows : 3
#   3.25 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# pre_rcard_no Total rows : 3
#   1.18 -- 4
#   1.12 -- 4
#   1.16 -- 4
#
# end_rcard_yes Total rows : 3
#   3.75 -- 4
#   3.75 -- 4
#   3.75 -- 4
#
# end_rcard_no Total rows : 3
#   1.33 -- 4
#   1.12 -- 4
#   1.16 -- 4

# %%
import mysql.connector
# -----------------------------------------------------------------
# CHECK
# -----------------------------------------------------------------
col = [
    'pre_match_winner_home', 
    'pre_match_winner_draw', 
    'pre_match_winner_away', 
    'end_match_winner_home', 
    'end_match_winner_draw', 
    'end_match_winner_away', 
    'pre_homeaway_home', 
    'pre_homeaway_away', 
    'end_homeaway_home', 
    'end_homeaway_away',
    'pre_first_half_winner_home',
    'pre_first_half_winner_draw',
    'pre_first_half_winner_away',
    'end_first_half_winner_home',
    'end_first_half_winner_draw',
    'end_first_half_winner_away',
    'pre_second_half_winner_home',
    'pre_second_half_winner_draw',
    'pre_second_half_winner_away',
    'end_second_half_winner_home',
    'end_second_half_winner_draw',
    'end_second_half_winner_away',
    'pre_asian_handicap_home_min_675',
    'pre_asian_handicap_away_min_675',
    'pre_asian_handicap_home_min_65',
    'pre_asian_handicap_away_min_65',
    'pre_asian_handicap_home_min_625',
    'pre_asian_handicap_away_min_625',
    'pre_asian_handicap_home_min_6',
    'pre_asian_handicap_away_min_6',
    'pre_asian_handicap_home_min_575',
    'pre_asian_handicap_away_min_575',
    'pre_asian_handicap_home_min_55',
    'pre_asian_handicap_away_min_55',
    'pre_asian_handicap_home_min_525',
    'pre_asian_handicap_away_min_525',
    'pre_asian_handicap_home_min_5',
    'pre_asian_handicap_away_min_5',
    'pre_asian_handicap_home_min_475',
    'pre_asian_handicap_away_min_475',
    'pre_asian_handicap_home_min_45',
    'pre_asian_handicap_away_min_45',
    'pre_asian_handicap_home_min_425',
    'pre_asian_handicap_away_min_425',
    'pre_asian_handicap_home_min_4',
    'pre_asian_handicap_away_min_4',
    'pre_asian_handicap_home_min_375',
    'pre_asian_handicap_away_min_375',
    'pre_asian_handicap_home_min_35',
    'pre_asian_handicap_away_min_35',
    'pre_asian_handicap_home_min_325',
    'pre_asian_handicap_away_min_325',
    'pre_asian_handicap_home_min_3',
    'pre_asian_handicap_away_min_3',
    'pre_asian_handicap_home_min_275',
    'pre_asian_handicap_away_min_275',
    'pre_asian_handicap_home_min_25',
    'pre_asian_handicap_away_min_25',
    'pre_asian_handicap_home_min_225',
    'pre_asian_handicap_away_min_225',
    'pre_asian_handicap_home_min_2',
    'pre_asian_handicap_away_min_2',
    'pre_asian_handicap_home_min_175',
    'pre_asian_handicap_away_min_175',
    'pre_asian_handicap_home_min_15',
    'pre_asian_handicap_away_min_15',
    'pre_asian_handicap_home_min_125',
    'pre_asian_handicap_away_min_125',
    'pre_asian_handicap_home_min_1',
    'pre_asian_handicap_away_min_1',
    'pre_asian_handicap_home_min_075',
    'pre_asian_handicap_away_min_075',
    'pre_asian_handicap_home_min_05',
    'pre_asian_handicap_away_min_05',
    'pre_asian_handicap_home_min_025',
    'pre_asian_handicap_away_min_025',
    'pre_asian_handicap_home_plus_0',
    'pre_asian_handicap_away_plus_0',
    'pre_asian_handicap_home_plus_025',
    'pre_asian_handicap_away_plus_025',
    'pre_asian_handicap_home_plus_05',
    'pre_asian_handicap_away_plus_05',
    'pre_asian_handicap_home_plus_075',
    'pre_asian_handicap_away_plus_075',
    'pre_asian_handicap_home_plus_1',
    'pre_asian_handicap_away_plus_1',
    'pre_asian_handicap_home_plus_125',
    'pre_asian_handicap_away_plus_125',
    'pre_asian_handicap_home_plus_15',
    'pre_asian_handicap_away_plus_15',
    'pre_asian_handicap_home_plus_175',
    'pre_asian_handicap_away_plus_175',
    'pre_asian_handicap_home_plus_2',
    'pre_asian_handicap_away_plus_2',
    'pre_asian_handicap_home_plus_225',
    'pre_asian_handicap_away_plus_225',
    'pre_asian_handicap_home_plus_25',
    'pre_asian_handicap_away_plus_25',
    'pre_asian_handicap_home_plus_275',
    'pre_asian_handicap_away_plus_275',
    'pre_asian_handicap_home_plus_3',
    'pre_asian_handicap_away_plus_3',
    'pre_asian_handicap_home_plus_325',
    'pre_asian_handicap_away_plus_325',
    'pre_asian_handicap_home_plus_35',
    'pre_asian_handicap_away_plus_35',
    'pre_asian_handicap_home_plus_375',
    'pre_asian_handicap_away_plus_375',
    'pre_asian_handicap_home_plus_4',
    'pre_asian_handicap_away_plus_4',
    'pre_asian_handicap_home_plus_425',
    'pre_asian_handicap_away_plus_425',
    'pre_asian_handicap_home_plus_45',
    'pre_asian_handicap_away_plus_45',
    'pre_asian_handicap_home_plus_475',
    'pre_asian_handicap_away_plus_475',
    'pre_asian_handicap_home_plus_5',
    'pre_asian_handicap_away_plus_5',
    'pre_asian_handicap_home_plus_525',
    'pre_asian_handicap_away_plus_525',
    'pre_asian_handicap_home_plus_55',
    'pre_asian_handicap_away_plus_55',
    'pre_asian_handicap_home_plus_575',
    'pre_asian_handicap_away_plus_575',
    'pre_asian_handicap_home_plus_6',
    'pre_asian_handicap_away_plus_6',
    'pre_asian_handicap_home_plus_625',
    'pre_asian_handicap_away_plus_625',
    'pre_asian_handicap_home_plus_65',
    'pre_asian_handicap_away_plus_65',
    'pre_asian_handicap_home_plus_675',
    'pre_asian_handicap_away_plus_675',
    'end_asian_handicap_home_min_675',
    'end_asian_handicap_away_min_675',
    'end_asian_handicap_home_min_65',
    'end_asian_handicap_away_min_65',
    'end_asian_handicap_home_min_625',
    'end_asian_handicap_away_min_625',
    'end_asian_handicap_home_min_6',
    'end_asian_handicap_away_min_6',
    'end_asian_handicap_home_min_575',
    'end_asian_handicap_away_min_575',
    'end_asian_handicap_home_min_55',
    'end_asian_handicap_away_min_55',
    'end_asian_handicap_home_min_525',
    'end_asian_handicap_away_min_525',
    'end_asian_handicap_home_min_5',
    'end_asian_handicap_away_min_5',
    'end_asian_handicap_home_min_475',
    'end_asian_handicap_away_min_475',
    'end_asian_handicap_home_min_45',
    'end_asian_handicap_away_min_45',
    'end_asian_handicap_home_min_425',
    'end_asian_handicap_away_min_425',
    'end_asian_handicap_home_min_4',
    'end_asian_handicap_away_min_4',
    'end_asian_handicap_home_min_375',
    'end_asian_handicap_away_min_375',
    'end_asian_handicap_home_min_35',
    'end_asian_handicap_away_min_35',
    'end_asian_handicap_home_min_325',
    'end_asian_handicap_away_min_325',
    'end_asian_handicap_home_min_3',
    'end_asian_handicap_away_min_3',
    'end_asian_handicap_home_min_275',
    'end_asian_handicap_away_min_275',
    'end_asian_handicap_home_min_25',
    'end_asian_handicap_away_min_25',
    'end_asian_handicap_home_min_225',
    'end_asian_handicap_away_min_225',
    'end_asian_handicap_home_min_2',
    'end_asian_handicap_away_min_2',
    'end_asian_handicap_home_min_175',
    'end_asian_handicap_away_min_175',
    'end_asian_handicap_home_min_15',
    'end_asian_handicap_away_min_15',
    'end_asian_handicap_home_min_125',
    'end_asian_handicap_away_min_125',
    'end_asian_handicap_home_min_1',
    'end_asian_handicap_away_min_1',
    'end_asian_handicap_home_min_075',
    'end_asian_handicap_away_min_075',
    'end_asian_handicap_home_min_05',
    'end_asian_handicap_away_min_05',
    'end_asian_handicap_home_min_025',
    'end_asian_handicap_away_min_025',
    'end_asian_handicap_home_plus_0',
    'end_asian_handicap_away_plus_0',
    'end_asian_handicap_home_plus_025',
    'end_asian_handicap_away_plus_025',
    'end_asian_handicap_home_plus_05',
    'end_asian_handicap_away_plus_05',
    'end_asian_handicap_home_plus_075',
    'end_asian_handicap_away_plus_075',
    'end_asian_handicap_home_plus_1',
    'end_asian_handicap_away_plus_1',
    'end_asian_handicap_home_plus_125',
    'end_asian_handicap_away_plus_125',
    'end_asian_handicap_home_plus_15',
    'end_asian_handicap_away_plus_15',
    'end_asian_handicap_home_plus_175',
    'end_asian_handicap_away_plus_175',
    'end_asian_handicap_home_plus_2',
    'end_asian_handicap_away_plus_2',
    'end_asian_handicap_home_plus_225',
    'end_asian_handicap_away_plus_225',
    'end_asian_handicap_home_plus_25',
    'end_asian_handicap_away_plus_25',
    'end_asian_handicap_home_plus_275',
    'end_asian_handicap_away_plus_275',
    'end_asian_handicap_home_plus_3',
    'end_asian_handicap_away_plus_3',
    'end_asian_handicap_home_plus_325',
    'end_asian_handicap_away_plus_325',
    'end_asian_handicap_home_plus_35',
    'end_asian_handicap_away_plus_35',
    'end_asian_handicap_home_plus_375',
    'end_asian_handicap_away_plus_375',
    'end_asian_handicap_home_plus_4',
    'end_asian_handicap_away_plus_4',
    'end_asian_handicap_home_plus_425',
    'end_asian_handicap_away_plus_425',
    'end_asian_handicap_home_plus_45',
    'end_asian_handicap_away_plus_45',
    'end_asian_handicap_home_plus_475',
    'end_asian_handicap_away_plus_475',
    'end_asian_handicap_home_plus_5',
    'end_asian_handicap_away_plus_5',
    'end_asian_handicap_home_plus_525',
    'end_asian_handicap_away_plus_525',
    'end_asian_handicap_home_plus_55',
    'end_asian_handicap_away_plus_55',
    'end_asian_handicap_home_plus_575',
    'end_asian_handicap_away_plus_575',
    'end_asian_handicap_home_plus_6',
    'end_asian_handicap_away_plus_6',
    'end_asian_handicap_home_plus_625',
    'end_asian_handicap_away_plus_625',
    'end_asian_handicap_home_plus_65',
    'end_asian_handicap_away_plus_65',
    'end_asian_handicap_home_plus_675',
    'end_asian_handicap_away_plus_675',
    'pre_goals_overunder_over_05',
    'pre_goals_overunder_under_05',
    'pre_goals_overunder_over_075',
    'pre_goals_overunder_under_075',
    'pre_goals_overunder_over_10',
    'pre_goals_overunder_under_10',
    'pre_goals_overunder_over_125',
    'pre_goals_overunder_under_125',
    'pre_goals_overunder_over_15',
    'pre_goals_overunder_under_15',
    'pre_goals_overunder_over_175',
    'pre_goals_overunder_under_175',
    'pre_goals_overunder_over_20',
    'pre_goals_overunder_under_20',
    'pre_goals_overunder_over_225',
    'pre_goals_overunder_under_225',
    'pre_goals_overunder_over_25',
    'pre_goals_overunder_under_25',
    'pre_goals_overunder_over_275',
    'pre_goals_overunder_under_275',
    'pre_goals_overunder_over_30',
    'pre_goals_overunder_under_30',
    'pre_goals_overunder_over_325',
    'pre_goals_overunder_under_325',
    'pre_goals_overunder_over_35',
    'pre_goals_overunder_under_35',
    'pre_goals_overunder_over_375',
    'pre_goals_overunder_under_375',
    'pre_goals_overunder_over_40',
    'pre_goals_overunder_under_40',
    'pre_goals_overunder_over_425',
    'pre_goals_overunder_under_425',
    'pre_goals_overunder_over_45',
    'pre_goals_overunder_under_45',
    'pre_goals_overunder_over_475',
    'pre_goals_overunder_under_475',
    'pre_goals_overunder_over_50',
    'pre_goals_overunder_under_50',
    'pre_goals_overunder_over_525',
    'pre_goals_overunder_under_525',
    'pre_goals_overunder_over_55',
    'pre_goals_overunder_under_55',
    'pre_goals_overunder_over_575',
    'pre_goals_overunder_under_575',
    'pre_goals_overunder_over_60',
    'pre_goals_overunder_under_60',
    'pre_goals_overunder_over_625',
    'pre_goals_overunder_under_625',
    'pre_goals_overunder_over_65',
    'pre_goals_overunder_under_65',
    'pre_goals_overunder_over_675',
    'pre_goals_overunder_under_675',
    'pre_goals_overunder_over_70',
    'pre_goals_overunder_under_70',
    'pre_goals_overunder_over_75',
    'pre_goals_overunder_under_75',
    'pre_goals_overunder_over_85',
    'pre_goals_overunder_under_85',
    'pre_goals_overunder_over_95',
    'pre_goals_overunder_under_95',
    'end_goals_overunder_over_05',
    'end_goals_overunder_under_05',
    'end_goals_overunder_over_075',
    'end_goals_overunder_under_075',
    'end_goals_overunder_over_10',
    'end_goals_overunder_under_10',
    'end_goals_overunder_over_125',
    'end_goals_overunder_under_125',
    'end_goals_overunder_over_15',
    'end_goals_overunder_under_15',
    'end_goals_overunder_over_175',
    'end_goals_overunder_under_175',
    'end_goals_overunder_over_20',
    'end_goals_overunder_under_20',
    'end_goals_overunder_over_225',
    'end_goals_overunder_under_225',
    'end_goals_overunder_over_25',
    'end_goals_overunder_under_25',
    'end_goals_overunder_over_275',
    'end_goals_overunder_under_275',
    'end_goals_overunder_over_30',
    'end_goals_overunder_under_30',
    'end_goals_overunder_over_325',
    'end_goals_overunder_under_325',
    'end_goals_overunder_over_35',
    'end_goals_overunder_under_35',
    'end_goals_overunder_over_375',
    'end_goals_overunder_under_375',
    'end_goals_overunder_over_40',
    'end_goals_overunder_under_40',
    'end_goals_overunder_over_425',
    'end_goals_overunder_under_425',
    'end_goals_overunder_over_45',
    'end_goals_overunder_under_45',
    'end_goals_overunder_over_475',
    'end_goals_overunder_under_475',
    'end_goals_overunder_over_50',
    'end_goals_overunder_under_50',
    'end_goals_overunder_over_525',
    'end_goals_overunder_under_525',
    'end_goals_overunder_over_55',
    'end_goals_overunder_under_55',
    'end_goals_overunder_over_575',
    'end_goals_overunder_under_575',
    'end_goals_overunder_over_60',
    'end_goals_overunder_under_60',
    'end_goals_overunder_over_625',
    'end_goals_overunder_under_625',
    'end_goals_overunder_over_65',
    'end_goals_overunder_under_65',
    'end_goals_overunder_over_675',
    'end_goals_overunder_under_675',
    'end_goals_overunder_over_70',
    'end_goals_overunder_under_70',
    'end_goals_overunder_over_75',
    'end_goals_overunder_under_75',
    'end_goals_overunder_over_85',
    'end_goals_overunder_under_85',
    'end_goals_overunder_over_95',
    'end_goals_overunder_under_95',
    'pre_asian_handicap_first_half_home_min_175',
    'pre_asian_handicap_first_half_away_min_175',
    'pre_asian_handicap_first_half_home_min_15',
    'pre_asian_handicap_first_half_away_min_15',
    'pre_asian_handicap_first_half_home_min_125',
    'pre_asian_handicap_first_half_away_min_125',
    'pre_asian_handicap_first_half_home_min_1',
    'pre_asian_handicap_first_half_away_min_1',
    'pre_asian_handicap_first_half_home_min_075',
    'pre_asian_handicap_first_half_away_min_075',
    'pre_asian_handicap_first_half_home_min_05',
    'pre_asian_handicap_first_half_away_min_05',
    'pre_asian_handicap_first_half_home_min_025',
    'pre_asian_handicap_first_half_away_min_025',
    'pre_asian_handicap_first_half_home_plus_0',
    'pre_asian_handicap_first_half_away_plus_0',
    'pre_asian_handicap_first_half_home_plus_025',
    'pre_asian_handicap_first_half_away_plus_025',
    'pre_asian_handicap_first_half_home_plus_05',
    'pre_asian_handicap_first_half_away_plus_05',
    'pre_asian_handicap_first_half_home_plus_075',
    'pre_asian_handicap_first_half_away_plus_075',
    'pre_asian_handicap_first_half_home_plus_1',
    'pre_asian_handicap_first_half_away_plus_1',
    'pre_asian_handicap_first_half_home_plus_125',
    'pre_asian_handicap_first_half_away_plus_125',
    'pre_asian_handicap_first_half_home_plus_15',
    'pre_asian_handicap_first_half_away_plus_15',
    'pre_asian_handicap_first_half_home_plus_175',
    'pre_asian_handicap_first_half_away_plus_175',
    'end_asian_handicap_first_half_home_min_175',
    'end_asian_handicap_first_half_away_min_175',
    'end_asian_handicap_first_half_home_min_15',
    'end_asian_handicap_first_half_away_min_15',
    'end_asian_handicap_first_half_home_min_125',
    'end_asian_handicap_first_half_away_min_125',
    'end_asian_handicap_first_half_home_min_1',
    'end_asian_handicap_first_half_away_min_1',
    'end_asian_handicap_first_half_home_min_075',
    'end_asian_handicap_first_half_away_min_075',
    'end_asian_handicap_first_half_home_min_05',
    'end_asian_handicap_first_half_away_min_05',
    'end_asian_handicap_first_half_home_min_025',
    'end_asian_handicap_first_half_away_min_025',
    'end_asian_handicap_first_half_home_plus_0',
    'end_asian_handicap_first_half_away_plus_0',
    'end_asian_handicap_first_half_home_plus_025',
    'end_asian_handicap_first_half_away_plus_025',
    'end_asian_handicap_first_half_home_plus_05',
    'end_asian_handicap_first_half_away_plus_05',
    'end_asian_handicap_first_half_home_plus_075',
    'end_asian_handicap_first_half_away_plus_075',
    'end_asian_handicap_first_half_home_plus_1',
    'end_asian_handicap_first_half_away_plus_1',
    'end_asian_handicap_first_half_home_plus_125',
    'end_asian_handicap_first_half_away_plus_125',
    'end_asian_handicap_first_half_home_plus_15',
    'end_asian_handicap_first_half_away_plus_15',
    'end_asian_handicap_first_half_home_plus_175',
    'end_asian_handicap_first_half_away_plus_175',
    'pre_goals_overunder_first_half_over_05',
    'pre_goals_overunder_first_half_under_05',
    'pre_goals_overunder_first_half_over_075',
    'pre_goals_overunder_first_half_under_075',
    'pre_goals_overunder_first_half_over_10',
    'pre_goals_overunder_first_half_under_10',
    'pre_goals_overunder_first_half_over_125',
    'pre_goals_overunder_first_half_under_125',
    'pre_goals_overunder_first_half_over_15',
    'pre_goals_overunder_first_half_under_15',
    'pre_goals_overunder_first_half_over_175',
    'pre_goals_overunder_first_half_under_175',
    'pre_goals_overunder_first_half_over_20',
    'pre_goals_overunder_first_half_under_20',
    'pre_goals_overunder_first_half_over_225',
    'pre_goals_overunder_first_half_under_225',
    'pre_goals_overunder_first_half_over_25',
    'pre_goals_overunder_first_half_under_25',
    'pre_goals_overunder_first_half_over_275',
    'pre_goals_overunder_first_half_under_275',
    'pre_goals_overunder_first_half_over_30',
    'pre_goals_overunder_first_half_under_30',
    'pre_goals_overunder_first_half_over_325',
    'pre_goals_overunder_first_half_under_325',
    'pre_goals_overunder_first_half_over_35',
    'pre_goals_overunder_first_half_under_35',
    'pre_goals_overunder_first_half_over_375',
    'pre_goals_overunder_first_half_under_375',
    'end_goals_overunder_first_half_over_05',
    'end_goals_overunder_first_half_under_05',
    'end_goals_overunder_first_half_over_075',
    'end_goals_overunder_first_half_under_075',
    'end_goals_overunder_first_half_over_10',
    'end_goals_overunder_first_half_under_10',
    'end_goals_overunder_first_half_over_125',
    'end_goals_overunder_first_half_under_125',
    'end_goals_overunder_first_half_over_15',
    'end_goals_overunder_first_half_under_15',
    'end_goals_overunder_first_half_over_175',
    'end_goals_overunder_first_half_under_175',
    'end_goals_overunder_first_half_over_20',
    'end_goals_overunder_first_half_under_20',
    'end_goals_overunder_first_half_over_225',
    'end_goals_overunder_first_half_under_225',
    'end_goals_overunder_first_half_over_25',
    'end_goals_overunder_first_half_under_25',
    'end_goals_overunder_first_half_over_275',
    'end_goals_overunder_first_half_under_275',
    'end_goals_overunder_first_half_over_30',
    'end_goals_overunder_first_half_under_30',
    'end_goals_overunder_first_half_over_325',
    'end_goals_overunder_first_half_under_325',
    'end_goals_overunder_first_half_over_35',
    'end_goals_overunder_first_half_under_35',
    'end_goals_overunder_first_half_over_375',
    'end_goals_overunder_first_half_under_375',
    'pre_goals_overunder__second_half_over_05',
    'pre_goals_overunder__second_half_under_05',
    'pre_goals_overunder__second_half_over_075',
    'pre_goals_overunder__second_half_under_075',
    'pre_goals_overunder__second_half_over_10',
    'pre_goals_overunder__second_half_under_10',
    'pre_goals_overunder__second_half_over_125',
    'pre_goals_overunder__second_half_under_125',
    'pre_goals_overunder__second_half_over_15',
    'pre_goals_overunder__second_half_under_15',
    'pre_goals_overunder__second_half_over_175',
    'pre_goals_overunder__second_half_under_175',
    'pre_goals_overunder__second_half_over_20',
    'pre_goals_overunder__second_half_under_20',
    'pre_goals_overunder__second_half_over_225',
    'pre_goals_overunder__second_half_under_225',
    'pre_goals_overunder__second_half_over_25',
    'pre_goals_overunder__second_half_under_25',
    'pre_goals_overunder__second_half_over_275',
    'pre_goals_overunder__second_half_under_275',
    'pre_goals_overunder__second_half_over_30',
    'pre_goals_overunder__second_half_under_30',
    'pre_goals_overunder__second_half_over_325',
    'pre_goals_overunder__second_half_under_325',
    'pre_goals_overunder__second_half_over_35',
    'pre_goals_overunder__second_half_under_35',
    'pre_goals_overunder__second_half_over_375',
    'pre_goals_overunder__second_half_under_375',
    'end_goals_overunder__second_half_over_05',
    'end_goals_overunder__second_half_under_05',
    'end_goals_overunder__second_half_over_075',
    'end_goals_overunder__second_half_under_075',
    'end_goals_overunder__second_half_over_10',
    'end_goals_overunder__second_half_under_10',
    'end_goals_overunder__second_half_over_125',
    'end_goals_overunder__second_half_under_125',
    'end_goals_overunder__second_half_over_15',
    'end_goals_overunder__second_half_under_15',
    'end_goals_overunder__second_half_over_175',
    'end_goals_overunder__second_half_under_175',
    'end_goals_overunder__second_half_over_20',
    'end_goals_overunder__second_half_under_20',
    'end_goals_overunder__second_half_over_225',
    'end_goals_overunder__second_half_under_225',
    'end_goals_overunder__second_half_over_25',
    'end_goals_overunder__second_half_under_25',
    'end_goals_overunder__second_half_over_275',
    'end_goals_overunder__second_half_under_275',
    'end_goals_overunder__second_half_over_30',
    'end_goals_overunder__second_half_under_30',
    'end_goals_overunder__second_half_over_325',
    'end_goals_overunder__second_half_under_325',
    'end_goals_overunder__second_half_over_35',
    'end_goals_overunder__second_half_under_35',
    'end_goals_overunder__second_half_over_375',
    'end_goals_overunder__second_half_under_375',
    'pre_htft_double_home_home',
    'pre_htft_double_home_draw',
    'pre_htft_double_home_away',
    'pre_htft_double_draw_home',
    'pre_htft_double_draw_draw',
    'pre_htft_double_draw_away',
    'pre_htft_double_away_home',
    'pre_htft_double_away_draw',
    'pre_htft_double_away_away',
    'end_htft_double_home_home',
    'end_htft_double_home_draw',
    'end_htft_double_home_away',
    'end_htft_double_draw_home',
    'end_htft_double_draw_draw',
    'end_htft_double_draw_away',
    'end_htft_double_away_home',
    'end_htft_double_away_draw',
    'end_htft_double_away_away',
    'pre_both_teams_score_yes',
    'pre_both_teams_score_no',
    'end_both_teams_score_yes',
    'end_both_teams_score_no',
    'pre_both_teams_score__first_half_yes',
    'pre_both_teams_score__first_half_no',
    'end_both_teams_score__first_half_yes',
    'end_both_teams_score__first_half_no',
    'pre_both_teams_to_score__second_half_yes',
    'pre_both_teams_to_score__second_half_no',
    'end_both_teams_to_score__second_half_yes',
    'end_both_teams_to_score__second_half_no',
    'pre_results_both_teams_score_home_yes',
    'pre_results_both_teams_score_draw_yes',
    'pre_results_both_teams_score_away_yes',
    'pre_results_both_teams_score_home_no',
    'pre_results_both_teams_score_draw_no',
    'pre_results_both_teams_score_away_no',
    'end_results_both_teams_score_home_yes',
    'end_results_both_teams_score_draw_yes',
    'end_results_both_teams_score_away_yes',
    'end_results_both_teams_score_home_no',
    'end_results_both_teams_score_draw_no',
    'end_results_both_teams_score_away_no',
    'pre_to_score_in_both_halves_by_teams_home',
    'pre_to_score_in_both_halves_by_teams_away',
    'end_to_score_in_both_halves_by_teams_home',
    'end_to_score_in_both_halves_by_teams_away',
    'pre_total_goals_both_teams_to_score_over_yes_25',
    'pre_total_goals_both_teams_to_score_over_no_25',
    'pre_total_goals_both_teams_to_score_under_yes_25',
    'pre_total_goals_both_teams_to_score_under_no_25',
    'end_total_goals_both_teams_to_score_over_yes_25',
    'end_total_goals_both_teams_to_score_over_no_25',
    'end_total_goals_both_teams_to_score_under_yes_25',
    'end_total_goals_both_teams_to_score_under_no_25',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_no',
    'pre_both_teams_to_score_1st_half__2nd_half_no_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_no_no',
    'end_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'end_both_teams_to_score_1st_half__2nd_half_yes_no',
    'end_both_teams_to_score_1st_half__2nd_half_no_yes',
    'end_both_teams_to_score_1st_half__2nd_half_no_no',
    'pre_highest_scoring_half_first',
    'pre_highest_scoring_half_draw',
    'pre_highest_scoring_half_second',
    'end_highest_scoring_half_first',
    'end_highest_scoring_half_draw',
    'end_highest_scoring_half_second',
    'pre_double_chance_home_draw',
    'pre_double_chance_home_away',
    'pre_double_chance_draw_away',
    'end_double_chance_home_draw',
    'end_double_chance_home_away',
    'end_double_chance_draw_away',
    'pre_double_chance__first_half_home_draw',
    'pre_double_chance__first_half_home_away',
    'pre_double_chance__first_half_draw_away',
    'end_double_chance__first_half_home_draw',
    'end_double_chance__first_half_home_away',
    'end_double_chance__first_half_draw_away',
    'pre_oddeven_odd',
    'pre_oddeven_even',
    'end_oddeven_odd',
    'end_oddeven_even',
    'pre_result_total_goals_home_over_35',
    'pre_result_total_goals_draw_over_35',
    'pre_result_total_goals_away_over_35',
    'pre_result_total_goals_home_under_35',
    'pre_result_total_goals_draw_under_35',
    'pre_result_total_goals_away_under_35',
    'pre_result_total_goals_home_over_25',
    'pre_result_total_goals_draw_over_25',
    'pre_result_total_goals_away_over_25',
    'pre_result_total_goals_home_under_25',
    'pre_result_total_goals_draw_under_25',
    'pre_result_total_goals_away_under_25',
    'end_result_total_goals_home_over_35',
    'end_result_total_goals_draw_over_35',
    'end_result_total_goals_away_over_35',
    'end_result_total_goals_home_under_35',
    'end_result_total_goals_draw_under_35',
    'end_result_total_goals_away_under_35',
    'end_result_total_goals_home_over_25',
    'end_result_total_goals_draw_over_25',
    'end_result_total_goals_away_over_25',
    'end_result_total_goals_home_under_25',
    'end_result_total_goals_draw_under_25',
    'end_result_total_goals_away_under_25',
    'pre_clean_sheet__home_yes',
    'pre_clean_sheet__home_no',
    'end_clean_sheet__home_yes',
    'end_clean_sheet__home_no',
    'pre_clean_sheet__away_yes',
    'pre_clean_sheet__away_no',
    'end_clean_sheet__away_yes',
    'end_clean_sheet__away_no',
    'pre_win_both_halves_home',
    'pre_win_both_halves_away',
    'end_win_both_halves_home',
    'end_win_both_halves_away',
    'pre_win_to_nil_home',
    'pre_win_to_nil_away',
    'end_win_to_nil_home',
    'end_win_to_nil_away',
    'pre_to_win_either_half_home',
    'pre_to_win_either_half_away',
    'end_to_win_either_half_home',
    'end_to_win_either_half_away',
    'pre_halftime_result_both_teams_score_home_yes',
    'pre_halftime_result_both_teams_score_draw_yes',
    'pre_halftime_result_both_teams_score_away_yes',
    'pre_halftime_result_both_teams_score_home_no',
    'pre_halftime_result_both_teams_score_draw_no',
    'pre_halftime_result_both_teams_score_away_no',
    'end_halftime_result_both_teams_score_home_yes',
    'end_halftime_result_both_teams_score_draw_yes',
    'end_halftime_result_both_teams_score_away_yes',
    'end_halftime_result_both_teams_score_home_no',
    'end_halftime_result_both_teams_score_draw_no',
    'end_halftime_result_both_teams_score_away_no',
    'pre_exact_goals_number_0',
    'pre_exact_goals_number_1',
    'pre_exact_goals_number_2',
    'pre_exact_goals_number_3',
    'pre_exact_goals_number_4',
    'pre_exact_goals_number_5',
    'pre_exact_goals_number_6',
    'pre_exact_goals_number_more_7',
    'end_exact_goals_number_0',
    'end_exact_goals_number_1',
    'end_exact_goals_number_2',
    'end_exact_goals_number_3',
    'end_exact_goals_number_4',
    'end_exact_goals_number_5',
    'end_exact_goals_number_6',
    'end_exact_goals_number_more_7',
    'pre_exact_goals_number__first_half_0',
    'pre_exact_goals_number__first_half_1',
    'pre_exact_goals_number__first_half_2',
    'pre_exact_goals_number__first_half_3',
    'pre_exact_goals_number__first_half_4',
    'pre_exact_goals_number__first_half_more_5',
    'end_exact_goals_number__first_half_0',
    'end_exact_goals_number__first_half_1',
    'end_exact_goals_number__first_half_2',
    'end_exact_goals_number__first_half_3',
    'end_exact_goals_number__first_half_4',
    'end_exact_goals_number__first_half_more_5',
    'pre_second_half_exact_goals_number_0',
    'pre_second_half_exact_goals_number_1',
    'pre_second_half_exact_goals_number_2',
    'pre_second_half_exact_goals_number_3',
    'pre_second_half_exact_goals_number_4',
    'pre_second_half_exact_goals_number_more_5',
    'end_second_half_exact_goals_number_0',
    'end_second_half_exact_goals_number_1',
    'end_second_half_exact_goals_number_2',
    'end_second_half_exact_goals_number_3',
    'end_second_half_exact_goals_number_4',
    'end_second_half_exact_goals_number_more_5',
    'pre_home_team_exact_goals_number_0',
    'pre_home_team_exact_goals_number_1',
    'pre_home_team_exact_goals_number_2',
    'pre_home_team_exact_goals_number_more_3',
    'end_home_team_exact_goals_number_0',
    'end_home_team_exact_goals_number_1',
    'end_home_team_exact_goals_number_2',
    'end_home_team_exact_goals_number_more_3',
    'pre_away_team_exact_goals_number_0',
    'pre_away_team_exact_goals_number_1',
    'pre_away_team_exact_goals_number_2',
    'pre_away_team_exact_goals_number_more_3',
    'end_away_team_exact_goals_number_0',
    'end_away_team_exact_goals_number_1',
    'end_away_team_exact_goals_number_2',
    'end_away_team_exact_goals_number_more_3',
    'pre_corners_winner_home',
    'pre_corners_winner_draw',
    'pre_corners_winner_away',
    'end_corners_winner_home',
    'end_corners_winner_draw',
    'end_corners_winner_away',
    'pre_10_overunder_over_05',
    'pre_10_overunder_under_05',
    'end_10_overunder_over_05',
    'end_10_overunder_under_05',
    'pre_cards_european_handicap_home_min_2',
    'pre_cards_european_handicap_draw_min_2',
    'pre_cards_european_handicap_away_min_2',
    'pre_cards_european_handicap_home_min_1',
    'pre_cards_european_handicap_draw_min_1',
    'pre_cards_european_handicap_away_min_1',
    'pre_cards_european_handicap_home_plus_0',
    'pre_cards_european_handicap_draw_plus_0',
    'pre_cards_european_handicap_away_plus_0',
    'pre_cards_european_handicap_home_plus_1',
    'pre_cards_european_handicap_draw_plus_1',
    'pre_cards_european_handicap_away_plus_1',
    'pre_cards_european_handicap_home_plus_2',
    'pre_cards_european_handicap_draw_plus_2',
    'pre_cards_european_handicap_away_plus_2',
    'end_cards_european_handicap_home_min_2',
    'end_cards_european_handicap_draw_min_2',
    'end_cards_european_handicap_away_min_2',
    'end_cards_european_handicap_home_min_1',
    'end_cards_european_handicap_draw_min_1',
    'end_cards_european_handicap_away_min_1',
    'end_cards_european_handicap_home_plus_0',
    'end_cards_european_handicap_draw_plus_0',
    'end_cards_european_handicap_away_plus_0',
    'end_cards_european_handicap_home_plus_1',
    'end_cards_european_handicap_draw_plus_1',
    'end_cards_european_handicap_away_plus_1',
    'end_cards_european_handicap_home_plus_2',
    'end_cards_european_handicap_draw_plus_2',
    'end_cards_european_handicap_away_plus_2',
    'pre_rcard_yes',
    'pre_rcard_no',
    'end_rcard_yes',
    'end_rcard_no',

    ]
# -----------------------------------------------------------------
for c in col:  
    # -----------------------------------------------------------------
    host="localhost"
    user="root"
    database="pr_mmbuzz_2022_06" 
    mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
    # -----------------------------------------------------------------
    query = ' select '
#     query += c 
    query += '  max(' + c + ') '  
    query += ' from football_fixtures '  
    query += ' where ' + c + ' is not null ' 
#     query += ' order by CHAR_LENGTH(' + c + ') desc ' 
#     query += ' limit 3 ' 
    # -----------------------------------------------------------------
    mycursor = mydb.cursor() 
    mycursor.execute(query)
    myresult = mycursor.fetchall()
    # -----------------------------------------------------------------
    print(c + " Total rows : " + str(len(myresult))) 
    # -----------------------------------------------------------------
    for x in myresult:  
        # -------------------------------------------------------------
        col = str(x[0])
#         col_length = str(x[1])
        # -------------------------------------------------------------
        print("  " + col ) 
        # ------------------------------------------------------------- 
    # ----------------------------------------------------------------- 
    print("")
    # -----------------------------------------------------------------
# Out:
# pre_match_winner_home Total rows : 1
#   126.0
#
# pre_match_winner_draw Total rows : 1
#   51.0
#
# pre_match_winner_away Total rows : 1
#   81.0
#
# end_match_winner_home Total rows : 1
#   91.0
#
# end_match_winner_draw Total rows : 1
#   51.0
#
# end_match_winner_away Total rows : 1
#   1000.0
#
# pre_homeaway_home Total rows : 1
#   41.0
#
# pre_homeaway_away Total rows : 1
#   41.0
#
# end_homeaway_home Total rows : 1
#   41.0
#
# end_homeaway_away Total rows : 1
#   51.0
#
# pre_first_half_winner_home Total rows : 1
#   67.0
#
# pre_first_half_winner_draw Total rows : 1
#   11.0
#
# pre_first_half_winner_away Total rows : 1
#   67.0
#
# end_first_half_winner_home Total rows : 1
#   67.0
#
# end_first_half_winner_draw Total rows : 1
#   11.0
#
# end_first_half_winner_away Total rows : 1
#   67.0
#
# pre_second_half_winner_home Total rows : 1
#   56.0
#
# pre_second_half_winner_draw Total rows : 1
#   17.0
#
# pre_second_half_winner_away Total rows : 1
#   59.0
#
# end_second_half_winner_home Total rows : 1
#   65.0
#
# end_second_half_winner_draw Total rows : 1
#   17.0
#
# end_second_half_winner_away Total rows : 1
#   56.0
#
# pre_asian_handicap_home_min_675 Total rows : 1
#   None
#
# pre_asian_handicap_away_min_675 Total rows : 1
#   None
#
# pre_asian_handicap_home_min_65 Total rows : 1
#   4.15
#
# pre_asian_handicap_away_min_65 Total rows : 1
#   1.22
#
# pre_asian_handicap_home_min_625 Total rows : 1
#   3.9
#
# pre_asian_handicap_away_min_625 Total rows : 1
#   1.26
#
# pre_asian_handicap_home_min_6 Total rows : 1
#   11.5
#
# pre_asian_handicap_away_min_6 Total rows : 1
#   1.26
#
# pre_asian_handicap_home_min_575 Total rows : 1
#   5.0
#
# pre_asian_handicap_away_min_575 Total rows : 1
#   2.05
#
# pre_asian_handicap_home_min_55 Total rows : 1
#   17.0
#
# pre_asian_handicap_away_min_55 Total rows : 1
#   2.2
#
# pre_asian_handicap_home_min_525 Total rows : 1
#   13.1
#
# pre_asian_handicap_away_min_525 Total rows : 1
#   2.42
#
# pre_asian_handicap_home_min_5 Total rows : 1
#   17.0
#
# pre_asian_handicap_away_min_5 Total rows : 1
#   2.75
#
# pre_asian_handicap_home_min_475 Total rows : 1
#   9.6
#
# pre_asian_handicap_away_min_475 Total rows : 1
#   3.1
#
# pre_asian_handicap_home_min_45 Total rows : 1
#   17.0
#
# pre_asian_handicap_away_min_45 Total rows : 1
#   3.3
#
# pre_asian_handicap_home_min_425 Total rows : 1
#   15.0
#
# pre_asian_handicap_away_min_425 Total rows : 1
#   3.9
#
# pre_asian_handicap_home_min_4 Total rows : 1
#   18.0
#
# pre_asian_handicap_away_min_4 Total rows : 1
#   5.0
#
# pre_asian_handicap_home_min_375 Total rows : 1
#   10.7
#
# pre_asian_handicap_away_min_375 Total rows : 1
#   5.25
#
# pre_asian_handicap_home_min_35 Total rows : 1
#   18.5
#
# pre_asian_handicap_away_min_35 Total rows : 1
#   10.5
#
# pre_asian_handicap_home_min_325 Total rows : 1
#   16.0
#
# pre_asian_handicap_away_min_325 Total rows : 1
#   5.5
#
# pre_asian_handicap_home_min_3 Total rows : 1
#   25.0
#
# pre_asian_handicap_away_min_3 Total rows : 1
#   9.8
#
# pre_asian_handicap_home_min_275 Total rows : 1
#   20.0
#
# pre_asian_handicap_away_min_275 Total rows : 1
#   6.8
#
# pre_asian_handicap_home_min_25 Total rows : 1
#   18.5
#
# pre_asian_handicap_away_min_25 Total rows : 1
#   9.0
#
# pre_asian_handicap_home_min_225 Total rows : 1
#   16.0
#
# pre_asian_handicap_away_min_225 Total rows : 1
#   7.0
#
# pre_asian_handicap_home_min_2 Total rows : 1
#   25.0
#
# pre_asian_handicap_away_min_2 Total rows : 1
#   7.9
#
# pre_asian_handicap_home_min_175 Total rows : 1
#   16.0
#
# pre_asian_handicap_away_min_175 Total rows : 1
#   7.0
#
# pre_asian_handicap_home_min_15 Total rows : 1
#   17.0
#
# pre_asian_handicap_away_min_15 Total rows : 1
#   11.0
#
# pre_asian_handicap_home_min_125 Total rows : 1
#   15.5
#
# pre_asian_handicap_away_min_125 Total rows : 1
#   7.0
#
# pre_asian_handicap_home_min_1 Total rows : 1
#   17.0
#
# pre_asian_handicap_away_min_1 Total rows : 1
#   8.9
#
# pre_asian_handicap_home_min_075 Total rows : 1
#   18.0
#
# pre_asian_handicap_away_min_075 Total rows : 1
#   8.3
#
# pre_asian_handicap_home_min_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_away_min_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_home_min_025 Total rows : 1
#   13.4
#
# pre_asian_handicap_away_min_025 Total rows : 1
#   11.5
#
# pre_asian_handicap_home_plus_0 Total rows : 1
#   41.0
#
# pre_asian_handicap_away_plus_0 Total rows : 1
#   51.0
#
# pre_asian_handicap_home_plus_025 Total rows : 1
#   8.3
#
# pre_asian_handicap_away_plus_025 Total rows : 1
#   13.5
#
# pre_asian_handicap_home_plus_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_away_plus_05 Total rows : 1
#   11.5
#
# pre_asian_handicap_home_plus_075 Total rows : 1
#   7.5
#
# pre_asian_handicap_away_plus_075 Total rows : 1
#   17.0
#
# pre_asian_handicap_home_plus_1 Total rows : 1
#   9.1
#
# pre_asian_handicap_away_plus_1 Total rows : 1
#   17.0
#
# pre_asian_handicap_home_plus_125 Total rows : 1
#   6.6
#
# pre_asian_handicap_away_plus_125 Total rows : 1
#   15.5
#
# pre_asian_handicap_home_plus_15 Total rows : 1
#   9.9
#
# pre_asian_handicap_away_plus_15 Total rows : 1
#   17.5
#
# pre_asian_handicap_home_plus_175 Total rows : 1
#   7.0
#
# pre_asian_handicap_away_plus_175 Total rows : 1
#   18.0
#
# pre_asian_handicap_home_plus_2 Total rows : 1
#   7.0
#
# pre_asian_handicap_away_plus_2 Total rows : 1
#   26.0
#
# pre_asian_handicap_home_plus_225 Total rows : 1
#   6.25
#
# pre_asian_handicap_away_plus_225 Total rows : 1
#   16.0
#
# pre_asian_handicap_home_plus_25 Total rows : 1
#   9.2
#
# pre_asian_handicap_away_plus_25 Total rows : 1
#   18.0
#
# pre_asian_handicap_home_plus_275 Total rows : 1
#   6.6
#
# pre_asian_handicap_away_plus_275 Total rows : 1
#   21.0
#
# pre_asian_handicap_home_plus_3 Total rows : 1
#   6.0
#
# pre_asian_handicap_away_plus_3 Total rows : 1
#   18.5
#
# pre_asian_handicap_home_plus_325 Total rows : 1
#   5.9
#
# pre_asian_handicap_away_plus_325 Total rows : 1
#   16.0
#
# pre_asian_handicap_home_plus_35 Total rows : 1
#   9.7
#
# pre_asian_handicap_away_plus_35 Total rows : 1
#   17.5
#
# pre_asian_handicap_home_plus_375 Total rows : 1
#   3.45
#
# pre_asian_handicap_away_plus_375 Total rows : 1
#   10.8
#
# pre_asian_handicap_home_plus_4 Total rows : 1
#   3.7
#
# pre_asian_handicap_away_plus_4 Total rows : 1
#   18.5
#
# pre_asian_handicap_home_plus_425 Total rows : 1
#   2.67
#
# pre_asian_handicap_away_plus_425 Total rows : 1
#   15.5
#
# pre_asian_handicap_home_plus_45 Total rows : 1
#   2.6
#
# pre_asian_handicap_away_plus_45 Total rows : 1
#   17.0
#
# pre_asian_handicap_home_plus_475 Total rows : 1
#   2.16
#
# pre_asian_handicap_away_plus_475 Total rows : 1
#   6.4
#
# pre_asian_handicap_home_plus_5 Total rows : 1
#   2.2
#
# pre_asian_handicap_away_plus_5 Total rows : 1
#   15.0
#
# pre_asian_handicap_home_plus_525 Total rows : 1
#   1.98
#
# pre_asian_handicap_away_plus_525 Total rows : 1
#   6.4
#
# pre_asian_handicap_home_plus_55 Total rows : 1
#   2.05
#
# pre_asian_handicap_away_plus_55 Total rows : 1
#   15.0
#
# pre_asian_handicap_home_plus_575 Total rows : 1
#   1.58
#
# pre_asian_handicap_away_plus_575 Total rows : 1
#   4.5
#
# pre_asian_handicap_home_plus_6 Total rows : 1
#   1.23
#
# pre_asian_handicap_away_plus_6 Total rows : 1
#   5.25
#
# pre_asian_handicap_home_plus_625 Total rows : 1
#   None
#
# pre_asian_handicap_away_plus_625 Total rows : 1
#   None
#
# pre_asian_handicap_home_plus_65 Total rows : 1
#   1.18
#
# pre_asian_handicap_away_plus_65 Total rows : 1
#   4.3
#
# pre_asian_handicap_home_plus_675 Total rows : 1
#   None
#
# pre_asian_handicap_away_plus_675 Total rows : 1
#   None
#
# end_asian_handicap_home_min_675 Total rows : 1
#   4.4
#
# end_asian_handicap_away_min_675 Total rows : 1
#   1.48
#
# end_asian_handicap_home_min_65 Total rows : 1
#   4.0
#
# end_asian_handicap_away_min_65 Total rows : 1
#   1.58
#
# end_asian_handicap_home_min_625 Total rows : 1
#   3.55
#
# end_asian_handicap_away_min_625 Total rows : 1
#   1.68
#
# end_asian_handicap_home_min_6 Total rows : 1
#   11.5
#
# end_asian_handicap_away_min_6 Total rows : 1
#   1.8
#
# end_asian_handicap_home_min_575 Total rows : 1
#   9.05
#
# end_asian_handicap_away_min_575 Total rows : 1
#   2.84
#
# end_asian_handicap_home_min_55 Total rows : 1
#   17.0
#
# end_asian_handicap_away_min_55 Total rows : 1
#   3.4
#
# end_asian_handicap_home_min_525 Total rows : 1
#   11.3
#
# end_asian_handicap_away_min_525 Total rows : 1
#   3.18
#
# end_asian_handicap_home_min_5 Total rows : 1
#   17.0
#
# end_asian_handicap_away_min_5 Total rows : 1
#   4.28
#
# end_asian_handicap_home_min_475 Total rows : 1
#   9.6
#
# end_asian_handicap_away_min_475 Total rows : 1
#   3.16
#
# end_asian_handicap_home_min_45 Total rows : 1
#   18.0
#
# end_asian_handicap_away_min_45 Total rows : 1
#   4.4
#
# end_asian_handicap_home_min_425 Total rows : 1
#   15.5
#
# end_asian_handicap_away_min_425 Total rows : 1
#   3.98
# end_asian_handicap_home_min_4 Total rows : 1
#   17.0
#
# end_asian_handicap_away_min_4 Total rows : 1
#   5.05
#
# end_asian_handicap_home_min_375 Total rows : 1
#   11.0
#
# end_asian_handicap_away_min_375 Total rows : 1
#   5.25
#
# end_asian_handicap_home_min_35 Total rows : 1
#   18.0
#
# end_asian_handicap_away_min_35 Total rows : 1
#   10.5
#
# end_asian_handicap_home_min_325 Total rows : 1
#   15.5
#
# end_asian_handicap_away_min_325 Total rows : 1
#   5.95
#
# end_asian_handicap_home_min_3 Total rows : 1
#   18.5
#
# end_asian_handicap_away_min_3 Total rows : 1
#   9.8
#
# end_asian_handicap_home_min_275 Total rows : 1
#   16.0
#
# end_asian_handicap_away_min_275 Total rows : 1
#   6.8
#
# end_asian_handicap_home_min_25 Total rows : 1
#   18.0
#
# end_asian_handicap_away_min_25 Total rows : 1
#   10.5
#
# end_asian_handicap_home_min_225 Total rows : 1
#   16.0
#
# end_asian_handicap_away_min_225 Total rows : 1
#   6.8
#
# end_asian_handicap_home_min_2 Total rows : 1
#   18.5
#
# end_asian_handicap_away_min_2 Total rows : 1
#   11.0
#
# end_asian_handicap_home_min_175 Total rows : 1
#   16.0
#
# end_asian_handicap_away_min_175 Total rows : 1
#   7.0
#
# end_asian_handicap_home_min_15 Total rows : 1
#   17.0
#
# end_asian_handicap_away_min_15 Total rows : 1
#   11.0
#
# end_asian_handicap_home_min_125 Total rows : 1
#   15.5
#
# end_asian_handicap_away_min_125 Total rows : 1
#   7.1
#
# end_asian_handicap_home_min_1 Total rows : 1
#   17.0
#
# end_asian_handicap_away_min_1 Total rows : 1
#   10.0
#
# end_asian_handicap_home_min_075 Total rows : 1
#   13.5
#
# end_asian_handicap_away_min_075 Total rows : 1
#   8.5
#
# end_asian_handicap_home_min_05 Total rows : 1
#   7.0
#
# end_asian_handicap_away_min_05 Total rows : 1
#   7.0
#
# end_asian_handicap_home_min_025 Total rows : 1
#   13.0
#
# end_asian_handicap_away_min_025 Total rows : 1
#   13.5
#
# end_asian_handicap_home_plus_0 Total rows : 1
#   41.0
#
# end_asian_handicap_away_plus_0 Total rows : 1
#   51.0
#
# end_asian_handicap_home_plus_025 Total rows : 1
#   11.0
#
# end_asian_handicap_away_plus_025 Total rows : 1
#   12.0
#
# end_asian_handicap_home_plus_05 Total rows : 1
#   7.0
#
# end_asian_handicap_away_plus_05 Total rows : 1
#   9.0
#
# end_asian_handicap_home_plus_075 Total rows : 1
#   8.4
#
# end_asian_handicap_away_plus_075 Total rows : 1
#   16.0
#
# end_asian_handicap_home_plus_1 Total rows : 1
#   10.0
#
# end_asian_handicap_away_plus_1 Total rows : 1
#   17.0
#
# end_asian_handicap_home_plus_125 Total rows : 1
#   7.0
#
# end_asian_handicap_away_plus_125 Total rows : 1
#   15.5
#
# end_asian_handicap_home_plus_15 Total rows : 1
#   9.9
#
# end_asian_handicap_away_plus_15 Total rows : 1
#   18.5
#
# end_asian_handicap_home_plus_175 Total rows : 1
#   8.4
#
# end_asian_handicap_away_plus_175 Total rows : 1
#   16.0
#
# end_asian_handicap_home_plus_2 Total rows : 1
#   11.5
#
# end_asian_handicap_away_plus_2 Total rows : 1
#   18.0
#
# end_asian_handicap_home_plus_225 Total rows : 1
#   6.4
#
# end_asian_handicap_away_plus_225 Total rows : 1
#   15.5
#
# end_asian_handicap_home_plus_25 Total rows : 1
#   12.5
#
# end_asian_handicap_away_plus_25 Total rows : 1
#   18.5
#
# end_asian_handicap_home_plus_275 Total rows : 1
#   6.6
#
# end_asian_handicap_away_plus_275 Total rows : 1
#   15.0
#
# end_asian_handicap_home_plus_3 Total rows : 1
#   6.7
#
# end_asian_handicap_away_plus_3 Total rows : 1
#   18.5
#
# end_asian_handicap_home_plus_325 Total rows : 1
#   5.9
#
# end_asian_handicap_away_plus_325 Total rows : 1
#   16.0
#
# end_asian_handicap_home_plus_35 Total rows : 1
#   9.7
#
# end_asian_handicap_away_plus_35 Total rows : 1
#   17.5
#
# end_asian_handicap_home_plus_375 Total rows : 1
#   4.25
#
# end_asian_handicap_away_plus_375 Total rows : 1
#   11.5
#
# end_asian_handicap_home_plus_4 Total rows : 1
#   4.84
#
# end_asian_handicap_away_plus_4 Total rows : 1
#   17.5
#
# end_asian_handicap_home_plus_425 Total rows : 1
#   3.3
#
# end_asian_handicap_away_plus_425 Total rows : 1
#   15.5
#
# end_asian_handicap_home_plus_45 Total rows : 1
#   3.28
#
# end_asian_handicap_away_plus_45 Total rows : 1
#   16.0
#
# end_asian_handicap_home_plus_475 Total rows : 1
#   3.08
#
# end_asian_handicap_away_plus_475 Total rows : 1
#   8.7
#
# end_asian_handicap_home_plus_5 Total rows : 1
#   2.89
#
# end_asian_handicap_away_plus_5 Total rows : 1
#   14.5
#
# end_asian_handicap_home_plus_525 Total rows : 1
#   2.47
#
# end_asian_handicap_away_plus_525 Total rows : 1
#   13.2
#
# end_asian_handicap_home_plus_55 Total rows : 1
#   2.31
#
# end_asian_handicap_away_plus_55 Total rows : 1
#   15.0
#
# end_asian_handicap_home_plus_575 Total rows : 1
#   2.08
#
# end_asian_handicap_away_plus_575 Total rows : 1
#   5.7
#
# end_asian_handicap_home_plus_6 Total rows : 1
#   2.0
#
# end_asian_handicap_away_plus_6 Total rows : 1
#   5.25
#
# end_asian_handicap_home_plus_625 Total rows : 1
#   None
#
# end_asian_handicap_away_plus_625 Total rows : 1
#   None
#
# end_asian_handicap_home_plus_65 Total rows : 1
#   1.18
#
# end_asian_handicap_away_plus_65 Total rows : 1
#   4.2
#
# end_asian_handicap_home_plus_675 Total rows : 1
#   None
#
# end_asian_handicap_away_plus_675 Total rows : 1
#   None
#
# pre_goals_overunder_over_05 Total rows : 1
#   21.0
#
# pre_goals_overunder_under_05 Total rows : 1
#   71.0
#
# pre_goals_overunder_over_075 Total rows : 1
#   1.32
#
# pre_goals_overunder_under_075 Total rows : 1
#   15.5
#
# pre_goals_overunder_over_10 Total rows : 1
#   1.43
#
# pre_goals_overunder_under_10 Total rows : 1
#   19.0
#
# pre_goals_overunder_over_125 Total rows : 1
#   1.76
#
# pre_goals_overunder_under_125 Total rows : 1
#   8.6
#
# pre_goals_overunder_over_15 Total rows : 1
#   8.0
#
# pre_goals_overunder_under_15 Total rows : 1
#   41.0
#
# pre_goals_overunder_over_175 Total rows : 1
#   2.34
#
# pre_goals_overunder_under_175 Total rows : 1
#   10.0
#
# pre_goals_overunder_over_20 Total rows : 1
#   3.14
#
# pre_goals_overunder_under_20 Total rows : 1
#   11.5
#
# pre_goals_overunder_over_225 Total rows : 1
#   3.56
#
# pre_goals_overunder_under_225 Total rows : 1
#   7.0
#
# pre_goals_overunder_over_25 Total rows : 1
#   4.04
#
# pre_goals_overunder_under_25 Total rows : 1
#   101.0
#
# pre_goals_overunder_over_275 Total rows : 1
#   5.2
#
# pre_goals_overunder_under_275 Total rows : 1
#   7.5
#
# pre_goals_overunder_over_30 Total rows : 1
#   7.8
#
# pre_goals_overunder_under_30 Total rows : 1
#   7.3
#
# pre_goals_overunder_over_325 Total rows : 1
#   8.3
#
# pre_goals_overunder_under_325 Total rows : 1
#   7.0
#
# pre_goals_overunder_over_35 Total rows : 1
#   9.0
#
# pre_goals_overunder_under_35 Total rows : 1
#   8.0
#
# pre_goals_overunder_over_375 Total rows : 1
#   10.0
#
# pre_goals_overunder_under_375 Total rows : 1
#   7.0
#
# pre_goals_overunder_over_40 Total rows : 1
#   11.5
#
# pre_goals_overunder_under_40 Total rows : 1
#   7.0
#
# pre_goals_overunder_over_425 Total rows : 1
#   12.5
#
# pre_goals_overunder_under_425 Total rows : 1
#   4.8
#
# pre_goals_overunder_over_45 Total rows : 1
#   21.0
#
# pre_goals_overunder_under_45 Total rows : 1
#   4.33
#
# pre_goals_overunder_over_475 Total rows : 1
#   16.0
#
# pre_goals_overunder_under_475 Total rows : 1
#   3.7
#
# pre_goals_overunder_over_50 Total rows : 1
#   19.0
#
# pre_goals_overunder_under_50 Total rows : 1
#   3.45
#
# pre_goals_overunder_over_525 Total rows : 1
#   20.0
#
# pre_goals_overunder_under_525 Total rows : 1
#   2.85
#
# pre_goals_overunder_over_55 Total rows : 1
#   67.0
#
# pre_goals_overunder_under_55 Total rows : 1
#   2.63
#
# pre_goals_overunder_over_575 Total rows : 1
#   15.0
#
# pre_goals_overunder_under_575 Total rows : 1
#   2.35
#
# pre_goals_overunder_over_60 Total rows : 1
#   18.5
#
# pre_goals_overunder_under_60 Total rows : 1
#   2.15
#
# pre_goals_overunder_over_625 Total rows : 1
#   16.0
#
# pre_goals_overunder_under_625 Total rows : 1
#   2.0
#
# pre_goals_overunder_over_65 Total rows : 1
#   61.0
#
# pre_goals_overunder_under_65 Total rows : 1
#   1.83
#
# pre_goals_overunder_over_675 Total rows : 1
#   7.0
#
# pre_goals_overunder_under_675 Total rows : 1
#   1.68
#
# pre_goals_overunder_over_70 Total rows : 1
#   9.5
#
# pre_goals_overunder_under_70 Total rows : 1
#   1.55
#
# pre_goals_overunder_over_75 Total rows : 1
#   51.0
#
# pre_goals_overunder_under_75 Total rows : 1
#   1.44
#
# pre_goals_overunder_over_85 Total rows : 1
#   51.0
#
# pre_goals_overunder_under_85 Total rows : 1
#   1.25
#
# pre_goals_overunder_over_95 Total rows : 1
#   51.0
#
# pre_goals_overunder_under_95 Total rows : 1
#   1.13
#
# end_goals_overunder_over_05 Total rows : 1
#   21.0
#
# end_goals_overunder_under_05 Total rows : 1
#   71.0
#
# end_goals_overunder_over_075 Total rows : 1
#   1.32
#
# end_goals_overunder_under_075 Total rows : 1
#   15.5
#
# end_goals_overunder_over_10 Total rows : 1
#   1.43
#
# end_goals_overunder_under_10 Total rows : 1
#   21.0
# end_goals_overunder_over_125 Total rows : 1
#   1.76
#
# end_goals_overunder_under_125 Total rows : 1
#   8.7
#
# end_goals_overunder_over_15 Total rows : 1
#   13.0
#
# end_goals_overunder_under_15 Total rows : 1
#   41.0
#
# end_goals_overunder_over_175 Total rows : 1
#   2.4
#
# end_goals_overunder_under_175 Total rows : 1
#   9.9
#
# end_goals_overunder_over_20 Total rows : 1
#   3.26
#
# end_goals_overunder_under_20 Total rows : 1
#   11.5
#
# end_goals_overunder_over_225 Total rows : 1
#   3.66
#
# end_goals_overunder_under_225 Total rows : 1
#   7.0
#
# end_goals_overunder_over_25 Total rows : 1
#   4.2
#
# end_goals_overunder_under_25 Total rows : 1
#   101.0
#
# end_goals_overunder_over_275 Total rows : 1
#   5.5
#
# end_goals_overunder_under_275 Total rows : 1
#   7.8
#
# end_goals_overunder_over_30 Total rows : 1
#   8.5
#
# end_goals_overunder_under_30 Total rows : 1
#   11.0
#
# end_goals_overunder_over_325 Total rows : 1
#   9.0
#
# end_goals_overunder_under_325 Total rows : 1
#   7.0
#
# end_goals_overunder_over_35 Total rows : 1
#   21.0
#
# end_goals_overunder_under_35 Total rows : 1
#   13.0
#
# end_goals_overunder_over_375 Total rows : 1
#   13.0
#
# end_goals_overunder_under_375 Total rows : 1
#   6.4
#
# end_goals_overunder_over_40 Total rows : 1
#   14.0
#
# end_goals_overunder_under_40 Total rows : 1
#   11.5
#
# end_goals_overunder_over_425 Total rows : 1
#   12.3
#
# end_goals_overunder_under_425 Total rows : 1
#   4.98
#
# end_goals_overunder_over_45 Total rows : 1
#   23.0
#
# end_goals_overunder_under_45 Total rows : 1
#   15.0
#
# end_goals_overunder_over_475 Total rows : 1
#   16.0
#
# end_goals_overunder_under_475 Total rows : 1
#   5.7
#
# end_goals_overunder_over_50 Total rows : 1
#   19.0
#
# end_goals_overunder_under_50 Total rows : 1
#   7.0
#
# end_goals_overunder_over_525 Total rows : 1
#   15.5
#
# end_goals_overunder_under_525 Total rows : 1
#   5.15
#
# end_goals_overunder_over_55 Total rows : 1
#   67.0
#
# end_goals_overunder_under_55 Total rows : 1
#   10.0
#
# end_goals_overunder_over_575 Total rows : 1
#   15.0
#
# end_goals_overunder_under_575 Total rows : 1
#   4.48
#
# end_goals_overunder_over_60 Total rows : 1
#   18.5
#
# end_goals_overunder_under_60 Total rows : 1
#   4.1
#
# end_goals_overunder_over_625 Total rows : 1
#   15.5
#
# end_goals_overunder_under_625 Total rows : 1
#   3.44
#
# end_goals_overunder_over_65 Total rows : 1
#   81.0
#
# end_goals_overunder_under_65 Total rows : 1
#   3.1
#
# end_goals_overunder_over_675 Total rows : 1
#   9.4
#
# end_goals_overunder_under_675 Total rows : 1
#   2.89
#
# end_goals_overunder_over_70 Total rows : 1
#   9.5
#
# end_goals_overunder_under_70 Total rows : 1
#   2.75
#
# end_goals_overunder_over_75 Total rows : 1
#   51.0
#
# end_goals_overunder_under_75 Total rows : 1
#   2.19
#
# end_goals_overunder_over_85 Total rows : 1
#   51.0
#
# end_goals_overunder_under_85 Total rows : 1
#   1.74
#
# end_goals_overunder_over_95 Total rows : 1
#   51.0
#
# end_goals_overunder_under_95 Total rows : 1
#   41.0
#
# pre_asian_handicap_first_half_home_min_175 Total rows : 1
#   7.1
#
# pre_asian_handicap_first_half_away_min_175 Total rows : 1
#   2.08
#
# pre_asian_handicap_first_half_home_min_15 Total rows : 1
#   15.0
#
# pre_asian_handicap_first_half_away_min_15 Total rows : 1
#   2.35
#
# pre_asian_handicap_first_half_home_min_125 Total rows : 1
#   13.3
#
# pre_asian_handicap_first_half_away_min_125 Total rows : 1
#   3.0
#
# pre_asian_handicap_first_half_home_min_1 Total rows : 1
#   14.5
#
# pre_asian_handicap_first_half_away_min_1 Total rows : 1
#   4.4
#
# pre_asian_handicap_first_half_home_min_075 Total rows : 1
#   8.3
#
# pre_asian_handicap_first_half_away_min_075 Total rows : 1
#   5.25
#
# pre_asian_handicap_first_half_home_min_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_first_half_away_min_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_first_half_home_min_025 Total rows : 1
#   9.25
#
# pre_asian_handicap_first_half_away_min_025 Total rows : 1
#   7.0
#
# pre_asian_handicap_first_half_home_plus_0 Total rows : 1
#   7.7
#
# pre_asian_handicap_first_half_away_plus_0 Total rows : 1
#   11.0
#
# pre_asian_handicap_first_half_home_plus_025 Total rows : 1
#   6.6
#
# pre_asian_handicap_first_half_away_plus_025 Total rows : 1
#   7.17
#
# pre_asian_handicap_first_half_home_plus_05 Total rows : 1
#   4.4
#
# pre_asian_handicap_first_half_away_plus_05 Total rows : 1
#   7.0
#
# pre_asian_handicap_first_half_home_plus_075 Total rows : 1
#   3.9
#
# pre_asian_handicap_first_half_away_plus_075 Total rows : 1
#   8.7
#
# pre_asian_handicap_first_half_home_plus_1 Total rows : 1
#   3.45
#
# pre_asian_handicap_first_half_away_plus_1 Total rows : 1
#   15.0
#
# pre_asian_handicap_first_half_home_plus_125 Total rows : 1
#   3.55
#
# pre_asian_handicap_first_half_away_plus_125 Total rows : 1
#   13.0
#
# pre_asian_handicap_first_half_home_plus_15 Total rows : 1
#   4.1
#
# pre_asian_handicap_first_half_away_plus_15 Total rows : 1
#   15.0
#
# pre_asian_handicap_first_half_home_plus_175 Total rows : 1
#   5.75
#
# pre_asian_handicap_first_half_away_plus_175 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_home_min_175 Total rows : 1
#   9.0
#
# end_asian_handicap_first_half_away_min_175 Total rows : 1
#   3.1
#
# end_asian_handicap_first_half_home_min_15 Total rows : 1
#   15.0
#
# end_asian_handicap_first_half_away_min_15 Total rows : 1
#   5.9
#
# end_asian_handicap_first_half_home_min_125 Total rows : 1
#   13.3
#
# end_asian_handicap_first_half_away_min_125 Total rows : 1
#   5.3
#
# end_asian_handicap_first_half_home_min_1 Total rows : 1
#   15.0
#
# end_asian_handicap_first_half_away_min_1 Total rows : 1
#   6.8
#
# end_asian_handicap_first_half_home_min_075 Total rows : 1
#   9.8
#
# end_asian_handicap_first_half_away_min_075 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_home_min_05 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_away_min_05 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_home_min_025 Total rows : 1
#   11.0
#
# end_asian_handicap_first_half_away_min_025 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_home_plus_0 Total rows : 1
#   9.1
#
# end_asian_handicap_first_half_away_plus_0 Total rows : 1
#   10.0
#
# end_asian_handicap_first_half_home_plus_025 Total rows : 1
#   6.25
#
# end_asian_handicap_first_half_away_plus_025 Total rows : 1
#   7.8
#
# end_asian_handicap_first_half_home_plus_05 Total rows : 1
#   4.15
#
# end_asian_handicap_first_half_away_plus_05 Total rows : 1
#   7.0
#
# end_asian_handicap_first_half_home_plus_075 Total rows : 1
#   4.56
#
# end_asian_handicap_first_half_away_plus_075 Total rows : 1
#   10.0
#
# end_asian_handicap_first_half_home_plus_1 Total rows : 1
#   4.1
#
# end_asian_handicap_first_half_away_plus_1 Total rows : 1
#   15.0
#
# end_asian_handicap_first_half_home_plus_125 Total rows : 1
#   3.55
#
# end_asian_handicap_first_half_away_plus_125 Total rows : 1
#   13.3
#
# end_asian_handicap_first_half_home_plus_15 Total rows : 1
#   4.1
#
# end_asian_handicap_first_half_away_plus_15 Total rows : 1
#   15.0
#
# end_asian_handicap_first_half_home_plus_175 Total rows : 1
#   5.75
#
# end_asian_handicap_first_half_away_plus_175 Total rows : 1
#   7.6
#
# pre_goals_overunder_first_half_over_05 Total rows : 1
#   1.99
#
# pre_goals_overunder_first_half_under_05 Total rows : 1
#   15.0
#
# pre_goals_overunder_first_half_over_075 Total rows : 1
#   2.47
#
# pre_goals_overunder_first_half_under_075 Total rows : 1
#   7.0
#
# pre_goals_overunder_first_half_over_10 Total rows : 1
#   3.84
#
# pre_goals_overunder_first_half_under_10 Total rows : 1
#   7.0
#
# pre_goals_overunder_first_half_over_125 Total rows : 1
#   4.68
#
# pre_goals_overunder_first_half_under_125 Total rows : 1
#   5.9
#
# pre_goals_overunder_first_half_over_15 Total rows : 1
#   5.5
#
# pre_goals_overunder_first_half_under_15 Total rows : 1
#   4.33
#
# pre_goals_overunder_first_half_over_175 Total rows : 1
#   7.6
#
# pre_goals_overunder_first_half_under_175 Total rows : 1
#   3.7
#
# pre_goals_overunder_first_half_over_20 Total rows : 1
#   12.0
#
# pre_goals_overunder_first_half_under_20 Total rows : 1
#   3.3
#
# pre_goals_overunder_first_half_over_225 Total rows : 1
#   11.5
#
# pre_goals_overunder_first_half_under_225 Total rows : 1
#   2.42
#
# pre_goals_overunder_first_half_over_25 Total rows : 1
#   19.0
#
# pre_goals_overunder_first_half_under_25 Total rows : 1
#   2.2
#
# pre_goals_overunder_first_half_over_275 Total rows : 1
#   16.0
#
# pre_goals_overunder_first_half_under_275 Total rows : 1
#   1.97
#
# pre_goals_overunder_first_half_over_30 Total rows : 1
#   18.5
#
# pre_goals_overunder_first_half_under_30 Total rows : 1
#   1.65
#
# pre_goals_overunder_first_half_over_325 Total rows : 1
#   15.5
#
# pre_goals_overunder_first_half_under_325 Total rows : 1
#   1.87
# pre_goals_overunder_first_half_over_35 Total rows : 1
#   81.0
#
# pre_goals_overunder_first_half_under_35 Total rows : 1
#   1.44
#
# pre_goals_overunder_first_half_over_375 Total rows : 1
#   7.0
#
# pre_goals_overunder_first_half_under_375 Total rows : 1
#   1.32
#
# end_goals_overunder_first_half_over_05 Total rows : 1
#   1.99
#
# end_goals_overunder_first_half_under_05 Total rows : 1
#   15.0
#
# end_goals_overunder_first_half_over_075 Total rows : 1
#   2.47
#
# end_goals_overunder_first_half_under_075 Total rows : 1
#   7.0
#
# end_goals_overunder_first_half_over_10 Total rows : 1
#   4.1
#
# end_goals_overunder_first_half_under_10 Total rows : 1
#   7.1
#
# end_goals_overunder_first_half_over_125 Total rows : 1
#   5.25
#
# end_goals_overunder_first_half_under_125 Total rows : 1
#   5.5
#
# end_goals_overunder_first_half_over_15 Total rows : 1
#   6.5
#
# end_goals_overunder_first_half_under_15 Total rows : 1
#   5.6
#
# end_goals_overunder_first_half_over_175 Total rows : 1
#   7.7
#
# end_goals_overunder_first_half_under_175 Total rows : 1
#   3.45
#
# end_goals_overunder_first_half_over_20 Total rows : 1
#   13.5
#
# end_goals_overunder_first_half_under_20 Total rows : 1
#   3.1
#
# end_goals_overunder_first_half_over_225 Total rows : 1
#   13.0
#
# end_goals_overunder_first_half_under_225 Total rows : 1
#   2.62
#
# end_goals_overunder_first_half_over_25 Total rows : 1
#   23.0
#
# end_goals_overunder_first_half_under_25 Total rows : 1
#   3.1
#
# end_goals_overunder_first_half_over_275 Total rows : 1
#   16.0
#
# end_goals_overunder_first_half_under_275 Total rows : 1
#   2.24
#
# end_goals_overunder_first_half_over_30 Total rows : 1
#   18.5
#
# end_goals_overunder_first_half_under_30 Total rows : 1
#   2.1
#
# end_goals_overunder_first_half_over_325 Total rows : 1
#   15.5
#
# end_goals_overunder_first_half_under_325 Total rows : 1
#   1.87
#
# end_goals_overunder_first_half_over_35 Total rows : 1
#   81.0
#
# end_goals_overunder_first_half_under_35 Total rows : 1
#   1.81
#
# end_goals_overunder_first_half_over_375 Total rows : 1
#   7.0
#
# end_goals_overunder_first_half_under_375 Total rows : 1
#   1.52
#
# pre_goals_overunder__second_half_over_05 Total rows : 1
#   1.62
#
# pre_goals_overunder__second_half_under_05 Total rows : 1
#   23.0
#
# pre_goals_overunder__second_half_over_075 Total rows : 1
#   1.9
#
# pre_goals_overunder__second_half_under_075 Total rows : 1
#   8.2
#
# pre_goals_overunder__second_half_over_10 Total rows : 1
#   2.59
#
# pre_goals_overunder__second_half_under_10 Total rows : 1
#   7.1
#
# pre_goals_overunder__second_half_over_125 Total rows : 1
#   3.2
#
# pre_goals_overunder__second_half_under_125 Total rows : 1
#   3.94
#
# pre_goals_overunder__second_half_over_15 Total rows : 1
#   3.82
#
# pre_goals_overunder__second_half_under_15 Total rows : 1
#   7.0
#
# pre_goals_overunder__second_half_over_175 Total rows : 1
#   5.15
#
# pre_goals_overunder__second_half_under_175 Total rows : 1
#   2.84
#
# pre_goals_overunder__second_half_over_20 Total rows : 1
#   9.2
#
# pre_goals_overunder__second_half_under_20 Total rows : 1
#   3.2
#
# pre_goals_overunder__second_half_over_225 Total rows : 1
#   9.8
#
# pre_goals_overunder__second_half_under_225 Total rows : 1
#   2.74
#
# pre_goals_overunder__second_half_over_25 Total rows : 1
#   11.0
#
# pre_goals_overunder__second_half_under_25 Total rows : 1
#   3.25
#
# pre_goals_overunder__second_half_over_275 Total rows : 1
#   9.35
#
# pre_goals_overunder__second_half_under_275 Total rows : 1
#   2.37
#
# pre_goals_overunder__second_half_over_30 Total rows : 1
#   18.5
#
# pre_goals_overunder__second_half_under_30 Total rows : 1
#   2.46
#
# pre_goals_overunder__second_half_over_325 Total rows : 1
#   16.0
#
# pre_goals_overunder__second_half_under_325 Total rows : 1
#   2.06
#
# pre_goals_overunder__second_half_over_35 Total rows : 1
#   41.0
#
# pre_goals_overunder__second_half_under_35 Total rows : 1
#   1.85
#
# pre_goals_overunder__second_half_over_375 Total rows : 1
#   9.25
#
# pre_goals_overunder__second_half_under_375 Total rows : 1
#   1.68
#
# end_goals_overunder__second_half_over_05 Total rows : 1
#   1.62
#
# end_goals_overunder__second_half_under_05 Total rows : 1
#   23.0
#
# end_goals_overunder__second_half_over_075 Total rows : 1
#   1.9
#
# end_goals_overunder__second_half_under_075 Total rows : 1
#   8.9
#
# end_goals_overunder__second_half_over_10 Total rows : 1
#   2.64
#
# end_goals_overunder__second_half_under_10 Total rows : 1
#   7.1
#
# end_goals_overunder__second_half_over_125 Total rows : 1
#   3.32
#
# end_goals_overunder__second_half_under_125 Total rows : 1
#   3.94
#
# end_goals_overunder__second_half_over_15 Total rows : 1
#   3.98
#
# end_goals_overunder__second_half_under_15 Total rows : 1
#   7.0
#
# end_goals_overunder__second_half_over_175 Total rows : 1
#   5.4
#
# end_goals_overunder__second_half_under_175 Total rows : 1
#   2.9
#
# end_goals_overunder__second_half_over_20 Total rows : 1
#   9.8
#
# end_goals_overunder__second_half_under_20 Total rows : 1
#   3.2
#
# end_goals_overunder__second_half_over_225 Total rows : 1
#   9.8
#
# end_goals_overunder__second_half_under_225 Total rows : 1
#   2.69
#
# end_goals_overunder__second_half_over_25 Total rows : 1
#   13.0
#
# end_goals_overunder__second_half_under_25 Total rows : 1
#   4.3
#
# end_goals_overunder__second_half_over_275 Total rows : 1
#   9.05
#
# end_goals_overunder__second_half_under_275 Total rows : 1
#   2.47
#
# end_goals_overunder__second_half_over_30 Total rows : 1
#   17.0
#
# end_goals_overunder__second_half_under_30 Total rows : 1
#   2.81
#
# end_goals_overunder__second_half_over_325 Total rows : 1
#   15.5
#
# end_goals_overunder__second_half_under_325 Total rows : 1
#   2.34
#
# end_goals_overunder__second_half_over_35 Total rows : 1
#   41.0
#
# end_goals_overunder__second_half_under_35 Total rows : 1
#   2.85
#
# end_goals_overunder__second_half_over_375 Total rows : 1
#   10.3
#
# end_goals_overunder__second_half_under_375 Total rows : 1
#   2.15
#
# pre_htft_double_home_home Total rows : 1
#   151.0
#
# pre_htft_double_home_draw Total rows : 1
#   81.0
#
# pre_htft_double_home_away Total rows : 1
#   201.0
#
# pre_htft_double_draw_home Total rows : 1
#   126.0
#
# pre_htft_double_draw_draw Total rows : 1
#   41.0
#
# pre_htft_double_draw_away Total rows : 1
#   81.0
#
# pre_htft_double_away_home Total rows : 1
#   201.0
#
# pre_htft_double_away_draw Total rows : 1
#   51.0
#
# pre_htft_double_away_away Total rows : 1
#   81.0
#
# end_htft_double_home_home Total rows : 1
#   151.0
#
# end_htft_double_home_draw Total rows : 1
#   81.0
#
# end_htft_double_home_away Total rows : 1
#   201.0
#
# end_htft_double_draw_home Total rows : 1
#   126.0
#
# end_htft_double_draw_draw Total rows : 1
#   51.0
#
# end_htft_double_draw_away Total rows : 1
#   101.0
#
# end_htft_double_away_home Total rows : 1
#   201.0
#
# end_htft_double_away_draw Total rows : 1
#   81.0
#
# end_htft_double_away_away Total rows : 1
#   151.0
#
# pre_both_teams_score_yes Total rows : 1
#   5.5
#
# pre_both_teams_score_no Total rows : 1
#   7.6
#
# end_both_teams_score_yes Total rows : 1
#   6.0
#
# end_both_teams_score_no Total rows : 1
#   7.6
#
# pre_both_teams_score__first_half_yes Total rows : 1
#   10.0
#
# pre_both_teams_score__first_half_no Total rows : 1
#   1.61
#
# end_both_teams_score__first_half_yes Total rows : 1
#   11.5
#
# end_both_teams_score__first_half_no Total rows : 1
#   1.74
#
# pre_both_teams_to_score__second_half_yes Total rows : 1
#   8.0
#
# pre_both_teams_to_score__second_half_no Total rows : 1
#   1.94
#
# end_both_teams_to_score__second_half_yes Total rows : 1
#   9.0
#
# end_both_teams_to_score__second_half_no Total rows : 1
#   2.0
#
# pre_results_both_teams_score_home_yes Total rows : 1
#   126.0
#
# pre_results_both_teams_score_draw_yes Total rows : 1
#   67.0
#
# pre_results_both_teams_score_away_yes Total rows : 1
#   126.0
#
# pre_results_both_teams_score_home_no Total rows : 1
#   451.0
#
# pre_results_both_teams_score_draw_no Total rows : 1
#   67.0
#
# pre_results_both_teams_score_away_no Total rows : 1
#   501.0
#
# end_results_both_teams_score_home_yes Total rows : 1
#   126.0
#
# end_results_both_teams_score_draw_yes Total rows : 1
#   67.0
#
# end_results_both_teams_score_away_yes Total rows : 1
#   151.0
#
# end_results_both_teams_score_home_no Total rows : 1
#   451.0
#
# end_results_both_teams_score_draw_no Total rows : 1
#   51.0
#
# end_results_both_teams_score_away_no Total rows : 1
#   401.0
#
# pre_to_score_in_both_halves_by_teams_home Total rows : 1
#   34.0
#
# pre_to_score_in_both_halves_by_teams_away Total rows : 1
#   26.0
#
# end_to_score_in_both_halves_by_teams_home Total rows : 1
#   41.0
#
# end_to_score_in_both_halves_by_teams_away Total rows : 1
#   51.0
#
# pre_total_goals_both_teams_to_score_over_yes_25 Total rows : 1
#   5.0
# pre_total_goals_both_teams_to_score_over_no_25 Total rows : 1
#   15.0
#
# pre_total_goals_both_teams_to_score_under_yes_25 Total rows : 1
#   126.0
#
# pre_total_goals_both_teams_to_score_under_no_25 Total rows : 1
#   19.0
#
# end_total_goals_both_teams_to_score_over_yes_25 Total rows : 1
#   7.0
#
# end_total_goals_both_teams_to_score_over_no_25 Total rows : 1
#   17.0
#
# end_total_goals_both_teams_to_score_under_yes_25 Total rows : 1
#   126.0
#
# end_total_goals_both_teams_to_score_under_no_25 Total rows : 1
#   19.0
#
# pre_both_teams_to_score_1st_half__2nd_half_yes_yes Total rows : 1
#   41.0
#
# pre_both_teams_to_score_1st_half__2nd_half_yes_no Total rows : 1
#   9.0
#
# pre_both_teams_to_score_1st_half__2nd_half_no_yes Total rows : 1
#   7.5
#
# pre_both_teams_to_score_1st_half__2nd_half_no_no Total rows : 1
#   2.4
#
# end_both_teams_to_score_1st_half__2nd_half_yes_yes Total rows : 1
#   51.0
#
# end_both_teams_to_score_1st_half__2nd_half_yes_no Total rows : 1
#   11.0
#
# end_both_teams_to_score_1st_half__2nd_half_no_yes Total rows : 1
#   8.0
#
# end_both_teams_to_score_1st_half__2nd_half_no_no Total rows : 1
#   2.6
#
# pre_highest_scoring_half_first Total rows : 1
#   3.75
#
# pre_highest_scoring_half_draw Total rows : 1
#   5.6
#
# pre_highest_scoring_half_second Total rows : 1
#   2.62
#
# end_highest_scoring_half_first Total rows : 1
#   4.0
#
# end_highest_scoring_half_draw Total rows : 1
#   5.6
#
# end_highest_scoring_half_second Total rows : 1
#   2.48
#
# pre_double_chance_home_draw Total rows : 1
#   41.0
#
# pre_double_chance_home_away Total rows : 1
#   2.04
#
# pre_double_chance_draw_away Total rows : 1
#   51.0
#
# end_double_chance_home_draw Total rows : 1
#   41.0
#
# end_double_chance_home_away Total rows : 1
#   1.61
#
# end_double_chance_draw_away Total rows : 1
#   51.0
#
# pre_double_chance__first_half_home_draw Total rows : 1
#   9.0
#
# pre_double_chance__first_half_home_away Total rows : 1
#   1.93
#
# pre_double_chance__first_half_draw_away Total rows : 1
#   6.8
#
# end_double_chance__first_half_home_draw Total rows : 1
#   10.0
#
# end_double_chance__first_half_home_away Total rows : 1
#   2.25
#
# end_double_chance__first_half_draw_away Total rows : 1
#   9.0
#
# pre_oddeven_odd Total rows : 1
#   2.05
#
# pre_oddeven_even Total rows : 1
#   1.94
#
# end_oddeven_odd Total rows : 1
#   2.21
#
# end_oddeven_even Total rows : 1
#   2.0
#
# pre_result_total_goals_home_over_35 Total rows : 1
#   201.0
#
# pre_result_total_goals_draw_over_35 Total rows : 1
#   67.0
#
# pre_result_total_goals_away_over_35 Total rows : 1
#   251.0
#
# pre_result_total_goals_home_under_35 Total rows : 1
#   51.0
#
# pre_result_total_goals_draw_under_35 Total rows : 1
#   19.0
#
# pre_result_total_goals_away_under_35 Total rows : 1
#   41.0
#
# pre_result_total_goals_home_over_25 Total rows : 1
#   81.0
#
# pre_result_total_goals_draw_over_25 Total rows : 1
#   51.0
#
# pre_result_total_goals_away_over_25 Total rows : 1
#   51.0
#
# pre_result_total_goals_home_under_25 Total rows : 1
#   51.0
#
# pre_result_total_goals_draw_under_25 Total rows : 1
#   12.5
#
# pre_result_total_goals_away_under_25 Total rows : 1
#   41.0
#
# end_result_total_goals_home_over_35 Total rows : 1
#   251.0
#
# end_result_total_goals_draw_over_35 Total rows : 1
#   81.0
#
# end_result_total_goals_away_over_35 Total rows : 1
#   251.0
#
# end_result_total_goals_home_under_35 Total rows : 1
#   51.0
#
# end_result_total_goals_draw_under_35 Total rows : 1
#   21.0
#
# end_result_total_goals_away_under_35 Total rows : 1
#   41.0
#
# end_result_total_goals_home_over_25 Total rows : 1
#   81.0
#
# end_result_total_goals_draw_over_25 Total rows : 1
#   81.0
#
# end_result_total_goals_away_over_25 Total rows : 1
#   81.0
#
# end_result_total_goals_home_under_25 Total rows : 1
#   51.0
#
# end_result_total_goals_draw_under_25 Total rows : 1
#   13.0
#
# end_result_total_goals_away_under_25 Total rows : 1
#   41.0
#
# pre_clean_sheet__home_yes Total rows : 1
#   51.0
#
# pre_clean_sheet__home_no Total rows : 1
#   5.0
#
# end_clean_sheet__home_yes Total rows : 1
#   51.0
#
# end_clean_sheet__home_no Total rows : 1
#   5.5
#
# pre_clean_sheet__away_yes Total rows : 1
#   41.0
#
# pre_clean_sheet__away_no Total rows : 1
#   4.33
#
# end_clean_sheet__away_yes Total rows : 1
#   41.0
#
# end_clean_sheet__away_no Total rows : 1
#   4.0
#
# pre_win_both_halves_home Total rows : 1
#   101.0
#
# pre_win_both_halves_away Total rows : 1
#   101.0
#
# end_win_both_halves_home Total rows : 1
#   101.0
#
# end_win_both_halves_away Total rows : 1
#   101.0
#
# pre_win_to_nil_home Total rows : 1
#   101.0
#
# pre_win_to_nil_away Total rows : 1
#   101.0
#
# end_win_to_nil_home Total rows : 1
#   101.0
#
# end_win_to_nil_away Total rows : 1
#   101.0
#
# pre_to_win_either_half_home Total rows : 1
#   29.0
#
# pre_to_win_either_half_away Total rows : 1
#   51.0
#
# end_to_win_either_half_home Total rows : 1
#   29.0
#
# end_to_win_either_half_away Total rows : 1
#   51.0
#
# pre_halftime_result_both_teams_score_home_yes Total rows : 1
#   81.0
#
# pre_halftime_result_both_teams_score_draw_yes Total rows : 1
#   17.0
#
# pre_halftime_result_both_teams_score_away_yes Total rows : 1
#   81.0
#
# pre_halftime_result_both_teams_score_home_no Total rows : 1
#   23.0
#
# pre_halftime_result_both_teams_score_draw_no Total rows : 1
#   8.0
#
# pre_halftime_result_both_teams_score_away_no Total rows : 1
#   26.0
#
# end_halftime_result_both_teams_score_home_yes Total rows : 1
#   126.0
#
# end_halftime_result_both_teams_score_draw_yes Total rows : 1
#   29.0
#
# end_halftime_result_both_teams_score_away_yes Total rows : 1
#   201.0
#
# end_halftime_result_both_teams_score_home_no Total rows : 1
#   34.0
#
# end_halftime_result_both_teams_score_draw_no Total rows : 1
#   13.0
#
# end_halftime_result_both_teams_score_away_no Total rows : 1
#   67.0
#
# pre_exact_goals_number_0 Total rows : 1
#   34.0
#
# pre_exact_goals_number_1 Total rows : 1
#   23.0
#
# pre_exact_goals_number_2 Total rows : 1
#   10.0
#
# pre_exact_goals_number_3 Total rows : 1
#   6.5
#
# pre_exact_goals_number_4 Total rows : 1
#   11.0
#
# pre_exact_goals_number_5 Total rows : 1
#   23.0
#
# pre_exact_goals_number_6 Total rows : 1
#   51.0
#
# pre_exact_goals_number_more_7 Total rows : 1
#   101.0
#
# end_exact_goals_number_0 Total rows : 1
#   34.0
#
# end_exact_goals_number_1 Total rows : 1
#   26.0
#
# end_exact_goals_number_2 Total rows : 1
#   11.0
#
# end_exact_goals_number_3 Total rows : 1
#   6.5
#
# end_exact_goals_number_4 Total rows : 1
#   12.0
#
# end_exact_goals_number_5 Total rows : 1
#   29.0
#
# end_exact_goals_number_6 Total rows : 1
#   51.0
#
# end_exact_goals_number_more_7 Total rows : 1
#   126.0
#
# pre_exact_goals_number__first_half_0 Total rows : 1
#   8.0
#
# pre_exact_goals_number__first_half_1 Total rows : 1
#   4.33
#
# pre_exact_goals_number__first_half_2 Total rows : 1
#   6.0
#
# pre_exact_goals_number__first_half_3 Total rows : 1
#   19.0
#
# pre_exact_goals_number__first_half_4 Total rows : 1
#   51.0
#
# pre_exact_goals_number__first_half_more_5 Total rows : 1
#   151.0
#
# end_exact_goals_number__first_half_0 Total rows : 1
#   8.0
#
# end_exact_goals_number__first_half_1 Total rows : 1
#   4.75
#
# end_exact_goals_number__first_half_2 Total rows : 1
#   6.5
#
# end_exact_goals_number__first_half_3 Total rows : 1
#   21.0
#
# end_exact_goals_number__first_half_4 Total rows : 1
#   67.0
#
# end_exact_goals_number__first_half_more_5 Total rows : 1
#   201.0
#
# pre_second_half_exact_goals_number_0 Total rows : 1
#   13.0
#
# pre_second_half_exact_goals_number_1 Total rows : 1
#   5.5
#
# pre_second_half_exact_goals_number_2 Total rows : 1
#   4.5
#
# pre_second_half_exact_goals_number_3 Total rows : 1
#   12.0
#
# pre_second_half_exact_goals_number_4 Total rows : 1
#   34.0
#
# pre_second_half_exact_goals_number_more_5 Total rows : 1
#   81.0
#
# end_second_half_exact_goals_number_0 Total rows : 1
#   13.0
#
# end_second_half_exact_goals_number_1 Total rows : 1
#   5.5
#
# end_second_half_exact_goals_number_2 Total rows : 1
#   4.75
#
# end_second_half_exact_goals_number_3 Total rows : 1
#   13.0
#
# end_second_half_exact_goals_number_4 Total rows : 1
#   41.0
#
# end_second_half_exact_goals_number_more_5 Total rows : 1
#   81.0
#
# pre_home_team_exact_goals_number_0 Total rows : 1
#   41.0
#
# pre_home_team_exact_goals_number_1 Total rows : 1
#   19.0
#
# pre_home_team_exact_goals_number_2 Total rows : 1
#   21.0
#
# pre_home_team_exact_goals_number_more_3 Total rows : 1
#   101.0
#
# end_home_team_exact_goals_number_0 Total rows : 1
#   51.0
#
# end_home_team_exact_goals_number_1 Total rows : 1
#   26.0
#
# end_home_team_exact_goals_number_2 Total rows : 1
#   23.0
#
# end_home_team_exact_goals_number_more_3 Total rows : 1
#   126.0
#
# pre_away_team_exact_goals_number_0 Total rows : 1
#   41.0
# pre_away_team_exact_goals_number_1 Total rows : 1
#   23.0
#
# pre_away_team_exact_goals_number_2 Total rows : 1
#   21.0
#
# pre_away_team_exact_goals_number_more_3 Total rows : 1
#   81.0
#
# end_away_team_exact_goals_number_0 Total rows : 1
#   34.0
#
# end_away_team_exact_goals_number_1 Total rows : 1
#   23.0
#
# end_away_team_exact_goals_number_2 Total rows : 1
#   34.0
#
# end_away_team_exact_goals_number_more_3 Total rows : 1
#   201.0
#
# pre_corners_winner_home Total rows : 1
#   9.0
#
# pre_corners_winner_draw Total rows : 1
#   17.0
#
# pre_corners_winner_away Total rows : 1
#   13.0
#
# end_corners_winner_home Total rows : 1
#   11.5
#
# end_corners_winner_draw Total rows : 1
#   26.0
#
# end_corners_winner_away Total rows : 1
#   26.0
#
# pre_10_overunder_over_05 Total rows : 1
#   6.5
#
# pre_10_overunder_under_05 Total rows : 1
#   1.53
#
# end_10_overunder_over_05 Total rows : 1
#   6.5
#
# end_10_overunder_under_05 Total rows : 1
#   1.53
#
# pre_cards_european_handicap_home_min_2 Total rows : 1
#   26.0
#
# pre_cards_european_handicap_draw_min_2 Total rows : 1
#   12.0
#
# pre_cards_european_handicap_away_min_2 Total rows : 1
#   1.83
#
# pre_cards_european_handicap_home_min_1 Total rows : 1
#   13.0
#
# pre_cards_european_handicap_draw_min_1 Total rows : 1
#   8.0
#
# pre_cards_european_handicap_away_min_1 Total rows : 1
#   3.1
#
# pre_cards_european_handicap_home_plus_0 Total rows : 1
#   8.0
#
# pre_cards_european_handicap_draw_plus_0 Total rows : 1
#   5.0
#
# pre_cards_european_handicap_away_plus_0 Total rows : 1
#   6.0
#
# pre_cards_european_handicap_home_plus_1 Total rows : 1
#   3.4
#
# pre_cards_european_handicap_draw_plus_1 Total rows : 1
#   7.5
#
# pre_cards_european_handicap_away_plus_1 Total rows : 1
#   11.0
#
# pre_cards_european_handicap_home_plus_2 Total rows : 1
#   1.83
#
# pre_cards_european_handicap_draw_plus_2 Total rows : 1
#   11.0
#
# pre_cards_european_handicap_away_plus_2 Total rows : 1
#   21.0
#
# end_cards_european_handicap_home_min_2 Total rows : 1
#   26.0
#
# end_cards_european_handicap_draw_min_2 Total rows : 1
#   12.0
#
# end_cards_european_handicap_away_min_2 Total rows : 1
#   1.83
#
# end_cards_european_handicap_home_min_1 Total rows : 1
#   23.0
#
# end_cards_european_handicap_draw_min_1 Total rows : 1
#   13.0
#
# end_cards_european_handicap_away_min_1 Total rows : 1
#   3.1
#
# end_cards_european_handicap_home_plus_0 Total rows : 1
#   10.0
#
# end_cards_european_handicap_draw_plus_0 Total rows : 1
#   6.0
#
# end_cards_european_handicap_away_plus_0 Total rows : 1
#   6.0
#
# end_cards_european_handicap_home_plus_1 Total rows : 1
#   4.33
#
# end_cards_european_handicap_draw_plus_1 Total rows : 1
#   7.5
#
# end_cards_european_handicap_away_plus_1 Total rows : 1
#   13.0
#
# end_cards_european_handicap_home_plus_2 Total rows : 1
#   2.3
#
# end_cards_european_handicap_draw_plus_2 Total rows : 1
#   15.0
#
# end_cards_european_handicap_away_plus_2 Total rows : 1
#   41.0
#
# pre_rcard_yes Total rows : 1
#   11.0
#
# pre_rcard_no Total rows : 1
#   1.4
#
# end_rcard_yes Total rows : 1
#   11.0
#
# end_rcard_no Total rows : 1
#   1.4

# %%
col = [
    'pre_match_winner_home', 
    'pre_match_winner_draw', 
    'pre_match_winner_away', 
    'end_match_winner_home', 
    'end_match_winner_draw', 
    'end_match_winner_away', 
    'pre_homeaway_home', 
    'pre_homeaway_away', 
    'end_homeaway_home', 
    'end_homeaway_away',
    'pre_first_half_winner_home',
    'pre_first_half_winner_draw',
    'pre_first_half_winner_away',
    'end_first_half_winner_home',
    'end_first_half_winner_draw',
    'end_first_half_winner_away',
    'pre_second_half_winner_home',
    'pre_second_half_winner_draw',
    'pre_second_half_winner_away',
    'end_second_half_winner_home',
    'end_second_half_winner_draw',
    'end_second_half_winner_away',
    'pre_asian_handicap_home_min_675',
    'pre_asian_handicap_away_min_675',
    'pre_asian_handicap_home_min_65',
    'pre_asian_handicap_away_min_65',
    'pre_asian_handicap_home_min_625',
    'pre_asian_handicap_away_min_625',
    'pre_asian_handicap_home_min_6',
    'pre_asian_handicap_away_min_6',
    'pre_asian_handicap_home_min_575',
    'pre_asian_handicap_away_min_575',
    'pre_asian_handicap_home_min_55',
    'pre_asian_handicap_away_min_55',
    'pre_asian_handicap_home_min_525',
    'pre_asian_handicap_away_min_525',
    'pre_asian_handicap_home_min_5',
    'pre_asian_handicap_away_min_5',
    'pre_asian_handicap_home_min_475',
    'pre_asian_handicap_away_min_475',
    'pre_asian_handicap_home_min_45',
    'pre_asian_handicap_away_min_45',
    'pre_asian_handicap_home_min_425',
    'pre_asian_handicap_away_min_425',
    'pre_asian_handicap_home_min_4',
    'pre_asian_handicap_away_min_4',
    'pre_asian_handicap_home_min_375',
    'pre_asian_handicap_away_min_375',
    'pre_asian_handicap_home_min_35',
    'pre_asian_handicap_away_min_35',
    'pre_asian_handicap_home_min_325',
    'pre_asian_handicap_away_min_325',
    'pre_asian_handicap_home_min_3',
    'pre_asian_handicap_away_min_3',
    'pre_asian_handicap_home_min_275',
    'pre_asian_handicap_away_min_275',
    'pre_asian_handicap_home_min_25',
    'pre_asian_handicap_away_min_25',
    'pre_asian_handicap_home_min_225',
    'pre_asian_handicap_away_min_225',
    'pre_asian_handicap_home_min_2',
    'pre_asian_handicap_away_min_2',
    'pre_asian_handicap_home_min_175',
    'pre_asian_handicap_away_min_175',
    'pre_asian_handicap_home_min_15',
    'pre_asian_handicap_away_min_15',
    'pre_asian_handicap_home_min_125',
    'pre_asian_handicap_away_min_125',
    'pre_asian_handicap_home_min_1',
    'pre_asian_handicap_away_min_1',
    'pre_asian_handicap_home_min_075',
    'pre_asian_handicap_away_min_075',
    'pre_asian_handicap_home_min_05',
    'pre_asian_handicap_away_min_05',
    'pre_asian_handicap_home_min_025',
    'pre_asian_handicap_away_min_025',
    'pre_asian_handicap_home_plus_0',
    'pre_asian_handicap_away_plus_0',
    'pre_asian_handicap_home_plus_025',
    'pre_asian_handicap_away_plus_025',
    'pre_asian_handicap_home_plus_05',
    'pre_asian_handicap_away_plus_05',
    'pre_asian_handicap_home_plus_075',
    'pre_asian_handicap_away_plus_075',
    'pre_asian_handicap_home_plus_1',
    'pre_asian_handicap_away_plus_1',
    'pre_asian_handicap_home_plus_125',
    'pre_asian_handicap_away_plus_125',
    'pre_asian_handicap_home_plus_15',
    'pre_asian_handicap_away_plus_15',
    'pre_asian_handicap_home_plus_175',
    'pre_asian_handicap_away_plus_175',
    'pre_asian_handicap_home_plus_2',
    'pre_asian_handicap_away_plus_2',
    'pre_asian_handicap_home_plus_225',
    'pre_asian_handicap_away_plus_225',
    'pre_asian_handicap_home_plus_25',
    'pre_asian_handicap_away_plus_25',
    'pre_asian_handicap_home_plus_275',
    'pre_asian_handicap_away_plus_275',
    'pre_asian_handicap_home_plus_3',
    'pre_asian_handicap_away_plus_3',
    'pre_asian_handicap_home_plus_325',
    'pre_asian_handicap_away_plus_325',
    'pre_asian_handicap_home_plus_35',
    'pre_asian_handicap_away_plus_35',
    'pre_asian_handicap_home_plus_375',
    'pre_asian_handicap_away_plus_375',
    'pre_asian_handicap_home_plus_4',
    'pre_asian_handicap_away_plus_4',
    'pre_asian_handicap_home_plus_425',
    'pre_asian_handicap_away_plus_425',
    'pre_asian_handicap_home_plus_45',
    'pre_asian_handicap_away_plus_45',
    'pre_asian_handicap_home_plus_475',
    'pre_asian_handicap_away_plus_475',
    'pre_asian_handicap_home_plus_5',
    'pre_asian_handicap_away_plus_5',
    'pre_asian_handicap_home_plus_525',
    'pre_asian_handicap_away_plus_525',
    'pre_asian_handicap_home_plus_55',
    'pre_asian_handicap_away_plus_55',
    'pre_asian_handicap_home_plus_575',
    'pre_asian_handicap_away_plus_575',
    'pre_asian_handicap_home_plus_6',
    'pre_asian_handicap_away_plus_6',
    'pre_asian_handicap_home_plus_625',
    'pre_asian_handicap_away_plus_625',
    'pre_asian_handicap_home_plus_65',
    'pre_asian_handicap_away_plus_65',
    'pre_asian_handicap_home_plus_675',
    'pre_asian_handicap_away_plus_675',
    'end_asian_handicap_home_min_675',
    'end_asian_handicap_away_min_675',
    'end_asian_handicap_home_min_65',
    'end_asian_handicap_away_min_65',
    'end_asian_handicap_home_min_625',
    'end_asian_handicap_away_min_625',
    'end_asian_handicap_home_min_6',
    'end_asian_handicap_away_min_6',
    'end_asian_handicap_home_min_575',
    'end_asian_handicap_away_min_575',
    'end_asian_handicap_home_min_55',
    'end_asian_handicap_away_min_55',
    'end_asian_handicap_home_min_525',
    'end_asian_handicap_away_min_525',
    'end_asian_handicap_home_min_5',
    'end_asian_handicap_away_min_5',
    'end_asian_handicap_home_min_475',
    'end_asian_handicap_away_min_475',
    'end_asian_handicap_home_min_45',
    'end_asian_handicap_away_min_45',
    'end_asian_handicap_home_min_425',
    'end_asian_handicap_away_min_425',
    'end_asian_handicap_home_min_4',
    'end_asian_handicap_away_min_4',
    'end_asian_handicap_home_min_375',
    'end_asian_handicap_away_min_375',
    'end_asian_handicap_home_min_35',
    'end_asian_handicap_away_min_35',
    'end_asian_handicap_home_min_325',
    'end_asian_handicap_away_min_325',
    'end_asian_handicap_home_min_3',
    'end_asian_handicap_away_min_3',
    'end_asian_handicap_home_min_275',
    'end_asian_handicap_away_min_275',
    'end_asian_handicap_home_min_25',
    'end_asian_handicap_away_min_25',
    'end_asian_handicap_home_min_225',
    'end_asian_handicap_away_min_225',
    'end_asian_handicap_home_min_2',
    'end_asian_handicap_away_min_2',
    'end_asian_handicap_home_min_175',
    'end_asian_handicap_away_min_175',
    'end_asian_handicap_home_min_15',
    'end_asian_handicap_away_min_15',
    'end_asian_handicap_home_min_125',
    'end_asian_handicap_away_min_125',
    'end_asian_handicap_home_min_1',
    'end_asian_handicap_away_min_1',
    'end_asian_handicap_home_min_075',
    'end_asian_handicap_away_min_075',
    'end_asian_handicap_home_min_05',
    'end_asian_handicap_away_min_05',
    'end_asian_handicap_home_min_025',
    'end_asian_handicap_away_min_025',
    'end_asian_handicap_home_plus_0',
    'end_asian_handicap_away_plus_0',
    'end_asian_handicap_home_plus_025',
    'end_asian_handicap_away_plus_025',
    'end_asian_handicap_home_plus_05',
    'end_asian_handicap_away_plus_05',
    'end_asian_handicap_home_plus_075',
    'end_asian_handicap_away_plus_075',
    'end_asian_handicap_home_plus_1',
    'end_asian_handicap_away_plus_1',
    'end_asian_handicap_home_plus_125',
    'end_asian_handicap_away_plus_125',
    'end_asian_handicap_home_plus_15',
    'end_asian_handicap_away_plus_15',
    'end_asian_handicap_home_plus_175',
    'end_asian_handicap_away_plus_175',
    'end_asian_handicap_home_plus_2',
    'end_asian_handicap_away_plus_2',
    'end_asian_handicap_home_plus_225',
    'end_asian_handicap_away_plus_225',
    'end_asian_handicap_home_plus_25',
    'end_asian_handicap_away_plus_25',
    'end_asian_handicap_home_plus_275',
    'end_asian_handicap_away_plus_275',
    'end_asian_handicap_home_plus_3',
    'end_asian_handicap_away_plus_3',
    'end_asian_handicap_home_plus_325',
    'end_asian_handicap_away_plus_325',
    'end_asian_handicap_home_plus_35',
    'end_asian_handicap_away_plus_35',
    'end_asian_handicap_home_plus_375',
    'end_asian_handicap_away_plus_375',
    'end_asian_handicap_home_plus_4',
    'end_asian_handicap_away_plus_4',
    'end_asian_handicap_home_plus_425',
    'end_asian_handicap_away_plus_425',
    'end_asian_handicap_home_plus_45',
    'end_asian_handicap_away_plus_45',
    'end_asian_handicap_home_plus_475',
    'end_asian_handicap_away_plus_475',
    'end_asian_handicap_home_plus_5',
    'end_asian_handicap_away_plus_5',
    'end_asian_handicap_home_plus_525',
    'end_asian_handicap_away_plus_525',
    'end_asian_handicap_home_plus_55',
    'end_asian_handicap_away_plus_55',
    'end_asian_handicap_home_plus_575',
    'end_asian_handicap_away_plus_575',
    'end_asian_handicap_home_plus_6',
    'end_asian_handicap_away_plus_6',
    'end_asian_handicap_home_plus_625',
    'end_asian_handicap_away_plus_625',
    'end_asian_handicap_home_plus_65',
    'end_asian_handicap_away_plus_65',
    'end_asian_handicap_home_plus_675',
    'end_asian_handicap_away_plus_675',
    'pre_goals_overunder_over_05',
    'pre_goals_overunder_under_05',
    'pre_goals_overunder_over_075',
    'pre_goals_overunder_under_075',
    'pre_goals_overunder_over_10',
    'pre_goals_overunder_under_10',
    'pre_goals_overunder_over_125',
    'pre_goals_overunder_under_125',
    'pre_goals_overunder_over_15',
    'pre_goals_overunder_under_15',
    'pre_goals_overunder_over_175',
    'pre_goals_overunder_under_175',
    'pre_goals_overunder_over_20',
    'pre_goals_overunder_under_20',
    'pre_goals_overunder_over_225',
    'pre_goals_overunder_under_225',
    'pre_goals_overunder_over_25',
    'pre_goals_overunder_under_25',
    'pre_goals_overunder_over_275',
    'pre_goals_overunder_under_275',
    'pre_goals_overunder_over_30',
    'pre_goals_overunder_under_30',
    'pre_goals_overunder_over_325',
    'pre_goals_overunder_under_325',
    'pre_goals_overunder_over_35',
    'pre_goals_overunder_under_35',
    'pre_goals_overunder_over_375',
    'pre_goals_overunder_under_375',
    'pre_goals_overunder_over_40',
    'pre_goals_overunder_under_40',
    'pre_goals_overunder_over_425',
    'pre_goals_overunder_under_425',
    'pre_goals_overunder_over_45',
    'pre_goals_overunder_under_45',
    'pre_goals_overunder_over_475',
    'pre_goals_overunder_under_475',
    'pre_goals_overunder_over_50',
    'pre_goals_overunder_under_50',
    'pre_goals_overunder_over_525',
    'pre_goals_overunder_under_525',
    'pre_goals_overunder_over_55',
    'pre_goals_overunder_under_55',
    'pre_goals_overunder_over_575',
    'pre_goals_overunder_under_575',
    'pre_goals_overunder_over_60',
    'pre_goals_overunder_under_60',
    'pre_goals_overunder_over_625',
    'pre_goals_overunder_under_625',
    'pre_goals_overunder_over_65',
    'pre_goals_overunder_under_65',
    'pre_goals_overunder_over_675',
    'pre_goals_overunder_under_675',
    'pre_goals_overunder_over_70',
    'pre_goals_overunder_under_70',
    'pre_goals_overunder_over_75',
    'pre_goals_overunder_under_75',
    'pre_goals_overunder_over_85',
    'pre_goals_overunder_under_85',
    'pre_goals_overunder_over_95',
    'pre_goals_overunder_under_95',
    'end_goals_overunder_over_05',
    'end_goals_overunder_under_05',
    'end_goals_overunder_over_075',
    'end_goals_overunder_under_075',
    'end_goals_overunder_over_10',
    'end_goals_overunder_under_10',
    'end_goals_overunder_over_125',
    'end_goals_overunder_under_125',
    'end_goals_overunder_over_15',
    'end_goals_overunder_under_15',
    'end_goals_overunder_over_175',
    'end_goals_overunder_under_175',
    'end_goals_overunder_over_20',
    'end_goals_overunder_under_20',
    'end_goals_overunder_over_225',
    'end_goals_overunder_under_225',
    'end_goals_overunder_over_25',
    'end_goals_overunder_under_25',
    'end_goals_overunder_over_275',
    'end_goals_overunder_under_275',
    'end_goals_overunder_over_30',
    'end_goals_overunder_under_30',
    'end_goals_overunder_over_325',
    'end_goals_overunder_under_325',
    'end_goals_overunder_over_35',
    'end_goals_overunder_under_35',
    'end_goals_overunder_over_375',
    'end_goals_overunder_under_375',
    'end_goals_overunder_over_40',
    'end_goals_overunder_under_40',
    'end_goals_overunder_over_425',
    'end_goals_overunder_under_425',
    'end_goals_overunder_over_45',
    'end_goals_overunder_under_45',
    'end_goals_overunder_over_475',
    'end_goals_overunder_under_475',
    'end_goals_overunder_over_50',
    'end_goals_overunder_under_50',
    'end_goals_overunder_over_525',
    'end_goals_overunder_under_525',
    'end_goals_overunder_over_55',
    'end_goals_overunder_under_55',
    'end_goals_overunder_over_575',
    'end_goals_overunder_under_575',
    'end_goals_overunder_over_60',
    'end_goals_overunder_under_60',
    'end_goals_overunder_over_625',
    'end_goals_overunder_under_625',
    'end_goals_overunder_over_65',
    'end_goals_overunder_under_65',
    'end_goals_overunder_over_675',
    'end_goals_overunder_under_675',
    'end_goals_overunder_over_70',
    'end_goals_overunder_under_70',
    'end_goals_overunder_over_75',
    'end_goals_overunder_under_75',
    'end_goals_overunder_over_85',
    'end_goals_overunder_under_85',
    'end_goals_overunder_over_95',
    'end_goals_overunder_under_95',
    'pre_asian_handicap_first_half_home_min_175',
    'pre_asian_handicap_first_half_away_min_175',
    'pre_asian_handicap_first_half_home_min_15',
    'pre_asian_handicap_first_half_away_min_15',
    'pre_asian_handicap_first_half_home_min_125',
    'pre_asian_handicap_first_half_away_min_125',
    'pre_asian_handicap_first_half_home_min_1',
    'pre_asian_handicap_first_half_away_min_1',
    'pre_asian_handicap_first_half_home_min_075',
    'pre_asian_handicap_first_half_away_min_075',
    'pre_asian_handicap_first_half_home_min_05',
    'pre_asian_handicap_first_half_away_min_05',
    'pre_asian_handicap_first_half_home_min_025',
    'pre_asian_handicap_first_half_away_min_025',
    'pre_asian_handicap_first_half_home_plus_0',
    'pre_asian_handicap_first_half_away_plus_0',
    'pre_asian_handicap_first_half_home_plus_025',
    'pre_asian_handicap_first_half_away_plus_025',
    'pre_asian_handicap_first_half_home_plus_05',
    'pre_asian_handicap_first_half_away_plus_05',
    'pre_asian_handicap_first_half_home_plus_075',
    'pre_asian_handicap_first_half_away_plus_075',
    'pre_asian_handicap_first_half_home_plus_1',
    'pre_asian_handicap_first_half_away_plus_1',
    'pre_asian_handicap_first_half_home_plus_125',
    'pre_asian_handicap_first_half_away_plus_125',
    'pre_asian_handicap_first_half_home_plus_15',
    'pre_asian_handicap_first_half_away_plus_15',
    'pre_asian_handicap_first_half_home_plus_175',
    'pre_asian_handicap_first_half_away_plus_175',
    'end_asian_handicap_first_half_home_min_175',
    'end_asian_handicap_first_half_away_min_175',
    'end_asian_handicap_first_half_home_min_15',
    'end_asian_handicap_first_half_away_min_15',
    'end_asian_handicap_first_half_home_min_125',
    'end_asian_handicap_first_half_away_min_125',
    'end_asian_handicap_first_half_home_min_1',
    'end_asian_handicap_first_half_away_min_1',
    'end_asian_handicap_first_half_home_min_075',
    'end_asian_handicap_first_half_away_min_075',
    'end_asian_handicap_first_half_home_min_05',
    'end_asian_handicap_first_half_away_min_05',
    'end_asian_handicap_first_half_home_min_025',
    'end_asian_handicap_first_half_away_min_025',
    'end_asian_handicap_first_half_home_plus_0',
    'end_asian_handicap_first_half_away_plus_0',
    'end_asian_handicap_first_half_home_plus_025',
    'end_asian_handicap_first_half_away_plus_025',
    'end_asian_handicap_first_half_home_plus_05',
    'end_asian_handicap_first_half_away_plus_05',
    'end_asian_handicap_first_half_home_plus_075',
    'end_asian_handicap_first_half_away_plus_075',
    'end_asian_handicap_first_half_home_plus_1',
    'end_asian_handicap_first_half_away_plus_1',
    'end_asian_handicap_first_half_home_plus_125',
    'end_asian_handicap_first_half_away_plus_125',
    'end_asian_handicap_first_half_home_plus_15',
    'end_asian_handicap_first_half_away_plus_15',
    'end_asian_handicap_first_half_home_plus_175',
    'end_asian_handicap_first_half_away_plus_175',
    'pre_goals_overunder_first_half_over_05',
    'pre_goals_overunder_first_half_under_05',
    'pre_goals_overunder_first_half_over_075',
    'pre_goals_overunder_first_half_under_075',
    'pre_goals_overunder_first_half_over_10',
    'pre_goals_overunder_first_half_under_10',
    'pre_goals_overunder_first_half_over_125',
    'pre_goals_overunder_first_half_under_125',
    'pre_goals_overunder_first_half_over_15',
    'pre_goals_overunder_first_half_under_15',
    'pre_goals_overunder_first_half_over_175',
    'pre_goals_overunder_first_half_under_175',
    'pre_goals_overunder_first_half_over_20',
    'pre_goals_overunder_first_half_under_20',
    'pre_goals_overunder_first_half_over_225',
    'pre_goals_overunder_first_half_under_225',
    'pre_goals_overunder_first_half_over_25',
    'pre_goals_overunder_first_half_under_25',
    'pre_goals_overunder_first_half_over_275',
    'pre_goals_overunder_first_half_under_275',
    'pre_goals_overunder_first_half_over_30',
    'pre_goals_overunder_first_half_under_30',
    'pre_goals_overunder_first_half_over_325',
    'pre_goals_overunder_first_half_under_325',
    'pre_goals_overunder_first_half_over_35',
    'pre_goals_overunder_first_half_under_35',
    'pre_goals_overunder_first_half_over_375',
    'pre_goals_overunder_first_half_under_375',
    'end_goals_overunder_first_half_over_05',
    'end_goals_overunder_first_half_under_05',
    'end_goals_overunder_first_half_over_075',
    'end_goals_overunder_first_half_under_075',
    'end_goals_overunder_first_half_over_10',
    'end_goals_overunder_first_half_under_10',
    'end_goals_overunder_first_half_over_125',
    'end_goals_overunder_first_half_under_125',
    'end_goals_overunder_first_half_over_15',
    'end_goals_overunder_first_half_under_15',
    'end_goals_overunder_first_half_over_175',
    'end_goals_overunder_first_half_under_175',
    'end_goals_overunder_first_half_over_20',
    'end_goals_overunder_first_half_under_20',
    'end_goals_overunder_first_half_over_225',
    'end_goals_overunder_first_half_under_225',
    'end_goals_overunder_first_half_over_25',
    'end_goals_overunder_first_half_under_25',
    'end_goals_overunder_first_half_over_275',
    'end_goals_overunder_first_half_under_275',
    'end_goals_overunder_first_half_over_30',
    'end_goals_overunder_first_half_under_30',
    'end_goals_overunder_first_half_over_325',
    'end_goals_overunder_first_half_under_325',
    'end_goals_overunder_first_half_over_35',
    'end_goals_overunder_first_half_under_35',
    'end_goals_overunder_first_half_over_375',
    'end_goals_overunder_first_half_under_375',
    'pre_goals_overunder__second_half_over_05',
    'pre_goals_overunder__second_half_under_05',
    'pre_goals_overunder__second_half_over_075',
    'pre_goals_overunder__second_half_under_075',
    'pre_goals_overunder__second_half_over_10',
    'pre_goals_overunder__second_half_under_10',
    'pre_goals_overunder__second_half_over_125',
    'pre_goals_overunder__second_half_under_125',
    'pre_goals_overunder__second_half_over_15',
    'pre_goals_overunder__second_half_under_15',
    'pre_goals_overunder__second_half_over_175',
    'pre_goals_overunder__second_half_under_175',
    'pre_goals_overunder__second_half_over_20',
    'pre_goals_overunder__second_half_under_20',
    'pre_goals_overunder__second_half_over_225',
    'pre_goals_overunder__second_half_under_225',
    'pre_goals_overunder__second_half_over_25',
    'pre_goals_overunder__second_half_under_25',
    'pre_goals_overunder__second_half_over_275',
    'pre_goals_overunder__second_half_under_275',
    'pre_goals_overunder__second_half_over_30',
    'pre_goals_overunder__second_half_under_30',
    'pre_goals_overunder__second_half_over_325',
    'pre_goals_overunder__second_half_under_325',
    'pre_goals_overunder__second_half_over_35',
    'pre_goals_overunder__second_half_under_35',
    'pre_goals_overunder__second_half_over_375',
    'pre_goals_overunder__second_half_under_375',
    'end_goals_overunder__second_half_over_05',
    'end_goals_overunder__second_half_under_05',
    'end_goals_overunder__second_half_over_075',
    'end_goals_overunder__second_half_under_075',
    'end_goals_overunder__second_half_over_10',
    'end_goals_overunder__second_half_under_10',
    'end_goals_overunder__second_half_over_125',
    'end_goals_overunder__second_half_under_125',
    'end_goals_overunder__second_half_over_15',
    'end_goals_overunder__second_half_under_15',
    'end_goals_overunder__second_half_over_175',
    'end_goals_overunder__second_half_under_175',
    'end_goals_overunder__second_half_over_20',
    'end_goals_overunder__second_half_under_20',
    'end_goals_overunder__second_half_over_225',
    'end_goals_overunder__second_half_under_225',
    'end_goals_overunder__second_half_over_25',
    'end_goals_overunder__second_half_under_25',
    'end_goals_overunder__second_half_over_275',
    'end_goals_overunder__second_half_under_275',
    'end_goals_overunder__second_half_over_30',
    'end_goals_overunder__second_half_under_30',
    'end_goals_overunder__second_half_over_325',
    'end_goals_overunder__second_half_under_325',
    'end_goals_overunder__second_half_over_35',
    'end_goals_overunder__second_half_under_35',
    'end_goals_overunder__second_half_over_375',
    'end_goals_overunder__second_half_under_375',
    'pre_htft_double_home_home',
    'pre_htft_double_home_draw',
    'pre_htft_double_home_away',
    'pre_htft_double_draw_home',
    'pre_htft_double_draw_draw',
    'pre_htft_double_draw_away',
    'pre_htft_double_away_home',
    'pre_htft_double_away_draw',
    'pre_htft_double_away_away',
    'end_htft_double_home_home',
    'end_htft_double_home_draw',
    'end_htft_double_home_away',
    'end_htft_double_draw_home',
    'end_htft_double_draw_draw',
    'end_htft_double_draw_away',
    'end_htft_double_away_home',
    'end_htft_double_away_draw',
    'end_htft_double_away_away',
    'pre_both_teams_score_yes',
    'pre_both_teams_score_no',
    'end_both_teams_score_yes',
    'end_both_teams_score_no',
    'pre_both_teams_score__first_half_yes',
    'pre_both_teams_score__first_half_no',
    'end_both_teams_score__first_half_yes',
    'end_both_teams_score__first_half_no',
    'pre_both_teams_to_score__second_half_yes',
    'pre_both_teams_to_score__second_half_no',
    'end_both_teams_to_score__second_half_yes',
    'end_both_teams_to_score__second_half_no',
    'pre_results_both_teams_score_home_yes',
    'pre_results_both_teams_score_draw_yes',
    'pre_results_both_teams_score_away_yes',
    'pre_results_both_teams_score_home_no',
    'pre_results_both_teams_score_draw_no',
    'pre_results_both_teams_score_away_no',
    'end_results_both_teams_score_home_yes',
    'end_results_both_teams_score_draw_yes',
    'end_results_both_teams_score_away_yes',
    'end_results_both_teams_score_home_no',
    'end_results_both_teams_score_draw_no',
    'end_results_both_teams_score_away_no',
    'pre_to_score_in_both_halves_by_teams_home',
    'pre_to_score_in_both_halves_by_teams_away',
    'end_to_score_in_both_halves_by_teams_home',
    'end_to_score_in_both_halves_by_teams_away',
    'pre_total_goals_both_teams_to_score_over_yes_25',
    'pre_total_goals_both_teams_to_score_over_no_25',
    'pre_total_goals_both_teams_to_score_under_yes_25',
    'pre_total_goals_both_teams_to_score_under_no_25',
    'end_total_goals_both_teams_to_score_over_yes_25',
    'end_total_goals_both_teams_to_score_over_no_25',
    'end_total_goals_both_teams_to_score_under_yes_25',
    'end_total_goals_both_teams_to_score_under_no_25',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_yes_no',
    'pre_both_teams_to_score_1st_half__2nd_half_no_yes',
    'pre_both_teams_to_score_1st_half__2nd_half_no_no',
    'end_both_teams_to_score_1st_half__2nd_half_yes_yes',
    'end_both_teams_to_score_1st_half__2nd_half_yes_no',
    'end_both_teams_to_score_1st_half__2nd_half_no_yes',
    'end_both_teams_to_score_1st_half__2nd_half_no_no',
    'pre_highest_scoring_half_first',
    'pre_highest_scoring_half_draw',
    'pre_highest_scoring_half_second',
    'end_highest_scoring_half_first',
    'end_highest_scoring_half_draw',
    'end_highest_scoring_half_second',
    'pre_double_chance_home_draw',
    'pre_double_chance_home_away',
    'pre_double_chance_draw_away',
    'end_double_chance_home_draw',
    'end_double_chance_home_away',
    'end_double_chance_draw_away',
    'pre_double_chance__first_half_home_draw',
    'pre_double_chance__first_half_home_away',
    'pre_double_chance__first_half_draw_away',
    'end_double_chance__first_half_home_draw',
    'end_double_chance__first_half_home_away',
    'end_double_chance__first_half_draw_away',
    'pre_oddeven_odd',
    'pre_oddeven_even',
    'end_oddeven_odd',
    'end_oddeven_even',
    'pre_result_total_goals_home_over_35',
    'pre_result_total_goals_draw_over_35',
    'pre_result_total_goals_away_over_35',
    'pre_result_total_goals_home_under_35',
    'pre_result_total_goals_draw_under_35',
    'pre_result_total_goals_away_under_35',
    'pre_result_total_goals_home_over_25',
    'pre_result_total_goals_draw_over_25',
    'pre_result_total_goals_away_over_25',
    'pre_result_total_goals_home_under_25',
    'pre_result_total_goals_draw_under_25',
    'pre_result_total_goals_away_under_25',
    'end_result_total_goals_home_over_35',
    'end_result_total_goals_draw_over_35',
    'end_result_total_goals_away_over_35',
    'end_result_total_goals_home_under_35',
    'end_result_total_goals_draw_under_35',
    'end_result_total_goals_away_under_35',
    'end_result_total_goals_home_over_25',
    'end_result_total_goals_draw_over_25',
    'end_result_total_goals_away_over_25',
    'end_result_total_goals_home_under_25',
    'end_result_total_goals_draw_under_25',
    'end_result_total_goals_away_under_25',
    'pre_clean_sheet__home_yes',
    'pre_clean_sheet__home_no',
    'end_clean_sheet__home_yes',
    'end_clean_sheet__home_no',
    'pre_clean_sheet__away_yes',
    'pre_clean_sheet__away_no',
    'end_clean_sheet__away_yes',
    'end_clean_sheet__away_no',
    'pre_win_both_halves_home',
    'pre_win_both_halves_away',
    'end_win_both_halves_home',
    'end_win_both_halves_away',
    'pre_win_to_nil_home',
    'pre_win_to_nil_away',
    'end_win_to_nil_home',
    'end_win_to_nil_away',
    'pre_to_win_either_half_home',
    'pre_to_win_either_half_away',
    'end_to_win_either_half_home',
    'end_to_win_either_half_away',
    'pre_halftime_result_both_teams_score_home_yes',
    'pre_halftime_result_both_teams_score_draw_yes',
    'pre_halftime_result_both_teams_score_away_yes',
    'pre_halftime_result_both_teams_score_home_no',
    'pre_halftime_result_both_teams_score_draw_no',
    'pre_halftime_result_both_teams_score_away_no',
    'end_halftime_result_both_teams_score_home_yes',
    'end_halftime_result_both_teams_score_draw_yes',
    'end_halftime_result_both_teams_score_away_yes',
    'end_halftime_result_both_teams_score_home_no',
    'end_halftime_result_both_teams_score_draw_no',
    'end_halftime_result_both_teams_score_away_no',
    'pre_exact_goals_number_0',
    'pre_exact_goals_number_1',
    'pre_exact_goals_number_2',
    'pre_exact_goals_number_3',
    'pre_exact_goals_number_4',
    'pre_exact_goals_number_5',
    'pre_exact_goals_number_6',
    'pre_exact_goals_number_more_7',
    'end_exact_goals_number_0',
    'end_exact_goals_number_1',
    'end_exact_goals_number_2',
    'end_exact_goals_number_3',
    'end_exact_goals_number_4',
    'end_exact_goals_number_5',
    'end_exact_goals_number_6',
    'end_exact_goals_number_more_7',
    'pre_exact_goals_number__first_half_0',
    'pre_exact_goals_number__first_half_1',
    'pre_exact_goals_number__first_half_2',
    'pre_exact_goals_number__first_half_3',
    'pre_exact_goals_number__first_half_4',
    'pre_exact_goals_number__first_half_more_5',
    'end_exact_goals_number__first_half_0',
    'end_exact_goals_number__first_half_1',
    'end_exact_goals_number__first_half_2',
    'end_exact_goals_number__first_half_3',
    'end_exact_goals_number__first_half_4',
    'end_exact_goals_number__first_half_more_5',
    'pre_second_half_exact_goals_number_0',
    'pre_second_half_exact_goals_number_1',
    'pre_second_half_exact_goals_number_2',
    'pre_second_half_exact_goals_number_3',
    'pre_second_half_exact_goals_number_4',
    'pre_second_half_exact_goals_number_more_5',
    'end_second_half_exact_goals_number_0',
    'end_second_half_exact_goals_number_1',
    'end_second_half_exact_goals_number_2',
    'end_second_half_exact_goals_number_3',
    'end_second_half_exact_goals_number_4',
    'end_second_half_exact_goals_number_more_5',
    'pre_home_team_exact_goals_number_0',
    'pre_home_team_exact_goals_number_1',
    'pre_home_team_exact_goals_number_2',
    'pre_home_team_exact_goals_number_more_3',
    'end_home_team_exact_goals_number_0',
    'end_home_team_exact_goals_number_1',
    'end_home_team_exact_goals_number_2',
    'end_home_team_exact_goals_number_more_3',
    'pre_away_team_exact_goals_number_0',
    'pre_away_team_exact_goals_number_1',
    'pre_away_team_exact_goals_number_2',
    'pre_away_team_exact_goals_number_more_3',
    'end_away_team_exact_goals_number_0',
    'end_away_team_exact_goals_number_1',
    'end_away_team_exact_goals_number_2',
    'end_away_team_exact_goals_number_more_3',
    'pre_corners_winner_home',
    'pre_corners_winner_draw',
    'pre_corners_winner_away',
    'end_corners_winner_home',
    'end_corners_winner_draw',
    'end_corners_winner_away',
    'pre_10_overunder_over_05',
    'pre_10_overunder_under_05',
    'end_10_overunder_over_05',
    'end_10_overunder_under_05',
    'pre_cards_european_handicap_home_min_2',
    'pre_cards_european_handicap_draw_min_2',
    'pre_cards_european_handicap_away_min_2',
    'pre_cards_european_handicap_home_min_1',
    'pre_cards_european_handicap_draw_min_1',
    'pre_cards_european_handicap_away_min_1',
    'pre_cards_european_handicap_home_plus_0',
    'pre_cards_european_handicap_draw_plus_0',
    'pre_cards_european_handicap_away_plus_0',
    'pre_cards_european_handicap_home_plus_1',
    'pre_cards_european_handicap_draw_plus_1',
    'pre_cards_european_handicap_away_plus_1',
    'pre_cards_european_handicap_home_plus_2',
    'pre_cards_european_handicap_draw_plus_2',
    'pre_cards_european_handicap_away_plus_2',
    'end_cards_european_handicap_home_min_2',
    'end_cards_european_handicap_draw_min_2',
    'end_cards_european_handicap_away_min_2',
    'end_cards_european_handicap_home_min_1',
    'end_cards_european_handicap_draw_min_1',
    'end_cards_european_handicap_away_min_1',
    'end_cards_european_handicap_home_plus_0',
    'end_cards_european_handicap_draw_plus_0',
    'end_cards_european_handicap_away_plus_0',
    'end_cards_european_handicap_home_plus_1',
    'end_cards_european_handicap_draw_plus_1',
    'end_cards_european_handicap_away_plus_1',
    'end_cards_european_handicap_home_plus_2',
    'end_cards_european_handicap_draw_plus_2',
    'end_cards_european_handicap_away_plus_2',
    'pre_rcard_yes',
    'pre_rcard_no',
    'end_rcard_yes',
    'end_rcard_no',

    ]
# -----------------------------------------------------------------
for c in col:   
    query = "ALTER TABLE `football_fixtures_new` CHANGE `"+c+"` `"+c+"` DECIMAL(5,3) NULL DEFAULT NULL;"
     
    mycursor.execute(query)
    mydb.commit()  
    print("Col updated")
# Out:
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated
# Col updated

# %%
import mysql.connector
# -----------------------------------------------------------------
# CHECK
# -----------------------------------------------------------------
col = 'pre_special_odds'
# -----------------------------------------------------------------
host="localhost"
user="root"
database="pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
# -----------------------------------------------------------------
query = ' select '
query += col  
query += ' from football_fixtures '  
query += ' where ' + col + ' like "%corner%" '  
# -----------------------------------------------------------------
mycursor = mydb.cursor() 
mycursor.execute(query)
myresult = mycursor.fetchall()
# -----------------------------------------------------------------
print("Total rows : " + str(len(myresult))) 
unique_list = []
# -----------------------------------------------------------------
for x in myresult:  
    # -------------------------------------------------------------
    col_name = str(x[0]) 
    # -------------------------------------------------------------
#     print(col_name  ) 
    for_col = col_name.split('</tr><tr>')
    
    for f in for_col:  
        temp_f = f.replace("</td><td>", " : ")
        temp_f = temp_f.replace("<tr><td>", "")
        temp_f = temp_f.replace("<td>", "")
        temp_f = temp_f.replace("</td>", "")
        temp_f = temp_f.replace("</td></tr>", "")
        temp_f = temp_f.replace("</tr>", "")
        
        final_f = temp_f
        
        if("Corners Over Under" in final_f):
            temp_final = final_f.replace("Under ", "").replace("Over ", "").replace("Corners ", "").replace(" : 1.98", "").replace(" : 1.83", "")
            if temp_final not in unique_list:
                unique_list.append(temp_final)
            
            #print(final_f) 
#         if("Corners Over Under" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Goal Line" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("To Win Either Half" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Asian Handicap" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Odd/Even" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Both Teams Score" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Double Chance" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Goals Over/Under First Half" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Handicap Result" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Total Corners" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Second Half Winner" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Goals Over/Under" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Total Goals/Both" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("First Half Winner" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Exact Goals Number" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Player to be booked" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Home/Away" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Clean Sheet" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Match Winner" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Win Both Halves" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("HT/FT Double" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Total Goals (3 way)" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Anytime Goal Scorer" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Result/Total Goals" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Highest Scoring" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Team Score a Goal" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Win To Nil" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Both Teams to Score" in final_f):
#             # print(final_f)
#             aaa = ''
#         elif("Corners Over/Under" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Last Corner" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("First Corner" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Corners 1x2" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Yellow" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Fouls." in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Total - " in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Team To Score First" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Team To Score Last" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Cards Over/Under" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Cards European" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("Team Total Cards" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif("To Score In Both Halves By Teams" in final_f):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif(final_f == ""):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         elif(final_f is None):
#             # print(final_f) 
#             # ini
#             aaa = ''
#         else:
#             aaa = ''
#             # print(final_f) 

unique_list.sort() 
print(unique_list)
# for x in unique_list:
#     print (x)
# Out:
# Total rows : 1094
# ['10', '10.25', '10.5', '10.75', '11', '11.25', '11.5', '12.25', '7.5', '7.75', '8', '8.25', '8.5', '8.75', '9', '9.25', '9.5', '9.75']

# %%
import mysql.connector
# -----------------------------------------------------------------
# CHECK
# -----------------------------------------------------------------
col = 'pre_special_odds'
# -----------------------------------------------------------------
host="localhost"
user="root"
database="pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database )
# -----------------------------------------------------------------
query = ' select '
query += col  
query += ' from football_fixtures '  
query += ' where ' + col + ' like "%corner%" '  
# -----------------------------------------------------------------
mycursor = mydb.cursor() 
mycursor.execute(query)
myresult = mycursor.fetchall()
# -----------------------------------------------------------------
print("Total rows : " + str(len(myresult))) 
print("")
# -----------------------------------------------------------------
for x in myresult:  
    # -------------------------------------------------------------
    col_name = str(x[0]) 
    # -------------------------------------------------------------
#     print(col_name  ) 
    for_col = col_name.split('</tr><tr>')
    for f in for_col:  
        temp_f = f.replace("</td><td>", " : ")
        temp_f = temp_f.replace("<tr><td>", "")
        temp_f = temp_f.replace("<td>", "")
        temp_f = temp_f.replace("</td>", "")
        temp_f = temp_f.replace("</td></tr>", "")
        temp_f = temp_f.replace("</tr>", "")
        
        final_f = temp_f
        
        if("Away Team Total Cards" in final_f):
            print(final_f)
            col_bet_id = 83
            print("col_bet_id:" + str(col_bet_id))
            
            col_bet = "Away Team Total Cards "
            print("col_bet:" + col_bet)
            
            col_value = final_f.replace(col_bet, "").replace(" : 1.83", "").replace(" : 1.98", "")
            print("col_value:" + col_value)
            
            col_category = "Null"
            
            col_columnx = final_f.replace("/", "").replace("+", "plus_").replace("-", "min_").replace(" : 1.83", "").replace(" : 1.98", "").replace(" ", "_").replace(".", "").lower()
            print("col_columnx:" + col_columnx)
            
            host="localhost"
            user="root"
            database="pr_mmbuzz_2022_06" 
            mydb = mysql.connector.connect( host=host, user=user, password="", database=database )

            query1 = ' select ' 
            query1 += ' * '  
            query1 += ' from bets_old '   
            query1 += ' where columnx = "'+col_columnx+'" '    
            # -------------------------------------------------------------
            mycursor = mydb.cursor() 
            mycursor.execute(query1)
            myresult1 = mycursor.fetchall()
            # ------------------------------------------------------------- 
            len_myresult1 = len(myresult1) 
            
            
            print("total rows " + str(len_myresult1))
            
            if(len_myresult1 == 0): 
                word = "INSERT INTO `bets_old`( "
                word += " `bet_id`, `bet`, `value`, `category`, `columnx` "
                word += " ) VALUES ( "
                word += " '"+str(col_bet_id)+"', "
                word += " '"+str(col_bet)+"', "
                word += " '"+str(col_value)+"', "
                word += " "+str(col_category)+", "
                word += " '"+str(col_columnx)+"' "
                word += " )  " 
                mycursor.execute(word)
                mydb.commit()  
            
            print("")
# Out:
# Total rows : 1094
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 0
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 0
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 1.5
# col_columnx:away_team_total_cards_over_15
# total rows 1
#
# Away Team Total Cards Under 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 1.5
# col_columnx:away_team_total_cards_under_15
# total rows 1
#
# Away Team Total Cards Over 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 1.5
# col_columnx:away_team_total_cards_over_15
# total rows 1
#
# Away Team Total Cards Under 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 1.5
# col_columnx:away_team_total_cards_under_15
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 1.5
# col_columnx:away_team_total_cards_over_15
# total rows 1
#
# Away Team Total Cards Under 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 1.5
# col_columnx:away_team_total_cards_under_15
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 3.5
# col_columnx:away_team_total_cards_over_35
# total rows 0
#
# Away Team Total Cards Under 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 3.5
# col_columnx:away_team_total_cards_under_35
# total rows 0
#
# Away Team Total Cards Over 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 3.5
# col_columnx:away_team_total_cards_over_35
# total rows 1
#
# Away Team Total Cards Under 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 3.5
# col_columnx:away_team_total_cards_under_35
# total rows 1
#
# Away Team Total Cards Over 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 3.5
# col_columnx:away_team_total_cards_over_35
# total rows 1
#
# Away Team Total Cards Under 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 3.5
# col_columnx:away_team_total_cards_under_35
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 3.5
# col_columnx:away_team_total_cards_over_35
# total rows 1
#
# Away Team Total Cards Under 3.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 3.5
# col_columnx:away_team_total_cards_under_35
# total rows 1
#
# Away Team Total Cards Over 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 1.5
# col_columnx:away_team_total_cards_over_15
# total rows 1
#
# Away Team Total Cards Under 1.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 1.5
# col_columnx:away_team_total_cards_under_15
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
#
# Away Team Total Cards Over 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Over 2.5
# col_columnx:away_team_total_cards_over_25
# total rows 1
#
# Away Team Total Cards Under 2.5 : 1.83
# col_bet_id:83
# col_bet:Away Team Total Cards
# col_value:Under 2.5
# col_columnx:away_team_total_cards_under_25
# total rows 1
