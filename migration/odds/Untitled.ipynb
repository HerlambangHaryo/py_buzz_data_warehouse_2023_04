# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += " date "
query += " , fixtureapi_id "
# query += " , venueapi_id "
query += " , referee "
query += " , leagueapi_id "
query += " , season "
query += " , round "
query += " , fixture_status "
query += " , fixture_elapsed "
query += " , teams_home_id "
query += " , teams_away_id "
query += " , goals_home "
query += " , goals_away "
query += " , score_halftime_home "
query += " , score_halftime_away "
query += " , score_fulltime_home "
query += " , score_fulltime_away "
query += " , score_extratime_home "
query += " , score_extratime_away "
query += " , score_penalty_home "
query += " , score_penalty_away "

query += " , pre_match_winner_home "
query += " , pre_match_winner_draw "
query += " , pre_match_winner_away "
query += " , end_match_winner_home "
query += " , end_match_winner_draw "
query += " , end_match_winner_away "
query += " , pre_homeaway_home "
query += " , pre_homeaway_away "
query += " , end_homeaway_home "
query += " , end_homeaway_away "
query += " , pre_first_half_winner_home "
query += " , pre_first_half_winner_draw "
query += " , pre_first_half_winner_away "
query += " , end_first_half_winner_home "
query += " , end_first_half_winner_draw "
query += " , end_first_half_winner_away "
query += " , pre_second_half_winner_home "
query += " , pre_second_half_winner_draw "
query += " , pre_second_half_winner_away "
query += " , end_second_half_winner_home "
query += " , end_second_half_winner_draw "
query += " , end_second_half_winner_away "
query += " , pre_asian_handicap_home_min_675 "
query += " , pre_asian_handicap_away_min_675 "
query += " , pre_asian_handicap_home_min_65 "
query += " , pre_asian_handicap_away_min_65 "
query += " , pre_asian_handicap_home_min_625 "
query += " , pre_asian_handicap_away_min_625 "
query += " , pre_asian_handicap_home_min_6 "
query += " , pre_asian_handicap_away_min_6 "
query += " , pre_asian_handicap_home_min_575 "
query += " , pre_asian_handicap_away_min_575 "
query += " , pre_asian_handicap_home_min_55 "
query += " , pre_asian_handicap_away_min_55 "
query += " , pre_asian_handicap_home_min_525 "
query += " , pre_asian_handicap_away_min_525 "
query += " , pre_asian_handicap_home_min_5 "
query += " , pre_asian_handicap_away_min_5 "
query += " , pre_asian_handicap_home_min_475 "
query += " , pre_asian_handicap_away_min_475 "
query += " , pre_asian_handicap_home_min_45 "
query += " , pre_asian_handicap_away_min_45 "
query += " , pre_asian_handicap_home_min_425 "
query += " , pre_asian_handicap_away_min_425 "
query += " , pre_asian_handicap_home_min_4 "
query += " , pre_asian_handicap_away_min_4 "
query += " , pre_asian_handicap_home_min_375 "
query += " , pre_asian_handicap_away_min_375 "
query += " , pre_asian_handicap_home_min_35 "
query += " , pre_asian_handicap_away_min_35 "
query += " , pre_asian_handicap_home_min_325 "
query += " , pre_asian_handicap_away_min_325 "
query += " , pre_asian_handicap_home_min_3 "
query += " , pre_asian_handicap_away_min_3 "
query += " , pre_asian_handicap_home_min_275 "
query += " , pre_asian_handicap_away_min_275 "
query += " , pre_asian_handicap_home_min_25 "
query += " , pre_asian_handicap_away_min_25 "
query += " , pre_asian_handicap_home_min_225 "
query += " , pre_asian_handicap_away_min_225 "
query += " , pre_asian_handicap_home_min_2 "
query += " , pre_asian_handicap_away_min_2 "
query += " , pre_asian_handicap_home_min_175 "
query += " , pre_asian_handicap_away_min_175 "
query += " , pre_asian_handicap_home_min_15 "
query += " , pre_asian_handicap_away_min_15 "
query += " , pre_asian_handicap_home_min_125 "
query += " , pre_asian_handicap_away_min_125 "
query += " , pre_asian_handicap_home_min_1 "
query += " , pre_asian_handicap_away_min_1 "
query += " , pre_asian_handicap_home_min_075 "
query += " , pre_asian_handicap_away_min_075 "
query += " , pre_asian_handicap_home_min_05 "
query += " , pre_asian_handicap_away_min_05 "
query += " , pre_asian_handicap_home_min_025 "
query += " , pre_asian_handicap_away_min_025 "
query += " , pre_asian_handicap_home_plus_0 "
query += " , pre_asian_handicap_away_plus_0 "
query += " , pre_asian_handicap_home_plus_025 "
query += " , pre_asian_handicap_away_plus_025 "
query += " , pre_asian_handicap_home_plus_05 "
query += " , pre_asian_handicap_away_plus_05 "
query += " , pre_asian_handicap_home_plus_075 "
query += " , pre_asian_handicap_away_plus_075 "
query += " , pre_asian_handicap_home_plus_1 "
query += " , pre_asian_handicap_away_plus_1 "
query += " , pre_asian_handicap_home_plus_125 "
query += " , pre_asian_handicap_away_plus_125 "
query += " , pre_asian_handicap_home_plus_15 "
query += " , pre_asian_handicap_away_plus_15 "
query += " , pre_asian_handicap_home_plus_175 "
query += " , pre_asian_handicap_away_plus_175 "
query += " , pre_asian_handicap_home_plus_2 "
query += " , pre_asian_handicap_away_plus_2 "
query += " , pre_asian_handicap_home_plus_225 "
query += " , pre_asian_handicap_away_plus_225 "
query += " , pre_asian_handicap_home_plus_25 "
query += " , pre_asian_handicap_away_plus_25 "
query += " , pre_asian_handicap_home_plus_275 "
query += " , pre_asian_handicap_away_plus_275 "
query += " , pre_asian_handicap_home_plus_3 "
query += " , pre_asian_handicap_away_plus_3 "
query += " , pre_asian_handicap_home_plus_325 "
query += " , pre_asian_handicap_away_plus_325 "
query += " , pre_asian_handicap_home_plus_35 "
query += " , pre_asian_handicap_away_plus_35 "
query += " , pre_asian_handicap_home_plus_375 "
query += " , pre_asian_handicap_away_plus_375 "
query += " , pre_asian_handicap_home_plus_4 "
query += " , pre_asian_handicap_away_plus_4 "
query += " , pre_asian_handicap_home_plus_425 "
query += " , pre_asian_handicap_away_plus_425 "
query += " , pre_asian_handicap_home_plus_45 "
query += " , pre_asian_handicap_away_plus_45 "
query += " , pre_asian_handicap_home_plus_475 "
query += " , pre_asian_handicap_away_plus_475 "
query += " , pre_asian_handicap_home_plus_5 "
query += " , pre_asian_handicap_away_plus_5 "
query += " , pre_asian_handicap_home_plus_525 "
query += " , pre_asian_handicap_away_plus_525 "
query += " , pre_asian_handicap_home_plus_55 "
query += " , pre_asian_handicap_away_plus_55 "
query += " , pre_asian_handicap_home_plus_575 "
query += " , pre_asian_handicap_away_plus_575 "
query += " , pre_asian_handicap_home_plus_6 "
query += " , pre_asian_handicap_away_plus_6 "
query += " , pre_asian_handicap_home_plus_625 "
query += " , pre_asian_handicap_away_plus_625 "
query += " , pre_asian_handicap_home_plus_65 "
query += " , pre_asian_handicap_away_plus_65 "
query += " , pre_asian_handicap_home_plus_675 "
query += " , pre_asian_handicap_away_plus_675 "
query += " , end_asian_handicap_home_min_675 "
query += " , end_asian_handicap_away_min_675 "
query += " , end_asian_handicap_home_min_65 "
query += " , end_asian_handicap_away_min_65 "
query += " , end_asian_handicap_home_min_625 "
query += " , end_asian_handicap_away_min_625 "
query += " , end_asian_handicap_home_min_6 "
query += " , end_asian_handicap_away_min_6 "
query += " , end_asian_handicap_home_min_575 "
query += " , end_asian_handicap_away_min_575 "
query += " , end_asian_handicap_home_min_55 "
query += " , end_asian_handicap_away_min_55 "
query += " , end_asian_handicap_home_min_525 "
query += " , end_asian_handicap_away_min_525 "
query += " , end_asian_handicap_home_min_5 "
query += " , end_asian_handicap_away_min_5 "
query += " , end_asian_handicap_home_min_475 "
query += " , end_asian_handicap_away_min_475 "
query += " , end_asian_handicap_home_min_45 "
query += " , end_asian_handicap_away_min_45 "
query += " , end_asian_handicap_home_min_425 "
query += " , end_asian_handicap_away_min_425 "
query += " , end_asian_handicap_home_min_4 "
query += " , end_asian_handicap_away_min_4 "
query += " , end_asian_handicap_home_min_375 "
query += " , end_asian_handicap_away_min_375 "
query += " , end_asian_handicap_home_min_35 "
query += " , end_asian_handicap_away_min_35 "
query += " , end_asian_handicap_home_min_325 "
query += " , end_asian_handicap_away_min_325 "
query += " , end_asian_handicap_home_min_3 "
query += " , end_asian_handicap_away_min_3 "
query += " , end_asian_handicap_home_min_275 "
query += " , end_asian_handicap_away_min_275 "
query += " , end_asian_handicap_home_min_25 "
query += " , end_asian_handicap_away_min_25 "
query += " , end_asian_handicap_home_min_225 "
query += " , end_asian_handicap_away_min_225 "
query += " , end_asian_handicap_home_min_2 "
query += " , end_asian_handicap_away_min_2 "
query += " , end_asian_handicap_home_min_175 "
query += " , end_asian_handicap_away_min_175 "
query += " , end_asian_handicap_home_min_15 "
query += " , end_asian_handicap_away_min_15 "
query += " , end_asian_handicap_home_min_125 "
query += " , end_asian_handicap_away_min_125 "
query += " , end_asian_handicap_home_min_1 "
query += " , end_asian_handicap_away_min_1 "
query += " , end_asian_handicap_home_min_075 "
query += " , end_asian_handicap_away_min_075 "
query += " , end_asian_handicap_home_min_05 "
query += " , end_asian_handicap_away_min_05 "
query += " , end_asian_handicap_home_min_025 "
query += " , end_asian_handicap_away_min_025 "
query += " , end_asian_handicap_home_plus_0 "
query += " , end_asian_handicap_away_plus_0 "
query += " , end_asian_handicap_home_plus_025 "
query += " , end_asian_handicap_away_plus_025 "
query += " , end_asian_handicap_home_plus_05 "
query += " , end_asian_handicap_away_plus_05 "
query += " , end_asian_handicap_home_plus_075 "
query += " , end_asian_handicap_away_plus_075 "
query += " , end_asian_handicap_home_plus_1 "
query += " , end_asian_handicap_away_plus_1 "
query += " , end_asian_handicap_home_plus_125 "
query += " , end_asian_handicap_away_plus_125 "
query += " , end_asian_handicap_home_plus_15 "
query += " , end_asian_handicap_away_plus_15 "
query += " , end_asian_handicap_home_plus_175 "
query += " , end_asian_handicap_away_plus_175 "
query += " , end_asian_handicap_home_plus_2 "
query += " , end_asian_handicap_away_plus_2 "
query += " , end_asian_handicap_home_plus_225 "
query += " , end_asian_handicap_away_plus_225 "
query += " , end_asian_handicap_home_plus_25 "
query += " , end_asian_handicap_away_plus_25 "
query += " , end_asian_handicap_home_plus_275 "
query += " , end_asian_handicap_away_plus_275 "
query += " , end_asian_handicap_home_plus_3 "
query += " , end_asian_handicap_away_plus_3 "
query += " , end_asian_handicap_home_plus_325 "
query += " , end_asian_handicap_away_plus_325 "
query += " , end_asian_handicap_home_plus_35 "
query += " , end_asian_handicap_away_plus_35 "
query += " , end_asian_handicap_home_plus_375 "
query += " , end_asian_handicap_away_plus_375 "
query += " , end_asian_handicap_home_plus_4 "
query += " , end_asian_handicap_away_plus_4 "
query += " , end_asian_handicap_home_plus_425 "
query += " , end_asian_handicap_away_plus_425 "
query += " , end_asian_handicap_home_plus_45 "
query += " , end_asian_handicap_away_plus_45 "
query += " , end_asian_handicap_home_plus_475 "
query += " , end_asian_handicap_away_plus_475 "
query += " , end_asian_handicap_home_plus_5 "
query += " , end_asian_handicap_away_plus_5 "
query += " , end_asian_handicap_home_plus_525 "
query += " , end_asian_handicap_away_plus_525 "
query += " , end_asian_handicap_home_plus_55 "
query += " , end_asian_handicap_away_plus_55 "
query += " , end_asian_handicap_home_plus_575 "
query += " , end_asian_handicap_away_plus_575 "
query += " , end_asian_handicap_home_plus_6 "
query += " , end_asian_handicap_away_plus_6 "
query += " , end_asian_handicap_home_plus_625 "
query += " , end_asian_handicap_away_plus_625 "
query += " , end_asian_handicap_home_plus_65 "
query += " , end_asian_handicap_away_plus_65 "
query += " , end_asian_handicap_home_plus_675 "
query += " , end_asian_handicap_away_plus_675 "
query += " , pre_goals_overunder_over_05 "
query += " , pre_goals_overunder_under_05 "
query += " , pre_goals_overunder_over_075 "
query += " , pre_goals_overunder_under_075 "
query += " , pre_goals_overunder_over_10 "
query += " , pre_goals_overunder_under_10 "
query += " , pre_goals_overunder_over_125 "
query += " , pre_goals_overunder_under_125 "
query += " , pre_goals_overunder_over_15 "
query += " , pre_goals_overunder_under_15 "
query += " , pre_goals_overunder_over_175 "
query += " , pre_goals_overunder_under_175 "
query += " , pre_goals_overunder_over_20 "
query += " , pre_goals_overunder_under_20 "
query += " , pre_goals_overunder_over_225 "
query += " , pre_goals_overunder_under_225 "
query += " , pre_goals_overunder_over_25 "
query += " , pre_goals_overunder_under_25 "
query += " , pre_goals_overunder_over_275 "
query += " , pre_goals_overunder_under_275 "
query += " , pre_goals_overunder_over_30 "
query += " , pre_goals_overunder_under_30 "
query += " , pre_goals_overunder_over_325 "
query += " , pre_goals_overunder_under_325 "
query += " , pre_goals_overunder_over_35 "
query += " , pre_goals_overunder_under_35 "
query += " , pre_goals_overunder_over_375 "
query += " , pre_goals_overunder_under_375 "
query += " , pre_goals_overunder_over_40 "
query += " , pre_goals_overunder_under_40 "
query += " , pre_goals_overunder_over_425 "
query += " , pre_goals_overunder_under_425 "
query += " , pre_goals_overunder_over_45 "
query += " , pre_goals_overunder_under_45 "
query += " , pre_goals_overunder_over_475 "
query += " , pre_goals_overunder_under_475 "
query += " , pre_goals_overunder_over_50 "
query += " , pre_goals_overunder_under_50 "
query += " , pre_goals_overunder_over_525 "
query += " , pre_goals_overunder_under_525 "
query += " , pre_goals_overunder_over_55 "
query += " , pre_goals_overunder_under_55 "
query += " , pre_goals_overunder_over_575 "
query += " , pre_goals_overunder_under_575 "
query += " , pre_goals_overunder_over_60 "
query += " , pre_goals_overunder_under_60 "
query += " , pre_goals_overunder_over_625 "
query += " , pre_goals_overunder_under_625 "
query += " , pre_goals_overunder_over_65 "
query += " , pre_goals_overunder_under_65 "
query += " , pre_goals_overunder_over_675 "
query += " , pre_goals_overunder_under_675 "
query += " , pre_goals_overunder_over_70 "
query += " , pre_goals_overunder_under_70 "
query += " , pre_goals_overunder_over_75 "
query += " , pre_goals_overunder_under_75 "
query += " , pre_goals_overunder_over_85 "
query += " , pre_goals_overunder_under_85 "
query += " , pre_goals_overunder_over_95 "
query += " , pre_goals_overunder_under_95 "
query += " , end_goals_overunder_over_05 "
query += " , end_goals_overunder_under_05 "
query += " , end_goals_overunder_over_075 "
query += " , end_goals_overunder_under_075 "
query += " , end_goals_overunder_over_10 "
query += " , end_goals_overunder_under_10 "
query += " , end_goals_overunder_over_125 "
query += " , end_goals_overunder_under_125 "
query += " , end_goals_overunder_over_15 "
query += " , end_goals_overunder_under_15 "
query += " , end_goals_overunder_over_175 "
query += " , end_goals_overunder_under_175 "
query += " , end_goals_overunder_over_20 "
query += " , end_goals_overunder_under_20 "
query += " , end_goals_overunder_over_225 "
query += " , end_goals_overunder_under_225 "
query += " , end_goals_overunder_over_25 "
query += " , end_goals_overunder_under_25 "
query += " , end_goals_overunder_over_275 "
query += " , end_goals_overunder_under_275 "
query += " , end_goals_overunder_over_30 "
query += " , end_goals_overunder_under_30 "
query += " , end_goals_overunder_over_325 "
query += " , end_goals_overunder_under_325 "
query += " , end_goals_overunder_over_35 "
query += " , end_goals_overunder_under_35 "
query += " , end_goals_overunder_over_375 "
query += " , end_goals_overunder_under_375 "
query += " , end_goals_overunder_over_40 "
query += " , end_goals_overunder_under_40 "
query += " , end_goals_overunder_over_425 "
query += " , end_goals_overunder_under_425 "
query += " , end_goals_overunder_over_45 "
query += " , end_goals_overunder_under_45 "
query += " , end_goals_overunder_over_475 "
query += " , end_goals_overunder_under_475 "
query += " , end_goals_overunder_over_50 "
query += " , end_goals_overunder_under_50 "
query += " , end_goals_overunder_over_525 "
query += " , end_goals_overunder_under_525 "
query += " , end_goals_overunder_over_55 "
query += " , end_goals_overunder_under_55 "
query += " , end_goals_overunder_over_575 "
query += " , end_goals_overunder_under_575 "
query += " , end_goals_overunder_over_60 "
query += " , end_goals_overunder_under_60 "
query += " , end_goals_overunder_over_625 "
query += " , end_goals_overunder_under_625 "
query += " , end_goals_overunder_over_65 "
query += " , end_goals_overunder_under_65 "
query += " , end_goals_overunder_over_675 "
query += " , end_goals_overunder_under_675 "
query += " , end_goals_overunder_over_70 "
query += " , end_goals_overunder_under_70 "
query += " , end_goals_overunder_over_75 "
query += " , end_goals_overunder_under_75 "
query += " , end_goals_overunder_over_85 "
query += " , end_goals_overunder_under_85 "
query += " , end_goals_overunder_over_95 "
query += " , end_goals_overunder_under_95 "
query += " , pre_asian_handicap_first_half_home_min_175 "
query += " , pre_asian_handicap_first_half_away_min_175 "
query += " , pre_asian_handicap_first_half_home_min_15 "
query += " , pre_asian_handicap_first_half_away_min_15 "
query += " , pre_asian_handicap_first_half_home_min_125 "
query += " , pre_asian_handicap_first_half_away_min_125 "
query += " , pre_asian_handicap_first_half_home_min_1 "
query += " , pre_asian_handicap_first_half_away_min_1 "
query += " , pre_asian_handicap_first_half_home_min_075 "
query += " , pre_asian_handicap_first_half_away_min_075 "
query += " , pre_asian_handicap_first_half_home_min_05 "
query += " , pre_asian_handicap_first_half_away_min_05 "
query += " , pre_asian_handicap_first_half_home_min_025 "
query += " , pre_asian_handicap_first_half_away_min_025 "
query += " , pre_asian_handicap_first_half_home_plus_0 "
query += " , pre_asian_handicap_first_half_away_plus_0 "
query += " , pre_asian_handicap_first_half_home_plus_025 "
query += " , pre_asian_handicap_first_half_away_plus_025 "
query += " , pre_asian_handicap_first_half_home_plus_05 "
query += " , pre_asian_handicap_first_half_away_plus_05 "
query += " , pre_asian_handicap_first_half_home_plus_075 "
query += " , pre_asian_handicap_first_half_away_plus_075 "
query += " , pre_asian_handicap_first_half_home_plus_1 "
query += " , pre_asian_handicap_first_half_away_plus_1 "
query += " , pre_asian_handicap_first_half_home_plus_125 "
query += " , pre_asian_handicap_first_half_away_plus_125 "
query += " , pre_asian_handicap_first_half_home_plus_15 "
query += " , pre_asian_handicap_first_half_away_plus_15 "
query += " , pre_asian_handicap_first_half_home_plus_175 "
query += " , pre_asian_handicap_first_half_away_plus_175 "
query += " , end_asian_handicap_first_half_home_min_175 "
query += " , end_asian_handicap_first_half_away_min_175 "
query += " , end_asian_handicap_first_half_home_min_15 "
query += " , end_asian_handicap_first_half_away_min_15 "
query += " , end_asian_handicap_first_half_home_min_125 "
query += " , end_asian_handicap_first_half_away_min_125 "
query += " , end_asian_handicap_first_half_home_min_1 "
query += " , end_asian_handicap_first_half_away_min_1 "
query += " , end_asian_handicap_first_half_home_min_075 "
query += " , end_asian_handicap_first_half_away_min_075 "
query += " , end_asian_handicap_first_half_home_min_05 "
query += " , end_asian_handicap_first_half_away_min_05 "
query += " , end_asian_handicap_first_half_home_min_025 "
query += " , end_asian_handicap_first_half_away_min_025 "
query += " , end_asian_handicap_first_half_home_plus_0 "
query += " , end_asian_handicap_first_half_away_plus_0 "
query += " , end_asian_handicap_first_half_home_plus_025 "
query += " , end_asian_handicap_first_half_away_plus_025 "
query += " , end_asian_handicap_first_half_home_plus_05 "
query += " , end_asian_handicap_first_half_away_plus_05 "
query += " , end_asian_handicap_first_half_home_plus_075 "
query += " , end_asian_handicap_first_half_away_plus_075 "
query += " , end_asian_handicap_first_half_home_plus_1 "
query += " , end_asian_handicap_first_half_away_plus_1 "
query += " , end_asian_handicap_first_half_home_plus_125 "
query += " , end_asian_handicap_first_half_away_plus_125 "
query += " , end_asian_handicap_first_half_home_plus_15 "
query += " , end_asian_handicap_first_half_away_plus_15 "
query += " , end_asian_handicap_first_half_home_plus_175 "
query += " , end_asian_handicap_first_half_away_plus_175 "
query += " , pre_goals_overunder_first_half_over_05 "
query += " , pre_goals_overunder_first_half_under_05 "
query += " , pre_goals_overunder_first_half_over_075 "
query += " , pre_goals_overunder_first_half_under_075 "
query += " , pre_goals_overunder_first_half_over_10 "
query += " , pre_goals_overunder_first_half_under_10 "
query += " , pre_goals_overunder_first_half_over_125 "
query += " , pre_goals_overunder_first_half_under_125 "
query += " , pre_goals_overunder_first_half_over_15 "
query += " , pre_goals_overunder_first_half_under_15 "
query += " , pre_goals_overunder_first_half_over_175 "
query += " , pre_goals_overunder_first_half_under_175 "
query += " , pre_goals_overunder_first_half_over_20 "
query += " , pre_goals_overunder_first_half_under_20 "
query += " , pre_goals_overunder_first_half_over_225 "
query += " , pre_goals_overunder_first_half_under_225 "
query += " , pre_goals_overunder_first_half_over_25 "
query += " , pre_goals_overunder_first_half_under_25 "
query += " , pre_goals_overunder_first_half_over_275 "
query += " , pre_goals_overunder_first_half_under_275 "
query += " , pre_goals_overunder_first_half_over_30 "
query += " , pre_goals_overunder_first_half_under_30 "
query += " , pre_goals_overunder_first_half_over_325 "
query += " , pre_goals_overunder_first_half_under_325 "
query += " , pre_goals_overunder_first_half_over_35 "
query += " , pre_goals_overunder_first_half_under_35 "
query += " , pre_goals_overunder_first_half_over_375 "
query += " , pre_goals_overunder_first_half_under_375 "
query += " , end_goals_overunder_first_half_over_05 "
query += " , end_goals_overunder_first_half_under_05 "
query += " , end_goals_overunder_first_half_over_075 "
query += " , end_goals_overunder_first_half_under_075 "
query += " , end_goals_overunder_first_half_over_10 "
query += " , end_goals_overunder_first_half_under_10 "
query += " , end_goals_overunder_first_half_over_125 "
query += " , end_goals_overunder_first_half_under_125 "
query += " , end_goals_overunder_first_half_over_15 "
query += " , end_goals_overunder_first_half_under_15 "
query += " , end_goals_overunder_first_half_over_175 "
query += " , end_goals_overunder_first_half_under_175 "
query += " , end_goals_overunder_first_half_over_20 "
query += " , end_goals_overunder_first_half_under_20 "
query += " , end_goals_overunder_first_half_over_225 "
query += " , end_goals_overunder_first_half_under_225 "
query += " , end_goals_overunder_first_half_over_25 "
query += " , end_goals_overunder_first_half_under_25 "
query += " , end_goals_overunder_first_half_over_275 "
query += " , end_goals_overunder_first_half_under_275 "
query += " , end_goals_overunder_first_half_over_30 "
query += " , end_goals_overunder_first_half_under_30 "
query += " , end_goals_overunder_first_half_over_325 "
query += " , end_goals_overunder_first_half_under_325 "
query += " , end_goals_overunder_first_half_over_35 "
query += " , end_goals_overunder_first_half_under_35 "
query += " , end_goals_overunder_first_half_over_375 "
query += " , end_goals_overunder_first_half_under_375 "
query += " , pre_goals_overunder__second_half_over_05 "
query += " , pre_goals_overunder__second_half_under_05 "
query += " , pre_goals_overunder__second_half_over_075 "
query += " , pre_goals_overunder__second_half_under_075 "
query += " , pre_goals_overunder__second_half_over_10 "
query += " , pre_goals_overunder__second_half_under_10 "
query += " , pre_goals_overunder__second_half_over_125 "
query += " , pre_goals_overunder__second_half_under_125 "
query += " , pre_goals_overunder__second_half_over_15 "
query += " , pre_goals_overunder__second_half_under_15 "
query += " , pre_goals_overunder__second_half_over_175 "
query += " , pre_goals_overunder__second_half_under_175 "
query += " , pre_goals_overunder__second_half_over_20 "
query += " , pre_goals_overunder__second_half_under_20 "
query += " , pre_goals_overunder__second_half_over_225 "
query += " , pre_goals_overunder__second_half_under_225 "
query += " , pre_goals_overunder__second_half_over_25 "
query += " , pre_goals_overunder__second_half_under_25 "
query += " , pre_goals_overunder__second_half_over_275 "
query += " , pre_goals_overunder__second_half_under_275 "
query += " , pre_goals_overunder__second_half_over_30 "
query += " , pre_goals_overunder__second_half_under_30 "
query += " , pre_goals_overunder__second_half_over_325 "
query += " , pre_goals_overunder__second_half_under_325 "
query += " , pre_goals_overunder__second_half_over_35 "
query += " , pre_goals_overunder__second_half_under_35 "
query += " , pre_goals_overunder__second_half_over_375 "
query += " , pre_goals_overunder__second_half_under_375 "
query += " , end_goals_overunder__second_half_over_05 "
query += " , end_goals_overunder__second_half_under_05 "
query += " , end_goals_overunder__second_half_over_075 "
query += " , end_goals_overunder__second_half_under_075 "
query += " , end_goals_overunder__second_half_over_10 "
query += " , end_goals_overunder__second_half_under_10 "
query += " , end_goals_overunder__second_half_over_125 "
query += " , end_goals_overunder__second_half_under_125 "
query += " , end_goals_overunder__second_half_over_15 "
query += " , end_goals_overunder__second_half_under_15 "
query += " , end_goals_overunder__second_half_over_175 "
query += " , end_goals_overunder__second_half_under_175 "
query += " , end_goals_overunder__second_half_over_20 "
query += " , end_goals_overunder__second_half_under_20 "
query += " , end_goals_overunder__second_half_over_225 "
query += " , end_goals_overunder__second_half_under_225 "
query += " , end_goals_overunder__second_half_over_25 "
query += " , end_goals_overunder__second_half_under_25 "
query += " , end_goals_overunder__second_half_over_275 "
query += " , end_goals_overunder__second_half_under_275 "
query += " , end_goals_overunder__second_half_over_30 "
query += " , end_goals_overunder__second_half_under_30 "
query += " , end_goals_overunder__second_half_over_325 "
query += " , end_goals_overunder__second_half_under_325 "
query += " , end_goals_overunder__second_half_over_35 "
query += " , end_goals_overunder__second_half_under_35 "
query += " , end_goals_overunder__second_half_over_375 "
query += " , end_goals_overunder__second_half_under_375 "
query += " , pre_htft_double_home_home "
query += " , pre_htft_double_home_draw "
query += " , pre_htft_double_home_away "
query += " , pre_htft_double_draw_home "
query += " , pre_htft_double_draw_draw "
query += " , pre_htft_double_draw_away "
query += " , pre_htft_double_away_home "
query += " , pre_htft_double_away_draw "
query += " , pre_htft_double_away_away "
query += " , end_htft_double_home_home "
query += " , end_htft_double_home_draw "
query += " , end_htft_double_home_away "
query += " , end_htft_double_draw_home "
query += " , end_htft_double_draw_draw "
query += " , end_htft_double_draw_away "
query += " , end_htft_double_away_home "
query += " , end_htft_double_away_draw "
query += " , end_htft_double_away_away "
query += " , pre_both_teams_score_yes "
query += " , pre_both_teams_score_no "
query += " , end_both_teams_score_yes "
query += " , end_both_teams_score_no "
query += " , pre_both_teams_score__first_half_yes "
query += " , pre_both_teams_score__first_half_no "
query += " , end_both_teams_score__first_half_yes "
query += " , end_both_teams_score__first_half_no "
query += " , pre_both_teams_to_score__second_half_yes "
query += " , pre_both_teams_to_score__second_half_no "
query += " , end_both_teams_to_score__second_half_yes "
query += " , end_both_teams_to_score__second_half_no "
query += " , pre_results_both_teams_score_home_yes "
query += " , pre_results_both_teams_score_draw_yes "
query += " , pre_results_both_teams_score_away_yes "
query += " , pre_results_both_teams_score_home_no "
query += " , pre_results_both_teams_score_draw_no "
query += " , pre_results_both_teams_score_away_no "
query += " , end_results_both_teams_score_home_yes "
query += " , end_results_both_teams_score_draw_yes "
query += " , end_results_both_teams_score_away_yes "
query += " , end_results_both_teams_score_home_no "
query += " , end_results_both_teams_score_draw_no "
query += " , end_results_both_teams_score_away_no "
query += " , pre_to_score_in_both_halves_by_teams_home "
query += " , pre_to_score_in_both_halves_by_teams_away "
query += " , end_to_score_in_both_halves_by_teams_home "
query += " , end_to_score_in_both_halves_by_teams_away "
query += " , pre_total_goals_both_teams_to_score_over_yes_25 "
query += " , pre_total_goals_both_teams_to_score_over_no_25 "
query += " , pre_total_goals_both_teams_to_score_under_yes_25 "
query += " , pre_total_goals_both_teams_to_score_under_no_25 "
query += " , end_total_goals_both_teams_to_score_over_yes_25 "
query += " , end_total_goals_both_teams_to_score_over_no_25 "
query += " , end_total_goals_both_teams_to_score_under_yes_25 "
query += " , end_total_goals_both_teams_to_score_under_no_25 "
query += " , pre_both_teams_to_score_1st_half__2nd_half_yes_yes "
query += " , pre_both_teams_to_score_1st_half__2nd_half_yes_no "
query += " , pre_both_teams_to_score_1st_half__2nd_half_no_yes "
query += " , pre_both_teams_to_score_1st_half__2nd_half_no_no "
query += " , end_both_teams_to_score_1st_half__2nd_half_yes_yes "
query += " , end_both_teams_to_score_1st_half__2nd_half_yes_no "
query += " , end_both_teams_to_score_1st_half__2nd_half_no_yes "
query += " , end_both_teams_to_score_1st_half__2nd_half_no_no "
query += " , pre_highest_scoring_half_first "
query += " , pre_highest_scoring_half_draw "
query += " , pre_highest_scoring_half_second "
query += " , end_highest_scoring_half_first "
query += " , end_highest_scoring_half_draw "
query += " , end_highest_scoring_half_second "
query += " , pre_double_chance_home_draw "
query += " , pre_double_chance_home_away "
query += " , pre_double_chance_draw_away "
query += " , end_double_chance_home_draw "
query += " , end_double_chance_home_away "
query += " , end_double_chance_draw_away "
query += " , pre_double_chance__first_half_home_draw "
query += " , pre_double_chance__first_half_home_away "
query += " , pre_double_chance__first_half_draw_away "
query += " , end_double_chance__first_half_home_draw "
query += " , end_double_chance__first_half_home_away "
query += " , end_double_chance__first_half_draw_away "
query += " , pre_oddeven_odd "
query += " , pre_oddeven_even "
query += " , end_oddeven_odd "
query += " , end_oddeven_even "
query += " , pre_result_total_goals_home_over_35 "
query += " , pre_result_total_goals_draw_over_35 "
query += " , pre_result_total_goals_away_over_35 "
query += " , pre_result_total_goals_home_under_35 "
query += " , pre_result_total_goals_draw_under_35 "
query += " , pre_result_total_goals_away_under_35 "
query += " , pre_result_total_goals_home_over_25 "
query += " , pre_result_total_goals_draw_over_25 "
query += " , pre_result_total_goals_away_over_25 "
query += " , pre_result_total_goals_home_under_25 "
query += " , pre_result_total_goals_draw_under_25 "
query += " , pre_result_total_goals_away_under_25 "
query += " , end_result_total_goals_home_over_35 "
query += " , end_result_total_goals_draw_over_35 "
query += " , end_result_total_goals_away_over_35 "
query += " , end_result_total_goals_home_under_35 "
query += " , end_result_total_goals_draw_under_35 "
query += " , end_result_total_goals_away_under_35 "
query += " , end_result_total_goals_home_over_25 "
query += " , end_result_total_goals_draw_over_25 "
query += " , end_result_total_goals_away_over_25 "
query += " , end_result_total_goals_home_under_25 "
query += " , end_result_total_goals_draw_under_25 "
query += " , end_result_total_goals_away_under_25 "
query += " , pre_clean_sheet__home_yes "
query += " , pre_clean_sheet__home_no "
query += " , end_clean_sheet__home_yes "
query += " , end_clean_sheet__home_no "
query += " , pre_clean_sheet__away_yes "
query += " , pre_clean_sheet__away_no "
query += " , end_clean_sheet__away_yes "
query += " , end_clean_sheet__away_no "
query += " , pre_win_both_halves_home "
query += " , pre_win_both_halves_away "
query += " , end_win_both_halves_home "
query += " , end_win_both_halves_away "
query += " , pre_win_to_nil_home "
query += " , pre_win_to_nil_away "
query += " , end_win_to_nil_home "
query += " , end_win_to_nil_away "
query += " , pre_to_win_either_half_home "
query += " , pre_to_win_either_half_away "
query += " , end_to_win_either_half_home "
query += " , end_to_win_either_half_away "
query += " , pre_halftime_result_both_teams_score_home_yes "
query += " , pre_halftime_result_both_teams_score_draw_yes "
query += " , pre_halftime_result_both_teams_score_away_yes "
query += " , pre_halftime_result_both_teams_score_home_no "
query += " , pre_halftime_result_both_teams_score_draw_no "
query += " , pre_halftime_result_both_teams_score_away_no "
query += " , end_halftime_result_both_teams_score_home_yes "
query += " , end_halftime_result_both_teams_score_draw_yes "
query += " , end_halftime_result_both_teams_score_away_yes "
query += " , end_halftime_result_both_teams_score_home_no "
query += " , end_halftime_result_both_teams_score_draw_no "
query += " , end_halftime_result_both_teams_score_away_no "
query += " , pre_exact_goals_number_0 "
query += " , pre_exact_goals_number_1 "
query += " , pre_exact_goals_number_2 "
query += " , pre_exact_goals_number_3 "
query += " , pre_exact_goals_number_4 "
query += " , pre_exact_goals_number_5 "
query += " , pre_exact_goals_number_6 "
query += " , pre_exact_goals_number_more_7 "
query += " , end_exact_goals_number_0 "
query += " , end_exact_goals_number_1 "
query += " , end_exact_goals_number_2 "
query += " , end_exact_goals_number_3 "
query += " , end_exact_goals_number_4 "
query += " , end_exact_goals_number_5 "
query += " , end_exact_goals_number_6 "
query += " , end_exact_goals_number_more_7 "
query += " , pre_exact_goals_number__first_half_0 "
query += " , pre_exact_goals_number__first_half_1 "
query += " , pre_exact_goals_number__first_half_2 "
query += " , pre_exact_goals_number__first_half_3 "
query += " , pre_exact_goals_number__first_half_4 "
query += " , pre_exact_goals_number__first_half_more_5 "
query += " , end_exact_goals_number__first_half_0 "
query += " , end_exact_goals_number__first_half_1 "
query += " , end_exact_goals_number__first_half_2 "
query += " , end_exact_goals_number__first_half_3 "
query += " , end_exact_goals_number__first_half_4 "
query += " , end_exact_goals_number__first_half_more_5 "
query += " , pre_second_half_exact_goals_number_0 "
query += " , pre_second_half_exact_goals_number_1 "
query += " , pre_second_half_exact_goals_number_2 "
query += " , pre_second_half_exact_goals_number_3 "
query += " , pre_second_half_exact_goals_number_4 "
query += " , pre_second_half_exact_goals_number_more_5 "
query += " , end_second_half_exact_goals_number_0 "
query += " , end_second_half_exact_goals_number_1 "
query += " , end_second_half_exact_goals_number_2 "
query += " , end_second_half_exact_goals_number_3 "
query += " , end_second_half_exact_goals_number_4 "
query += " , end_second_half_exact_goals_number_more_5 "
query += " , pre_home_team_exact_goals_number_0 "
query += " , pre_home_team_exact_goals_number_1 "
query += " , pre_home_team_exact_goals_number_2 "
query += " , pre_home_team_exact_goals_number_more_3 "
query += " , end_home_team_exact_goals_number_0 "
query += " , end_home_team_exact_goals_number_1 "
query += " , end_home_team_exact_goals_number_2 "
query += " , end_home_team_exact_goals_number_more_3 "
query += " , pre_away_team_exact_goals_number_0 "
query += " , pre_away_team_exact_goals_number_1 "
query += " , pre_away_team_exact_goals_number_2 "
query += " , pre_away_team_exact_goals_number_more_3 "
query += " , end_away_team_exact_goals_number_0 "
query += " , end_away_team_exact_goals_number_1 "
query += " , end_away_team_exact_goals_number_2 "
query += " , end_away_team_exact_goals_number_more_3 "
query += " , pre_corners_winner_home "
query += " , pre_corners_winner_draw "
query += " , pre_corners_winner_away "
query += " , end_corners_winner_home "
query += " , end_corners_winner_draw "
query += " , end_corners_winner_away "
query += " , pre_10_overunder_over_05 "
query += " , pre_10_overunder_under_05 "
query += " , end_10_overunder_over_05 "
query += " , end_10_overunder_under_05 "
query += " , pre_cards_european_handicap_home_min_2 "
query += " , pre_cards_european_handicap_draw_min_2 "
query += " , pre_cards_european_handicap_away_min_2 "
query += " , pre_cards_european_handicap_home_min_1 "
query += " , pre_cards_european_handicap_draw_min_1 "
query += " , pre_cards_european_handicap_away_min_1 "
query += " , pre_cards_european_handicap_home_plus_0 "
query += " , pre_cards_european_handicap_draw_plus_0 "
query += " , pre_cards_european_handicap_away_plus_0 "
query += " , pre_cards_european_handicap_home_plus_1 "
query += " , pre_cards_european_handicap_draw_plus_1 "
query += " , pre_cards_european_handicap_away_plus_1 "
query += " , pre_cards_european_handicap_home_plus_2 "
query += " , pre_cards_european_handicap_draw_plus_2 "
query += " , pre_cards_european_handicap_away_plus_2 "
query += " , end_cards_european_handicap_home_min_2 "
query += " , end_cards_european_handicap_draw_min_2 "
query += " , end_cards_european_handicap_away_min_2 "
query += " , end_cards_european_handicap_home_min_1 "
query += " , end_cards_european_handicap_draw_min_1 "
query += " , end_cards_european_handicap_away_min_1 "
query += " , end_cards_european_handicap_home_plus_0 "
query += " , end_cards_european_handicap_draw_plus_0 "
query += " , end_cards_european_handicap_away_plus_0 "
query += " , end_cards_european_handicap_home_plus_1 "
query += " , end_cards_european_handicap_draw_plus_1 "
query += " , end_cards_european_handicap_away_plus_1 "
query += " , end_cards_european_handicap_home_plus_2 "
query += " , end_cards_european_handicap_draw_plus_2 "
query += " , end_cards_european_handicap_away_plus_2 "
query += " , pre_rcard_yes "
query += " , pre_rcard_no "
query += " , end_rcard_yes "
query += " , end_rcard_no "
query += " , pre_anytime_goal_scorer "
query += " , end_anytime_goal_scorer "
query += " , pre_first_goal_scorer "
query += " , end_first_goal_scorer "
query += " , pre_last_goal_scorer "
query += " , end_last_goal_scorer "
query += " , pre_to_score_two_or_more_goals "
query += " , end_to_score_two_or_more_goals "
query += " , pre_last_goal_scorer2 "
query += " , end_last_goal_scorer2 "
query += " , pre_exact_score "
query += " , end_exact_score "
query += " , pre_team_to_score_first_home "
query += " , pre_team_to_score_first_draw "
query += " , pre_team_to_score_first_away "
query += " , end_team_to_score_first_home "
query += " , end_team_to_score_first_draw "
query += " , end_team_to_score_first_away "
query += " , pre_team_to_score_last_home "
query += " , pre_team_to_score_last_draw "
query += " , pre_team_to_score_last_away "
query += " , end_team_to_score_last_home "
query += " , end_team_to_score_last_draw "
query += " , end_team_to_score_last_away "
query += " , pre_total_home_over_15 "
query += " , pre_total_home_under_15 "
query += " , pre_total_home_over_25 "
query += " , pre_total_home_under_25 "
query += " , pre_total_home_over_35 "
query += " , pre_total_home_under_35 "
query += " , pre_total_home_over_45 "
query += " , pre_total_home_under_45 "
query += " , pre_total_home_over_55 "
query += " , pre_total_home_under_55 "
query += " , pre_total_home_over_65 "
query += " , pre_total_home_under_65 "
query += " , end_total_home_over_15 "
query += " , end_total_home_under_15 "
query += " , end_total_home_over_25 "
query += " , end_total_home_under_25 "
query += " , end_total_home_over_35 "
query += " , end_total_home_under_35 "
query += " , end_total_home_over_45 "
query += " , end_total_home_under_45 "
query += " , end_total_home_over_55 "
query += " , end_total_home_under_55 "
query += " , end_total_home_over_65 "
query += " , end_total_home_under_65 "
query += " , pre_total_away_over_15 "
query += " , pre_total_away_under_15 "
query += " , pre_total_away_over_25 "
query += " , pre_total_away_under_25 "
query += " , pre_total_away_over_35 "
query += " , pre_total_away_under_35 "
query += " , pre_total_away_over_45 "
query += " , pre_total_away_under_45 "
query += " , pre_total_away_over_55 "
query += " , pre_total_away_under_55 "
query += " , pre_total_away_over_65 "
query += " , pre_total_away_under_65 "
query += " , end_total_away_over_15 "
query += " , end_total_away_under_15 "
query += " , end_total_away_over_25 "
query += " , end_total_away_under_25 "
query += " , end_total_away_over_35 "
query += " , end_total_away_under_35 "
query += " , end_total_away_over_45 "
query += " , end_total_away_under_45 "
query += " , end_total_away_over_55 "
query += " , end_total_away_under_55 "
query += " , end_total_away_over_65 "
query += " , end_total_away_under_65 "
query += " , pre_corners_asian_handicap_home_min_65 "
query += " , pre_corners_asian_handicap_away_min_65 "
query += " , pre_corners_asian_handicap_home_min_6 "
query += " , pre_corners_asian_handicap_away_min_6 "
query += " , pre_corners_asian_handicap_home_min_55 "
query += " , pre_corners_asian_handicap_away_min_55 "
query += " , pre_corners_asian_handicap_home_min_5 "
query += " , pre_corners_asian_handicap_away_min_5 "
query += " , pre_corners_asian_handicap_home_min_45 "
query += " , pre_corners_asian_handicap_away_min_45 "
query += " , pre_corners_asian_handicap_home_min_4 "
query += " , pre_corners_asian_handicap_away_min_4 "
query += " , pre_corners_asian_handicap_home_min_35 "
query += " , pre_corners_asian_handicap_away_min_35 "
query += " , pre_corners_asian_handicap_home_min_3 "
query += " , pre_corners_asian_handicap_away_min_3 "
query += " , pre_corners_asian_handicap_home_min_25 "
query += " , pre_corners_asian_handicap_away_min_25 "
query += " , pre_corners_asian_handicap_home_min_2 "
query += " , pre_corners_asian_handicap_away_min_2 "
query += " , pre_corners_asian_handicap_home_min_15 "
query += " , pre_corners_asian_handicap_away_min_15 "
query += " , pre_corners_asian_handicap_home_min_1 "
query += " , pre_corners_asian_handicap_home_min_05 "
query += " , pre_corners_asian_handicap_away_min_1 "
query += " , pre_corners_asian_handicap_away_min_05 "
query += " , pre_corners_asian_handicap_home_plus_0 "
query += " , pre_corners_asian_handicap_away_plus_0 "
query += " , pre_corners_asian_handicap_home_plus_05 "
query += " , pre_corners_asian_handicap_away_plus_05 "
query += " , pre_corners_asian_handicap_home_plus_1 "
query += " , pre_corners_asian_handicap_away_plus_1 "
query += " , pre_corners_asian_handicap_home_plus_15 "
query += " , pre_corners_asian_handicap_away_plus_15 "
query += " , pre_corners_asian_handicap_home_plus_2 "
query += " , pre_corners_asian_handicap_away_plus_2 "
query += " , pre_corners_asian_handicap_home_plus_25 "
query += " , pre_corners_asian_handicap_away_plus_25 "
query += " , pre_corners_asian_handicap_home_plus_3 "
query += " , pre_corners_asian_handicap_away_plus_3 "
query += " , pre_corners_asian_handicap_home_plus_35 "
query += " , pre_corners_asian_handicap_away_plus_35 "
query += " , pre_corners_asian_handicap_home_plus_4 "
query += " , pre_corners_asian_handicap_away_plus_4 "
query += " , pre_corners_asian_handicap_home_plus_45 "
query += " , pre_corners_asian_handicap_away_plus_45 "
query += " , pre_corners_asian_handicap_home_plus_5 "
query += " , pre_corners_asian_handicap_away_plus_5 "
query += " , pre_corners_asian_handicap_home_plus_55 "
query += " , pre_corners_asian_handicap_away_plus_55 "
query += " , pre_corners_asian_handicap_home_plus_6 "
query += " , pre_corners_asian_handicap_away_plus_6 "
query += " , pre_corners_asian_handicap_home_plus_65 "
query += " , pre_corners_asian_handicap_away_plus_65 "
query += " , end_corners_asian_handicap_home_min_65 "
query += " , end_corners_asian_handicap_away_min_65 "
query += " , end_corners_asian_handicap_home_min_6 "
query += " , end_corners_asian_handicap_away_min_6 "
query += " , end_corners_asian_handicap_home_min_55 "
query += " , end_corners_asian_handicap_away_min_55 "
query += " , end_corners_asian_handicap_home_min_5 "
query += " , end_corners_asian_handicap_away_min_5 "
query += " , end_corners_asian_handicap_home_min_45 "
query += " , end_corners_asian_handicap_away_min_45 "
query += " , end_corners_asian_handicap_home_min_4 "
query += " , end_corners_asian_handicap_away_min_4 "
query += " , end_corners_asian_handicap_home_min_35 "
query += " , end_corners_asian_handicap_away_min_35 "
query += " , end_corners_asian_handicap_home_min_3 "
query += " , end_corners_asian_handicap_away_min_3 "
query += " , end_corners_asian_handicap_home_min_25 "
query += " , end_corners_asian_handicap_away_min_25 "
query += " , end_corners_asian_handicap_home_min_2 "
query += " , end_corners_asian_handicap_away_min_2 "
query += " , end_corners_asian_handicap_home_min_15 "
query += " , end_corners_asian_handicap_away_min_15 "
query += " , end_corners_asian_handicap_home_min_1 "
query += " , end_corners_asian_handicap_home_min_05 "
query += " , end_corners_asian_handicap_away_min_1 "
query += " , end_corners_asian_handicap_away_min_05 "
query += " , end_corners_asian_handicap_home_plus_0 "
query += " , end_corners_asian_handicap_away_plus_0 "
query += " , end_corners_asian_handicap_home_plus_05 "
query += " , end_corners_asian_handicap_away_plus_05 "
query += " , end_corners_asian_handicap_home_plus_1 "
query += " , end_corners_asian_handicap_away_plus_1 "
query += " , end_corners_asian_handicap_home_plus_15 "
query += " , end_corners_asian_handicap_away_plus_15 "
query += " , end_corners_asian_handicap_home_plus_2 "
query += " , end_corners_asian_handicap_away_plus_2 "
query += " , end_corners_asian_handicap_home_plus_25 "
query += " , end_corners_asian_handicap_away_plus_25 "
query += " , end_corners_asian_handicap_home_plus_3 "
query += " , end_corners_asian_handicap_away_plus_3 "
query += " , end_corners_asian_handicap_home_plus_35 "
query += " , end_corners_asian_handicap_away_plus_35 "
query += " , end_corners_asian_handicap_home_plus_4 "
query += " , end_corners_asian_handicap_away_plus_4 "
query += " , end_corners_asian_handicap_home_plus_45 "
query += " , end_corners_asian_handicap_away_plus_45 "
query += " , end_corners_asian_handicap_home_plus_5 "
query += " , end_corners_asian_handicap_away_plus_5 "
query += " , end_corners_asian_handicap_home_plus_55 "
query += " , end_corners_asian_handicap_away_plus_55 "
query += " , end_corners_asian_handicap_home_plus_6 "
query += " , end_corners_asian_handicap_away_plus_6 "
query += " , end_corners_asian_handicap_home_plus_65 "
query += " , end_corners_asian_handicap_away_plus_65 "
query += " , pre_corners_over_under_over_700 "
query += " , pre_corners_over_under_under_700 "
query += " , pre_corners_over_under_over_725 "
query += " , pre_corners_over_under_under_725 "
query += " , pre_corners_over_under_over_750 "
query += " , pre_corners_over_under_under_750 "
query += " , pre_corners_over_under_over_775 "
query += " , pre_corners_over_under_under_775 "
query += " , pre_corners_over_under_over_800 "
query += " , pre_corners_over_under_under_800 "
query += " , pre_corners_over_under_over_825 "
query += " , pre_corners_over_under_under_825 "
query += " , pre_corners_over_under_over_850 "
query += " , pre_corners_over_under_under_850 "
query += " , pre_corners_over_under_over_875 "
query += " , pre_corners_over_under_under_875 "
query += " , pre_corners_over_under_over_900 "
query += " , pre_corners_over_under_under_900 "
query += " , pre_corners_over_under_over_925 "
query += " , pre_corners_over_under_under_925 "
query += " , pre_corners_over_under_over_950 "
query += " , pre_corners_over_under_under_950 "
query += " , pre_corners_over_under_over_975 "
query += " , pre_corners_over_under_under_975 "
query += " , pre_corners_over_under_over_1000 "
query += " , pre_corners_over_under_under_1000 "
query += " , pre_corners_over_under_over_1025 "
query += " , pre_corners_over_under_under_1025 "
query += " , pre_corners_over_under_over_1050 "
query += " , pre_corners_over_under_under_1050 "
query += " , pre_corners_over_under_over_1075 "
query += " , pre_corners_over_under_under_1075 "
query += " , pre_corners_over_under_over_1100 "
query += " , pre_corners_over_under_under_1100 "
query += " , pre_corners_over_under_over_1125 "
query += " , pre_corners_over_under_under_1125 "
query += " , pre_corners_over_under_over_1150 "
query += " , pre_corners_over_under_under_1150 "
query += " , pre_corners_over_under_over_1175 "
query += " , pre_corners_over_under_under_1175 "
query += " , pre_corners_over_under_over_1200 "
query += " , pre_corners_over_under_under_1200 "
query += " , pre_corners_over_under_over_1225 "
query += " , pre_corners_over_under_under_1225 "
query += " , pre_corners_over_under_over_1250 "
query += " , pre_corners_over_under_under_1250 "
query += " , pre_corners_over_under_over_1275 "
query += " , pre_corners_over_under_under_1275 "
query += " , end_corners_over_under_over_700 "
query += " , end_corners_over_under_under_700 "
query += " , end_corners_over_under_over_725 "
query += " , end_corners_over_under_under_725 "
query += " , end_corners_over_under_over_750 "
query += " , end_corners_over_under_under_750 "
query += " , end_corners_over_under_over_775 "
query += " , end_corners_over_under_under_775 "
query += " , end_corners_over_under_over_800 "
query += " , end_corners_over_under_under_800 "
query += " , end_corners_over_under_over_825 "
query += " , end_corners_over_under_under_825 "
query += " , end_corners_over_under_over_850 "
query += " , end_corners_over_under_under_850 "
query += " , end_corners_over_under_over_875 "
query += " , end_corners_over_under_under_875 "
query += " , end_corners_over_under_over_900 "
query += " , end_corners_over_under_under_900 "
query += " , end_corners_over_under_over_925 "
query += " , end_corners_over_under_under_925 "
query += " , end_corners_over_under_over_950 "
query += " , end_corners_over_under_under_950 "
query += " , end_corners_over_under_over_975 "
query += " , end_corners_over_under_under_975 "
query += " , end_corners_over_under_over_1000 "
query += " , end_corners_over_under_under_1000 "
query += " , end_corners_over_under_over_1025 "
query += " , end_corners_over_under_under_1025 "
query += " , end_corners_over_under_over_1050 "
query += " , end_corners_over_under_under_1050 "
query += " , end_corners_over_under_over_1075 "
query += " , end_corners_over_under_under_1075 "
query += " , end_corners_over_under_over_1100 "
query += " , end_corners_over_under_under_1100 "
query += " , end_corners_over_under_over_1125 "
query += " , end_corners_over_under_under_1125 "
query += " , end_corners_over_under_over_1150 "
query += " , end_corners_over_under_under_1150 "
query += " , end_corners_over_under_over_1175 "
query += " , end_corners_over_under_under_1175 "
query += " , end_corners_over_under_over_1200 "
query += " , end_corners_over_under_under_1200 "
query += " , end_corners_over_under_over_1225 "
query += " , end_corners_over_under_under_1225 "
query += " , end_corners_over_under_over_1250 "
query += " , end_corners_over_under_under_1250 "
query += " , end_corners_over_under_over_1275 "
query += " , end_corners_over_under_under_1275 "
query += " , pre_home_corners_overunder_over_25 "
query += " , pre_home_corners_overunder_under_25 "
query += " , pre_home_corners_overunder_over_35 "
query += " , pre_home_corners_overunder_under_35 "
query += " , pre_home_corners_overunder_over_45 "
query += " , pre_home_corners_overunder_under_45 "
query += " , pre_home_corners_overunder_over_55 "
query += " , pre_home_corners_overunder_under_55 "
query += " , pre_home_corners_overunder_over_65 "
query += " , pre_home_corners_overunder_under_65 "
query += " , pre_home_corners_overunder_over_75 "
query += " , pre_home_corners_overunder_under_75 "
query += " , pre_home_corners_overunder_over_85 "
query += " , pre_home_corners_overunder_under_85 "
query += " , end_home_corners_overunder_over_25 "
query += " , end_home_corners_overunder_under_25 "
query += " , end_home_corners_overunder_over_35 "
query += " , end_home_corners_overunder_under_35 "
query += " , end_home_corners_overunder_over_45 "
query += " , end_home_corners_overunder_under_45 "
query += " , end_home_corners_overunder_over_55 "
query += " , end_home_corners_overunder_under_55 "
query += " , end_home_corners_overunder_over_65 "
query += " , end_home_corners_overunder_under_65 "
query += " , end_home_corners_overunder_over_75 "
query += " , end_home_corners_overunder_under_75 "
query += " , end_home_corners_overunder_over_85 "
query += " , end_home_corners_overunder_under_85 "
query += " , pre_away_corners_overunder_over_25 "
query += " , pre_away_corners_overunder_under_25 "
query += " , pre_away_corners_overunder_over_35 "
query += " , pre_away_corners_overunder_under_35 "
query += " , pre_away_corners_overunder_over_45 "
query += " , pre_away_corners_overunder_under_45 "
query += " , pre_away_corners_overunder_over_55 "
query += " , pre_away_corners_overunder_under_55 "
query += " , pre_away_corners_overunder_over_65 "
query += " , pre_away_corners_overunder_under_65 "
query += " , pre_away_corners_overunder_over_75 "
query += " , pre_away_corners_overunder_under_75 "
query += " , pre_away_corners_overunder_over_85 "
query += " , pre_away_corners_overunder_under_85 "
query += " , end_away_corners_overunder_over_25 "
query += " , end_away_corners_overunder_under_25 "
query += " , end_away_corners_overunder_over_35 "
query += " , end_away_corners_overunder_under_35 "
query += " , end_away_corners_overunder_over_45 "
query += " , end_away_corners_overunder_under_45 "
query += " , end_away_corners_overunder_over_55 "
query += " , end_away_corners_overunder_under_55 "
query += " , end_away_corners_overunder_over_65 "
query += " , end_away_corners_overunder_under_65 "
query += " , end_away_corners_overunder_over_75 "
query += " , end_away_corners_overunder_under_75 "
query += " , end_away_corners_overunder_over_85 "
query += " , end_away_corners_overunder_under_85 "
query += " , pre_first_corner_home "
query += " , pre_first_corner_away "
query += " , end_first_corner_home "
query += " , end_first_corner_away "
query += " , pre_last_corner_home "
query += " , pre_last_corner_away "
query += " , end_last_corner_home "
query += " , end_last_corner_away "
query += " , pre_cards_asian_handicap_home_min_05 "
query += " , pre_cards_asian_handicap_away_min_05 "
query += " , pre_cards_asian_handicap_home_plus_0 "
query += " , pre_cards_asian_handicap_away_plus_0 "
query += " , pre_cards_asian_handicap_home_plus_05 "
query += " , pre_cards_asian_handicap_away_plus_05 "
query += " , end_cards_asian_handicap_home_min_05 "
query += " , end_cards_asian_handicap_away_min_05 "
query += " , end_cards_asian_handicap_home_plus_0 "
query += " , end_cards_asian_handicap_away_plus_0 "
query += " , end_cards_asian_handicap_home_plus_05 "
query += " , end_cards_asian_handicap_away_plus_05 "
query += " , pre_cards_overunder_over_25 "
query += " , pre_cards_overunder_under_25 "
query += " , pre_cards_overunder_over_35 "
query += " , pre_cards_overunder_under_35 "
query += " , pre_cards_overunder_over_45 "
query += " , pre_cards_overunder_under_45 "
query += " , pre_cards_overunder_over_55 "
query += " , pre_cards_overunder_under_55 "
query += " , pre_cards_overunder_over_65 "
query += " , pre_cards_overunder_under_65 "
query += " , pre_cards_overunder_over_75 "
query += " , pre_cards_overunder_under_75 "
query += " , end_cards_overunder_over_25 "
query += " , end_cards_overunder_under_25 "
query += " , end_cards_overunder_over_35 "
query += " , end_cards_overunder_under_35 "
query += " , end_cards_overunder_over_45 "
query += " , end_cards_overunder_under_45 "
query += " , end_cards_overunder_over_55 "
query += " , end_cards_overunder_under_55 "
query += " , end_cards_overunder_over_65 "
query += " , end_cards_overunder_under_65 "
query += " , end_cards_overunder_over_75 "
query += " , end_cards_overunder_under_75 "
query += " , pre_home_team_total_cards_over_15 "
query += " , pre_home_team_total_cards_under_15 "
query += " , pre_home_team_total_cards_over_25 "
query += " , pre_home_team_total_cards_under_25 "
query += " , pre_home_team_total_cards_over_35 "
query += " , pre_home_team_total_cards_under_35 "
query += " , end_home_team_total_cards_over_15 "
query += " , end_home_team_total_cards_under_15 "
query += " , end_home_team_total_cards_over_25 "
query += " , end_home_team_total_cards_under_25 "
query += " , end_home_team_total_cards_over_35 "
query += " , end_home_team_total_cards_under_35 "
query += " , pre_away_team_total_cards_over_15 "
query += " , pre_away_team_total_cards_under_15 "
query += " , pre_away_team_total_cards_over_25 "
query += " , pre_away_team_total_cards_under_25 "
query += " , pre_away_team_total_cards_over_35 "
query += " , pre_away_team_total_cards_under_35 "
query += " , end_away_team_total_cards_over_15 "
query += " , end_away_team_total_cards_under_15 "
query += " , end_away_team_total_cards_over_25 "
query += " , end_away_team_total_cards_under_25 "
query += " , end_away_team_total_cards_over_35 "
query += " , end_away_team_total_cards_under_35 "
query += " , pre_total_goals_under_2 "
query += " , pre_total_goals_2_or_3 "
query += " , pre_total_goals_over_3 "
query += " , end_total_goals_under_2 "
query += " , end_total_goals_2_or_3 "
query += " , end_total_goals_over_3 "
query += " , pre_first_goal_method_shot "
query += " , pre_first_goal_method_header "
query += " , pre_first_goal_method_penalty "
query += " , pre_first_goal_method_freekick "
query += " , pre_first_goal_method_owngoal "
query += " , pre_first_goal_method_draw "
query += " , end_first_goal_method_shot "
query += " , end_first_goal_method_header "
query += " , end_first_goal_method_penalty "
query += " , end_first_goal_method_freekick "
query += " , end_first_goal_method_owngoal "
query += " , end_first_goal_method_draw "
query += " , pre_to_score_a_penalty_home "
query += " , pre_to_score_a_penalty_away "
query += " , end_to_score_a_penalty_home "
query += " , end_to_score_a_penalty_away "
query += " , pre_to_miss_a_penalty_home "
query += " , pre_to_miss_a_penalty_away "
query += " , end_to_miss_a_penalty_home "
query += " , end_to_miss_a_penalty_away "
query += " , pre_player_to_be_booked "
query += " , end_player_to_be_booked "
query += " , pre_ah_pattern "
query += " , pre_ah_pattern_mirror "
query += " , pre_gou_pattern "
query += " , end_ah_pattern "
query += " , end_ah_pattern_mirror "
query += " , end_gou_pattern "
# ---------------------------------------------------------- 
query += " from football_fixturesx "  
query += " order by date asc "  
# ----------------------------------------------------------  
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
total_rows = len(result)
countdown = total_rows
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:  
    # ------------------------------------------------------ 
    date = "Null"
    fixtureapi_id = "Null"
    venueapi_id = "Null"
    referee = "Null"
    leagueapi_id = "Null"
    season = "Null"
    xround = "Null"
    fixture_status = "Null"
    fixture_elapsed = "Null"
    teams_homeapi_id = "Null"
    teams_awayapi_id = "Null"
    goals_home = "Null"
    goals_away = "Null"
    score_halftime_home = "Null"
    score_halftime_away = "Null"
    score_fulltime_home = "Null"
    score_fulltime_away = "Null"
    score_extratime_home = "Null"
    score_extratime_away = "Null"
    score_penalty_home = "Null"
    score_penalty_away = "Null"

    pre_match_winner_home  = "Null"
    pre_match_winner_draw  = "Null"
    pre_match_winner_away  = "Null"
    end_match_winner_home  = "Null"
    end_match_winner_draw  = "Null"
    end_match_winner_away  = "Null"
    pre_homeaway_home  = "Null"
    pre_homeaway_away  = "Null"
    end_homeaway_home  = "Null"
    end_homeaway_away  = "Null"
    pre_first_half_winner_home  = "Null"
    pre_first_half_winner_draw  = "Null"
    pre_first_half_winner_away  = "Null"
    end_first_half_winner_home  = "Null"
    end_first_half_winner_draw  = "Null"
    end_first_half_winner_away  = "Null"
    pre_second_half_winner_home  = "Null"
    pre_second_half_winner_draw  = "Null"
    pre_second_half_winner_away  = "Null"
    end_second_half_winner_home  = "Null"
    end_second_half_winner_draw  = "Null"
    end_second_half_winner_away  = "Null"
    pre_asian_handicap_home_min_675  = "Null"
    pre_asian_handicap_away_min_675  = "Null"
    pre_asian_handicap_home_min_65  = "Null"
    pre_asian_handicap_away_min_65  = "Null"
    pre_asian_handicap_home_min_625  = "Null"
    pre_asian_handicap_away_min_625  = "Null"
    pre_asian_handicap_home_min_6  = "Null"
    pre_asian_handicap_away_min_6  = "Null"
    pre_asian_handicap_home_min_575  = "Null"
    pre_asian_handicap_away_min_575  = "Null"
    pre_asian_handicap_home_min_55  = "Null"
    pre_asian_handicap_away_min_55  = "Null"
    pre_asian_handicap_home_min_525  = "Null"
    pre_asian_handicap_away_min_525  = "Null"
    pre_asian_handicap_home_min_5  = "Null"
    pre_asian_handicap_away_min_5  = "Null"
    pre_asian_handicap_home_min_475  = "Null"
    pre_asian_handicap_away_min_475  = "Null"
    pre_asian_handicap_home_min_45  = "Null"
    pre_asian_handicap_away_min_45  = "Null"
    pre_asian_handicap_home_min_425  = "Null"
    pre_asian_handicap_away_min_425  = "Null"
    pre_asian_handicap_home_min_4  = "Null"
    pre_asian_handicap_away_min_4  = "Null"
    pre_asian_handicap_home_min_375  = "Null"
    pre_asian_handicap_away_min_375  = "Null"
    pre_asian_handicap_home_min_35  = "Null"
    pre_asian_handicap_away_min_35  = "Null"
    pre_asian_handicap_home_min_325  = "Null"
    pre_asian_handicap_away_min_325  = "Null"
    pre_asian_handicap_home_min_3  = "Null"
    pre_asian_handicap_away_min_3  = "Null"
    pre_asian_handicap_home_min_275  = "Null"
    pre_asian_handicap_away_min_275  = "Null"
    pre_asian_handicap_home_min_25  = "Null"
    pre_asian_handicap_away_min_25  = "Null"
    pre_asian_handicap_home_min_225  = "Null"
    pre_asian_handicap_away_min_225  = "Null"
    pre_asian_handicap_home_min_2  = "Null"
    pre_asian_handicap_away_min_2  = "Null"
    pre_asian_handicap_home_min_175  = "Null"
    pre_asian_handicap_away_min_175  = "Null"
    pre_asian_handicap_home_min_15  = "Null"
    pre_asian_handicap_away_min_15  = "Null"
    pre_asian_handicap_home_min_125  = "Null"
    pre_asian_handicap_away_min_125  = "Null"
    pre_asian_handicap_home_min_1  = "Null"
    pre_asian_handicap_away_min_1  = "Null"
    pre_asian_handicap_home_min_075  = "Null"
    pre_asian_handicap_away_min_075  = "Null"
    pre_asian_handicap_home_min_05  = "Null"
    pre_asian_handicap_away_min_05  = "Null"
    pre_asian_handicap_home_min_025  = "Null"
    pre_asian_handicap_away_min_025  = "Null"
    pre_asian_handicap_home_plus_0  = "Null"
    pre_asian_handicap_away_plus_0  = "Null"
    pre_asian_handicap_home_plus_025  = "Null"
    pre_asian_handicap_away_plus_025  = "Null"
    pre_asian_handicap_home_plus_05  = "Null"
    pre_asian_handicap_away_plus_05  = "Null"
    pre_asian_handicap_home_plus_075  = "Null"
    pre_asian_handicap_away_plus_075  = "Null"
    pre_asian_handicap_home_plus_1  = "Null"
    pre_asian_handicap_away_plus_1  = "Null"
    pre_asian_handicap_home_plus_125  = "Null"
    pre_asian_handicap_away_plus_125  = "Null"
    pre_asian_handicap_home_plus_15  = "Null"
    pre_asian_handicap_away_plus_15  = "Null"
    pre_asian_handicap_home_plus_175  = "Null"
    pre_asian_handicap_away_plus_175  = "Null"
    pre_asian_handicap_home_plus_2  = "Null"
    pre_asian_handicap_away_plus_2  = "Null"
    pre_asian_handicap_home_plus_225  = "Null"
    pre_asian_handicap_away_plus_225  = "Null"
    pre_asian_handicap_home_plus_25  = "Null"
    pre_asian_handicap_away_plus_25  = "Null"
    pre_asian_handicap_home_plus_275  = "Null"
    pre_asian_handicap_away_plus_275  = "Null"
    pre_asian_handicap_home_plus_3  = "Null"
    pre_asian_handicap_away_plus_3  = "Null"
    pre_asian_handicap_home_plus_325  = "Null"
    pre_asian_handicap_away_plus_325  = "Null"
    pre_asian_handicap_home_plus_35  = "Null"
    pre_asian_handicap_away_plus_35  = "Null"
    pre_asian_handicap_home_plus_375  = "Null"
    pre_asian_handicap_away_plus_375  = "Null"
    pre_asian_handicap_home_plus_4  = "Null"
    pre_asian_handicap_away_plus_4  = "Null"
    pre_asian_handicap_home_plus_425  = "Null"
    pre_asian_handicap_away_plus_425  = "Null"
    pre_asian_handicap_home_plus_45  = "Null"
    pre_asian_handicap_away_plus_45  = "Null"
    pre_asian_handicap_home_plus_475  = "Null"
    pre_asian_handicap_away_plus_475  = "Null"
    pre_asian_handicap_home_plus_5  = "Null"
    pre_asian_handicap_away_plus_5  = "Null"
    pre_asian_handicap_home_plus_525  = "Null"
    pre_asian_handicap_away_plus_525  = "Null"
    pre_asian_handicap_home_plus_55  = "Null"
    pre_asian_handicap_away_plus_55  = "Null"
    pre_asian_handicap_home_plus_575  = "Null"
    pre_asian_handicap_away_plus_575  = "Null"
    pre_asian_handicap_home_plus_6  = "Null"
    pre_asian_handicap_away_plus_6  = "Null"
    pre_asian_handicap_home_plus_625  = "Null"
    pre_asian_handicap_away_plus_625  = "Null"
    pre_asian_handicap_home_plus_65  = "Null"
    pre_asian_handicap_away_plus_65  = "Null"
    pre_asian_handicap_home_plus_675  = "Null"
    pre_asian_handicap_away_plus_675  = "Null"
    end_asian_handicap_home_min_675  = "Null"
    end_asian_handicap_away_min_675  = "Null"
    end_asian_handicap_home_min_65  = "Null"
    end_asian_handicap_away_min_65  = "Null"
    end_asian_handicap_home_min_625  = "Null"
    end_asian_handicap_away_min_625  = "Null"
    end_asian_handicap_home_min_6  = "Null"
    end_asian_handicap_away_min_6  = "Null"
    end_asian_handicap_home_min_575  = "Null"
    end_asian_handicap_away_min_575  = "Null"
    end_asian_handicap_home_min_55  = "Null"
    end_asian_handicap_away_min_55  = "Null"
    end_asian_handicap_home_min_525  = "Null"
    end_asian_handicap_away_min_525  = "Null"
    end_asian_handicap_home_min_5  = "Null"
    end_asian_handicap_away_min_5  = "Null"
    end_asian_handicap_home_min_475  = "Null"
    end_asian_handicap_away_min_475  = "Null"
    end_asian_handicap_home_min_45  = "Null"
    end_asian_handicap_away_min_45  = "Null"
    end_asian_handicap_home_min_425  = "Null"
    end_asian_handicap_away_min_425  = "Null"
    end_asian_handicap_home_min_4  = "Null"
    end_asian_handicap_away_min_4  = "Null"
    end_asian_handicap_home_min_375  = "Null"
    end_asian_handicap_away_min_375  = "Null"
    end_asian_handicap_home_min_35  = "Null"
    end_asian_handicap_away_min_35  = "Null"
    end_asian_handicap_home_min_325  = "Null"
    end_asian_handicap_away_min_325  = "Null"
    end_asian_handicap_home_min_3  = "Null"
    end_asian_handicap_away_min_3  = "Null"
    end_asian_handicap_home_min_275  = "Null"
    end_asian_handicap_away_min_275  = "Null"
    end_asian_handicap_home_min_25  = "Null"
    end_asian_handicap_away_min_25  = "Null"
    end_asian_handicap_home_min_225  = "Null"
    end_asian_handicap_away_min_225  = "Null"
    end_asian_handicap_home_min_2  = "Null"
    end_asian_handicap_away_min_2  = "Null"
    end_asian_handicap_home_min_175  = "Null"
    end_asian_handicap_away_min_175  = "Null"
    end_asian_handicap_home_min_15  = "Null"
    end_asian_handicap_away_min_15  = "Null"
    end_asian_handicap_home_min_125  = "Null"
    end_asian_handicap_away_min_125  = "Null"
    end_asian_handicap_home_min_1  = "Null"
    end_asian_handicap_away_min_1  = "Null"
    end_asian_handicap_home_min_075  = "Null"
    end_asian_handicap_away_min_075  = "Null"
    end_asian_handicap_home_min_05  = "Null"
    end_asian_handicap_away_min_05  = "Null"
    end_asian_handicap_home_min_025  = "Null"
    end_asian_handicap_away_min_025  = "Null"
    end_asian_handicap_home_plus_0  = "Null"
    end_asian_handicap_away_plus_0  = "Null"
    end_asian_handicap_home_plus_025  = "Null"
    end_asian_handicap_away_plus_025  = "Null"
    end_asian_handicap_home_plus_05  = "Null"
    end_asian_handicap_away_plus_05  = "Null"
    end_asian_handicap_home_plus_075  = "Null"
    end_asian_handicap_away_plus_075  = "Null"
    end_asian_handicap_home_plus_1  = "Null"
    end_asian_handicap_away_plus_1  = "Null"
    end_asian_handicap_home_plus_125  = "Null"
    end_asian_handicap_away_plus_125  = "Null"
    end_asian_handicap_home_plus_15  = "Null"
    end_asian_handicap_away_plus_15  = "Null"
    end_asian_handicap_home_plus_175  = "Null"
    end_asian_handicap_away_plus_175  = "Null"
    end_asian_handicap_home_plus_2  = "Null"
    end_asian_handicap_away_plus_2  = "Null"
    end_asian_handicap_home_plus_225  = "Null"
    end_asian_handicap_away_plus_225  = "Null"
    end_asian_handicap_home_plus_25  = "Null"
    end_asian_handicap_away_plus_25  = "Null"
    end_asian_handicap_home_plus_275  = "Null"
    end_asian_handicap_away_plus_275  = "Null"
    end_asian_handicap_home_plus_3  = "Null"
    end_asian_handicap_away_plus_3  = "Null"
    end_asian_handicap_home_plus_325  = "Null"
    end_asian_handicap_away_plus_325  = "Null"
    end_asian_handicap_home_plus_35  = "Null"
    end_asian_handicap_away_plus_35  = "Null"
    end_asian_handicap_home_plus_375  = "Null"
    end_asian_handicap_away_plus_375  = "Null"
    end_asian_handicap_home_plus_4  = "Null"
    end_asian_handicap_away_plus_4  = "Null"
    end_asian_handicap_home_plus_425  = "Null"
    end_asian_handicap_away_plus_425  = "Null"
    end_asian_handicap_home_plus_45  = "Null"
    end_asian_handicap_away_plus_45  = "Null"
    end_asian_handicap_home_plus_475  = "Null"
    end_asian_handicap_away_plus_475  = "Null"
    end_asian_handicap_home_plus_5  = "Null"
    end_asian_handicap_away_plus_5  = "Null"
    end_asian_handicap_home_plus_525  = "Null"
    end_asian_handicap_away_plus_525  = "Null"
    end_asian_handicap_home_plus_55  = "Null"
    end_asian_handicap_away_plus_55  = "Null"
    end_asian_handicap_home_plus_575  = "Null"
    end_asian_handicap_away_plus_575  = "Null"
    end_asian_handicap_home_plus_6  = "Null"
    end_asian_handicap_away_plus_6  = "Null"
    end_asian_handicap_home_plus_625  = "Null"
    end_asian_handicap_away_plus_625  = "Null"
    end_asian_handicap_home_plus_65  = "Null"
    end_asian_handicap_away_plus_65  = "Null"
    end_asian_handicap_home_plus_675  = "Null"
    end_asian_handicap_away_plus_675  = "Null"
    pre_goals_overunder_over_05  = "Null"
    pre_goals_overunder_under_05  = "Null"
    pre_goals_overunder_over_075  = "Null"
    pre_goals_overunder_under_075  = "Null"
    pre_goals_overunder_over_10  = "Null"
    pre_goals_overunder_under_10  = "Null"
    pre_goals_overunder_over_125  = "Null"
    pre_goals_overunder_under_125  = "Null"
    pre_goals_overunder_over_15  = "Null"
    pre_goals_overunder_under_15  = "Null"
    pre_goals_overunder_over_175  = "Null"
    pre_goals_overunder_under_175  = "Null"
    pre_goals_overunder_over_20  = "Null"
    pre_goals_overunder_under_20  = "Null"
    pre_goals_overunder_over_225  = "Null"
    pre_goals_overunder_under_225  = "Null"
    pre_goals_overunder_over_25  = "Null"
    pre_goals_overunder_under_25  = "Null"
    pre_goals_overunder_over_275  = "Null"
    pre_goals_overunder_under_275  = "Null"
    pre_goals_overunder_over_30  = "Null"
    pre_goals_overunder_under_30  = "Null"
    pre_goals_overunder_over_325  = "Null"
    pre_goals_overunder_under_325  = "Null"
    pre_goals_overunder_over_35  = "Null"
    pre_goals_overunder_under_35  = "Null"
    pre_goals_overunder_over_375  = "Null"
    pre_goals_overunder_under_375  = "Null"
    pre_goals_overunder_over_40  = "Null"
    pre_goals_overunder_under_40  = "Null"
    pre_goals_overunder_over_425  = "Null"
    pre_goals_overunder_under_425  = "Null"
    pre_goals_overunder_over_45  = "Null"
    pre_goals_overunder_under_45  = "Null"
    pre_goals_overunder_over_475  = "Null"
    pre_goals_overunder_under_475  = "Null"
    pre_goals_overunder_over_50  = "Null"
    pre_goals_overunder_under_50  = "Null"
    pre_goals_overunder_over_525  = "Null"
    pre_goals_overunder_under_525  = "Null"
    pre_goals_overunder_over_55  = "Null"
    pre_goals_overunder_under_55  = "Null"
    pre_goals_overunder_over_575  = "Null"
    pre_goals_overunder_under_575  = "Null"
    pre_goals_overunder_over_60  = "Null"
    pre_goals_overunder_under_60  = "Null"
    pre_goals_overunder_over_625  = "Null"
    pre_goals_overunder_under_625  = "Null"
    pre_goals_overunder_over_65  = "Null"
    pre_goals_overunder_under_65  = "Null"
    pre_goals_overunder_over_675  = "Null"
    pre_goals_overunder_under_675  = "Null"
    pre_goals_overunder_over_70  = "Null"
    pre_goals_overunder_under_70  = "Null"
    pre_goals_overunder_over_75  = "Null"
    pre_goals_overunder_under_75  = "Null"
    pre_goals_overunder_over_85  = "Null"
    pre_goals_overunder_under_85  = "Null"
    pre_goals_overunder_over_95  = "Null"
    pre_goals_overunder_under_95  = "Null"
    end_goals_overunder_over_05  = "Null"
    end_goals_overunder_under_05  = "Null"
    end_goals_overunder_over_075  = "Null"
    end_goals_overunder_under_075  = "Null"
    end_goals_overunder_over_10  = "Null"
    end_goals_overunder_under_10  = "Null"
    end_goals_overunder_over_125  = "Null"
    end_goals_overunder_under_125  = "Null"
    end_goals_overunder_over_15  = "Null"
    end_goals_overunder_under_15  = "Null"
    end_goals_overunder_over_175  = "Null"
    end_goals_overunder_under_175  = "Null"
    end_goals_overunder_over_20  = "Null"
    end_goals_overunder_under_20  = "Null"
    end_goals_overunder_over_225  = "Null"
    end_goals_overunder_under_225  = "Null"
    end_goals_overunder_over_25  = "Null"
    end_goals_overunder_under_25  = "Null"
    end_goals_overunder_over_275  = "Null"
    end_goals_overunder_under_275  = "Null"
    end_goals_overunder_over_30  = "Null"
    end_goals_overunder_under_30  = "Null"
    end_goals_overunder_over_325  = "Null"
    end_goals_overunder_under_325  = "Null"
    end_goals_overunder_over_35  = "Null"
    end_goals_overunder_under_35  = "Null"
    end_goals_overunder_over_375  = "Null"
    end_goals_overunder_under_375  = "Null"
    end_goals_overunder_over_40  = "Null"
    end_goals_overunder_under_40  = "Null"
    end_goals_overunder_over_425  = "Null"
    end_goals_overunder_under_425  = "Null"
    end_goals_overunder_over_45  = "Null"
    end_goals_overunder_under_45  = "Null"
    end_goals_overunder_over_475  = "Null"
    end_goals_overunder_under_475  = "Null"
    end_goals_overunder_over_50  = "Null"
    end_goals_overunder_under_50  = "Null"
    end_goals_overunder_over_525  = "Null"
    end_goals_overunder_under_525  = "Null"
    end_goals_overunder_over_55  = "Null"
    end_goals_overunder_under_55  = "Null"
    end_goals_overunder_over_575  = "Null"
    end_goals_overunder_under_575  = "Null"
    end_goals_overunder_over_60  = "Null"
    end_goals_overunder_under_60  = "Null"
    end_goals_overunder_over_625  = "Null"
    end_goals_overunder_under_625  = "Null"
    end_goals_overunder_over_65  = "Null"
    end_goals_overunder_under_65  = "Null"
    end_goals_overunder_over_675  = "Null"
    end_goals_overunder_under_675  = "Null"
    end_goals_overunder_over_70  = "Null"
    end_goals_overunder_under_70  = "Null"
    end_goals_overunder_over_75  = "Null"
    end_goals_overunder_under_75  = "Null"
    end_goals_overunder_over_85  = "Null"
    end_goals_overunder_under_85  = "Null"
    end_goals_overunder_over_95  = "Null"
    end_goals_overunder_under_95  = "Null"
    pre_asian_handicap_first_half_home_min_175  = "Null"
    pre_asian_handicap_first_half_away_min_175  = "Null"
    pre_asian_handicap_first_half_home_min_15  = "Null"
    pre_asian_handicap_first_half_away_min_15  = "Null"
    pre_asian_handicap_first_half_home_min_125  = "Null"
    pre_asian_handicap_first_half_away_min_125  = "Null"
    pre_asian_handicap_first_half_home_min_1  = "Null"
    pre_asian_handicap_first_half_away_min_1  = "Null"
    pre_asian_handicap_first_half_home_min_075  = "Null"
    pre_asian_handicap_first_half_away_min_075  = "Null"
    pre_asian_handicap_first_half_home_min_05  = "Null"
    pre_asian_handicap_first_half_away_min_05  = "Null"
    pre_asian_handicap_first_half_home_min_025  = "Null"
    pre_asian_handicap_first_half_away_min_025  = "Null"
    pre_asian_handicap_first_half_home_plus_0  = "Null"
    pre_asian_handicap_first_half_away_plus_0  = "Null"
    pre_asian_handicap_first_half_home_plus_025  = "Null"
    pre_asian_handicap_first_half_away_plus_025  = "Null"
    pre_asian_handicap_first_half_home_plus_05  = "Null"
    pre_asian_handicap_first_half_away_plus_05  = "Null"
    pre_asian_handicap_first_half_home_plus_075  = "Null"
    pre_asian_handicap_first_half_away_plus_075  = "Null"
    pre_asian_handicap_first_half_home_plus_1  = "Null"
    pre_asian_handicap_first_half_away_plus_1  = "Null"
    pre_asian_handicap_first_half_home_plus_125  = "Null"
    pre_asian_handicap_first_half_away_plus_125  = "Null"
    pre_asian_handicap_first_half_home_plus_15  = "Null"
    pre_asian_handicap_first_half_away_plus_15  = "Null"
    pre_asian_handicap_first_half_home_plus_175  = "Null"
    pre_asian_handicap_first_half_away_plus_175  = "Null"
    end_asian_handicap_first_half_home_min_175  = "Null"
    end_asian_handicap_first_half_away_min_175  = "Null"
    end_asian_handicap_first_half_home_min_15  = "Null"
    end_asian_handicap_first_half_away_min_15  = "Null"
    end_asian_handicap_first_half_home_min_125  = "Null"
    end_asian_handicap_first_half_away_min_125  = "Null"
    end_asian_handicap_first_half_home_min_1  = "Null"
    end_asian_handicap_first_half_away_min_1  = "Null"
    end_asian_handicap_first_half_home_min_075  = "Null"
    end_asian_handicap_first_half_away_min_075  = "Null"
    end_asian_handicap_first_half_home_min_05  = "Null"
    end_asian_handicap_first_half_away_min_05  = "Null"
    end_asian_handicap_first_half_home_min_025  = "Null"
    end_asian_handicap_first_half_away_min_025  = "Null"
    end_asian_handicap_first_half_home_plus_0  = "Null"
    end_asian_handicap_first_half_away_plus_0  = "Null"
    end_asian_handicap_first_half_home_plus_025  = "Null"
    end_asian_handicap_first_half_away_plus_025  = "Null"
    end_asian_handicap_first_half_home_plus_05  = "Null"
    end_asian_handicap_first_half_away_plus_05  = "Null"
    end_asian_handicap_first_half_home_plus_075  = "Null"
    end_asian_handicap_first_half_away_plus_075  = "Null"
    end_asian_handicap_first_half_home_plus_1  = "Null"
    end_asian_handicap_first_half_away_plus_1  = "Null"
    end_asian_handicap_first_half_home_plus_125  = "Null"
    end_asian_handicap_first_half_away_plus_125  = "Null"
    end_asian_handicap_first_half_home_plus_15  = "Null"
    end_asian_handicap_first_half_away_plus_15  = "Null"
    end_asian_handicap_first_half_home_plus_175  = "Null"
    end_asian_handicap_first_half_away_plus_175  = "Null"
    pre_goals_overunder_first_half_over_05  = "Null"
    pre_goals_overunder_first_half_under_05  = "Null"
    pre_goals_overunder_first_half_over_075  = "Null"
    pre_goals_overunder_first_half_under_075  = "Null"
    pre_goals_overunder_first_half_over_10  = "Null"
    pre_goals_overunder_first_half_under_10  = "Null"
    pre_goals_overunder_first_half_over_125  = "Null"
    pre_goals_overunder_first_half_under_125  = "Null"
    pre_goals_overunder_first_half_over_15  = "Null"
    pre_goals_overunder_first_half_under_15  = "Null"
    pre_goals_overunder_first_half_over_175  = "Null"
    pre_goals_overunder_first_half_under_175  = "Null"
    pre_goals_overunder_first_half_over_20  = "Null"
    pre_goals_overunder_first_half_under_20  = "Null"
    pre_goals_overunder_first_half_over_225  = "Null"
    pre_goals_overunder_first_half_under_225  = "Null"
    pre_goals_overunder_first_half_over_25  = "Null"
    pre_goals_overunder_first_half_under_25  = "Null"
    pre_goals_overunder_first_half_over_275  = "Null"
    pre_goals_overunder_first_half_under_275  = "Null"
    pre_goals_overunder_first_half_over_30  = "Null"
    pre_goals_overunder_first_half_under_30  = "Null"
    pre_goals_overunder_first_half_over_325  = "Null"
    pre_goals_overunder_first_half_under_325  = "Null"
    pre_goals_overunder_first_half_over_35  = "Null"
    pre_goals_overunder_first_half_under_35  = "Null"
    pre_goals_overunder_first_half_over_375  = "Null"
    pre_goals_overunder_first_half_under_375  = "Null"
    end_goals_overunder_first_half_over_05  = "Null"
    end_goals_overunder_first_half_under_05  = "Null"
    end_goals_overunder_first_half_over_075  = "Null"
    end_goals_overunder_first_half_under_075  = "Null"
    end_goals_overunder_first_half_over_10  = "Null"
    end_goals_overunder_first_half_under_10  = "Null"
    end_goals_overunder_first_half_over_125  = "Null"
    end_goals_overunder_first_half_under_125  = "Null"
    end_goals_overunder_first_half_over_15  = "Null"
    end_goals_overunder_first_half_under_15  = "Null"
    end_goals_overunder_first_half_over_175  = "Null"
    end_goals_overunder_first_half_under_175  = "Null"
    end_goals_overunder_first_half_over_20  = "Null"
    end_goals_overunder_first_half_under_20  = "Null"
    end_goals_overunder_first_half_over_225  = "Null"
    end_goals_overunder_first_half_under_225  = "Null"
    end_goals_overunder_first_half_over_25  = "Null"
    end_goals_overunder_first_half_under_25  = "Null"
    end_goals_overunder_first_half_over_275  = "Null"
    end_goals_overunder_first_half_under_275  = "Null"
    end_goals_overunder_first_half_over_30  = "Null"
    end_goals_overunder_first_half_under_30  = "Null"
    end_goals_overunder_first_half_over_325  = "Null"
    end_goals_overunder_first_half_under_325  = "Null"
    end_goals_overunder_first_half_over_35  = "Null"
    end_goals_overunder_first_half_under_35  = "Null"
    end_goals_overunder_first_half_over_375  = "Null"
    end_goals_overunder_first_half_under_375  = "Null"
    pre_goals_overunder__second_half_over_05  = "Null"
    pre_goals_overunder__second_half_under_05  = "Null"
    pre_goals_overunder__second_half_over_075  = "Null"
    pre_goals_overunder__second_half_under_075  = "Null"
    pre_goals_overunder__second_half_over_10  = "Null"
    pre_goals_overunder__second_half_under_10  = "Null"
    pre_goals_overunder__second_half_over_125  = "Null"
    pre_goals_overunder__second_half_under_125  = "Null"
    pre_goals_overunder__second_half_over_15  = "Null"
    pre_goals_overunder__second_half_under_15  = "Null"
    pre_goals_overunder__second_half_over_175  = "Null"
    pre_goals_overunder__second_half_under_175  = "Null"
    pre_goals_overunder__second_half_over_20  = "Null"
    pre_goals_overunder__second_half_under_20  = "Null"
    pre_goals_overunder__second_half_over_225  = "Null"
    pre_goals_overunder__second_half_under_225  = "Null"
    pre_goals_overunder__second_half_over_25  = "Null"
    pre_goals_overunder__second_half_under_25  = "Null"
    pre_goals_overunder__second_half_over_275  = "Null"
    pre_goals_overunder__second_half_under_275  = "Null"
    pre_goals_overunder__second_half_over_30  = "Null"
    pre_goals_overunder__second_half_under_30  = "Null"
    pre_goals_overunder__second_half_over_325  = "Null"
    pre_goals_overunder__second_half_under_325  = "Null"
    pre_goals_overunder__second_half_over_35  = "Null"
    pre_goals_overunder__second_half_under_35  = "Null"
    pre_goals_overunder__second_half_over_375  = "Null"
    pre_goals_overunder__second_half_under_375  = "Null"
    end_goals_overunder__second_half_over_05  = "Null"
    end_goals_overunder__second_half_under_05  = "Null"
    end_goals_overunder__second_half_over_075  = "Null"
    end_goals_overunder__second_half_under_075  = "Null"
    end_goals_overunder__second_half_over_10  = "Null"
    end_goals_overunder__second_half_under_10  = "Null"
    end_goals_overunder__second_half_over_125  = "Null"
    end_goals_overunder__second_half_under_125  = "Null"
    end_goals_overunder__second_half_over_15  = "Null"
    end_goals_overunder__second_half_under_15  = "Null"
    end_goals_overunder__second_half_over_175  = "Null"
    end_goals_overunder__second_half_under_175  = "Null"
    end_goals_overunder__second_half_over_20  = "Null"
    end_goals_overunder__second_half_under_20  = "Null"
    end_goals_overunder__second_half_over_225  = "Null"
    end_goals_overunder__second_half_under_225  = "Null"
    end_goals_overunder__second_half_over_25  = "Null"
    end_goals_overunder__second_half_under_25  = "Null"
    end_goals_overunder__second_half_over_275  = "Null"
    end_goals_overunder__second_half_under_275  = "Null"
    end_goals_overunder__second_half_over_30  = "Null"
    end_goals_overunder__second_half_under_30  = "Null"
    end_goals_overunder__second_half_over_325  = "Null"
    end_goals_overunder__second_half_under_325  = "Null"
    end_goals_overunder__second_half_over_35  = "Null"
    end_goals_overunder__second_half_under_35  = "Null"
    end_goals_overunder__second_half_over_375  = "Null"
    end_goals_overunder__second_half_under_375  = "Null"
    pre_htft_double_home_home  = "Null"
    pre_htft_double_home_draw  = "Null"
    pre_htft_double_home_away  = "Null"
    pre_htft_double_draw_home  = "Null"
    pre_htft_double_draw_draw  = "Null"
    pre_htft_double_draw_away  = "Null"
    pre_htft_double_away_home  = "Null"
    pre_htft_double_away_draw  = "Null"
    pre_htft_double_away_away  = "Null"
    end_htft_double_home_home  = "Null"
    end_htft_double_home_draw  = "Null"
    end_htft_double_home_away  = "Null"
    end_htft_double_draw_home  = "Null"
    end_htft_double_draw_draw  = "Null"
    end_htft_double_draw_away  = "Null"
    end_htft_double_away_home  = "Null"
    end_htft_double_away_draw  = "Null"
    end_htft_double_away_away  = "Null"
    pre_both_teams_score_yes  = "Null"
    pre_both_teams_score_no  = "Null"
    end_both_teams_score_yes  = "Null"
    end_both_teams_score_no  = "Null"
    pre_both_teams_score__first_half_yes  = "Null"
    pre_both_teams_score__first_half_no  = "Null"
    end_both_teams_score__first_half_yes  = "Null"
    end_both_teams_score__first_half_no  = "Null"
    pre_both_teams_to_score__second_half_yes  = "Null"
    pre_both_teams_to_score__second_half_no  = "Null"
    end_both_teams_to_score__second_half_yes  = "Null"
    end_both_teams_to_score__second_half_no  = "Null"
    pre_results_both_teams_score_home_yes  = "Null"
    pre_results_both_teams_score_draw_yes  = "Null"
    pre_results_both_teams_score_away_yes  = "Null"
    pre_results_both_teams_score_home_no  = "Null"
    pre_results_both_teams_score_draw_no  = "Null"
    pre_results_both_teams_score_away_no  = "Null"
    end_results_both_teams_score_home_yes  = "Null"
    end_results_both_teams_score_draw_yes  = "Null"
    end_results_both_teams_score_away_yes  = "Null"
    end_results_both_teams_score_home_no  = "Null"
    end_results_both_teams_score_draw_no  = "Null"
    end_results_both_teams_score_away_no  = "Null"
    pre_to_score_in_both_halves_by_teams_home  = "Null"
    pre_to_score_in_both_halves_by_teams_away  = "Null"
    end_to_score_in_both_halves_by_teams_home  = "Null"
    end_to_score_in_both_halves_by_teams_away  = "Null"
    pre_total_goals_both_teams_to_score_over_yes_25  = "Null"
    pre_total_goals_both_teams_to_score_over_no_25  = "Null"
    pre_total_goals_both_teams_to_score_under_yes_25  = "Null"
    pre_total_goals_both_teams_to_score_under_no_25  = "Null"
    end_total_goals_both_teams_to_score_over_yes_25  = "Null"
    end_total_goals_both_teams_to_score_over_no_25  = "Null"
    end_total_goals_both_teams_to_score_under_yes_25  = "Null"
    end_total_goals_both_teams_to_score_under_no_25  = "Null"
    pre_both_teams_to_score_1st_half__2nd_half_yes_yes  = "Null"
    pre_both_teams_to_score_1st_half__2nd_half_yes_no  = "Null"
    pre_both_teams_to_score_1st_half__2nd_half_no_yes  = "Null"
    pre_both_teams_to_score_1st_half__2nd_half_no_no  = "Null"
    end_both_teams_to_score_1st_half__2nd_half_yes_yes  = "Null"
    end_both_teams_to_score_1st_half__2nd_half_yes_no  = "Null"
    end_both_teams_to_score_1st_half__2nd_half_no_yes  = "Null"
    end_both_teams_to_score_1st_half__2nd_half_no_no  = "Null"
    pre_highest_scoring_half_first  = "Null"
    pre_highest_scoring_half_draw  = "Null"
    pre_highest_scoring_half_second  = "Null"
    end_highest_scoring_half_first  = "Null"
    end_highest_scoring_half_draw  = "Null"
    end_highest_scoring_half_second  = "Null"
    pre_double_chance_home_draw  = "Null"
    pre_double_chance_home_away  = "Null"
    pre_double_chance_draw_away  = "Null"
    end_double_chance_home_draw  = "Null"
    end_double_chance_home_away  = "Null"
    end_double_chance_draw_away  = "Null"
    pre_double_chance__first_half_home_draw  = "Null"
    pre_double_chance__first_half_home_away  = "Null"
    pre_double_chance__first_half_draw_away  = "Null"
    end_double_chance__first_half_home_draw  = "Null"
    end_double_chance__first_half_home_away  = "Null"
    end_double_chance__first_half_draw_away  = "Null"
    pre_oddeven_odd  = "Null"
    pre_oddeven_even  = "Null"
    end_oddeven_odd  = "Null"
    end_oddeven_even  = "Null"
    pre_result_total_goals_home_over_35  = "Null"
    pre_result_total_goals_draw_over_35  = "Null"
    pre_result_total_goals_away_over_35  = "Null"
    pre_result_total_goals_home_under_35  = "Null"
    pre_result_total_goals_draw_under_35  = "Null"
    pre_result_total_goals_away_under_35  = "Null"
    pre_result_total_goals_home_over_25  = "Null"
    pre_result_total_goals_draw_over_25  = "Null"
    pre_result_total_goals_away_over_25  = "Null"
    pre_result_total_goals_home_under_25  = "Null"
    pre_result_total_goals_draw_under_25  = "Null"
    pre_result_total_goals_away_under_25  = "Null"
    end_result_total_goals_home_over_35  = "Null"
    end_result_total_goals_draw_over_35  = "Null"
    end_result_total_goals_away_over_35  = "Null"
    end_result_total_goals_home_under_35  = "Null"
    end_result_total_goals_draw_under_35  = "Null"
    end_result_total_goals_away_under_35  = "Null"
    end_result_total_goals_home_over_25  = "Null"
    end_result_total_goals_draw_over_25  = "Null"
    end_result_total_goals_away_over_25  = "Null"
    end_result_total_goals_home_under_25  = "Null"
    end_result_total_goals_draw_under_25  = "Null"
    end_result_total_goals_away_under_25  = "Null"
    pre_clean_sheet__home_yes  = "Null"
    pre_clean_sheet__home_no  = "Null"
    end_clean_sheet__home_yes  = "Null"
    end_clean_sheet__home_no  = "Null"
    pre_clean_sheet__away_yes  = "Null"
    pre_clean_sheet__away_no  = "Null"
    end_clean_sheet__away_yes  = "Null"
    end_clean_sheet__away_no  = "Null"
    pre_win_both_halves_home  = "Null"
    pre_win_both_halves_away  = "Null"
    end_win_both_halves_home  = "Null"
    end_win_both_halves_away  = "Null"
    pre_win_to_nil_home  = "Null"
    pre_win_to_nil_away  = "Null"
    end_win_to_nil_home  = "Null"
    end_win_to_nil_away  = "Null"
    pre_to_win_either_half_home  = "Null"
    pre_to_win_either_half_away  = "Null"
    end_to_win_either_half_home  = "Null"
    end_to_win_either_half_away  = "Null"
    pre_halftime_result_both_teams_score_home_yes  = "Null"
    pre_halftime_result_both_teams_score_draw_yes  = "Null"
    pre_halftime_result_both_teams_score_away_yes  = "Null"
    pre_halftime_result_both_teams_score_home_no  = "Null"
    pre_halftime_result_both_teams_score_draw_no  = "Null"
    pre_halftime_result_both_teams_score_away_no  = "Null"
    end_halftime_result_both_teams_score_home_yes  = "Null"
    end_halftime_result_both_teams_score_draw_yes  = "Null"
    end_halftime_result_both_teams_score_away_yes  = "Null"
    end_halftime_result_both_teams_score_home_no  = "Null"
    end_halftime_result_both_teams_score_draw_no  = "Null"
    end_halftime_result_both_teams_score_away_no  = "Null"
    pre_exact_goals_number_0  = "Null"
    pre_exact_goals_number_1  = "Null"
    pre_exact_goals_number_2  = "Null"
    pre_exact_goals_number_3  = "Null"
    pre_exact_goals_number_4  = "Null"
    pre_exact_goals_number_5  = "Null"
    pre_exact_goals_number_6  = "Null"
    pre_exact_goals_number_more_7  = "Null"
    end_exact_goals_number_0  = "Null"
    end_exact_goals_number_1  = "Null"
    end_exact_goals_number_2  = "Null"
    end_exact_goals_number_3  = "Null"
    end_exact_goals_number_4  = "Null"
    end_exact_goals_number_5  = "Null"
    end_exact_goals_number_6  = "Null"
    end_exact_goals_number_more_7  = "Null"
    pre_exact_goals_number__first_half_0  = "Null"
    pre_exact_goals_number__first_half_1  = "Null"
    pre_exact_goals_number__first_half_2  = "Null"
    pre_exact_goals_number__first_half_3  = "Null"
    pre_exact_goals_number__first_half_4  = "Null"
    pre_exact_goals_number__first_half_more_5  = "Null"
    end_exact_goals_number__first_half_0  = "Null"
    end_exact_goals_number__first_half_1  = "Null"
    end_exact_goals_number__first_half_2  = "Null"
    end_exact_goals_number__first_half_3  = "Null"
    end_exact_goals_number__first_half_4  = "Null"
    end_exact_goals_number__first_half_more_5  = "Null"
    pre_second_half_exact_goals_number_0  = "Null"
    pre_second_half_exact_goals_number_1  = "Null"
    pre_second_half_exact_goals_number_2  = "Null"
    pre_second_half_exact_goals_number_3  = "Null"
    pre_second_half_exact_goals_number_4  = "Null"
    pre_second_half_exact_goals_number_more_5  = "Null"
    end_second_half_exact_goals_number_0  = "Null"
    end_second_half_exact_goals_number_1  = "Null"
    end_second_half_exact_goals_number_2  = "Null"
    end_second_half_exact_goals_number_3  = "Null"
    end_second_half_exact_goals_number_4  = "Null"
    end_second_half_exact_goals_number_more_5  = "Null"
    pre_home_team_exact_goals_number_0  = "Null"
    pre_home_team_exact_goals_number_1  = "Null"
    pre_home_team_exact_goals_number_2  = "Null"
    pre_home_team_exact_goals_number_more_3  = "Null"
    end_home_team_exact_goals_number_0  = "Null"
    end_home_team_exact_goals_number_1  = "Null"
    end_home_team_exact_goals_number_2  = "Null"
    end_home_team_exact_goals_number_more_3  = "Null"
    pre_away_team_exact_goals_number_0  = "Null"
    pre_away_team_exact_goals_number_1  = "Null"
    pre_away_team_exact_goals_number_2  = "Null"
    pre_away_team_exact_goals_number_more_3  = "Null"
    end_away_team_exact_goals_number_0  = "Null"
    end_away_team_exact_goals_number_1  = "Null"
    end_away_team_exact_goals_number_2  = "Null"
    end_away_team_exact_goals_number_more_3  = "Null"
    pre_corners_winner_home  = "Null"
    pre_corners_winner_draw  = "Null"
    pre_corners_winner_away  = "Null"
    end_corners_winner_home  = "Null"
    end_corners_winner_draw  = "Null"
    end_corners_winner_away  = "Null"
    pre_10_overunder_over_05  = "Null"
    pre_10_overunder_under_05  = "Null"
    end_10_overunder_over_05  = "Null"
    end_10_overunder_under_05  = "Null"
    pre_cards_european_handicap_home_min_2  = "Null"
    pre_cards_european_handicap_draw_min_2  = "Null"
    pre_cards_european_handicap_away_min_2  = "Null"
    pre_cards_european_handicap_home_min_1  = "Null"
    pre_cards_european_handicap_draw_min_1  = "Null"
    pre_cards_european_handicap_away_min_1  = "Null"
    pre_cards_european_handicap_home_plus_0  = "Null"
    pre_cards_european_handicap_draw_plus_0  = "Null"
    pre_cards_european_handicap_away_plus_0  = "Null"
    pre_cards_european_handicap_home_plus_1  = "Null"
    pre_cards_european_handicap_draw_plus_1  = "Null"
    pre_cards_european_handicap_away_plus_1  = "Null"
    pre_cards_european_handicap_home_plus_2  = "Null"
    pre_cards_european_handicap_draw_plus_2  = "Null"
    pre_cards_european_handicap_away_plus_2  = "Null"
    end_cards_european_handicap_home_min_2  = "Null"
    end_cards_european_handicap_draw_min_2  = "Null"
    end_cards_european_handicap_away_min_2  = "Null"
    end_cards_european_handicap_home_min_1  = "Null"
    end_cards_european_handicap_draw_min_1  = "Null"
    end_cards_european_handicap_away_min_1  = "Null"
    end_cards_european_handicap_home_plus_0  = "Null"
    end_cards_european_handicap_draw_plus_0  = "Null"
    end_cards_european_handicap_away_plus_0  = "Null"
    end_cards_european_handicap_home_plus_1  = "Null"
    end_cards_european_handicap_draw_plus_1  = "Null"
    end_cards_european_handicap_away_plus_1  = "Null"
    end_cards_european_handicap_home_plus_2  = "Null"
    end_cards_european_handicap_draw_plus_2  = "Null"
    end_cards_european_handicap_away_plus_2  = "Null"
    pre_rcard_yes  = "Null"
    pre_rcard_no  = "Null"
    end_rcard_yes  = "Null"
    end_rcard_no  = "Null"
    pre_anytime_goal_scorer  = "Null"
    end_anytime_goal_scorer  = "Null"
    pre_first_goal_scorer  = "Null"
    end_first_goal_scorer  = "Null"
    pre_last_goal_scorer  = "Null"
    end_last_goal_scorer  = "Null"
    pre_to_score_two_or_more_goals  = "Null"
    end_to_score_two_or_more_goals  = "Null"
    pre_last_goal_scorer2  = "Null"
    end_last_goal_scorer2  = "Null"
    pre_exact_score  = "Null"
    end_exact_score  = "Null"
    pre_team_to_score_first_home  = "Null"
    pre_team_to_score_first_draw  = "Null"
    pre_team_to_score_first_away  = "Null"
    end_team_to_score_first_home  = "Null"
    end_team_to_score_first_draw  = "Null"
    end_team_to_score_first_away  = "Null"
    pre_team_to_score_last_home  = "Null"
    pre_team_to_score_last_draw  = "Null"
    pre_team_to_score_last_away  = "Null"
    end_team_to_score_last_home  = "Null"
    end_team_to_score_last_draw  = "Null"
    end_team_to_score_last_away  = "Null"
    pre_total_home_over_15  = "Null"
    pre_total_home_under_15  = "Null"
    pre_total_home_over_25  = "Null"
    pre_total_home_under_25  = "Null"
    pre_total_home_over_35  = "Null"
    pre_total_home_under_35  = "Null"
    pre_total_home_over_45  = "Null"
    pre_total_home_under_45  = "Null"
    pre_total_home_over_55  = "Null"
    pre_total_home_under_55  = "Null"
    pre_total_home_over_65  = "Null"
    pre_total_home_under_65  = "Null"
    end_total_home_over_15  = "Null"
    end_total_home_under_15  = "Null"
    end_total_home_over_25  = "Null"
    end_total_home_under_25  = "Null"
    end_total_home_over_35  = "Null"
    end_total_home_under_35  = "Null"
    end_total_home_over_45  = "Null"
    end_total_home_under_45  = "Null"
    end_total_home_over_55  = "Null"
    end_total_home_under_55  = "Null"
    end_total_home_over_65  = "Null"
    end_total_home_under_65  = "Null"
    pre_total_away_over_15  = "Null"
    pre_total_away_under_15  = "Null"
    pre_total_away_over_25  = "Null"
    pre_total_away_under_25  = "Null"
    pre_total_away_over_35  = "Null"
    pre_total_away_under_35  = "Null"
    pre_total_away_over_45  = "Null"
    pre_total_away_under_45  = "Null"
    pre_total_away_over_55  = "Null"
    pre_total_away_under_55  = "Null"
    pre_total_away_over_65  = "Null"
    pre_total_away_under_65  = "Null"
    end_total_away_over_15  = "Null"
    end_total_away_under_15  = "Null"
    end_total_away_over_25  = "Null"
    end_total_away_under_25  = "Null"
    end_total_away_over_35  = "Null"
    end_total_away_under_35  = "Null"
    end_total_away_over_45  = "Null"
    end_total_away_under_45  = "Null"
    end_total_away_over_55  = "Null"
    end_total_away_under_55  = "Null"
    end_total_away_over_65  = "Null"
    end_total_away_under_65  = "Null"
    pre_corners_asian_handicap_home_min_65  = "Null"
    pre_corners_asian_handicap_away_min_65  = "Null"
    pre_corners_asian_handicap_home_min_6  = "Null"
    pre_corners_asian_handicap_away_min_6  = "Null"
    pre_corners_asian_handicap_home_min_55  = "Null"
    pre_corners_asian_handicap_away_min_55  = "Null"
    pre_corners_asian_handicap_home_min_5  = "Null"
    pre_corners_asian_handicap_away_min_5  = "Null"
    pre_corners_asian_handicap_home_min_45  = "Null"
    pre_corners_asian_handicap_away_min_45  = "Null"
    pre_corners_asian_handicap_home_min_4  = "Null"
    pre_corners_asian_handicap_away_min_4  = "Null"
    pre_corners_asian_handicap_home_min_35  = "Null"
    pre_corners_asian_handicap_away_min_35  = "Null"
    pre_corners_asian_handicap_home_min_3  = "Null"
    pre_corners_asian_handicap_away_min_3  = "Null"
    pre_corners_asian_handicap_home_min_25  = "Null"
    pre_corners_asian_handicap_away_min_25  = "Null"
    pre_corners_asian_handicap_home_min_2  = "Null"
    pre_corners_asian_handicap_away_min_2  = "Null"
    pre_corners_asian_handicap_home_min_15  = "Null"
    pre_corners_asian_handicap_away_min_15  = "Null"
    pre_corners_asian_handicap_home_min_1  = "Null"
    pre_corners_asian_handicap_home_min_05  = "Null"
    pre_corners_asian_handicap_away_min_1  = "Null"
    pre_corners_asian_handicap_away_min_05  = "Null"
    pre_corners_asian_handicap_home_plus_0  = "Null"
    pre_corners_asian_handicap_away_plus_0  = "Null"
    pre_corners_asian_handicap_home_plus_05  = "Null"
    pre_corners_asian_handicap_away_plus_05  = "Null"
    pre_corners_asian_handicap_home_plus_1  = "Null"
    pre_corners_asian_handicap_away_plus_1  = "Null"
    pre_corners_asian_handicap_home_plus_15  = "Null"
    pre_corners_asian_handicap_away_plus_15  = "Null"
    pre_corners_asian_handicap_home_plus_2  = "Null"
    pre_corners_asian_handicap_away_plus_2  = "Null"
    pre_corners_asian_handicap_home_plus_25  = "Null"
    pre_corners_asian_handicap_away_plus_25  = "Null"
    pre_corners_asian_handicap_home_plus_3  = "Null"
    pre_corners_asian_handicap_away_plus_3  = "Null"
    pre_corners_asian_handicap_home_plus_35  = "Null"
    pre_corners_asian_handicap_away_plus_35  = "Null"
    pre_corners_asian_handicap_home_plus_4  = "Null"
    pre_corners_asian_handicap_away_plus_4  = "Null"
    pre_corners_asian_handicap_home_plus_45  = "Null"
    pre_corners_asian_handicap_away_plus_45  = "Null"
    pre_corners_asian_handicap_home_plus_5  = "Null"
    pre_corners_asian_handicap_away_plus_5  = "Null"
    pre_corners_asian_handicap_home_plus_55  = "Null"
    pre_corners_asian_handicap_away_plus_55  = "Null"
    pre_corners_asian_handicap_home_plus_6  = "Null"
    pre_corners_asian_handicap_away_plus_6  = "Null"
    pre_corners_asian_handicap_home_plus_65  = "Null"
    pre_corners_asian_handicap_away_plus_65  = "Null"
    end_corners_asian_handicap_home_min_65  = "Null"
    end_corners_asian_handicap_away_min_65  = "Null"
    end_corners_asian_handicap_home_min_6  = "Null"
    end_corners_asian_handicap_away_min_6  = "Null"
    end_corners_asian_handicap_home_min_55  = "Null"
    end_corners_asian_handicap_away_min_55  = "Null"
    end_corners_asian_handicap_home_min_5  = "Null"
    end_corners_asian_handicap_away_min_5  = "Null"
    end_corners_asian_handicap_home_min_45  = "Null"
    end_corners_asian_handicap_away_min_45  = "Null"
    end_corners_asian_handicap_home_min_4  = "Null"
    end_corners_asian_handicap_away_min_4  = "Null"
    end_corners_asian_handicap_home_min_35  = "Null"
    end_corners_asian_handicap_away_min_35  = "Null"
    end_corners_asian_handicap_home_min_3  = "Null"
    end_corners_asian_handicap_away_min_3  = "Null"
    end_corners_asian_handicap_home_min_25  = "Null"
    end_corners_asian_handicap_away_min_25  = "Null"
    end_corners_asian_handicap_home_min_2  = "Null"
    end_corners_asian_handicap_away_min_2  = "Null"
    end_corners_asian_handicap_home_min_15  = "Null"
    end_corners_asian_handicap_away_min_15  = "Null"
    end_corners_asian_handicap_home_min_1  = "Null"
    end_corners_asian_handicap_home_min_05  = "Null"
    end_corners_asian_handicap_away_min_1  = "Null"
    end_corners_asian_handicap_away_min_05  = "Null"
    end_corners_asian_handicap_home_plus_0  = "Null"
    end_corners_asian_handicap_away_plus_0  = "Null"
    end_corners_asian_handicap_home_plus_05  = "Null"
    end_corners_asian_handicap_away_plus_05  = "Null"
    end_corners_asian_handicap_home_plus_1  = "Null"
    end_corners_asian_handicap_away_plus_1  = "Null"
    end_corners_asian_handicap_home_plus_15  = "Null"
    end_corners_asian_handicap_away_plus_15  = "Null"
    end_corners_asian_handicap_home_plus_2  = "Null"
    end_corners_asian_handicap_away_plus_2  = "Null"
    end_corners_asian_handicap_home_plus_25  = "Null"
    end_corners_asian_handicap_away_plus_25  = "Null"
    end_corners_asian_handicap_home_plus_3  = "Null"
    end_corners_asian_handicap_away_plus_3  = "Null"
    end_corners_asian_handicap_home_plus_35  = "Null"
    end_corners_asian_handicap_away_plus_35  = "Null"
    end_corners_asian_handicap_home_plus_4  = "Null"
    end_corners_asian_handicap_away_plus_4  = "Null"
    end_corners_asian_handicap_home_plus_45  = "Null"
    end_corners_asian_handicap_away_plus_45  = "Null"
    end_corners_asian_handicap_home_plus_5  = "Null"
    end_corners_asian_handicap_away_plus_5  = "Null"
    end_corners_asian_handicap_home_plus_55  = "Null"
    end_corners_asian_handicap_away_plus_55  = "Null"
    end_corners_asian_handicap_home_plus_6  = "Null"
    end_corners_asian_handicap_away_plus_6  = "Null"
    end_corners_asian_handicap_home_plus_65  = "Null"
    end_corners_asian_handicap_away_plus_65  = "Null"
    pre_corners_over_under_over_700  = "Null"
    pre_corners_over_under_under_700  = "Null"
    pre_corners_over_under_over_725  = "Null"
    pre_corners_over_under_under_725  = "Null"
    pre_corners_over_under_over_750  = "Null"
    pre_corners_over_under_under_750  = "Null"
    pre_corners_over_under_over_775  = "Null"
    pre_corners_over_under_under_775  = "Null"
    pre_corners_over_under_over_800  = "Null"
    pre_corners_over_under_under_800  = "Null"
    pre_corners_over_under_over_825  = "Null"
    pre_corners_over_under_under_825  = "Null"
    pre_corners_over_under_over_850  = "Null"
    pre_corners_over_under_under_850  = "Null"
    pre_corners_over_under_over_875  = "Null"
    pre_corners_over_under_under_875  = "Null"
    pre_corners_over_under_over_900  = "Null"
    pre_corners_over_under_under_900  = "Null"
    pre_corners_over_under_over_925  = "Null"
    pre_corners_over_under_under_925  = "Null"
    pre_corners_over_under_over_950  = "Null"
    pre_corners_over_under_under_950  = "Null"
    pre_corners_over_under_over_975  = "Null"
    pre_corners_over_under_under_975  = "Null"
    pre_corners_over_under_over_1000  = "Null"
    pre_corners_over_under_under_1000  = "Null"
    pre_corners_over_under_over_1025  = "Null"
    pre_corners_over_under_under_1025  = "Null"
    pre_corners_over_under_over_1050  = "Null"
    pre_corners_over_under_under_1050  = "Null"
    pre_corners_over_under_over_1075  = "Null"
    pre_corners_over_under_under_1075  = "Null"
    pre_corners_over_under_over_1100  = "Null"
    pre_corners_over_under_under_1100  = "Null"
    pre_corners_over_under_over_1125  = "Null"
    pre_corners_over_under_under_1125  = "Null"
    pre_corners_over_under_over_1150  = "Null"
    pre_corners_over_under_under_1150  = "Null"
    pre_corners_over_under_over_1175  = "Null"
    pre_corners_over_under_under_1175  = "Null"
    pre_corners_over_under_over_1200  = "Null"
    pre_corners_over_under_under_1200  = "Null"
    pre_corners_over_under_over_1225  = "Null"
    pre_corners_over_under_under_1225  = "Null"
    pre_corners_over_under_over_1250  = "Null"
    pre_corners_over_under_under_1250  = "Null"
    pre_corners_over_under_over_1275  = "Null"
    pre_corners_over_under_under_1275  = "Null"
    end_corners_over_under_over_700  = "Null"
    end_corners_over_under_under_700  = "Null"
    end_corners_over_under_over_725  = "Null"
    end_corners_over_under_under_725  = "Null"
    end_corners_over_under_over_750  = "Null"
    end_corners_over_under_under_750  = "Null"
    end_corners_over_under_over_775  = "Null"
    end_corners_over_under_under_775  = "Null"
    end_corners_over_under_over_800  = "Null"
    end_corners_over_under_under_800  = "Null"
    end_corners_over_under_over_825  = "Null"
    end_corners_over_under_under_825  = "Null"
    end_corners_over_under_over_850  = "Null"
    end_corners_over_under_under_850  = "Null"
    end_corners_over_under_over_875  = "Null"
    end_corners_over_under_under_875  = "Null"
    end_corners_over_under_over_900  = "Null"
    end_corners_over_under_under_900  = "Null"
    end_corners_over_under_over_925  = "Null"
    end_corners_over_under_under_925  = "Null"
    end_corners_over_under_over_950  = "Null"
    end_corners_over_under_under_950  = "Null"
    end_corners_over_under_over_975  = "Null"
    end_corners_over_under_under_975  = "Null"
    end_corners_over_under_over_1000  = "Null"
    end_corners_over_under_under_1000  = "Null"
    end_corners_over_under_over_1025  = "Null"
    end_corners_over_under_under_1025  = "Null"
    end_corners_over_under_over_1050  = "Null"
    end_corners_over_under_under_1050  = "Null"
    end_corners_over_under_over_1075  = "Null"
    end_corners_over_under_under_1075  = "Null"
    end_corners_over_under_over_1100  = "Null"
    end_corners_over_under_under_1100  = "Null"
    end_corners_over_under_over_1125  = "Null"
    end_corners_over_under_under_1125  = "Null"
    end_corners_over_under_over_1150  = "Null"
    end_corners_over_under_under_1150  = "Null"
    end_corners_over_under_over_1175  = "Null"
    end_corners_over_under_under_1175  = "Null"
    end_corners_over_under_over_1200  = "Null"
    end_corners_over_under_under_1200  = "Null"
    end_corners_over_under_over_1225  = "Null"
    end_corners_over_under_under_1225  = "Null"
    end_corners_over_under_over_1250  = "Null"
    end_corners_over_under_under_1250  = "Null"
    end_corners_over_under_over_1275  = "Null"
    end_corners_over_under_under_1275  = "Null"
    pre_home_corners_overunder_over_25  = "Null"
    pre_home_corners_overunder_under_25  = "Null"
    pre_home_corners_overunder_over_35  = "Null"
    pre_home_corners_overunder_under_35  = "Null"
    pre_home_corners_overunder_over_45  = "Null"
    pre_home_corners_overunder_under_45  = "Null"
    pre_home_corners_overunder_over_55  = "Null"
    pre_home_corners_overunder_under_55  = "Null"
    pre_home_corners_overunder_over_65  = "Null"
    pre_home_corners_overunder_under_65  = "Null"
    pre_home_corners_overunder_over_75  = "Null"
    pre_home_corners_overunder_under_75  = "Null"
    pre_home_corners_overunder_over_85  = "Null"
    pre_home_corners_overunder_under_85  = "Null"
    end_home_corners_overunder_over_25  = "Null"
    end_home_corners_overunder_under_25  = "Null"
    end_home_corners_overunder_over_35  = "Null"
    end_home_corners_overunder_under_35  = "Null"
    end_home_corners_overunder_over_45  = "Null"
    end_home_corners_overunder_under_45  = "Null"
    end_home_corners_overunder_over_55  = "Null"
    end_home_corners_overunder_under_55  = "Null"
    end_home_corners_overunder_over_65  = "Null"
    end_home_corners_overunder_under_65  = "Null"
    end_home_corners_overunder_over_75  = "Null"
    end_home_corners_overunder_under_75  = "Null"
    end_home_corners_overunder_over_85  = "Null"
    end_home_corners_overunder_under_85  = "Null"
    pre_away_corners_overunder_over_25  = "Null"
    pre_away_corners_overunder_under_25  = "Null"
    pre_away_corners_overunder_over_35  = "Null"
    pre_away_corners_overunder_under_35  = "Null"
    pre_away_corners_overunder_over_45  = "Null"
    pre_away_corners_overunder_under_45  = "Null"
    pre_away_corners_overunder_over_55  = "Null"
    pre_away_corners_overunder_under_55  = "Null"
    pre_away_corners_overunder_over_65  = "Null"
    pre_away_corners_overunder_under_65  = "Null"
    pre_away_corners_overunder_over_75  = "Null"
    pre_away_corners_overunder_under_75  = "Null"
    pre_away_corners_overunder_over_85  = "Null"
    pre_away_corners_overunder_under_85  = "Null"
    end_away_corners_overunder_over_25  = "Null"
    end_away_corners_overunder_under_25  = "Null"
    end_away_corners_overunder_over_35  = "Null"
    end_away_corners_overunder_under_35  = "Null"
    end_away_corners_overunder_over_45  = "Null"
    end_away_corners_overunder_under_45  = "Null"
    end_away_corners_overunder_over_55  = "Null"
    end_away_corners_overunder_under_55  = "Null"
    end_away_corners_overunder_over_65  = "Null"
    end_away_corners_overunder_under_65  = "Null"
    end_away_corners_overunder_over_75  = "Null"
    end_away_corners_overunder_under_75  = "Null"
    end_away_corners_overunder_over_85  = "Null"
    end_away_corners_overunder_under_85  = "Null"
    pre_first_corner_home  = "Null"
    pre_first_corner_away  = "Null"
    end_first_corner_home  = "Null"
    end_first_corner_away  = "Null"
    pre_last_corner_home  = "Null"
    pre_last_corner_away  = "Null"
    end_last_corner_home  = "Null"
    end_last_corner_away  = "Null"
    pre_cards_asian_handicap_home_min_05  = "Null"
    pre_cards_asian_handicap_away_min_05  = "Null"
    pre_cards_asian_handicap_home_plus_0  = "Null"
    pre_cards_asian_handicap_away_plus_0  = "Null"
    pre_cards_asian_handicap_home_plus_05  = "Null"
    pre_cards_asian_handicap_away_plus_05  = "Null"
    end_cards_asian_handicap_home_min_05  = "Null"
    end_cards_asian_handicap_away_min_05  = "Null"
    end_cards_asian_handicap_home_plus_0  = "Null"
    end_cards_asian_handicap_away_plus_0  = "Null"
    end_cards_asian_handicap_home_plus_05  = "Null"
    end_cards_asian_handicap_away_plus_05  = "Null"
    pre_cards_overunder_over_25  = "Null"
    pre_cards_overunder_under_25  = "Null"
    pre_cards_overunder_over_35  = "Null"
    pre_cards_overunder_under_35  = "Null"
    pre_cards_overunder_over_45  = "Null"
    pre_cards_overunder_under_45  = "Null"
    pre_cards_overunder_over_55  = "Null"
    pre_cards_overunder_under_55  = "Null"
    pre_cards_overunder_over_65  = "Null"
    pre_cards_overunder_under_65  = "Null"
    pre_cards_overunder_over_75  = "Null"
    pre_cards_overunder_under_75  = "Null"
    end_cards_overunder_over_25  = "Null"
    end_cards_overunder_under_25  = "Null"
    end_cards_overunder_over_35  = "Null"
    end_cards_overunder_under_35  = "Null"
    end_cards_overunder_over_45  = "Null"
    end_cards_overunder_under_45  = "Null"
    end_cards_overunder_over_55  = "Null"
    end_cards_overunder_under_55  = "Null"
    end_cards_overunder_over_65  = "Null"
    end_cards_overunder_under_65  = "Null"
    end_cards_overunder_over_75  = "Null"
    end_cards_overunder_under_75  = "Null"
    pre_home_team_total_cards_over_15  = "Null"
    pre_home_team_total_cards_under_15  = "Null"
    pre_home_team_total_cards_over_25  = "Null"
    pre_home_team_total_cards_under_25  = "Null"
    pre_home_team_total_cards_over_35  = "Null"
    pre_home_team_total_cards_under_35  = "Null"
    end_home_team_total_cards_over_15  = "Null"
    end_home_team_total_cards_under_15  = "Null"
    end_home_team_total_cards_over_25  = "Null"
    end_home_team_total_cards_under_25  = "Null"
    end_home_team_total_cards_over_35  = "Null"
    end_home_team_total_cards_under_35  = "Null"
    pre_away_team_total_cards_over_15  = "Null"
    pre_away_team_total_cards_under_15  = "Null"
    pre_away_team_total_cards_over_25  = "Null"
    pre_away_team_total_cards_under_25  = "Null"
    pre_away_team_total_cards_over_35  = "Null"
    pre_away_team_total_cards_under_35  = "Null"
    end_away_team_total_cards_over_15  = "Null"
    end_away_team_total_cards_under_15  = "Null"
    end_away_team_total_cards_over_25  = "Null"
    end_away_team_total_cards_under_25  = "Null"
    end_away_team_total_cards_over_35  = "Null"
    end_away_team_total_cards_under_35  = "Null"
    pre_total_goals_under_2  = "Null"
    pre_total_goals_2_or_3  = "Null"
    pre_total_goals_over_3  = "Null"
    end_total_goals_under_2  = "Null"
    end_total_goals_2_or_3  = "Null"
    end_total_goals_over_3  = "Null"
    pre_first_goal_method_shot  = "Null"
    pre_first_goal_method_header  = "Null"
    pre_first_goal_method_penalty  = "Null"
    pre_first_goal_method_freekick  = "Null"
    pre_first_goal_method_owngoal  = "Null"
    pre_first_goal_method_draw  = "Null"
    end_first_goal_method_shot  = "Null"
    end_first_goal_method_header  = "Null"
    end_first_goal_method_penalty  = "Null"
    end_first_goal_method_freekick  = "Null"
    end_first_goal_method_owngoal  = "Null"
    end_first_goal_method_draw  = "Null"
    pre_to_score_a_penalty_home  = "Null"
    pre_to_score_a_penalty_away  = "Null"
    end_to_score_a_penalty_home  = "Null"
    end_to_score_a_penalty_away  = "Null"
    pre_to_miss_a_penalty_home  = "Null"
    pre_to_miss_a_penalty_away  = "Null"
    end_to_miss_a_penalty_home  = "Null"
    end_to_miss_a_penalty_away  = "Null"
    pre_player_to_be_booked  = "Null"
    end_player_to_be_booked  = "Null"
    pre_ah_pattern  = "Null"
    pre_ah_pattern_mirror  = "Null"
    pre_gou_pattern  = "Null"
    end_ah_pattern  = "Null"
    end_ah_pattern_mirror  = "Null"
    end_gou_pattern  = "Null"
    # ------------------------------------------------------ 
    col_counter = 0
    if(x[col_counter] is not None): 
        date = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        fixtureapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
#     col_counter += 1
#     if(x[col_counter] is not None): 
#         venueapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        referee = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        leagueapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        season = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        xround = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        fixture_status = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        fixture_elapsed = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        teams_homeapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        teams_awayapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_halftime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_halftime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_fulltime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_fulltime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_extratime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_extratime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_penalty_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        score_penalty_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_match_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_match_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_match_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_match_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_match_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_match_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_homeaway_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_homeaway_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_homeaway_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_homeaway_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_half_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_half_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_half_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_half_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_half_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_half_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_home_plus_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_away_plus_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_home_plus_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_away_plus_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_40  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_40  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_50  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_50  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_60  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_60  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_70  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_70  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_over_95  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_under_95  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_40  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_40  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_425  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_475  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_50  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_50  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_525  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_575  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_60  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_60  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_625  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_675  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_70  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_70  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_over_95  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_under_95  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_home_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_asian_handicap_first_half_away_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_min_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_home_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_asian_handicap_first_half_away_plus_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder_first_half_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder_first_half_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_goals_overunder__second_half_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_10  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_20  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_30  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_325  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_over_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_goals_overunder__second_half_under_375  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_home_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_draw_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_draw_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_away_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_away_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_htft_double_away_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_home_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_draw_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_draw_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_away_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_away_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_htft_double_away_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_score_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_score_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_score_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_score_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_score__first_half_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_score__first_half_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_score__first_half_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_score__first_half_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score__second_half_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score__second_half_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score__second_half_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score__second_half_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_draw_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_draw_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_results_both_teams_score_away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_draw_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_draw_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_results_both_teams_score_away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_score_in_both_halves_by_teams_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_score_in_both_halves_by_teams_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_score_in_both_halves_by_teams_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_score_in_both_halves_by_teams_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_both_teams_to_score_over_yes_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_both_teams_to_score_over_no_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_both_teams_to_score_under_yes_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_both_teams_to_score_under_no_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_both_teams_to_score_over_yes_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_both_teams_to_score_over_no_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_both_teams_to_score_under_yes_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_both_teams_to_score_under_no_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score_1st_half__2nd_half_yes_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score_1st_half__2nd_half_yes_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score_1st_half__2nd_half_no_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_both_teams_to_score_1st_half__2nd_half_no_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score_1st_half__2nd_half_yes_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score_1st_half__2nd_half_yes_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score_1st_half__2nd_half_no_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_both_teams_to_score_1st_half__2nd_half_no_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_highest_scoring_half_first  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_highest_scoring_half_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_highest_scoring_half_second  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_highest_scoring_half_first  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_highest_scoring_half_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_highest_scoring_half_second  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance__first_half_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance__first_half_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_double_chance__first_half_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance__first_half_home_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance__first_half_home_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_double_chance__first_half_draw_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_oddeven_odd  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_oddeven_even  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_oddeven_odd  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_oddeven_even  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_home_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_draw_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_away_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_home_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_draw_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_away_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_home_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_draw_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_away_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_home_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_draw_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_result_total_goals_away_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_home_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_draw_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_away_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_home_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_draw_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_away_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_home_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_draw_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_away_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_home_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_draw_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_result_total_goals_away_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_clean_sheet__home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_clean_sheet__home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_clean_sheet__home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_clean_sheet__home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_clean_sheet__away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_clean_sheet__away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_clean_sheet__away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_clean_sheet__away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_win_both_halves_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_win_both_halves_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_win_both_halves_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_win_both_halves_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_win_to_nil_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_win_to_nil_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_win_to_nil_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_win_to_nil_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_win_either_half_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_win_either_half_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_win_either_half_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_win_either_half_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_draw_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_draw_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_halftime_result_both_teams_score_away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_home_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_draw_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_away_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_home_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_draw_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_halftime_result_both_teams_score_away_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number_more_7  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number_more_7  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_goals_number__first_half_more_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_goals_number__first_half_more_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_second_half_exact_goals_number_more_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_second_half_exact_goals_number_more_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_exact_goals_number_more_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_exact_goals_number_more_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_exact_goals_number_more_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_exact_goals_number_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_exact_goals_number_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_exact_goals_number_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_exact_goals_number_more_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_winner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_winner_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_winner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_10_overunder_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_10_overunder_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_10_overunder_over_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_10_overunder_under_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_draw_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_draw_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_draw_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_draw_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_draw_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_european_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_draw_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_draw_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_draw_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_draw_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_draw_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_european_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_rcard_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_rcard_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_rcard_yes  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_rcard_no  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_anytime_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_anytime_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_last_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_last_goal_scorer  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_score_two_or_more_goals  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_score_two_or_more_goals  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_last_goal_scorer2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_last_goal_scorer2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_exact_score  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_exact_score  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_first_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_first_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_first_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_first_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_first_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_first_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_last_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_last_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_team_to_score_last_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_last_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_last_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_team_to_score_last_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_home_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_home_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_away_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_away_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_home_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_asian_handicap_away_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_1  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_4  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_5  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_6  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_home_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_asian_handicap_away_plus_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_700  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_700  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_725  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_725  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_750  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_750  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_775  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_775  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_800  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_800  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_825  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_825  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_850  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_850  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_875  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_875  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_900  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_900  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_925  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_925  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_950  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_950  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_975  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_975  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1000  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1000  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1050  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1050  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1100  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1100  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1150  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1150  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1200  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1200  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1250  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1250  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_over_1275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_corners_over_under_under_1275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_700  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_700  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_725  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_725  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_750  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_750  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_775  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_775  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_800  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_800  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_825  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_825  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_850  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_850  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_875  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_875  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_900  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_900  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_925  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_925  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_950  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_950  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_975  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_975  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1000  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1000  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1025  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1050  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1050  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1075  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1100  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1100  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1125  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1150  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1150  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1175  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1200  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1200  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1225  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1250  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1250  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_over_1275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_corners_over_under_under_1275  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_corners_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_corners_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_corners_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_over_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_corners_overunder_under_85  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_corner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_corner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_corner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_corner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_last_corner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_last_corner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_last_corner_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_last_corner_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_home_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_away_min_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_home_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_away_plus_0  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_home_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_asian_handicap_away_plus_05  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_cards_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_45  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_55  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_65  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_over_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_cards_overunder_under_75  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_home_team_total_cards_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_home_team_total_cards_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_away_team_total_cards_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_over_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_under_15  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_over_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_under_25  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_over_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_away_team_total_cards_under_35  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_under_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_2_or_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_total_goals_over_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_under_2  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_2_or_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_total_goals_over_3  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_shot  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_header  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_penalty  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_freekick  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_owngoal  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_first_goal_method_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_shot  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_header  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_penalty  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_freekick  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_owngoal  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_first_goal_method_draw  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_score_a_penalty_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_score_a_penalty_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_score_a_penalty_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_score_a_penalty_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_miss_a_penalty_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_to_miss_a_penalty_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_miss_a_penalty_home  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_to_miss_a_penalty_away  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_player_to_be_booked  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_player_to_be_booked  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_ah_pattern  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_ah_pattern_mirror  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        pre_gou_pattern  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_ah_pattern  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_ah_pattern_mirror  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None): 
        end_gou_pattern  = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    # ------------------------------------------------------ 
    # ------------------------------------------------------  
    countdown -= 1
    word = space + " [" + str(countdown) + "/" + str(total_rows) + "] "
    word += "#" + fixtureapi_id
    word += " #" + leagueapi_id
    word += " - " + season    
    print(word, flush=True)
    # ------------------------------------------------------  
    insert = "INSERT INTO `football_odds`( "
    # ------------------------------------------------------
    insert += " `date`, "
    insert += " `fixtureapi_id`, "
    insert += " `venueapi_id`, "
    insert += " `referee`, "
    insert += " `leagueapi_id`, "
    insert += " `season`, "
    insert += " `round`, "
    insert += " `fixture_status`, "
    insert += " `fixture_elapsed`, "
    insert += " `teams_homeapi_id`, "
    insert += " `teams_awayapi_id`, "
    insert += " `goals_home`, "
    insert += " `goals_away`, "
    insert += " `score_halftime_home`, "
    insert += " `score_halftime_away`, "
    insert += " `score_fulltime_home`, "
    insert += " `score_fulltime_away`, "
    insert += " `score_extratime_home`, "
    insert += " `score_extratime_away`, "
    insert += " `score_penalty_home`, "
    insert += " `score_penalty_away`, "
    
    insert += " `pre_match_winner_home`, "
    insert += " `pre_match_winner_draw`, "
    insert += " `pre_match_winner_away`, "
    insert += " `end_match_winner_home`, "
    insert += " `end_match_winner_draw`, "
    insert += " `end_match_winner_away`, "
    insert += " `pre_homeaway_home`, "
    insert += " `pre_homeaway_away`, "
    insert += " `end_homeaway_home`, "
    insert += " `end_homeaway_away`, "
    insert += " `pre_first_half_winner_home`, "
    insert += " `pre_first_half_winner_draw`, "
    insert += " `pre_first_half_winner_away`, "
    insert += " `end_first_half_winner_home`, "
    insert += " `end_first_half_winner_draw`, "
    insert += " `end_first_half_winner_away`, "
    insert += " `pre_second_half_winner_home`, "
    insert += " `pre_second_half_winner_draw`, "
    insert += " `pre_second_half_winner_away`, "
    insert += " `end_second_half_winner_home`, "
    insert += " `end_second_half_winner_draw`, "
    insert += " `end_second_half_winner_away`, "
    insert += " `pre_asian_handicap_home_min_675`, "
    insert += " `pre_asian_handicap_away_min_675`, "
    insert += " `pre_asian_handicap_home_min_65`, "
    insert += " `pre_asian_handicap_away_min_65`, "
    insert += " `pre_asian_handicap_home_min_625`, "
    insert += " `pre_asian_handicap_away_min_625`, "
    insert += " `pre_asian_handicap_home_min_6`, "
    insert += " `pre_asian_handicap_away_min_6`, "
    insert += " `pre_asian_handicap_home_min_575`, "
    insert += " `pre_asian_handicap_away_min_575`, "
    insert += " `pre_asian_handicap_home_min_55`, "
    insert += " `pre_asian_handicap_away_min_55`, "
    insert += " `pre_asian_handicap_home_min_525`, "
    insert += " `pre_asian_handicap_away_min_525`, "
    insert += " `pre_asian_handicap_home_min_5`, "
    insert += " `pre_asian_handicap_away_min_5`, "
    insert += " `pre_asian_handicap_home_min_475`, "
    insert += " `pre_asian_handicap_away_min_475`, "
    insert += " `pre_asian_handicap_home_min_45`, "
    insert += " `pre_asian_handicap_away_min_45`, "
    insert += " `pre_asian_handicap_home_min_425`, "
    insert += " `pre_asian_handicap_away_min_425`, "
    insert += " `pre_asian_handicap_home_min_4`, "
    insert += " `pre_asian_handicap_away_min_4`, "
    insert += " `pre_asian_handicap_home_min_375`, "
    insert += " `pre_asian_handicap_away_min_375`, "
    insert += " `pre_asian_handicap_home_min_35`, "
    insert += " `pre_asian_handicap_away_min_35`, "
    insert += " `pre_asian_handicap_home_min_325`, "
    insert += " `pre_asian_handicap_away_min_325`, "
    insert += " `pre_asian_handicap_home_min_3`, "
    insert += " `pre_asian_handicap_away_min_3`, "
    insert += " `pre_asian_handicap_home_min_275`, "
    insert += " `pre_asian_handicap_away_min_275`, "
    insert += " `pre_asian_handicap_home_min_25`, "
    insert += " `pre_asian_handicap_away_min_25`, "
    insert += " `pre_asian_handicap_home_min_225`, "
    insert += " `pre_asian_handicap_away_min_225`, "
    insert += " `pre_asian_handicap_home_min_2`, "
    insert += " `pre_asian_handicap_away_min_2`, "
    insert += " `pre_asian_handicap_home_min_175`, "
    insert += " `pre_asian_handicap_away_min_175`, "
    insert += " `pre_asian_handicap_home_min_15`, "
    insert += " `pre_asian_handicap_away_min_15`, "
    insert += " `pre_asian_handicap_home_min_125`, "
    insert += " `pre_asian_handicap_away_min_125`, "
    insert += " `pre_asian_handicap_home_min_1`, "
    insert += " `pre_asian_handicap_away_min_1`, "
    insert += " `pre_asian_handicap_home_min_075`, "
    insert += " `pre_asian_handicap_away_min_075`, "
    insert += " `pre_asian_handicap_home_min_05`, "
    insert += " `pre_asian_handicap_away_min_05`, "
    insert += " `pre_asian_handicap_home_min_025`, "
    insert += " `pre_asian_handicap_away_min_025`, "
    insert += " `pre_asian_handicap_home_plus_0`, "
    insert += " `pre_asian_handicap_away_plus_0`, "
    insert += " `pre_asian_handicap_home_plus_025`, "
    insert += " `pre_asian_handicap_away_plus_025`, "
    insert += " `pre_asian_handicap_home_plus_05`, "
    insert += " `pre_asian_handicap_away_plus_05`, "
    insert += " `pre_asian_handicap_home_plus_075`, "
    insert += " `pre_asian_handicap_away_plus_075`, "
    insert += " `pre_asian_handicap_home_plus_1`, "
    insert += " `pre_asian_handicap_away_plus_1`, "
    insert += " `pre_asian_handicap_home_plus_125`, "
    insert += " `pre_asian_handicap_away_plus_125`, "
    insert += " `pre_asian_handicap_home_plus_15`, "
    insert += " `pre_asian_handicap_away_plus_15`, "
    insert += " `pre_asian_handicap_home_plus_175`, "
    insert += " `pre_asian_handicap_away_plus_175`, "
    insert += " `pre_asian_handicap_home_plus_2`, "
    insert += " `pre_asian_handicap_away_plus_2`, "
    insert += " `pre_asian_handicap_home_plus_225`, "
    insert += " `pre_asian_handicap_away_plus_225`, "
    insert += " `pre_asian_handicap_home_plus_25`, "
    insert += " `pre_asian_handicap_away_plus_25`, "
    insert += " `pre_asian_handicap_home_plus_275`, "
    insert += " `pre_asian_handicap_away_plus_275`, "
    insert += " `pre_asian_handicap_home_plus_3`, "
    insert += " `pre_asian_handicap_away_plus_3`, "
    insert += " `pre_asian_handicap_home_plus_325`, "
    insert += " `pre_asian_handicap_away_plus_325`, "
    insert += " `pre_asian_handicap_home_plus_35`, "
    insert += " `pre_asian_handicap_away_plus_35`, "
    insert += " `pre_asian_handicap_home_plus_375`, "
    insert += " `pre_asian_handicap_away_plus_375`, "
    insert += " `pre_asian_handicap_home_plus_4`, "
    insert += " `pre_asian_handicap_away_plus_4`, "
    insert += " `pre_asian_handicap_home_plus_425`, "
    insert += " `pre_asian_handicap_away_plus_425`, "
    insert += " `pre_asian_handicap_home_plus_45`, "
    insert += " `pre_asian_handicap_away_plus_45`, "
    insert += " `pre_asian_handicap_home_plus_475`, "
    insert += " `pre_asian_handicap_away_plus_475`, "
    insert += " `pre_asian_handicap_home_plus_5`, "
    insert += " `pre_asian_handicap_away_plus_5`, "
    insert += " `pre_asian_handicap_home_plus_525`, "
    insert += " `pre_asian_handicap_away_plus_525`, "
    insert += " `pre_asian_handicap_home_plus_55`, "
    insert += " `pre_asian_handicap_away_plus_55`, "
    insert += " `pre_asian_handicap_home_plus_575`, "
    insert += " `pre_asian_handicap_away_plus_575`, "
    insert += " `pre_asian_handicap_home_plus_6`, "
    insert += " `pre_asian_handicap_away_plus_6`, "
    insert += " `pre_asian_handicap_home_plus_625`, "
    insert += " `pre_asian_handicap_away_plus_625`, "
    insert += " `pre_asian_handicap_home_plus_65`, "
    insert += " `pre_asian_handicap_away_plus_65`, "
    insert += " `pre_asian_handicap_home_plus_675`, "
    insert += " `pre_asian_handicap_away_plus_675`, "
    insert += " `end_asian_handicap_home_min_675`, "
    insert += " `end_asian_handicap_away_min_675`, "
    insert += " `end_asian_handicap_home_min_65`, "
    insert += " `end_asian_handicap_away_min_65`, "
    insert += " `end_asian_handicap_home_min_625`, "
    insert += " `end_asian_handicap_away_min_625`, "
    insert += " `end_asian_handicap_home_min_6`, "
    insert += " `end_asian_handicap_away_min_6`, "
    insert += " `end_asian_handicap_home_min_575`, "
    insert += " `end_asian_handicap_away_min_575`, "
    insert += " `end_asian_handicap_home_min_55`, "
    insert += " `end_asian_handicap_away_min_55`, "
    insert += " `end_asian_handicap_home_min_525`, "
    insert += " `end_asian_handicap_away_min_525`, "
    insert += " `end_asian_handicap_home_min_5`, "
    insert += " `end_asian_handicap_away_min_5`, "
    insert += " `end_asian_handicap_home_min_475`, "
    insert += " `end_asian_handicap_away_min_475`, "
    insert += " `end_asian_handicap_home_min_45`, "
    insert += " `end_asian_handicap_away_min_45`, "
    insert += " `end_asian_handicap_home_min_425`, "
    insert += " `end_asian_handicap_away_min_425`, "
    insert += " `end_asian_handicap_home_min_4`, "
    insert += " `end_asian_handicap_away_min_4`, "
    insert += " `end_asian_handicap_home_min_375`, "
    insert += " `end_asian_handicap_away_min_375`, "
    insert += " `end_asian_handicap_home_min_35`, "
    insert += " `end_asian_handicap_away_min_35`, "
    insert += " `end_asian_handicap_home_min_325`, "
    insert += " `end_asian_handicap_away_min_325`, "
    insert += " `end_asian_handicap_home_min_3`, "
    insert += " `end_asian_handicap_away_min_3`, "
    insert += " `end_asian_handicap_home_min_275`, "
    insert += " `end_asian_handicap_away_min_275`, "
    insert += " `end_asian_handicap_home_min_25`, "
    insert += " `end_asian_handicap_away_min_25`, "
    insert += " `end_asian_handicap_home_min_225`, "
    insert += " `end_asian_handicap_away_min_225`, "
    insert += " `end_asian_handicap_home_min_2`, "
    insert += " `end_asian_handicap_away_min_2`, "
    insert += " `end_asian_handicap_home_min_175`, "
    insert += " `end_asian_handicap_away_min_175`, "
    insert += " `end_asian_handicap_home_min_15`, "
    insert += " `end_asian_handicap_away_min_15`, "
    insert += " `end_asian_handicap_home_min_125`, "
    insert += " `end_asian_handicap_away_min_125`, "
    insert += " `end_asian_handicap_home_min_1`, "
    insert += " `end_asian_handicap_away_min_1`, "
    insert += " `end_asian_handicap_home_min_075`, "
    insert += " `end_asian_handicap_away_min_075`, "
    insert += " `end_asian_handicap_home_min_05`, "
    insert += " `end_asian_handicap_away_min_05`, "
    insert += " `end_asian_handicap_home_min_025`, "
    insert += " `end_asian_handicap_away_min_025`, "
    insert += " `end_asian_handicap_home_plus_0`, "
    insert += " `end_asian_handicap_away_plus_0`, "
    insert += " `end_asian_handicap_home_plus_025`, "
    insert += " `end_asian_handicap_away_plus_025`, "
    insert += " `end_asian_handicap_home_plus_05`, "
    insert += " `end_asian_handicap_away_plus_05`, "
    insert += " `end_asian_handicap_home_plus_075`, "
    insert += " `end_asian_handicap_away_plus_075`, "
    insert += " `end_asian_handicap_home_plus_1`, "
    insert += " `end_asian_handicap_away_plus_1`, "
    insert += " `end_asian_handicap_home_plus_125`, "
    insert += " `end_asian_handicap_away_plus_125`, "
    insert += " `end_asian_handicap_home_plus_15`, "
    insert += " `end_asian_handicap_away_plus_15`, "
    insert += " `end_asian_handicap_home_plus_175`, "
    insert += " `end_asian_handicap_away_plus_175`, "
    insert += " `end_asian_handicap_home_plus_2`, "
    insert += " `end_asian_handicap_away_plus_2`, "
    insert += " `end_asian_handicap_home_plus_225`, "
    insert += " `end_asian_handicap_away_plus_225`, "
    insert += " `end_asian_handicap_home_plus_25`, "
    insert += " `end_asian_handicap_away_plus_25`, "
    insert += " `end_asian_handicap_home_plus_275`, "
    insert += " `end_asian_handicap_away_plus_275`, "
    insert += " `end_asian_handicap_home_plus_3`, "
    insert += " `end_asian_handicap_away_plus_3`, "
    insert += " `end_asian_handicap_home_plus_325`, "
    insert += " `end_asian_handicap_away_plus_325`, "
    insert += " `end_asian_handicap_home_plus_35`, "
    insert += " `end_asian_handicap_away_plus_35`, "
    insert += " `end_asian_handicap_home_plus_375`, "
    insert += " `end_asian_handicap_away_plus_375`, "
    insert += " `end_asian_handicap_home_plus_4`, "
    insert += " `end_asian_handicap_away_plus_4`, "
    insert += " `end_asian_handicap_home_plus_425`, "
    insert += " `end_asian_handicap_away_plus_425`, "
    insert += " `end_asian_handicap_home_plus_45`, "
    insert += " `end_asian_handicap_away_plus_45`, "
    insert += " `end_asian_handicap_home_plus_475`, "
    insert += " `end_asian_handicap_away_plus_475`, "
    insert += " `end_asian_handicap_home_plus_5`, "
    insert += " `end_asian_handicap_away_plus_5`, "
    insert += " `end_asian_handicap_home_plus_525`, "
    insert += " `end_asian_handicap_away_plus_525`, "
    insert += " `end_asian_handicap_home_plus_55`, "
    insert += " `end_asian_handicap_away_plus_55`, "
    insert += " `end_asian_handicap_home_plus_575`, "
    insert += " `end_asian_handicap_away_plus_575`, "
    insert += " `end_asian_handicap_home_plus_6`, "
    insert += " `end_asian_handicap_away_plus_6`, "
    insert += " `end_asian_handicap_home_plus_625`, "
    insert += " `end_asian_handicap_away_plus_625`, "
    insert += " `end_asian_handicap_home_plus_65`, "
    insert += " `end_asian_handicap_away_plus_65`, "
    insert += " `end_asian_handicap_home_plus_675`, "
    insert += " `end_asian_handicap_away_plus_675`, "
    insert += " `pre_goals_overunder_over_05`, "
    insert += " `pre_goals_overunder_under_05`, "
    insert += " `pre_goals_overunder_over_075`, "
    insert += " `pre_goals_overunder_under_075`, "
    insert += " `pre_goals_overunder_over_10`, "
    insert += " `pre_goals_overunder_under_10`, "
    insert += " `pre_goals_overunder_over_125`, "
    insert += " `pre_goals_overunder_under_125`, "
    insert += " `pre_goals_overunder_over_15`, "
    insert += " `pre_goals_overunder_under_15`, "
    insert += " `pre_goals_overunder_over_175`, "
    insert += " `pre_goals_overunder_under_175`, "
    insert += " `pre_goals_overunder_over_20`, "
    insert += " `pre_goals_overunder_under_20`, "
    insert += " `pre_goals_overunder_over_225`, "
    insert += " `pre_goals_overunder_under_225`, "
    insert += " `pre_goals_overunder_over_25`, "
    insert += " `pre_goals_overunder_under_25`, "
    insert += " `pre_goals_overunder_over_275`, "
    insert += " `pre_goals_overunder_under_275`, "
    insert += " `pre_goals_overunder_over_30`, "
    insert += " `pre_goals_overunder_under_30`, "
    insert += " `pre_goals_overunder_over_325`, "
    insert += " `pre_goals_overunder_under_325`, "
    insert += " `pre_goals_overunder_over_35`, "
    insert += " `pre_goals_overunder_under_35`, "
    insert += " `pre_goals_overunder_over_375`, "
    insert += " `pre_goals_overunder_under_375`, "
    insert += " `pre_goals_overunder_over_40`, "
    insert += " `pre_goals_overunder_under_40`, "
    insert += " `pre_goals_overunder_over_425`, "
    insert += " `pre_goals_overunder_under_425`, "
    insert += " `pre_goals_overunder_over_45`, "
    insert += " `pre_goals_overunder_under_45`, "
    insert += " `pre_goals_overunder_over_475`, "
    insert += " `pre_goals_overunder_under_475`, "
    insert += " `pre_goals_overunder_over_50`, "
    insert += " `pre_goals_overunder_under_50`, "
    insert += " `pre_goals_overunder_over_525`, "
    insert += " `pre_goals_overunder_under_525`, "
    insert += " `pre_goals_overunder_over_55`, "
    insert += " `pre_goals_overunder_under_55`, "
    insert += " `pre_goals_overunder_over_575`, "
    insert += " `pre_goals_overunder_under_575`, "
    insert += " `pre_goals_overunder_over_60`, "
    insert += " `pre_goals_overunder_under_60`, "
    insert += " `pre_goals_overunder_over_625`, "
    insert += " `pre_goals_overunder_under_625`, "
    insert += " `pre_goals_overunder_over_65`, "
    insert += " `pre_goals_overunder_under_65`, "
    insert += " `pre_goals_overunder_over_675`, "
    insert += " `pre_goals_overunder_under_675`, "
    insert += " `pre_goals_overunder_over_70`, "
    insert += " `pre_goals_overunder_under_70`, "
    insert += " `pre_goals_overunder_over_75`, "
    insert += " `pre_goals_overunder_under_75`, "
    insert += " `pre_goals_overunder_over_85`, "
    insert += " `pre_goals_overunder_under_85`, "
    insert += " `pre_goals_overunder_over_95`, "
    insert += " `pre_goals_overunder_under_95`, "
    insert += " `end_goals_overunder_over_05`, "
    insert += " `end_goals_overunder_under_05`, "
    insert += " `end_goals_overunder_over_075`, "
    insert += " `end_goals_overunder_under_075`, "
    insert += " `end_goals_overunder_over_10`, "
    insert += " `end_goals_overunder_under_10`, "
    insert += " `end_goals_overunder_over_125`, "
    insert += " `end_goals_overunder_under_125`, "
    insert += " `end_goals_overunder_over_15`, "
    insert += " `end_goals_overunder_under_15`, "
    insert += " `end_goals_overunder_over_175`, "
    insert += " `end_goals_overunder_under_175`, "
    insert += " `end_goals_overunder_over_20`, "
    insert += " `end_goals_overunder_under_20`, "
    insert += " `end_goals_overunder_over_225`, "
    insert += " `end_goals_overunder_under_225`, "
    insert += " `end_goals_overunder_over_25`, "
    insert += " `end_goals_overunder_under_25`, "
    insert += " `end_goals_overunder_over_275`, "
    insert += " `end_goals_overunder_under_275`, "
    insert += " `end_goals_overunder_over_30`, "
    insert += " `end_goals_overunder_under_30`, "
    insert += " `end_goals_overunder_over_325`, "
    insert += " `end_goals_overunder_under_325`, "
    insert += " `end_goals_overunder_over_35`, "
    insert += " `end_goals_overunder_under_35`, "
    insert += " `end_goals_overunder_over_375`, "
    insert += " `end_goals_overunder_under_375`, "
    insert += " `end_goals_overunder_over_40`, "
    insert += " `end_goals_overunder_under_40`, "
    insert += " `end_goals_overunder_over_425`, "
    insert += " `end_goals_overunder_under_425`, "
    insert += " `end_goals_overunder_over_45`, "
    insert += " `end_goals_overunder_under_45`, "
    insert += " `end_goals_overunder_over_475`, "
    insert += " `end_goals_overunder_under_475`, "
    insert += " `end_goals_overunder_over_50`, "
    insert += " `end_goals_overunder_under_50`, "
    insert += " `end_goals_overunder_over_525`, "
    insert += " `end_goals_overunder_under_525`, "
    insert += " `end_goals_overunder_over_55`, "
    insert += " `end_goals_overunder_under_55`, "
    insert += " `end_goals_overunder_over_575`, "
    insert += " `end_goals_overunder_under_575`, "
    insert += " `end_goals_overunder_over_60`, "
    insert += " `end_goals_overunder_under_60`, "
    insert += " `end_goals_overunder_over_625`, "
    insert += " `end_goals_overunder_under_625`, "
    insert += " `end_goals_overunder_over_65`, "
    insert += " `end_goals_overunder_under_65`, "
    insert += " `end_goals_overunder_over_675`, "
    insert += " `end_goals_overunder_under_675`, "
    insert += " `end_goals_overunder_over_70`, "
    insert += " `end_goals_overunder_under_70`, "
    insert += " `end_goals_overunder_over_75`, "
    insert += " `end_goals_overunder_under_75`, "
    insert += " `end_goals_overunder_over_85`, "
    insert += " `end_goals_overunder_under_85`, "
    insert += " `end_goals_overunder_over_95`, "
    insert += " `end_goals_overunder_under_95`, "
    insert += " `pre_asian_handicap_first_half_home_min_175`, "
    insert += " `pre_asian_handicap_first_half_away_min_175`, "
    insert += " `pre_asian_handicap_first_half_home_min_15`, "
    insert += " `pre_asian_handicap_first_half_away_min_15`, "
    insert += " `pre_asian_handicap_first_half_home_min_125`, "
    insert += " `pre_asian_handicap_first_half_away_min_125`, "
    insert += " `pre_asian_handicap_first_half_home_min_1`, "
    insert += " `pre_asian_handicap_first_half_away_min_1`, "
    insert += " `pre_asian_handicap_first_half_home_min_075`, "
    insert += " `pre_asian_handicap_first_half_away_min_075`, "
    insert += " `pre_asian_handicap_first_half_home_min_05`, "
    insert += " `pre_asian_handicap_first_half_away_min_05`, "
    insert += " `pre_asian_handicap_first_half_home_min_025`, "
    insert += " `pre_asian_handicap_first_half_away_min_025`, "
    insert += " `pre_asian_handicap_first_half_home_plus_0`, "
    insert += " `pre_asian_handicap_first_half_away_plus_0`, "
    insert += " `pre_asian_handicap_first_half_home_plus_025`, "
    insert += " `pre_asian_handicap_first_half_away_plus_025`, "
    insert += " `pre_asian_handicap_first_half_home_plus_05`, "
    insert += " `pre_asian_handicap_first_half_away_plus_05`, "
    insert += " `pre_asian_handicap_first_half_home_plus_075`, "
    insert += " `pre_asian_handicap_first_half_away_plus_075`, "
    insert += " `pre_asian_handicap_first_half_home_plus_1`, "
    insert += " `pre_asian_handicap_first_half_away_plus_1`, "
    insert += " `pre_asian_handicap_first_half_home_plus_125`, "
    insert += " `pre_asian_handicap_first_half_away_plus_125`, "
    insert += " `pre_asian_handicap_first_half_home_plus_15`, "
    insert += " `pre_asian_handicap_first_half_away_plus_15`, "
    insert += " `pre_asian_handicap_first_half_home_plus_175`, "
    insert += " `pre_asian_handicap_first_half_away_plus_175`, "
    insert += " `end_asian_handicap_first_half_home_min_175`, "
    insert += " `end_asian_handicap_first_half_away_min_175`, "
    insert += " `end_asian_handicap_first_half_home_min_15`, "
    insert += " `end_asian_handicap_first_half_away_min_15`, "
    insert += " `end_asian_handicap_first_half_home_min_125`, "
    insert += " `end_asian_handicap_first_half_away_min_125`, "
    insert += " `end_asian_handicap_first_half_home_min_1`, "
    insert += " `end_asian_handicap_first_half_away_min_1`, "
    insert += " `end_asian_handicap_first_half_home_min_075`, "
    insert += " `end_asian_handicap_first_half_away_min_075`, "
    insert += " `end_asian_handicap_first_half_home_min_05`, "
    insert += " `end_asian_handicap_first_half_away_min_05`, "
    insert += " `end_asian_handicap_first_half_home_min_025`, "
    insert += " `end_asian_handicap_first_half_away_min_025`, "
    insert += " `end_asian_handicap_first_half_home_plus_0`, "
    insert += " `end_asian_handicap_first_half_away_plus_0`, "
    insert += " `end_asian_handicap_first_half_home_plus_025`, "
    insert += " `end_asian_handicap_first_half_away_plus_025`, "
    insert += " `end_asian_handicap_first_half_home_plus_05`, "
    insert += " `end_asian_handicap_first_half_away_plus_05`, "
    insert += " `end_asian_handicap_first_half_home_plus_075`, "
    insert += " `end_asian_handicap_first_half_away_plus_075`, "
    insert += " `end_asian_handicap_first_half_home_plus_1`, "
    insert += " `end_asian_handicap_first_half_away_plus_1`, "
    insert += " `end_asian_handicap_first_half_home_plus_125`, "
    insert += " `end_asian_handicap_first_half_away_plus_125`, "
    insert += " `end_asian_handicap_first_half_home_plus_15`, "
    insert += " `end_asian_handicap_first_half_away_plus_15`, "
    insert += " `end_asian_handicap_first_half_home_plus_175`, "
    insert += " `end_asian_handicap_first_half_away_plus_175`, "
    insert += " `pre_goals_overunder_first_half_over_05`, "
    insert += " `pre_goals_overunder_first_half_under_05`, "
    insert += " `pre_goals_overunder_first_half_over_075`, "
    insert += " `pre_goals_overunder_first_half_under_075`, "
    insert += " `pre_goals_overunder_first_half_over_10`, "
    insert += " `pre_goals_overunder_first_half_under_10`, "
    insert += " `pre_goals_overunder_first_half_over_125`, "
    insert += " `pre_goals_overunder_first_half_under_125`, "
    insert += " `pre_goals_overunder_first_half_over_15`, "
    insert += " `pre_goals_overunder_first_half_under_15`, "
    insert += " `pre_goals_overunder_first_half_over_175`, "
    insert += " `pre_goals_overunder_first_half_under_175`, "
    insert += " `pre_goals_overunder_first_half_over_20`, "
    insert += " `pre_goals_overunder_first_half_under_20`, "
    insert += " `pre_goals_overunder_first_half_over_225`, "
    insert += " `pre_goals_overunder_first_half_under_225`, "
    insert += " `pre_goals_overunder_first_half_over_25`, "
    insert += " `pre_goals_overunder_first_half_under_25`, "
    insert += " `pre_goals_overunder_first_half_over_275`, "
    insert += " `pre_goals_overunder_first_half_under_275`, "
    insert += " `pre_goals_overunder_first_half_over_30`, "
    insert += " `pre_goals_overunder_first_half_under_30`, "
    insert += " `pre_goals_overunder_first_half_over_325`, "
    insert += " `pre_goals_overunder_first_half_under_325`, "
    insert += " `pre_goals_overunder_first_half_over_35`, "
    insert += " `pre_goals_overunder_first_half_under_35`, "
    insert += " `pre_goals_overunder_first_half_over_375`, "
    insert += " `pre_goals_overunder_first_half_under_375`, "
    insert += " `end_goals_overunder_first_half_over_05`, "
    insert += " `end_goals_overunder_first_half_under_05`, "
    insert += " `end_goals_overunder_first_half_over_075`, "
    insert += " `end_goals_overunder_first_half_under_075`, "
    insert += " `end_goals_overunder_first_half_over_10`, "
    insert += " `end_goals_overunder_first_half_under_10`, "
    insert += " `end_goals_overunder_first_half_over_125`, "
    insert += " `end_goals_overunder_first_half_under_125`, "
    insert += " `end_goals_overunder_first_half_over_15`, "
    insert += " `end_goals_overunder_first_half_under_15`, "
    insert += " `end_goals_overunder_first_half_over_175`, "
    insert += " `end_goals_overunder_first_half_under_175`, "
    insert += " `end_goals_overunder_first_half_over_20`, "
    insert += " `end_goals_overunder_first_half_under_20`, "
    insert += " `end_goals_overunder_first_half_over_225`, "
    insert += " `end_goals_overunder_first_half_under_225`, "
    insert += " `end_goals_overunder_first_half_over_25`, "
    insert += " `end_goals_overunder_first_half_under_25`, "
    insert += " `end_goals_overunder_first_half_over_275`, "
    insert += " `end_goals_overunder_first_half_under_275`, "
    insert += " `end_goals_overunder_first_half_over_30`, "
    insert += " `end_goals_overunder_first_half_under_30`, "
    insert += " `end_goals_overunder_first_half_over_325`, "
    insert += " `end_goals_overunder_first_half_under_325`, "
    insert += " `end_goals_overunder_first_half_over_35`, "
    insert += " `end_goals_overunder_first_half_under_35`, "
    insert += " `end_goals_overunder_first_half_over_375`, "
    insert += " `end_goals_overunder_first_half_under_375`, "
    insert += " `pre_goals_overunder__second_half_over_05`, "
    insert += " `pre_goals_overunder__second_half_under_05`, "
    insert += " `pre_goals_overunder__second_half_over_075`, "
    insert += " `pre_goals_overunder__second_half_under_075`, "
    insert += " `pre_goals_overunder__second_half_over_10`, "
    insert += " `pre_goals_overunder__second_half_under_10`, "
    insert += " `pre_goals_overunder__second_half_over_125`, "
    insert += " `pre_goals_overunder__second_half_under_125`, "
    insert += " `pre_goals_overunder__second_half_over_15`, "
    insert += " `pre_goals_overunder__second_half_under_15`, "
    insert += " `pre_goals_overunder__second_half_over_175`, "
    insert += " `pre_goals_overunder__second_half_under_175`, "
    insert += " `pre_goals_overunder__second_half_over_20`, "
    insert += " `pre_goals_overunder__second_half_under_20`, "
    insert += " `pre_goals_overunder__second_half_over_225`, "
    insert += " `pre_goals_overunder__second_half_under_225`, "
    insert += " `pre_goals_overunder__second_half_over_25`, "
    insert += " `pre_goals_overunder__second_half_under_25`, "
    insert += " `pre_goals_overunder__second_half_over_275`, "
    insert += " `pre_goals_overunder__second_half_under_275`, "
    insert += " `pre_goals_overunder__second_half_over_30`, "
    insert += " `pre_goals_overunder__second_half_under_30`, "
    insert += " `pre_goals_overunder__second_half_over_325`, "
    insert += " `pre_goals_overunder__second_half_under_325`, "
    insert += " `pre_goals_overunder__second_half_over_35`, "
    insert += " `pre_goals_overunder__second_half_under_35`, "
    insert += " `pre_goals_overunder__second_half_over_375`, "
    insert += " `pre_goals_overunder__second_half_under_375`, "
    insert += " `end_goals_overunder__second_half_over_05`, "
    insert += " `end_goals_overunder__second_half_under_05`, "
    insert += " `end_goals_overunder__second_half_over_075`, "
    insert += " `end_goals_overunder__second_half_under_075`, "
    insert += " `end_goals_overunder__second_half_over_10`, "
    insert += " `end_goals_overunder__second_half_under_10`, "
    insert += " `end_goals_overunder__second_half_over_125`, "
    insert += " `end_goals_overunder__second_half_under_125`, "
    insert += " `end_goals_overunder__second_half_over_15`, "
    insert += " `end_goals_overunder__second_half_under_15`, "
    insert += " `end_goals_overunder__second_half_over_175`, "
    insert += " `end_goals_overunder__second_half_under_175`, "
    insert += " `end_goals_overunder__second_half_over_20`, "
    insert += " `end_goals_overunder__second_half_under_20`, "
    insert += " `end_goals_overunder__second_half_over_225`, "
    insert += " `end_goals_overunder__second_half_under_225`, "
    insert += " `end_goals_overunder__second_half_over_25`, "
    insert += " `end_goals_overunder__second_half_under_25`, "
    insert += " `end_goals_overunder__second_half_over_275`, "
    insert += " `end_goals_overunder__second_half_under_275`, "
    insert += " `end_goals_overunder__second_half_over_30`, "
    insert += " `end_goals_overunder__second_half_under_30`, "
    insert += " `end_goals_overunder__second_half_over_325`, "
    insert += " `end_goals_overunder__second_half_under_325`, "
    insert += " `end_goals_overunder__second_half_over_35`, "
    insert += " `end_goals_overunder__second_half_under_35`, "
    insert += " `end_goals_overunder__second_half_over_375`, "
    insert += " `end_goals_overunder__second_half_under_375`, "
    insert += " `pre_htft_double_home_home`, "
    insert += " `pre_htft_double_home_draw`, "
    insert += " `pre_htft_double_home_away`, "
    insert += " `pre_htft_double_draw_home`, "
    insert += " `pre_htft_double_draw_draw`, "
    insert += " `pre_htft_double_draw_away`, "
    insert += " `pre_htft_double_away_home`, "
    insert += " `pre_htft_double_away_draw`, "
    insert += " `pre_htft_double_away_away`, "
    insert += " `end_htft_double_home_home`, "
    insert += " `end_htft_double_home_draw`, "
    insert += " `end_htft_double_home_away`, "
    insert += " `end_htft_double_draw_home`, "
    insert += " `end_htft_double_draw_draw`, "
    insert += " `end_htft_double_draw_away`, "
    insert += " `end_htft_double_away_home`, "
    insert += " `end_htft_double_away_draw`, "
    insert += " `end_htft_double_away_away`, "
    insert += " `pre_both_teams_score_yes`, "
    insert += " `pre_both_teams_score_no`, "
    insert += " `end_both_teams_score_yes`, "
    insert += " `end_both_teams_score_no`, "
    insert += " `pre_both_teams_score__first_half_yes`, "
    insert += " `pre_both_teams_score__first_half_no`, "
    insert += " `end_both_teams_score__first_half_yes`, "
    insert += " `end_both_teams_score__first_half_no`, "
    insert += " `pre_both_teams_to_score__second_half_yes`, "
    insert += " `pre_both_teams_to_score__second_half_no`, "
    insert += " `end_both_teams_to_score__second_half_yes`, "
    insert += " `end_both_teams_to_score__second_half_no`, "
    insert += " `pre_results_both_teams_score_home_yes`, "
    insert += " `pre_results_both_teams_score_draw_yes`, "
    insert += " `pre_results_both_teams_score_away_yes`, "
    insert += " `pre_results_both_teams_score_home_no`, "
    insert += " `pre_results_both_teams_score_draw_no`, "
    insert += " `pre_results_both_teams_score_away_no`, "
    insert += " `end_results_both_teams_score_home_yes`, "
    insert += " `end_results_both_teams_score_draw_yes`, "
    insert += " `end_results_both_teams_score_away_yes`, "
    insert += " `end_results_both_teams_score_home_no`, "
    insert += " `end_results_both_teams_score_draw_no`, "
    insert += " `end_results_both_teams_score_away_no`, "
    insert += " `pre_to_score_in_both_halves_by_teams_home`, "
    insert += " `pre_to_score_in_both_halves_by_teams_away`, "
    insert += " `end_to_score_in_both_halves_by_teams_home`, "
    insert += " `end_to_score_in_both_halves_by_teams_away`, "
    insert += " `pre_total_goals_both_teams_to_score_over_yes_25`, "
    insert += " `pre_total_goals_both_teams_to_score_over_no_25`, "
    insert += " `pre_total_goals_both_teams_to_score_under_yes_25`, "
    insert += " `pre_total_goals_both_teams_to_score_under_no_25`, "
    insert += " `end_total_goals_both_teams_to_score_over_yes_25`, "
    insert += " `end_total_goals_both_teams_to_score_over_no_25`, "
    insert += " `end_total_goals_both_teams_to_score_under_yes_25`, "
    insert += " `end_total_goals_both_teams_to_score_under_no_25`, "
    insert += " `pre_both_teams_to_score_1st_half__2nd_half_yes_yes`, "
    insert += " `pre_both_teams_to_score_1st_half__2nd_half_yes_no`, "
    insert += " `pre_both_teams_to_score_1st_half__2nd_half_no_yes`, "
    insert += " `pre_both_teams_to_score_1st_half__2nd_half_no_no`, "
    insert += " `end_both_teams_to_score_1st_half__2nd_half_yes_yes`, "
    insert += " `end_both_teams_to_score_1st_half__2nd_half_yes_no`, "
    insert += " `end_both_teams_to_score_1st_half__2nd_half_no_yes`, "
    insert += " `end_both_teams_to_score_1st_half__2nd_half_no_no`, "
    insert += " `pre_highest_scoring_half_first`, "
    insert += " `pre_highest_scoring_half_draw`, "
    insert += " `pre_highest_scoring_half_second`, "
    insert += " `end_highest_scoring_half_first`, "
    insert += " `end_highest_scoring_half_draw`, "
    insert += " `end_highest_scoring_half_second`, "
    insert += " `pre_double_chance_home_draw`, "
    insert += " `pre_double_chance_home_away`, "
    insert += " `pre_double_chance_draw_away`, "
    insert += " `end_double_chance_home_draw`, "
    insert += " `end_double_chance_home_away`, "
    insert += " `end_double_chance_draw_away`, "
    insert += " `pre_double_chance__first_half_home_draw`, "
    insert += " `pre_double_chance__first_half_home_away`, "
    insert += " `pre_double_chance__first_half_draw_away`, "
    insert += " `end_double_chance__first_half_home_draw`, "
    insert += " `end_double_chance__first_half_home_away`, "
    insert += " `end_double_chance__first_half_draw_away`, "
    insert += " `pre_oddeven_odd`, "
    insert += " `pre_oddeven_even`, "
    insert += " `end_oddeven_odd`, "
    insert += " `end_oddeven_even`, "
    insert += " `pre_result_total_goals_home_over_35`, "
    insert += " `pre_result_total_goals_draw_over_35`, "
    insert += " `pre_result_total_goals_away_over_35`, "
    insert += " `pre_result_total_goals_home_under_35`, "
    insert += " `pre_result_total_goals_draw_under_35`, "
    insert += " `pre_result_total_goals_away_under_35`, "
    insert += " `pre_result_total_goals_home_over_25`, "
    insert += " `pre_result_total_goals_draw_over_25`, "
    insert += " `pre_result_total_goals_away_over_25`, "
    insert += " `pre_result_total_goals_home_under_25`, "
    insert += " `pre_result_total_goals_draw_under_25`, "
    insert += " `pre_result_total_goals_away_under_25`, "
    insert += " `end_result_total_goals_home_over_35`, "
    insert += " `end_result_total_goals_draw_over_35`, "
    insert += " `end_result_total_goals_away_over_35`, "
    insert += " `end_result_total_goals_home_under_35`, "
    insert += " `end_result_total_goals_draw_under_35`, "
    insert += " `end_result_total_goals_away_under_35`, "
    insert += " `end_result_total_goals_home_over_25`, "
    insert += " `end_result_total_goals_draw_over_25`, "
    insert += " `end_result_total_goals_away_over_25`, "
    insert += " `end_result_total_goals_home_under_25`, "
    insert += " `end_result_total_goals_draw_under_25`, "
    insert += " `end_result_total_goals_away_under_25`, "
    insert += " `pre_clean_sheet__home_yes`, "
    insert += " `pre_clean_sheet__home_no`, "
    insert += " `end_clean_sheet__home_yes`, "
    insert += " `end_clean_sheet__home_no`, "
    insert += " `pre_clean_sheet__away_yes`, "
    insert += " `pre_clean_sheet__away_no`, "
    insert += " `end_clean_sheet__away_yes`, "
    insert += " `end_clean_sheet__away_no`, "
    insert += " `pre_win_both_halves_home`, "
    insert += " `pre_win_both_halves_away`, "
    insert += " `end_win_both_halves_home`, "
    insert += " `end_win_both_halves_away`, "
    insert += " `pre_win_to_nil_home`, "
    insert += " `pre_win_to_nil_away`, "
    insert += " `end_win_to_nil_home`, "
    insert += " `end_win_to_nil_away`, "
    insert += " `pre_to_win_either_half_home`, "
    insert += " `pre_to_win_either_half_away`, "
    insert += " `end_to_win_either_half_home`, "
    insert += " `end_to_win_either_half_away`, "
    insert += " `pre_halftime_result_both_teams_score_home_yes`, "
    insert += " `pre_halftime_result_both_teams_score_draw_yes`, "
    insert += " `pre_halftime_result_both_teams_score_away_yes`, "
    insert += " `pre_halftime_result_both_teams_score_home_no`, "
    insert += " `pre_halftime_result_both_teams_score_draw_no`, "
    insert += " `pre_halftime_result_both_teams_score_away_no`, "
    insert += " `end_halftime_result_both_teams_score_home_yes`, "
    insert += " `end_halftime_result_both_teams_score_draw_yes`, "
    insert += " `end_halftime_result_both_teams_score_away_yes`, "
    insert += " `end_halftime_result_both_teams_score_home_no`, "
    insert += " `end_halftime_result_both_teams_score_draw_no`, "
    insert += " `end_halftime_result_both_teams_score_away_no`, "
    insert += " `pre_exact_goals_number_0`, "
    insert += " `pre_exact_goals_number_1`, "
    insert += " `pre_exact_goals_number_2`, "
    insert += " `pre_exact_goals_number_3`, "
    insert += " `pre_exact_goals_number_4`, "
    insert += " `pre_exact_goals_number_5`, "
    insert += " `pre_exact_goals_number_6`, "
    insert += " `pre_exact_goals_number_more_7`, "
    insert += " `end_exact_goals_number_0`, "
    insert += " `end_exact_goals_number_1`, "
    insert += " `end_exact_goals_number_2`, "
    insert += " `end_exact_goals_number_3`, "
    insert += " `end_exact_goals_number_4`, "
    insert += " `end_exact_goals_number_5`, "
    insert += " `end_exact_goals_number_6`, "
    insert += " `end_exact_goals_number_more_7`, "
    insert += " `pre_exact_goals_number__first_half_0`, "
    insert += " `pre_exact_goals_number__first_half_1`, "
    insert += " `pre_exact_goals_number__first_half_2`, "
    insert += " `pre_exact_goals_number__first_half_3`, "
    insert += " `pre_exact_goals_number__first_half_4`, "
    insert += " `pre_exact_goals_number__first_half_more_5`, "
    insert += " `end_exact_goals_number__first_half_0`, "
    insert += " `end_exact_goals_number__first_half_1`, "
    insert += " `end_exact_goals_number__first_half_2`, "
    insert += " `end_exact_goals_number__first_half_3`, "
    insert += " `end_exact_goals_number__first_half_4`, "
    insert += " `end_exact_goals_number__first_half_more_5`, "
    insert += " `pre_second_half_exact_goals_number_0`, "
    insert += " `pre_second_half_exact_goals_number_1`, "
    insert += " `pre_second_half_exact_goals_number_2`, "
    insert += " `pre_second_half_exact_goals_number_3`, "
    insert += " `pre_second_half_exact_goals_number_4`, "
    insert += " `pre_second_half_exact_goals_number_more_5`, "
    insert += " `end_second_half_exact_goals_number_0`, "
    insert += " `end_second_half_exact_goals_number_1`, "
    insert += " `end_second_half_exact_goals_number_2`, "
    insert += " `end_second_half_exact_goals_number_3`, "
    insert += " `end_second_half_exact_goals_number_4`, "
    insert += " `end_second_half_exact_goals_number_more_5`, "
    insert += " `pre_home_team_exact_goals_number_0`, "
    insert += " `pre_home_team_exact_goals_number_1`, "
    insert += " `pre_home_team_exact_goals_number_2`, "
    insert += " `pre_home_team_exact_goals_number_more_3`, "
    insert += " `end_home_team_exact_goals_number_0`, "
    insert += " `end_home_team_exact_goals_number_1`, "
    insert += " `end_home_team_exact_goals_number_2`, "
    insert += " `end_home_team_exact_goals_number_more_3`, "
    insert += " `pre_away_team_exact_goals_number_0`, "
    insert += " `pre_away_team_exact_goals_number_1`, "
    insert += " `pre_away_team_exact_goals_number_2`, "
    insert += " `pre_away_team_exact_goals_number_more_3`, "
    insert += " `end_away_team_exact_goals_number_0`, "
    insert += " `end_away_team_exact_goals_number_1`, "
    insert += " `end_away_team_exact_goals_number_2`, "
    insert += " `end_away_team_exact_goals_number_more_3`, "
    insert += " `pre_corners_winner_home`, "
    insert += " `pre_corners_winner_draw`, "
    insert += " `pre_corners_winner_away`, "
    insert += " `end_corners_winner_home`, "
    insert += " `end_corners_winner_draw`, "
    insert += " `end_corners_winner_away`, "
    insert += " `pre_10_overunder_over_05`, "
    insert += " `pre_10_overunder_under_05`, "
    insert += " `end_10_overunder_over_05`, "
    insert += " `end_10_overunder_under_05`, "
    insert += " `pre_cards_european_handicap_home_min_2`, "
    insert += " `pre_cards_european_handicap_draw_min_2`, "
    insert += " `pre_cards_european_handicap_away_min_2`, "
    insert += " `pre_cards_european_handicap_home_min_1`, "
    insert += " `pre_cards_european_handicap_draw_min_1`, "
    insert += " `pre_cards_european_handicap_away_min_1`, "
    insert += " `pre_cards_european_handicap_home_plus_0`, "
    insert += " `pre_cards_european_handicap_draw_plus_0`, "
    insert += " `pre_cards_european_handicap_away_plus_0`, "
    insert += " `pre_cards_european_handicap_home_plus_1`, "
    insert += " `pre_cards_european_handicap_draw_plus_1`, "
    insert += " `pre_cards_european_handicap_away_plus_1`, "
    insert += " `pre_cards_european_handicap_home_plus_2`, "
    insert += " `pre_cards_european_handicap_draw_plus_2`, "
    insert += " `pre_cards_european_handicap_away_plus_2`, "
    insert += " `end_cards_european_handicap_home_min_2`, "
    insert += " `end_cards_european_handicap_draw_min_2`, "
    insert += " `end_cards_european_handicap_away_min_2`, "
    insert += " `end_cards_european_handicap_home_min_1`, "
    insert += " `end_cards_european_handicap_draw_min_1`, "
    insert += " `end_cards_european_handicap_away_min_1`, "
    insert += " `end_cards_european_handicap_home_plus_0`, "
    insert += " `end_cards_european_handicap_draw_plus_0`, "
    insert += " `end_cards_european_handicap_away_plus_0`, "
    insert += " `end_cards_european_handicap_home_plus_1`, "
    insert += " `end_cards_european_handicap_draw_plus_1`, "
    insert += " `end_cards_european_handicap_away_plus_1`, "
    insert += " `end_cards_european_handicap_home_plus_2`, "
    insert += " `end_cards_european_handicap_draw_plus_2`, "
    insert += " `end_cards_european_handicap_away_plus_2`, "
    insert += " `pre_rcard_yes`, "
    insert += " `pre_rcard_no`, "
    insert += " `end_rcard_yes`, "
    insert += " `end_rcard_no`, "
    insert += " `pre_anytime_goal_scorer`, "
    insert += " `end_anytime_goal_scorer`, "
    insert += " `pre_first_goal_scorer`, "
    insert += " `end_first_goal_scorer`, "
    insert += " `pre_last_goal_scorer`, "
    insert += " `end_last_goal_scorer`, "
    insert += " `pre_to_score_two_or_more_goals`, "
    insert += " `end_to_score_two_or_more_goals`, "
    insert += " `pre_last_goal_scorer2`, "
    insert += " `end_last_goal_scorer2`, "
    insert += " `pre_exact_score`, "
    insert += " `end_exact_score`, "
    insert += " `pre_team_to_score_first_home`, "
    insert += " `pre_team_to_score_first_draw`, "
    insert += " `pre_team_to_score_first_away`, "
    insert += " `end_team_to_score_first_home`, "
    insert += " `end_team_to_score_first_draw`, "
    insert += " `end_team_to_score_first_away`, "
    insert += " `pre_team_to_score_last_home`, "
    insert += " `pre_team_to_score_last_draw`, "
    insert += " `pre_team_to_score_last_away`, "
    insert += " `end_team_to_score_last_home`, "
    insert += " `end_team_to_score_last_draw`, "
    insert += " `end_team_to_score_last_away`, "
    insert += " `pre_total_home_over_15`, "
    insert += " `pre_total_home_under_15`, "
    insert += " `pre_total_home_over_25`, "
    insert += " `pre_total_home_under_25`, "
    insert += " `pre_total_home_over_35`, "
    insert += " `pre_total_home_under_35`, "
    insert += " `pre_total_home_over_45`, "
    insert += " `pre_total_home_under_45`, "
    insert += " `pre_total_home_over_55`, "
    insert += " `pre_total_home_under_55`, "
    insert += " `pre_total_home_over_65`, "
    insert += " `pre_total_home_under_65`, "
    insert += " `end_total_home_over_15`, "
    insert += " `end_total_home_under_15`, "
    insert += " `end_total_home_over_25`, "
    insert += " `end_total_home_under_25`, "
    insert += " `end_total_home_over_35`, "
    insert += " `end_total_home_under_35`, "
    insert += " `end_total_home_over_45`, "
    insert += " `end_total_home_under_45`, "
    insert += " `end_total_home_over_55`, "
    insert += " `end_total_home_under_55`, "
    insert += " `end_total_home_over_65`, "
    insert += " `end_total_home_under_65`, "
    insert += " `pre_total_away_over_15`, "
    insert += " `pre_total_away_under_15`, "
    insert += " `pre_total_away_over_25`, "
    insert += " `pre_total_away_under_25`, "
    insert += " `pre_total_away_over_35`, "
    insert += " `pre_total_away_under_35`, "
    insert += " `pre_total_away_over_45`, "
    insert += " `pre_total_away_under_45`, "
    insert += " `pre_total_away_over_55`, "
    insert += " `pre_total_away_under_55`, "
    insert += " `pre_total_away_over_65`, "
    insert += " `pre_total_away_under_65`, "
    insert += " `end_total_away_over_15`, "
    insert += " `end_total_away_under_15`, "
    insert += " `end_total_away_over_25`, "
    insert += " `end_total_away_under_25`, "
    insert += " `end_total_away_over_35`, "
    insert += " `end_total_away_under_35`, "
    insert += " `end_total_away_over_45`, "
    insert += " `end_total_away_under_45`, "
    insert += " `end_total_away_over_55`, "
    insert += " `end_total_away_under_55`, "
    insert += " `end_total_away_over_65`, "
    insert += " `end_total_away_under_65`, "
    insert += " `pre_corners_asian_handicap_home_min_65`, "
    insert += " `pre_corners_asian_handicap_away_min_65`, "
    insert += " `pre_corners_asian_handicap_home_min_6`, "
    insert += " `pre_corners_asian_handicap_away_min_6`, "
    insert += " `pre_corners_asian_handicap_home_min_55`, "
    insert += " `pre_corners_asian_handicap_away_min_55`, "
    insert += " `pre_corners_asian_handicap_home_min_5`, "
    insert += " `pre_corners_asian_handicap_away_min_5`, "
    insert += " `pre_corners_asian_handicap_home_min_45`, "
    insert += " `pre_corners_asian_handicap_away_min_45`, "
    insert += " `pre_corners_asian_handicap_home_min_4`, "
    insert += " `pre_corners_asian_handicap_away_min_4`, "
    insert += " `pre_corners_asian_handicap_home_min_35`, "
    insert += " `pre_corners_asian_handicap_away_min_35`, "
    insert += " `pre_corners_asian_handicap_home_min_3`, "
    insert += " `pre_corners_asian_handicap_away_min_3`, "
    insert += " `pre_corners_asian_handicap_home_min_25`, "
    insert += " `pre_corners_asian_handicap_away_min_25`, "
    insert += " `pre_corners_asian_handicap_home_min_2`, "
    insert += " `pre_corners_asian_handicap_away_min_2`, "
    insert += " `pre_corners_asian_handicap_home_min_15`, "
    insert += " `pre_corners_asian_handicap_away_min_15`, "
    insert += " `pre_corners_asian_handicap_home_min_1`, "
    insert += " `pre_corners_asian_handicap_home_min_05`, "
    insert += " `pre_corners_asian_handicap_away_min_1`, "
    insert += " `pre_corners_asian_handicap_away_min_05`, "
    insert += " `pre_corners_asian_handicap_home_plus_0`, "
    insert += " `pre_corners_asian_handicap_away_plus_0`, "
    insert += " `pre_corners_asian_handicap_home_plus_05`, "
    insert += " `pre_corners_asian_handicap_away_plus_05`, "
    insert += " `pre_corners_asian_handicap_home_plus_1`, "
    insert += " `pre_corners_asian_handicap_away_plus_1`, "
    insert += " `pre_corners_asian_handicap_home_plus_15`, "
    insert += " `pre_corners_asian_handicap_away_plus_15`, "
    insert += " `pre_corners_asian_handicap_home_plus_2`, "
    insert += " `pre_corners_asian_handicap_away_plus_2`, "
    insert += " `pre_corners_asian_handicap_home_plus_25`, "
    insert += " `pre_corners_asian_handicap_away_plus_25`, "
    insert += " `pre_corners_asian_handicap_home_plus_3`, "
    insert += " `pre_corners_asian_handicap_away_plus_3`, "
    insert += " `pre_corners_asian_handicap_home_plus_35`, "
    insert += " `pre_corners_asian_handicap_away_plus_35`, "
    insert += " `pre_corners_asian_handicap_home_plus_4`, "
    insert += " `pre_corners_asian_handicap_away_plus_4`, "
    insert += " `pre_corners_asian_handicap_home_plus_45`, "
    insert += " `pre_corners_asian_handicap_away_plus_45`, "
    insert += " `pre_corners_asian_handicap_home_plus_5`, "
    insert += " `pre_corners_asian_handicap_away_plus_5`, "
    insert += " `pre_corners_asian_handicap_home_plus_55`, "
    insert += " `pre_corners_asian_handicap_away_plus_55`, "
    insert += " `pre_corners_asian_handicap_home_plus_6`, "
    insert += " `pre_corners_asian_handicap_away_plus_6`, "
    insert += " `pre_corners_asian_handicap_home_plus_65`, "
    insert += " `pre_corners_asian_handicap_away_plus_65`, "
    insert += " `end_corners_asian_handicap_home_min_65`, "
    insert += " `end_corners_asian_handicap_away_min_65`, "
    insert += " `end_corners_asian_handicap_home_min_6`, "
    insert += " `end_corners_asian_handicap_away_min_6`, "
    insert += " `end_corners_asian_handicap_home_min_55`, "
    insert += " `end_corners_asian_handicap_away_min_55`, "
    insert += " `end_corners_asian_handicap_home_min_5`, "
    insert += " `end_corners_asian_handicap_away_min_5`, "
    insert += " `end_corners_asian_handicap_home_min_45`, "
    insert += " `end_corners_asian_handicap_away_min_45`, "
    insert += " `end_corners_asian_handicap_home_min_4`, "
    insert += " `end_corners_asian_handicap_away_min_4`, "
    insert += " `end_corners_asian_handicap_home_min_35`, "
    insert += " `end_corners_asian_handicap_away_min_35`, "
    insert += " `end_corners_asian_handicap_home_min_3`, "
    insert += " `end_corners_asian_handicap_away_min_3`, "
    insert += " `end_corners_asian_handicap_home_min_25`, "
    insert += " `end_corners_asian_handicap_away_min_25`, "
    insert += " `end_corners_asian_handicap_home_min_2`, "
    insert += " `end_corners_asian_handicap_away_min_2`, "
    insert += " `end_corners_asian_handicap_home_min_15`, "
    insert += " `end_corners_asian_handicap_away_min_15`, "
    insert += " `end_corners_asian_handicap_home_min_1`, "
    insert += " `end_corners_asian_handicap_home_min_05`, "
    insert += " `end_corners_asian_handicap_away_min_1`, "
    insert += " `end_corners_asian_handicap_away_min_05`, "
    insert += " `end_corners_asian_handicap_home_plus_0`, "
    insert += " `end_corners_asian_handicap_away_plus_0`, "
    insert += " `end_corners_asian_handicap_home_plus_05`, "
    insert += " `end_corners_asian_handicap_away_plus_05`, "
    insert += " `end_corners_asian_handicap_home_plus_1`, "
    insert += " `end_corners_asian_handicap_away_plus_1`, "
    insert += " `end_corners_asian_handicap_home_plus_15`, "
    insert += " `end_corners_asian_handicap_away_plus_15`, "
    insert += " `end_corners_asian_handicap_home_plus_2`, "
    insert += " `end_corners_asian_handicap_away_plus_2`, "
    insert += " `end_corners_asian_handicap_home_plus_25`, "
    insert += " `end_corners_asian_handicap_away_plus_25`, "
    insert += " `end_corners_asian_handicap_home_plus_3`, "
    insert += " `end_corners_asian_handicap_away_plus_3`, "
    insert += " `end_corners_asian_handicap_home_plus_35`, "
    insert += " `end_corners_asian_handicap_away_plus_35`, "
    insert += " `end_corners_asian_handicap_home_plus_4`, "
    insert += " `end_corners_asian_handicap_away_plus_4`, "
    insert += " `end_corners_asian_handicap_home_plus_45`, "
    insert += " `end_corners_asian_handicap_away_plus_45`, "
    insert += " `end_corners_asian_handicap_home_plus_5`, "
    insert += " `end_corners_asian_handicap_away_plus_5`, "
    insert += " `end_corners_asian_handicap_home_plus_55`, "
    insert += " `end_corners_asian_handicap_away_plus_55`, "
    insert += " `end_corners_asian_handicap_home_plus_6`, "
    insert += " `end_corners_asian_handicap_away_plus_6`, "
    insert += " `end_corners_asian_handicap_home_plus_65`, "
    insert += " `end_corners_asian_handicap_away_plus_65`, "
    insert += " `pre_corners_over_under_over_700`, "
    insert += " `pre_corners_over_under_under_700`, "
    insert += " `pre_corners_over_under_over_725`, "
    insert += " `pre_corners_over_under_under_725`, "
    insert += " `pre_corners_over_under_over_750`, "
    insert += " `pre_corners_over_under_under_750`, "
    insert += " `pre_corners_over_under_over_775`, "
    insert += " `pre_corners_over_under_under_775`, "
    insert += " `pre_corners_over_under_over_800`, "
    insert += " `pre_corners_over_under_under_800`, "
    insert += " `pre_corners_over_under_over_825`, "
    insert += " `pre_corners_over_under_under_825`, "
    insert += " `pre_corners_over_under_over_850`, "
    insert += " `pre_corners_over_under_under_850`, "
    insert += " `pre_corners_over_under_over_875`, "
    insert += " `pre_corners_over_under_under_875`, "
    insert += " `pre_corners_over_under_over_900`, "
    insert += " `pre_corners_over_under_under_900`, "
    insert += " `pre_corners_over_under_over_925`, "
    insert += " `pre_corners_over_under_under_925`, "
    insert += " `pre_corners_over_under_over_950`, "
    insert += " `pre_corners_over_under_under_950`, "
    insert += " `pre_corners_over_under_over_975`, "
    insert += " `pre_corners_over_under_under_975`, "
    insert += " `pre_corners_over_under_over_1000`, "
    insert += " `pre_corners_over_under_under_1000`, "
    insert += " `pre_corners_over_under_over_1025`, "
    insert += " `pre_corners_over_under_under_1025`, "
    insert += " `pre_corners_over_under_over_1050`, "
    insert += " `pre_corners_over_under_under_1050`, "
    insert += " `pre_corners_over_under_over_1075`, "
    insert += " `pre_corners_over_under_under_1075`, "
    insert += " `pre_corners_over_under_over_1100`, "
    insert += " `pre_corners_over_under_under_1100`, "
    insert += " `pre_corners_over_under_over_1125`, "
    insert += " `pre_corners_over_under_under_1125`, "
    insert += " `pre_corners_over_under_over_1150`, "
    insert += " `pre_corners_over_under_under_1150`, "
    insert += " `pre_corners_over_under_over_1175`, "
    insert += " `pre_corners_over_under_under_1175`, "
    insert += " `pre_corners_over_under_over_1200`, "
    insert += " `pre_corners_over_under_under_1200`, "
    insert += " `pre_corners_over_under_over_1225`, "
    insert += " `pre_corners_over_under_under_1225`, "
    insert += " `pre_corners_over_under_over_1250`, "
    insert += " `pre_corners_over_under_under_1250`, "
    insert += " `pre_corners_over_under_over_1275`, "
    insert += " `pre_corners_over_under_under_1275`, "
    insert += " `end_corners_over_under_over_700`, "
    insert += " `end_corners_over_under_under_700`, "
    insert += " `end_corners_over_under_over_725`, "
    insert += " `end_corners_over_under_under_725`, "
    insert += " `end_corners_over_under_over_750`, "
    insert += " `end_corners_over_under_under_750`, "
    insert += " `end_corners_over_under_over_775`, "
    insert += " `end_corners_over_under_under_775`, "
    insert += " `end_corners_over_under_over_800`, "
    insert += " `end_corners_over_under_under_800`, "
    insert += " `end_corners_over_under_over_825`, "
    insert += " `end_corners_over_under_under_825`, "
    insert += " `end_corners_over_under_over_850`, "
    insert += " `end_corners_over_under_under_850`, "
    insert += " `end_corners_over_under_over_875`, "
    insert += " `end_corners_over_under_under_875`, "
    insert += " `end_corners_over_under_over_900`, "
    insert += " `end_corners_over_under_under_900`, "
    insert += " `end_corners_over_under_over_925`, "
    insert += " `end_corners_over_under_under_925`, "
    insert += " `end_corners_over_under_over_950`, "
    insert += " `end_corners_over_under_under_950`, "
    insert += " `end_corners_over_under_over_975`, "
    insert += " `end_corners_over_under_under_975`, "
    insert += " `end_corners_over_under_over_1000`, "
    insert += " `end_corners_over_under_under_1000`, "
    insert += " `end_corners_over_under_over_1025`, "
    insert += " `end_corners_over_under_under_1025`, "
    insert += " `end_corners_over_under_over_1050`, "
    insert += " `end_corners_over_under_under_1050`, "
    insert += " `end_corners_over_under_over_1075`, "
    insert += " `end_corners_over_under_under_1075`, "
    insert += " `end_corners_over_under_over_1100`, "
    insert += " `end_corners_over_under_under_1100`, "
    insert += " `end_corners_over_under_over_1125`, "
    insert += " `end_corners_over_under_under_1125`, "
    insert += " `end_corners_over_under_over_1150`, "
    insert += " `end_corners_over_under_under_1150`, "
    insert += " `end_corners_over_under_over_1175`, "
    insert += " `end_corners_over_under_under_1175`, "
    insert += " `end_corners_over_under_over_1200`, "
    insert += " `end_corners_over_under_under_1200`, "
    insert += " `end_corners_over_under_over_1225`, "
    insert += " `end_corners_over_under_under_1225`, "
    insert += " `end_corners_over_under_over_1250`, "
    insert += " `end_corners_over_under_under_1250`, "
    insert += " `end_corners_over_under_over_1275`, "
    insert += " `end_corners_over_under_under_1275`, "
    insert += " `pre_home_corners_overunder_over_25`, "
    insert += " `pre_home_corners_overunder_under_25`, "
    insert += " `pre_home_corners_overunder_over_35`, "
    insert += " `pre_home_corners_overunder_under_35`, "
    insert += " `pre_home_corners_overunder_over_45`, "
    insert += " `pre_home_corners_overunder_under_45`, "
    insert += " `pre_home_corners_overunder_over_55`, "
    insert += " `pre_home_corners_overunder_under_55`, "
    insert += " `pre_home_corners_overunder_over_65`, "
    insert += " `pre_home_corners_overunder_under_65`, "
    insert += " `pre_home_corners_overunder_over_75`, "
    insert += " `pre_home_corners_overunder_under_75`, "
    insert += " `pre_home_corners_overunder_over_85`, "
    insert += " `pre_home_corners_overunder_under_85`, "
    insert += " `end_home_corners_overunder_over_25`, "
    insert += " `end_home_corners_overunder_under_25`, "
    insert += " `end_home_corners_overunder_over_35`, "
    insert += " `end_home_corners_overunder_under_35`, "
    insert += " `end_home_corners_overunder_over_45`, "
    insert += " `end_home_corners_overunder_under_45`, "
    insert += " `end_home_corners_overunder_over_55`, "
    insert += " `end_home_corners_overunder_under_55`, "
    insert += " `end_home_corners_overunder_over_65`, "
    insert += " `end_home_corners_overunder_under_65`, "
    insert += " `end_home_corners_overunder_over_75`, "
    insert += " `end_home_corners_overunder_under_75`, "
    insert += " `end_home_corners_overunder_over_85`, "
    insert += " `end_home_corners_overunder_under_85`, "
    insert += " `pre_away_corners_overunder_over_25`, "
    insert += " `pre_away_corners_overunder_under_25`, "
    insert += " `pre_away_corners_overunder_over_35`, "
    insert += " `pre_away_corners_overunder_under_35`, "
    insert += " `pre_away_corners_overunder_over_45`, "
    insert += " `pre_away_corners_overunder_under_45`, "
    insert += " `pre_away_corners_overunder_over_55`, "
    insert += " `pre_away_corners_overunder_under_55`, "
    insert += " `pre_away_corners_overunder_over_65`, "
    insert += " `pre_away_corners_overunder_under_65`, "
    insert += " `pre_away_corners_overunder_over_75`, "
    insert += " `pre_away_corners_overunder_under_75`, "
    insert += " `pre_away_corners_overunder_over_85`, "
    insert += " `pre_away_corners_overunder_under_85`, "
    insert += " `end_away_corners_overunder_over_25`, "
    insert += " `end_away_corners_overunder_under_25`, "
    insert += " `end_away_corners_overunder_over_35`, "
    insert += " `end_away_corners_overunder_under_35`, "
    insert += " `end_away_corners_overunder_over_45`, "
    insert += " `end_away_corners_overunder_under_45`, "
    insert += " `end_away_corners_overunder_over_55`, "
    insert += " `end_away_corners_overunder_under_55`, "
    insert += " `end_away_corners_overunder_over_65`, "
    insert += " `end_away_corners_overunder_under_65`, "
    insert += " `end_away_corners_overunder_over_75`, "
    insert += " `end_away_corners_overunder_under_75`, "
    insert += " `end_away_corners_overunder_over_85`, "
    insert += " `end_away_corners_overunder_under_85`, "
    insert += " `pre_first_corner_home`, "
    insert += " `pre_first_corner_away`, "
    insert += " `end_first_corner_home`, "
    insert += " `end_first_corner_away`, "
    insert += " `pre_last_corner_home`, "
    insert += " `pre_last_corner_away`, "
    insert += " `end_last_corner_home`, "
    insert += " `end_last_corner_away`, "
    insert += " `pre_cards_asian_handicap_home_min_05`, "
    insert += " `pre_cards_asian_handicap_away_min_05`, "
    insert += " `pre_cards_asian_handicap_home_plus_0`, "
    insert += " `pre_cards_asian_handicap_away_plus_0`, "
    insert += " `pre_cards_asian_handicap_home_plus_05`, "
    insert += " `pre_cards_asian_handicap_away_plus_05`, "
    insert += " `end_cards_asian_handicap_home_min_05`, "
    insert += " `end_cards_asian_handicap_away_min_05`, "
    insert += " `end_cards_asian_handicap_home_plus_0`, "
    insert += " `end_cards_asian_handicap_away_plus_0`, "
    insert += " `end_cards_asian_handicap_home_plus_05`, "
    insert += " `end_cards_asian_handicap_away_plus_05`, "
    insert += " `pre_cards_overunder_over_25`, "
    insert += " `pre_cards_overunder_under_25`, "
    insert += " `pre_cards_overunder_over_35`, "
    insert += " `pre_cards_overunder_under_35`, "
    insert += " `pre_cards_overunder_over_45`, "
    insert += " `pre_cards_overunder_under_45`, "
    insert += " `pre_cards_overunder_over_55`, "
    insert += " `pre_cards_overunder_under_55`, "
    insert += " `pre_cards_overunder_over_65`, "
    insert += " `pre_cards_overunder_under_65`, "
    insert += " `pre_cards_overunder_over_75`, "
    insert += " `pre_cards_overunder_under_75`, "
    insert += " `end_cards_overunder_over_25`, "
    insert += " `end_cards_overunder_under_25`, "
    insert += " `end_cards_overunder_over_35`, "
    insert += " `end_cards_overunder_under_35`, "
    insert += " `end_cards_overunder_over_45`, "
    insert += " `end_cards_overunder_under_45`, "
    insert += " `end_cards_overunder_over_55`, "
    insert += " `end_cards_overunder_under_55`, "
    insert += " `end_cards_overunder_over_65`, "
    insert += " `end_cards_overunder_under_65`, "
    insert += " `end_cards_overunder_over_75`, "
    insert += " `end_cards_overunder_under_75`, "
    insert += " `pre_home_team_total_cards_over_15`, "
    insert += " `pre_home_team_total_cards_under_15`, "
    insert += " `pre_home_team_total_cards_over_25`, "
    insert += " `pre_home_team_total_cards_under_25`, "
    insert += " `pre_home_team_total_cards_over_35`, "
    insert += " `pre_home_team_total_cards_under_35`, "
    insert += " `end_home_team_total_cards_over_15`, "
    insert += " `end_home_team_total_cards_under_15`, "
    insert += " `end_home_team_total_cards_over_25`, "
    insert += " `end_home_team_total_cards_under_25`, "
    insert += " `end_home_team_total_cards_over_35`, "
    insert += " `end_home_team_total_cards_under_35`, "
    insert += " `pre_away_team_total_cards_over_15`, "
    insert += " `pre_away_team_total_cards_under_15`, "
    insert += " `pre_away_team_total_cards_over_25`, "
    insert += " `pre_away_team_total_cards_under_25`, "
    insert += " `pre_away_team_total_cards_over_35`, "
    insert += " `pre_away_team_total_cards_under_35`, "
    insert += " `end_away_team_total_cards_over_15`, "
    insert += " `end_away_team_total_cards_under_15`, "
    insert += " `end_away_team_total_cards_over_25`, "
    insert += " `end_away_team_total_cards_under_25`, "
    insert += " `end_away_team_total_cards_over_35`, "
    insert += " `end_away_team_total_cards_under_35`, "
    insert += " `pre_total_goals_under_2`, "
    insert += " `pre_total_goals_2_or_3`, "
    insert += " `pre_total_goals_over_3`, "
    insert += " `end_total_goals_under_2`, "
    insert += " `end_total_goals_2_or_3`, "
    insert += " `end_total_goals_over_3`, "
    insert += " `pre_first_goal_method_shot`, "
    insert += " `pre_first_goal_method_header`, "
    insert += " `pre_first_goal_method_penalty`, "
    insert += " `pre_first_goal_method_freekick`, "
    insert += " `pre_first_goal_method_owngoal`, "
    insert += " `pre_first_goal_method_draw`, "
    insert += " `end_first_goal_method_shot`, "
    insert += " `end_first_goal_method_header`, "
    insert += " `end_first_goal_method_penalty`, "
    insert += " `end_first_goal_method_freekick`, "
    insert += " `end_first_goal_method_owngoal`, "
    insert += " `end_first_goal_method_draw`, "
    insert += " `pre_to_score_a_penalty_home`, "
    insert += " `pre_to_score_a_penalty_away`, "
    insert += " `end_to_score_a_penalty_home`, "
    insert += " `end_to_score_a_penalty_away`, "
    insert += " `pre_to_miss_a_penalty_home`, "
    insert += " `pre_to_miss_a_penalty_away`, "
    insert += " `end_to_miss_a_penalty_home`, "
    insert += " `end_to_miss_a_penalty_away`, "
    insert += " `pre_player_to_be_booked`, "
    insert += " `end_player_to_be_booked`, "
    insert += " `pre_ah_pattern`, "
    insert += " `pre_ah_pattern_mirror`, "
    insert += " `pre_gou_pattern`, "
    insert += " `end_ah_pattern`, "
    insert += " `end_ah_pattern_mirror`, "
    insert += " `end_gou_pattern` "
    # ------------------------------------------------------ 
    insert += "  ) VALUES ( " 
    # ------------------------------------------------------
    insert += "  " + fixtureapi_id + ", "
    insert += "  " + leagueapi_id + ", "
    insert += "  " + season + ", "
    
    insert += "  " + pre_match_winner_home + ", "
    insert += "  " + pre_match_winner_draw + ", "
    insert += "  " + pre_match_winner_away + ", "
    insert += "  " + end_match_winner_home + ", "
    insert += "  " + end_match_winner_draw + ", "
    insert += "  " + end_match_winner_away + ", "
    insert += "  " + pre_homeaway_home + ", "
    insert += "  " + pre_homeaway_away + ", "
    insert += "  " + end_homeaway_home + ", "
    insert += "  " + end_homeaway_away + ", "
    insert += "  " + pre_first_half_winner_home + ", "
    insert += "  " + pre_first_half_winner_draw + ", "
    insert += "  " + pre_first_half_winner_away + ", "
    insert += "  " + end_first_half_winner_home + ", "
    insert += "  " + end_first_half_winner_draw + ", "
    insert += "  " + end_first_half_winner_away + ", "
    insert += "  " + pre_second_half_winner_home + ", "
    insert += "  " + pre_second_half_winner_draw + ", "
    insert += "  " + pre_second_half_winner_away + ", "
    insert += "  " + end_second_half_winner_home + ", "
    insert += "  " + end_second_half_winner_draw + ", "
    insert += "  " + end_second_half_winner_away + ", "
    insert += "  " + pre_asian_handicap_home_min_675 + ", "
    insert += "  " + pre_asian_handicap_away_min_675 + ", "
    insert += "  " + pre_asian_handicap_home_min_65 + ", "
    insert += "  " + pre_asian_handicap_away_min_65 + ", "
    insert += "  " + pre_asian_handicap_home_min_625 + ", "
    insert += "  " + pre_asian_handicap_away_min_625 + ", "
    insert += "  " + pre_asian_handicap_home_min_6 + ", "
    insert += "  " + pre_asian_handicap_away_min_6 + ", "
    insert += "  " + pre_asian_handicap_home_min_575 + ", "
    insert += "  " + pre_asian_handicap_away_min_575 + ", "
    insert += "  " + pre_asian_handicap_home_min_55 + ", "
    insert += "  " + pre_asian_handicap_away_min_55 + ", "
    insert += "  " + pre_asian_handicap_home_min_525 + ", "
    insert += "  " + pre_asian_handicap_away_min_525 + ", "
    insert += "  " + pre_asian_handicap_home_min_5 + ", "
    insert += "  " + pre_asian_handicap_away_min_5 + ", "
    insert += "  " + pre_asian_handicap_home_min_475 + ", "
    insert += "  " + pre_asian_handicap_away_min_475 + ", "
    insert += "  " + pre_asian_handicap_home_min_45 + ", "
    insert += "  " + pre_asian_handicap_away_min_45 + ", "
    insert += "  " + pre_asian_handicap_home_min_425 + ", "
    insert += "  " + pre_asian_handicap_away_min_425 + ", "
    insert += "  " + pre_asian_handicap_home_min_4 + ", "
    insert += "  " + pre_asian_handicap_away_min_4 + ", "
    insert += "  " + pre_asian_handicap_home_min_375 + ", "
    insert += "  " + pre_asian_handicap_away_min_375 + ", "
    insert += "  " + pre_asian_handicap_home_min_35 + ", "
    insert += "  " + pre_asian_handicap_away_min_35 + ", "
    insert += "  " + pre_asian_handicap_home_min_325 + ", "
    insert += "  " + pre_asian_handicap_away_min_325 + ", "
    insert += "  " + pre_asian_handicap_home_min_3 + ", "
    insert += "  " + pre_asian_handicap_away_min_3 + ", "
    insert += "  " + pre_asian_handicap_home_min_275 + ", "
    insert += "  " + pre_asian_handicap_away_min_275 + ", "
    insert += "  " + pre_asian_handicap_home_min_25 + ", "
    insert += "  " + pre_asian_handicap_away_min_25 + ", "
    insert += "  " + pre_asian_handicap_home_min_225 + ", "
    insert += "  " + pre_asian_handicap_away_min_225 + ", "
    insert += "  " + pre_asian_handicap_home_min_2 + ", "
    insert += "  " + pre_asian_handicap_away_min_2 + ", "
    insert += "  " + pre_asian_handicap_home_min_175 + ", "
    insert += "  " + pre_asian_handicap_away_min_175 + ", "
    insert += "  " + pre_asian_handicap_home_min_15 + ", "
    insert += "  " + pre_asian_handicap_away_min_15 + ", "
    insert += "  " + pre_asian_handicap_home_min_125 + ", "
    insert += "  " + pre_asian_handicap_away_min_125 + ", "
    insert += "  " + pre_asian_handicap_home_min_1 + ", "
    insert += "  " + pre_asian_handicap_away_min_1 + ", "
    insert += "  " + pre_asian_handicap_home_min_075 + ", "
    insert += "  " + pre_asian_handicap_away_min_075 + ", "
    insert += "  " + pre_asian_handicap_home_min_05 + ", "
    insert += "  " + pre_asian_handicap_away_min_05 + ", "
    insert += "  " + pre_asian_handicap_home_min_025 + ", "
    insert += "  " + pre_asian_handicap_away_min_025 + ", "
    insert += "  " + pre_asian_handicap_home_plus_0 + ", "
    insert += "  " + pre_asian_handicap_away_plus_0 + ", "
    insert += "  " + pre_asian_handicap_home_plus_025 + ", "
    insert += "  " + pre_asian_handicap_away_plus_025 + ", "
    insert += "  " + pre_asian_handicap_home_plus_05 + ", "
    insert += "  " + pre_asian_handicap_away_plus_05 + ", "
    insert += "  " + pre_asian_handicap_home_plus_075 + ", "
    insert += "  " + pre_asian_handicap_away_plus_075 + ", "
    insert += "  " + pre_asian_handicap_home_plus_1 + ", "
    insert += "  " + pre_asian_handicap_away_plus_1 + ", "
    insert += "  " + pre_asian_handicap_home_plus_125 + ", "
    insert += "  " + pre_asian_handicap_away_plus_125 + ", "
    insert += "  " + pre_asian_handicap_home_plus_15 + ", "
    insert += "  " + pre_asian_handicap_away_plus_15 + ", "
    insert += "  " + pre_asian_handicap_home_plus_175 + ", "
    insert += "  " + pre_asian_handicap_away_plus_175 + ", "
    insert += "  " + pre_asian_handicap_home_plus_2 + ", "
    insert += "  " + pre_asian_handicap_away_plus_2 + ", "
    insert += "  " + pre_asian_handicap_home_plus_225 + ", "
    insert += "  " + pre_asian_handicap_away_plus_225 + ", "
    insert += "  " + pre_asian_handicap_home_plus_25 + ", "
    insert += "  " + pre_asian_handicap_away_plus_25 + ", "
    insert += "  " + pre_asian_handicap_home_plus_275 + ", "
    insert += "  " + pre_asian_handicap_away_plus_275 + ", "
    insert += "  " + pre_asian_handicap_home_plus_3 + ", "
    insert += "  " + pre_asian_handicap_away_plus_3 + ", "
    insert += "  " + pre_asian_handicap_home_plus_325 + ", "
    insert += "  " + pre_asian_handicap_away_plus_325 + ", "
    insert += "  " + pre_asian_handicap_home_plus_35 + ", "
    insert += "  " + pre_asian_handicap_away_plus_35 + ", "
    insert += "  " + pre_asian_handicap_home_plus_375 + ", "
    insert += "  " + pre_asian_handicap_away_plus_375 + ", "
    insert += "  " + pre_asian_handicap_home_plus_4 + ", "
    insert += "  " + pre_asian_handicap_away_plus_4 + ", "
    insert += "  " + pre_asian_handicap_home_plus_425 + ", "
    insert += "  " + pre_asian_handicap_away_plus_425 + ", "
    insert += "  " + pre_asian_handicap_home_plus_45 + ", "
    insert += "  " + pre_asian_handicap_away_plus_45 + ", "
    insert += "  " + pre_asian_handicap_home_plus_475 + ", "
    insert += "  " + pre_asian_handicap_away_plus_475 + ", "
    insert += "  " + pre_asian_handicap_home_plus_5 + ", "
    insert += "  " + pre_asian_handicap_away_plus_5 + ", "
    insert += "  " + pre_asian_handicap_home_plus_525 + ", "
    insert += "  " + pre_asian_handicap_away_plus_525 + ", "
    insert += "  " + pre_asian_handicap_home_plus_55 + ", "
    insert += "  " + pre_asian_handicap_away_plus_55 + ", "
    insert += "  " + pre_asian_handicap_home_plus_575 + ", "
    insert += "  " + pre_asian_handicap_away_plus_575 + ", "
    insert += "  " + pre_asian_handicap_home_plus_6 + ", "
    insert += "  " + pre_asian_handicap_away_plus_6 + ", "
    insert += "  " + pre_asian_handicap_home_plus_625 + ", "
    insert += "  " + pre_asian_handicap_away_plus_625 + ", "
    insert += "  " + pre_asian_handicap_home_plus_65 + ", "
    insert += "  " + pre_asian_handicap_away_plus_65 + ", "
    insert += "  " + pre_asian_handicap_home_plus_675 + ", "
    insert += "  " + pre_asian_handicap_away_plus_675 + ", "
    insert += "  " + end_asian_handicap_home_min_675 + ", "
    insert += "  " + end_asian_handicap_away_min_675 + ", "
    insert += "  " + end_asian_handicap_home_min_65 + ", "
    insert += "  " + end_asian_handicap_away_min_65 + ", "
    insert += "  " + end_asian_handicap_home_min_625 + ", "
    insert += "  " + end_asian_handicap_away_min_625 + ", "
    insert += "  " + end_asian_handicap_home_min_6 + ", "
    insert += "  " + end_asian_handicap_away_min_6 + ", "
    insert += "  " + end_asian_handicap_home_min_575 + ", "
    insert += "  " + end_asian_handicap_away_min_575 + ", "
    insert += "  " + end_asian_handicap_home_min_55 + ", "
    insert += "  " + end_asian_handicap_away_min_55 + ", "
    insert += "  " + end_asian_handicap_home_min_525 + ", "
    insert += "  " + end_asian_handicap_away_min_525 + ", "
    insert += "  " + end_asian_handicap_home_min_5 + ", "
    insert += "  " + end_asian_handicap_away_min_5 + ", "
    insert += "  " + end_asian_handicap_home_min_475 + ", "
    insert += "  " + end_asian_handicap_away_min_475 + ", "
    insert += "  " + end_asian_handicap_home_min_45 + ", "
    insert += "  " + end_asian_handicap_away_min_45 + ", "
    insert += "  " + end_asian_handicap_home_min_425 + ", "
    insert += "  " + end_asian_handicap_away_min_425 + ", "
    insert += "  " + end_asian_handicap_home_min_4 + ", "
    insert += "  " + end_asian_handicap_away_min_4 + ", "
    insert += "  " + end_asian_handicap_home_min_375 + ", "
    insert += "  " + end_asian_handicap_away_min_375 + ", "
    insert += "  " + end_asian_handicap_home_min_35 + ", "
    insert += "  " + end_asian_handicap_away_min_35 + ", "
    insert += "  " + end_asian_handicap_home_min_325 + ", "
    insert += "  " + end_asian_handicap_away_min_325 + ", "
    insert += "  " + end_asian_handicap_home_min_3 + ", "
    insert += "  " + end_asian_handicap_away_min_3 + ", "
    insert += "  " + end_asian_handicap_home_min_275 + ", "
    insert += "  " + end_asian_handicap_away_min_275 + ", "
    insert += "  " + end_asian_handicap_home_min_25 + ", "
    insert += "  " + end_asian_handicap_away_min_25 + ", "
    insert += "  " + end_asian_handicap_home_min_225 + ", "
    insert += "  " + end_asian_handicap_away_min_225 + ", "
    insert += "  " + end_asian_handicap_home_min_2 + ", "
    insert += "  " + end_asian_handicap_away_min_2 + ", "
    insert += "  " + end_asian_handicap_home_min_175 + ", "
    insert += "  " + end_asian_handicap_away_min_175 + ", "
    insert += "  " + end_asian_handicap_home_min_15 + ", "
    insert += "  " + end_asian_handicap_away_min_15 + ", "
    insert += "  " + end_asian_handicap_home_min_125 + ", "
    insert += "  " + end_asian_handicap_away_min_125 + ", "
    insert += "  " + end_asian_handicap_home_min_1 + ", "
    insert += "  " + end_asian_handicap_away_min_1 + ", "
    insert += "  " + end_asian_handicap_home_min_075 + ", "
    insert += "  " + end_asian_handicap_away_min_075 + ", "
    insert += "  " + end_asian_handicap_home_min_05 + ", "
    insert += "  " + end_asian_handicap_away_min_05 + ", "
    insert += "  " + end_asian_handicap_home_min_025 + ", "
    insert += "  " + end_asian_handicap_away_min_025 + ", "
    insert += "  " + end_asian_handicap_home_plus_0 + ", "
    insert += "  " + end_asian_handicap_away_plus_0 + ", "
    insert += "  " + end_asian_handicap_home_plus_025 + ", "
    insert += "  " + end_asian_handicap_away_plus_025 + ", "
    insert += "  " + end_asian_handicap_home_plus_05 + ", "
    insert += "  " + end_asian_handicap_away_plus_05 + ", "
    insert += "  " + end_asian_handicap_home_plus_075 + ", "
    insert += "  " + end_asian_handicap_away_plus_075 + ", "
    insert += "  " + end_asian_handicap_home_plus_1 + ", "
    insert += "  " + end_asian_handicap_away_plus_1 + ", "
    insert += "  " + end_asian_handicap_home_plus_125 + ", "
    insert += "  " + end_asian_handicap_away_plus_125 + ", "
    insert += "  " + end_asian_handicap_home_plus_15 + ", "
    insert += "  " + end_asian_handicap_away_plus_15 + ", "
    insert += "  " + end_asian_handicap_home_plus_175 + ", "
    insert += "  " + end_asian_handicap_away_plus_175 + ", "
    insert += "  " + end_asian_handicap_home_plus_2 + ", "
    insert += "  " + end_asian_handicap_away_plus_2 + ", "
    insert += "  " + end_asian_handicap_home_plus_225 + ", "
    insert += "  " + end_asian_handicap_away_plus_225 + ", "
    insert += "  " + end_asian_handicap_home_plus_25 + ", "
    insert += "  " + end_asian_handicap_away_plus_25 + ", "
    insert += "  " + end_asian_handicap_home_plus_275 + ", "
    insert += "  " + end_asian_handicap_away_plus_275 + ", "
    insert += "  " + end_asian_handicap_home_plus_3 + ", "
    insert += "  " + end_asian_handicap_away_plus_3 + ", "
    insert += "  " + end_asian_handicap_home_plus_325 + ", "
    insert += "  " + end_asian_handicap_away_plus_325 + ", "
    insert += "  " + end_asian_handicap_home_plus_35 + ", "
    insert += "  " + end_asian_handicap_away_plus_35 + ", "
    insert += "  " + end_asian_handicap_home_plus_375 + ", "
    insert += "  " + end_asian_handicap_away_plus_375 + ", "
    insert += "  " + end_asian_handicap_home_plus_4 + ", "
    insert += "  " + end_asian_handicap_away_plus_4 + ", "
    insert += "  " + end_asian_handicap_home_plus_425 + ", "
    insert += "  " + end_asian_handicap_away_plus_425 + ", "
    insert += "  " + end_asian_handicap_home_plus_45 + ", "
    insert += "  " + end_asian_handicap_away_plus_45 + ", "
    insert += "  " + end_asian_handicap_home_plus_475 + ", "
    insert += "  " + end_asian_handicap_away_plus_475 + ", "
    insert += "  " + end_asian_handicap_home_plus_5 + ", "
    insert += "  " + end_asian_handicap_away_plus_5 + ", "
    insert += "  " + end_asian_handicap_home_plus_525 + ", "
    insert += "  " + end_asian_handicap_away_plus_525 + ", "
    insert += "  " + end_asian_handicap_home_plus_55 + ", "
    insert += "  " + end_asian_handicap_away_plus_55 + ", "
    insert += "  " + end_asian_handicap_home_plus_575 + ", "
    insert += "  " + end_asian_handicap_away_plus_575 + ", "
    insert += "  " + end_asian_handicap_home_plus_6 + ", "
    insert += "  " + end_asian_handicap_away_plus_6 + ", "
    insert += "  " + end_asian_handicap_home_plus_625 + ", "
    insert += "  " + end_asian_handicap_away_plus_625 + ", "
    insert += "  " + end_asian_handicap_home_plus_65 + ", "
    insert += "  " + end_asian_handicap_away_plus_65 + ", "
    insert += "  " + end_asian_handicap_home_plus_675 + ", "
    insert += "  " + end_asian_handicap_away_plus_675 + ", "
    insert += "  " + pre_goals_overunder_over_05 + ", "
    insert += "  " + pre_goals_overunder_under_05 + ", "
    insert += "  " + pre_goals_overunder_over_075 + ", "
    insert += "  " + pre_goals_overunder_under_075 + ", "
    insert += "  " + pre_goals_overunder_over_10 + ", "
    insert += "  " + pre_goals_overunder_under_10 + ", "
    insert += "  " + pre_goals_overunder_over_125 + ", "
    insert += "  " + pre_goals_overunder_under_125 + ", "
    insert += "  " + pre_goals_overunder_over_15 + ", "
    insert += "  " + pre_goals_overunder_under_15 + ", "
    insert += "  " + pre_goals_overunder_over_175 + ", "
    insert += "  " + pre_goals_overunder_under_175 + ", "
    insert += "  " + pre_goals_overunder_over_20 + ", "
    insert += "  " + pre_goals_overunder_under_20 + ", "
    insert += "  " + pre_goals_overunder_over_225 + ", "
    insert += "  " + pre_goals_overunder_under_225 + ", "
    insert += "  " + pre_goals_overunder_over_25 + ", "
    insert += "  " + pre_goals_overunder_under_25 + ", "
    insert += "  " + pre_goals_overunder_over_275 + ", "
    insert += "  " + pre_goals_overunder_under_275 + ", "
    insert += "  " + pre_goals_overunder_over_30 + ", "
    insert += "  " + pre_goals_overunder_under_30 + ", "
    insert += "  " + pre_goals_overunder_over_325 + ", "
    insert += "  " + pre_goals_overunder_under_325 + ", "
    insert += "  " + pre_goals_overunder_over_35 + ", "
    insert += "  " + pre_goals_overunder_under_35 + ", "
    insert += "  " + pre_goals_overunder_over_375 + ", "
    insert += "  " + pre_goals_overunder_under_375 + ", "
    insert += "  " + pre_goals_overunder_over_40 + ", "
    insert += "  " + pre_goals_overunder_under_40 + ", "
    insert += "  " + pre_goals_overunder_over_425 + ", "
    insert += "  " + pre_goals_overunder_under_425 + ", "
    insert += "  " + pre_goals_overunder_over_45 + ", "
    insert += "  " + pre_goals_overunder_under_45 + ", "
    insert += "  " + pre_goals_overunder_over_475 + ", "
    insert += "  " + pre_goals_overunder_under_475 + ", "
    insert += "  " + pre_goals_overunder_over_50 + ", "
    insert += "  " + pre_goals_overunder_under_50 + ", "
    insert += "  " + pre_goals_overunder_over_525 + ", "
    insert += "  " + pre_goals_overunder_under_525 + ", "
    insert += "  " + pre_goals_overunder_over_55 + ", "
    insert += "  " + pre_goals_overunder_under_55 + ", "
    insert += "  " + pre_goals_overunder_over_575 + ", "
    insert += "  " + pre_goals_overunder_under_575 + ", "
    insert += "  " + pre_goals_overunder_over_60 + ", "
    insert += "  " + pre_goals_overunder_under_60 + ", "
    insert += "  " + pre_goals_overunder_over_625 + ", "
    insert += "  " + pre_goals_overunder_under_625 + ", "
    insert += "  " + pre_goals_overunder_over_65 + ", "
    insert += "  " + pre_goals_overunder_under_65 + ", "
    insert += "  " + pre_goals_overunder_over_675 + ", "
    insert += "  " + pre_goals_overunder_under_675 + ", "
    insert += "  " + pre_goals_overunder_over_70 + ", "
    insert += "  " + pre_goals_overunder_under_70 + ", "
    insert += "  " + pre_goals_overunder_over_75 + ", "
    insert += "  " + pre_goals_overunder_under_75 + ", "
    insert += "  " + pre_goals_overunder_over_85 + ", "
    insert += "  " + pre_goals_overunder_under_85 + ", "
    insert += "  " + pre_goals_overunder_over_95 + ", "
    insert += "  " + pre_goals_overunder_under_95 + ", "
    insert += "  " + end_goals_overunder_over_05 + ", "
    insert += "  " + end_goals_overunder_under_05 + ", "
    insert += "  " + end_goals_overunder_over_075 + ", "
    insert += "  " + end_goals_overunder_under_075 + ", "
    insert += "  " + end_goals_overunder_over_10 + ", "
    insert += "  " + end_goals_overunder_under_10 + ", "
    insert += "  " + end_goals_overunder_over_125 + ", "
    insert += "  " + end_goals_overunder_under_125 + ", "
    insert += "  " + end_goals_overunder_over_15 + ", "
    insert += "  " + end_goals_overunder_under_15 + ", "
    insert += "  " + end_goals_overunder_over_175 + ", "
    insert += "  " + end_goals_overunder_under_175 + ", "
    insert += "  " + end_goals_overunder_over_20 + ", "
    insert += "  " + end_goals_overunder_under_20 + ", "
    insert += "  " + end_goals_overunder_over_225 + ", "
    insert += "  " + end_goals_overunder_under_225 + ", "
    insert += "  " + end_goals_overunder_over_25 + ", "
    insert += "  " + end_goals_overunder_under_25 + ", "
    insert += "  " + end_goals_overunder_over_275 + ", "
    insert += "  " + end_goals_overunder_under_275 + ", "
    insert += "  " + end_goals_overunder_over_30 + ", "
    insert += "  " + end_goals_overunder_under_30 + ", "
    insert += "  " + end_goals_overunder_over_325 + ", "
    insert += "  " + end_goals_overunder_under_325 + ", "
    insert += "  " + end_goals_overunder_over_35 + ", "
    insert += "  " + end_goals_overunder_under_35 + ", "
    insert += "  " + end_goals_overunder_over_375 + ", "
    insert += "  " + end_goals_overunder_under_375 + ", "
    insert += "  " + end_goals_overunder_over_40 + ", "
    insert += "  " + end_goals_overunder_under_40 + ", "
    insert += "  " + end_goals_overunder_over_425 + ", "
    insert += "  " + end_goals_overunder_under_425 + ", "
    insert += "  " + end_goals_overunder_over_45 + ", "
    insert += "  " + end_goals_overunder_under_45 + ", "
    insert += "  " + end_goals_overunder_over_475 + ", "
    insert += "  " + end_goals_overunder_under_475 + ", "
    insert += "  " + end_goals_overunder_over_50 + ", "
    insert += "  " + end_goals_overunder_under_50 + ", "
    insert += "  " + end_goals_overunder_over_525 + ", "
    insert += "  " + end_goals_overunder_under_525 + ", "
    insert += "  " + end_goals_overunder_over_55 + ", "
    insert += "  " + end_goals_overunder_under_55 + ", "
    insert += "  " + end_goals_overunder_over_575 + ", "
    insert += "  " + end_goals_overunder_under_575 + ", "
    insert += "  " + end_goals_overunder_over_60 + ", "
    insert += "  " + end_goals_overunder_under_60 + ", "
    insert += "  " + end_goals_overunder_over_625 + ", "
    insert += "  " + end_goals_overunder_under_625 + ", "
    insert += "  " + end_goals_overunder_over_65 + ", "
    insert += "  " + end_goals_overunder_under_65 + ", "
    insert += "  " + end_goals_overunder_over_675 + ", "
    insert += "  " + end_goals_overunder_under_675 + ", "
    insert += "  " + end_goals_overunder_over_70 + ", "
    insert += "  " + end_goals_overunder_under_70 + ", "
    insert += "  " + end_goals_overunder_over_75 + ", "
    insert += "  " + end_goals_overunder_under_75 + ", "
    insert += "  " + end_goals_overunder_over_85 + ", "
    insert += "  " + end_goals_overunder_under_85 + ", "
    insert += "  " + end_goals_overunder_over_95 + ", "
    insert += "  " + end_goals_overunder_under_95 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_175 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_175 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_15 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_15 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_125 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_125 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_1 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_1 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_075 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_075 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_05 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_05 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_min_025 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_min_025 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_0 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_0 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_025 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_025 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_05 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_05 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_075 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_075 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_1 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_1 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_125 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_125 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_15 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_15 + ", "
    insert += "  " + pre_asian_handicap_first_half_home_plus_175 + ", "
    insert += "  " + pre_asian_handicap_first_half_away_plus_175 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_175 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_175 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_15 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_15 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_125 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_125 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_1 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_1 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_075 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_075 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_05 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_05 + ", "
    insert += "  " + end_asian_handicap_first_half_home_min_025 + ", "
    insert += "  " + end_asian_handicap_first_half_away_min_025 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_0 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_0 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_025 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_025 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_05 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_05 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_075 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_075 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_1 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_1 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_125 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_125 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_15 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_15 + ", "
    insert += "  " + end_asian_handicap_first_half_home_plus_175 + ", "
    insert += "  " + end_asian_handicap_first_half_away_plus_175 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_05 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_05 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_075 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_075 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_10 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_10 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_125 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_125 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_15 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_15 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_175 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_175 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_20 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_20 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_225 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_225 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_25 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_25 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_275 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_275 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_30 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_30 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_325 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_325 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_35 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_35 + ", "
    insert += "  " + pre_goals_overunder_first_half_over_375 + ", "
    insert += "  " + pre_goals_overunder_first_half_under_375 + ", "
    insert += "  " + end_goals_overunder_first_half_over_05 + ", "
    insert += "  " + end_goals_overunder_first_half_under_05 + ", "
    insert += "  " + end_goals_overunder_first_half_over_075 + ", "
    insert += "  " + end_goals_overunder_first_half_under_075 + ", "
    insert += "  " + end_goals_overunder_first_half_over_10 + ", "
    insert += "  " + end_goals_overunder_first_half_under_10 + ", "
    insert += "  " + end_goals_overunder_first_half_over_125 + ", "
    insert += "  " + end_goals_overunder_first_half_under_125 + ", "
    insert += "  " + end_goals_overunder_first_half_over_15 + ", "
    insert += "  " + end_goals_overunder_first_half_under_15 + ", "
    insert += "  " + end_goals_overunder_first_half_over_175 + ", "
    insert += "  " + end_goals_overunder_first_half_under_175 + ", "
    insert += "  " + end_goals_overunder_first_half_over_20 + ", "
    insert += "  " + end_goals_overunder_first_half_under_20 + ", "
    insert += "  " + end_goals_overunder_first_half_over_225 + ", "
    insert += "  " + end_goals_overunder_first_half_under_225 + ", "
    insert += "  " + end_goals_overunder_first_half_over_25 + ", "
    insert += "  " + end_goals_overunder_first_half_under_25 + ", "
    insert += "  " + end_goals_overunder_first_half_over_275 + ", "
    insert += "  " + end_goals_overunder_first_half_under_275 + ", "
    insert += "  " + end_goals_overunder_first_half_over_30 + ", "
    insert += "  " + end_goals_overunder_first_half_under_30 + ", "
    insert += "  " + end_goals_overunder_first_half_over_325 + ", "
    insert += "  " + end_goals_overunder_first_half_under_325 + ", "
    insert += "  " + end_goals_overunder_first_half_over_35 + ", "
    insert += "  " + end_goals_overunder_first_half_under_35 + ", "
    insert += "  " + end_goals_overunder_first_half_over_375 + ", "
    insert += "  " + end_goals_overunder_first_half_under_375 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_05 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_05 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_075 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_075 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_10 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_10 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_125 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_125 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_15 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_15 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_175 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_175 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_20 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_20 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_225 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_225 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_25 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_25 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_275 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_275 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_30 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_30 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_325 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_325 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_35 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_35 + ", "
    insert += "  " + pre_goals_overunder__second_half_over_375 + ", "
    insert += "  " + pre_goals_overunder__second_half_under_375 + ", "
    insert += "  " + end_goals_overunder__second_half_over_05 + ", "
    insert += "  " + end_goals_overunder__second_half_under_05 + ", "
    insert += "  " + end_goals_overunder__second_half_over_075 + ", "
    insert += "  " + end_goals_overunder__second_half_under_075 + ", "
    insert += "  " + end_goals_overunder__second_half_over_10 + ", "
    insert += "  " + end_goals_overunder__second_half_under_10 + ", "
    insert += "  " + end_goals_overunder__second_half_over_125 + ", "
    insert += "  " + end_goals_overunder__second_half_under_125 + ", "
    insert += "  " + end_goals_overunder__second_half_over_15 + ", "
    insert += "  " + end_goals_overunder__second_half_under_15 + ", "
    insert += "  " + end_goals_overunder__second_half_over_175 + ", "
    insert += "  " + end_goals_overunder__second_half_under_175 + ", "
    insert += "  " + end_goals_overunder__second_half_over_20 + ", "
    insert += "  " + end_goals_overunder__second_half_under_20 + ", "
    insert += "  " + end_goals_overunder__second_half_over_225 + ", "
    insert += "  " + end_goals_overunder__second_half_under_225 + ", "
    insert += "  " + end_goals_overunder__second_half_over_25 + ", "
    insert += "  " + end_goals_overunder__second_half_under_25 + ", "
    insert += "  " + end_goals_overunder__second_half_over_275 + ", "
    insert += "  " + end_goals_overunder__second_half_under_275 + ", "
    insert += "  " + end_goals_overunder__second_half_over_30 + ", "
    insert += "  " + end_goals_overunder__second_half_under_30 + ", "
    insert += "  " + end_goals_overunder__second_half_over_325 + ", "
    insert += "  " + end_goals_overunder__second_half_under_325 + ", "
    insert += "  " + end_goals_overunder__second_half_over_35 + ", "
    insert += "  " + end_goals_overunder__second_half_under_35 + ", "
    insert += "  " + end_goals_overunder__second_half_over_375 + ", "
    insert += "  " + end_goals_overunder__second_half_under_375 + ", "
    insert += "  " + pre_htft_double_home_home + ", "
    insert += "  " + pre_htft_double_home_draw + ", "
    insert += "  " + pre_htft_double_home_away + ", "
    insert += "  " + pre_htft_double_draw_home + ", "
    insert += "  " + pre_htft_double_draw_draw + ", "
    insert += "  " + pre_htft_double_draw_away + ", "
    insert += "  " + pre_htft_double_away_home + ", "
    insert += "  " + pre_htft_double_away_draw + ", "
    insert += "  " + pre_htft_double_away_away + ", "
    insert += "  " + end_htft_double_home_home + ", "
    insert += "  " + end_htft_double_home_draw + ", "
    insert += "  " + end_htft_double_home_away + ", "
    insert += "  " + end_htft_double_draw_home + ", "
    insert += "  " + end_htft_double_draw_draw + ", "
    insert += "  " + end_htft_double_draw_away + ", "
    insert += "  " + end_htft_double_away_home + ", "
    insert += "  " + end_htft_double_away_draw + ", "
    insert += "  " + end_htft_double_away_away + ", "
    insert += "  " + pre_both_teams_score_yes + ", "
    insert += "  " + pre_both_teams_score_no + ", "
    insert += "  " + end_both_teams_score_yes + ", "
    insert += "  " + end_both_teams_score_no + ", "
    insert += "  " + pre_both_teams_score__first_half_yes + ", "
    insert += "  " + pre_both_teams_score__first_half_no + ", "
    insert += "  " + end_both_teams_score__first_half_yes + ", "
    insert += "  " + end_both_teams_score__first_half_no + ", "
    insert += "  " + pre_both_teams_to_score__second_half_yes + ", "
    insert += "  " + pre_both_teams_to_score__second_half_no + ", "
    insert += "  " + end_both_teams_to_score__second_half_yes + ", "
    insert += "  " + end_both_teams_to_score__second_half_no + ", "
    insert += "  " + pre_results_both_teams_score_home_yes + ", "
    insert += "  " + pre_results_both_teams_score_draw_yes + ", "
    insert += "  " + pre_results_both_teams_score_away_yes + ", "
    insert += "  " + pre_results_both_teams_score_home_no + ", "
    insert += "  " + pre_results_both_teams_score_draw_no + ", "
    insert += "  " + pre_results_both_teams_score_away_no + ", "
    insert += "  " + end_results_both_teams_score_home_yes + ", "
    insert += "  " + end_results_both_teams_score_draw_yes + ", "
    insert += "  " + end_results_both_teams_score_away_yes + ", "
    insert += "  " + end_results_both_teams_score_home_no + ", "
    insert += "  " + end_results_both_teams_score_draw_no + ", "
    insert += "  " + end_results_both_teams_score_away_no + ", "
    insert += "  " + pre_to_score_in_both_halves_by_teams_home + ", "
    insert += "  " + pre_to_score_in_both_halves_by_teams_away + ", "
    insert += "  " + end_to_score_in_both_halves_by_teams_home + ", "
    insert += "  " + end_to_score_in_both_halves_by_teams_away + ", "
    insert += "  " + pre_total_goals_both_teams_to_score_over_yes_25 + ", "
    insert += "  " + pre_total_goals_both_teams_to_score_over_no_25 + ", "
    insert += "  " + pre_total_goals_both_teams_to_score_under_yes_25 + ", "
    insert += "  " + pre_total_goals_both_teams_to_score_under_no_25 + ", "
    insert += "  " + end_total_goals_both_teams_to_score_over_yes_25 + ", "
    insert += "  " + end_total_goals_both_teams_to_score_over_no_25 + ", "
    insert += "  " + end_total_goals_both_teams_to_score_under_yes_25 + ", "
    insert += "  " + end_total_goals_both_teams_to_score_under_no_25 + ", "
    insert += "  " + pre_both_teams_to_score_1st_half__2nd_half_yes_yes + ", "
    insert += "  " + pre_both_teams_to_score_1st_half__2nd_half_yes_no + ", "
    insert += "  " + pre_both_teams_to_score_1st_half__2nd_half_no_yes + ", "
    insert += "  " + pre_both_teams_to_score_1st_half__2nd_half_no_no + ", "
    insert += "  " + end_both_teams_to_score_1st_half__2nd_half_yes_yes + ", "
    insert += "  " + end_both_teams_to_score_1st_half__2nd_half_yes_no + ", "
    insert += "  " + end_both_teams_to_score_1st_half__2nd_half_no_yes + ", "
    insert += "  " + end_both_teams_to_score_1st_half__2nd_half_no_no + ", "
    insert += "  " + pre_highest_scoring_half_first + ", "
    insert += "  " + pre_highest_scoring_half_draw + ", "
    insert += "  " + pre_highest_scoring_half_second + ", "
    insert += "  " + end_highest_scoring_half_first + ", "
    insert += "  " + end_highest_scoring_half_draw + ", "
    insert += "  " + end_highest_scoring_half_second + ", "
    insert += "  " + pre_double_chance_home_draw + ", "
    insert += "  " + pre_double_chance_home_away + ", "
    insert += "  " + pre_double_chance_draw_away + ", "
    insert += "  " + end_double_chance_home_draw + ", "
    insert += "  " + end_double_chance_home_away + ", "
    insert += "  " + end_double_chance_draw_away + ", "
    insert += "  " + pre_double_chance__first_half_home_draw + ", "
    insert += "  " + pre_double_chance__first_half_home_away + ", "
    insert += "  " + pre_double_chance__first_half_draw_away + ", "
    insert += "  " + end_double_chance__first_half_home_draw + ", "
    insert += "  " + end_double_chance__first_half_home_away + ", "
    insert += "  " + end_double_chance__first_half_draw_away + ", "
    insert += "  " + pre_oddeven_odd + ", "
    insert += "  " + pre_oddeven_even + ", "
    insert += "  " + end_oddeven_odd + ", "
    insert += "  " + end_oddeven_even + ", "
    insert += "  " + pre_result_total_goals_home_over_35 + ", "
    insert += "  " + pre_result_total_goals_draw_over_35 + ", "
    insert += "  " + pre_result_total_goals_away_over_35 + ", "
    insert += "  " + pre_result_total_goals_home_under_35 + ", "
    insert += "  " + pre_result_total_goals_draw_under_35 + ", "
    insert += "  " + pre_result_total_goals_away_under_35 + ", "
    insert += "  " + pre_result_total_goals_home_over_25 + ", "
    insert += "  " + pre_result_total_goals_draw_over_25 + ", "
    insert += "  " + pre_result_total_goals_away_over_25 + ", "
    insert += "  " + pre_result_total_goals_home_under_25 + ", "
    insert += "  " + pre_result_total_goals_draw_under_25 + ", "
    insert += "  " + pre_result_total_goals_away_under_25 + ", "
    insert += "  " + end_result_total_goals_home_over_35 + ", "
    insert += "  " + end_result_total_goals_draw_over_35 + ", "
    insert += "  " + end_result_total_goals_away_over_35 + ", "
    insert += "  " + end_result_total_goals_home_under_35 + ", "
    insert += "  " + end_result_total_goals_draw_under_35 + ", "
    insert += "  " + end_result_total_goals_away_under_35 + ", "
    insert += "  " + end_result_total_goals_home_over_25 + ", "
    insert += "  " + end_result_total_goals_draw_over_25 + ", "
    insert += "  " + end_result_total_goals_away_over_25 + ", "
    insert += "  " + end_result_total_goals_home_under_25 + ", "
    insert += "  " + end_result_total_goals_draw_under_25 + ", "
    insert += "  " + end_result_total_goals_away_under_25 + ", "
    insert += "  " + pre_clean_sheet__home_yes + ", "
    insert += "  " + pre_clean_sheet__home_no + ", "
    insert += "  " + end_clean_sheet__home_yes + ", "
    insert += "  " + end_clean_sheet__home_no + ", "
    insert += "  " + pre_clean_sheet__away_yes + ", "
    insert += "  " + pre_clean_sheet__away_no + ", "
    insert += "  " + end_clean_sheet__away_yes + ", "
    insert += "  " + end_clean_sheet__away_no + ", "
    insert += "  " + pre_win_both_halves_home + ", "
    insert += "  " + pre_win_both_halves_away + ", "
    insert += "  " + end_win_both_halves_home + ", "
    insert += "  " + end_win_both_halves_away + ", "
    insert += "  " + pre_win_to_nil_home + ", "
    insert += "  " + pre_win_to_nil_away + ", "
    insert += "  " + end_win_to_nil_home + ", "
    insert += "  " + end_win_to_nil_away + ", "
    insert += "  " + pre_to_win_either_half_home + ", "
    insert += "  " + pre_to_win_either_half_away + ", "
    insert += "  " + end_to_win_either_half_home + ", "
    insert += "  " + end_to_win_either_half_away + ", "
    insert += "  " + pre_halftime_result_both_teams_score_home_yes + ", "
    insert += "  " + pre_halftime_result_both_teams_score_draw_yes + ", "
    insert += "  " + pre_halftime_result_both_teams_score_away_yes + ", "
    insert += "  " + pre_halftime_result_both_teams_score_home_no + ", "
    insert += "  " + pre_halftime_result_both_teams_score_draw_no + ", "
    insert += "  " + pre_halftime_result_both_teams_score_away_no + ", "
    insert += "  " + end_halftime_result_both_teams_score_home_yes + ", "
    insert += "  " + end_halftime_result_both_teams_score_draw_yes + ", "
    insert += "  " + end_halftime_result_both_teams_score_away_yes + ", "
    insert += "  " + end_halftime_result_both_teams_score_home_no + ", "
    insert += "  " + end_halftime_result_both_teams_score_draw_no + ", "
    insert += "  " + end_halftime_result_both_teams_score_away_no + ", "
    insert += "  " + pre_exact_goals_number_0 + ", "
    insert += "  " + pre_exact_goals_number_1 + ", "
    insert += "  " + pre_exact_goals_number_2 + ", "
    insert += "  " + pre_exact_goals_number_3 + ", "
    insert += "  " + pre_exact_goals_number_4 + ", "
    insert += "  " + pre_exact_goals_number_5 + ", "
    insert += "  " + pre_exact_goals_number_6 + ", "
    insert += "  " + pre_exact_goals_number_more_7 + ", "
    insert += "  " + end_exact_goals_number_0 + ", "
    insert += "  " + end_exact_goals_number_1 + ", "
    insert += "  " + end_exact_goals_number_2 + ", "
    insert += "  " + end_exact_goals_number_3 + ", "
    insert += "  " + end_exact_goals_number_4 + ", "
    insert += "  " + end_exact_goals_number_5 + ", "
    insert += "  " + end_exact_goals_number_6 + ", "
    insert += "  " + end_exact_goals_number_more_7 + ", "
    insert += "  " + pre_exact_goals_number__first_half_0 + ", "
    insert += "  " + pre_exact_goals_number__first_half_1 + ", "
    insert += "  " + pre_exact_goals_number__first_half_2 + ", "
    insert += "  " + pre_exact_goals_number__first_half_3 + ", "
    insert += "  " + pre_exact_goals_number__first_half_4 + ", "
    insert += "  " + pre_exact_goals_number__first_half_more_5 + ", "
    insert += "  " + end_exact_goals_number__first_half_0 + ", "
    insert += "  " + end_exact_goals_number__first_half_1 + ", "
    insert += "  " + end_exact_goals_number__first_half_2 + ", "
    insert += "  " + end_exact_goals_number__first_half_3 + ", "
    insert += "  " + end_exact_goals_number__first_half_4 + ", "
    insert += "  " + end_exact_goals_number__first_half_more_5 + ", "
    insert += "  " + pre_second_half_exact_goals_number_0 + ", "
    insert += "  " + pre_second_half_exact_goals_number_1 + ", "
    insert += "  " + pre_second_half_exact_goals_number_2 + ", "
    insert += "  " + pre_second_half_exact_goals_number_3 + ", "
    insert += "  " + pre_second_half_exact_goals_number_4 + ", "
    insert += "  " + pre_second_half_exact_goals_number_more_5 + ", "
    insert += "  " + end_second_half_exact_goals_number_0 + ", "
    insert += "  " + end_second_half_exact_goals_number_1 + ", "
    insert += "  " + end_second_half_exact_goals_number_2 + ", "
    insert += "  " + end_second_half_exact_goals_number_3 + ", "
    insert += "  " + end_second_half_exact_goals_number_4 + ", "
    insert += "  " + end_second_half_exact_goals_number_more_5 + ", "
    insert += "  " + pre_home_team_exact_goals_number_0 + ", "
    insert += "  " + pre_home_team_exact_goals_number_1 + ", "
    insert += "  " + pre_home_team_exact_goals_number_2 + ", "
    insert += "  " + pre_home_team_exact_goals_number_more_3 + ", "
    insert += "  " + end_home_team_exact_goals_number_0 + ", "
    insert += "  " + end_home_team_exact_goals_number_1 + ", "
    insert += "  " + end_home_team_exact_goals_number_2 + ", "
    insert += "  " + end_home_team_exact_goals_number_more_3 + ", "
    insert += "  " + pre_away_team_exact_goals_number_0 + ", "
    insert += "  " + pre_away_team_exact_goals_number_1 + ", "
    insert += "  " + pre_away_team_exact_goals_number_2 + ", "
    insert += "  " + pre_away_team_exact_goals_number_more_3 + ", "
    insert += "  " + end_away_team_exact_goals_number_0 + ", "
    insert += "  " + end_away_team_exact_goals_number_1 + ", "
    insert += "  " + end_away_team_exact_goals_number_2 + ", "
    insert += "  " + end_away_team_exact_goals_number_more_3 + ", "
    insert += "  " + pre_corners_winner_home + ", "
    insert += "  " + pre_corners_winner_draw + ", "
    insert += "  " + pre_corners_winner_away + ", "
    insert += "  " + end_corners_winner_home + ", "
    insert += "  " + end_corners_winner_draw + ", "
    insert += "  " + end_corners_winner_away + ", "
    insert += "  " + pre_10_overunder_over_05 + ", "
    insert += "  " + pre_10_overunder_under_05 + ", "
    insert += "  " + end_10_overunder_over_05 + ", "
    insert += "  " + end_10_overunder_under_05 + ", "
    insert += "  " + pre_cards_european_handicap_home_min_2 + ", "
    insert += "  " + pre_cards_european_handicap_draw_min_2 + ", "
    insert += "  " + pre_cards_european_handicap_away_min_2 + ", "
    insert += "  " + pre_cards_european_handicap_home_min_1 + ", "
    insert += "  " + pre_cards_european_handicap_draw_min_1 + ", "
    insert += "  " + pre_cards_european_handicap_away_min_1 + ", "
    insert += "  " + pre_cards_european_handicap_home_plus_0 + ", "
    insert += "  " + pre_cards_european_handicap_draw_plus_0 + ", "
    insert += "  " + pre_cards_european_handicap_away_plus_0 + ", "
    insert += "  " + pre_cards_european_handicap_home_plus_1 + ", "
    insert += "  " + pre_cards_european_handicap_draw_plus_1 + ", "
    insert += "  " + pre_cards_european_handicap_away_plus_1 + ", "
    insert += "  " + pre_cards_european_handicap_home_plus_2 + ", "
    insert += "  " + pre_cards_european_handicap_draw_plus_2 + ", "
    insert += "  " + pre_cards_european_handicap_away_plus_2 + ", "
    insert += "  " + end_cards_european_handicap_home_min_2 + ", "
    insert += "  " + end_cards_european_handicap_draw_min_2 + ", "
    insert += "  " + end_cards_european_handicap_away_min_2 + ", "
    insert += "  " + end_cards_european_handicap_home_min_1 + ", "
    insert += "  " + end_cards_european_handicap_draw_min_1 + ", "
    insert += "  " + end_cards_european_handicap_away_min_1 + ", "
    insert += "  " + end_cards_european_handicap_home_plus_0 + ", "
    insert += "  " + end_cards_european_handicap_draw_plus_0 + ", "
    insert += "  " + end_cards_european_handicap_away_plus_0 + ", "
    insert += "  " + end_cards_european_handicap_home_plus_1 + ", "
    insert += "  " + end_cards_european_handicap_draw_plus_1 + ", "
    insert += "  " + end_cards_european_handicap_away_plus_1 + ", "
    insert += "  " + end_cards_european_handicap_home_plus_2 + ", "
    insert += "  " + end_cards_european_handicap_draw_plus_2 + ", "
    insert += "  " + end_cards_european_handicap_away_plus_2 + ", "
    insert += "  " + pre_rcard_yes + ", "
    insert += "  " + pre_rcard_no + ", "
    insert += "  " + end_rcard_yes + ", "
    insert += "  " + end_rcard_no + ", "
    insert += "  " + pre_anytime_goal_scorer + ", "
    insert += "  " + end_anytime_goal_scorer + ", "
    insert += "  " + pre_first_goal_scorer + ", "
    insert += "  " + end_first_goal_scorer + ", "
    insert += "  " + pre_last_goal_scorer + ", "
    insert += "  " + end_last_goal_scorer + ", "
    insert += "  " + pre_to_score_two_or_more_goals + ", "
    insert += "  " + end_to_score_two_or_more_goals + ", "
    insert += "  " + pre_last_goal_scorer2 + ", "
    insert += "  " + end_last_goal_scorer2 + ", "
    insert += "  " + pre_exact_score + ", "
    insert += "  " + end_exact_score + ", "
    insert += "  " + pre_team_to_score_first_home + ", "
    insert += "  " + pre_team_to_score_first_draw + ", "
    insert += "  " + pre_team_to_score_first_away + ", "
    insert += "  " + end_team_to_score_first_home + ", "
    insert += "  " + end_team_to_score_first_draw + ", "
    insert += "  " + end_team_to_score_first_away + ", "
    insert += "  " + pre_team_to_score_last_home + ", "
    insert += "  " + pre_team_to_score_last_draw + ", "
    insert += "  " + pre_team_to_score_last_away + ", "
    insert += "  " + end_team_to_score_last_home + ", "
    insert += "  " + end_team_to_score_last_draw + ", "
    insert += "  " + end_team_to_score_last_away + ", "
    insert += "  " + pre_total_home_over_15 + ", "
    insert += "  " + pre_total_home_under_15 + ", "
    insert += "  " + pre_total_home_over_25 + ", "
    insert += "  " + pre_total_home_under_25 + ", "
    insert += "  " + pre_total_home_over_35 + ", "
    insert += "  " + pre_total_home_under_35 + ", "
    insert += "  " + pre_total_home_over_45 + ", "
    insert += "  " + pre_total_home_under_45 + ", "
    insert += "  " + pre_total_home_over_55 + ", "
    insert += "  " + pre_total_home_under_55 + ", "
    insert += "  " + pre_total_home_over_65 + ", "
    insert += "  " + pre_total_home_under_65 + ", "
    insert += "  " + end_total_home_over_15 + ", "
    insert += "  " + end_total_home_under_15 + ", "
    insert += "  " + end_total_home_over_25 + ", "
    insert += "  " + end_total_home_under_25 + ", "
    insert += "  " + end_total_home_over_35 + ", "
    insert += "  " + end_total_home_under_35 + ", "
    insert += "  " + end_total_home_over_45 + ", "
    insert += "  " + end_total_home_under_45 + ", "
    insert += "  " + end_total_home_over_55 + ", "
    insert += "  " + end_total_home_under_55 + ", "
    insert += "  " + end_total_home_over_65 + ", "
    insert += "  " + end_total_home_under_65 + ", "
    insert += "  " + pre_total_away_over_15 + ", "
    insert += "  " + pre_total_away_under_15 + ", "
    insert += "  " + pre_total_away_over_25 + ", "
    insert += "  " + pre_total_away_under_25 + ", "
    insert += "  " + pre_total_away_over_35 + ", "
    insert += "  " + pre_total_away_under_35 + ", "
    insert += "  " + pre_total_away_over_45 + ", "
    insert += "  " + pre_total_away_under_45 + ", "
    insert += "  " + pre_total_away_over_55 + ", "
    insert += "  " + pre_total_away_under_55 + ", "
    insert += "  " + pre_total_away_over_65 + ", "
    insert += "  " + pre_total_away_under_65 + ", "
    insert += "  " + end_total_away_over_15 + ", "
    insert += "  " + end_total_away_under_15 + ", "
    insert += "  " + end_total_away_over_25 + ", "
    insert += "  " + end_total_away_under_25 + ", "
    insert += "  " + end_total_away_over_35 + ", "
    insert += "  " + end_total_away_under_35 + ", "
    insert += "  " + end_total_away_over_45 + ", "
    insert += "  " + end_total_away_under_45 + ", "
    insert += "  " + end_total_away_over_55 + ", "
    insert += "  " + end_total_away_under_55 + ", "
    insert += "  " + end_total_away_over_65 + ", "
    insert += "  " + end_total_away_under_65 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_65 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_65 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_6 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_6 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_55 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_55 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_5 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_5 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_45 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_45 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_4 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_4 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_35 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_35 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_3 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_3 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_25 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_25 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_2 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_2 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_15 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_15 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_1 + ", "
    insert += "  " + pre_corners_asian_handicap_home_min_05 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_1 + ", "
    insert += "  " + pre_corners_asian_handicap_away_min_05 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_0 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_0 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_05 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_05 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_1 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_1 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_15 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_15 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_2 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_2 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_25 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_25 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_3 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_3 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_35 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_35 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_4 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_4 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_45 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_45 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_5 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_5 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_55 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_55 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_6 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_6 + ", "
    insert += "  " + pre_corners_asian_handicap_home_plus_65 + ", "
    insert += "  " + pre_corners_asian_handicap_away_plus_65 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_65 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_65 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_6 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_6 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_55 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_55 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_5 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_5 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_45 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_45 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_4 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_4 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_35 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_35 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_3 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_3 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_25 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_25 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_2 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_2 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_15 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_15 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_1 + ", "
    insert += "  " + end_corners_asian_handicap_home_min_05 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_1 + ", "
    insert += "  " + end_corners_asian_handicap_away_min_05 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_0 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_0 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_05 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_05 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_1 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_1 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_15 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_15 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_2 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_2 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_25 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_25 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_3 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_3 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_35 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_35 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_4 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_4 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_45 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_45 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_5 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_5 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_55 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_55 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_6 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_6 + ", "
    insert += "  " + end_corners_asian_handicap_home_plus_65 + ", "
    insert += "  " + end_corners_asian_handicap_away_plus_65 + ", "
    insert += "  " + pre_corners_over_under_over_700 + ", "
    insert += "  " + pre_corners_over_under_under_700 + ", "
    insert += "  " + pre_corners_over_under_over_725 + ", "
    insert += "  " + pre_corners_over_under_under_725 + ", "
    insert += "  " + pre_corners_over_under_over_750 + ", "
    insert += "  " + pre_corners_over_under_under_750 + ", "
    insert += "  " + pre_corners_over_under_over_775 + ", "
    insert += "  " + pre_corners_over_under_under_775 + ", "
    insert += "  " + pre_corners_over_under_over_800 + ", "
    insert += "  " + pre_corners_over_under_under_800 + ", "
    insert += "  " + pre_corners_over_under_over_825 + ", "
    insert += "  " + pre_corners_over_under_under_825 + ", "
    insert += "  " + pre_corners_over_under_over_850 + ", "
    insert += "  " + pre_corners_over_under_under_850 + ", "
    insert += "  " + pre_corners_over_under_over_875 + ", "
    insert += "  " + pre_corners_over_under_under_875 + ", "
    insert += "  " + pre_corners_over_under_over_900 + ", "
    insert += "  " + pre_corners_over_under_under_900 + ", "
    insert += "  " + pre_corners_over_under_over_925 + ", "
    insert += "  " + pre_corners_over_under_under_925 + ", "
    insert += "  " + pre_corners_over_under_over_950 + ", "
    insert += "  " + pre_corners_over_under_under_950 + ", "
    insert += "  " + pre_corners_over_under_over_975 + ", "
    insert += "  " + pre_corners_over_under_under_975 + ", "
    insert += "  " + pre_corners_over_under_over_1000 + ", "
    insert += "  " + pre_corners_over_under_under_1000 + ", "
    insert += "  " + pre_corners_over_under_over_1025 + ", "
    insert += "  " + pre_corners_over_under_under_1025 + ", "
    insert += "  " + pre_corners_over_under_over_1050 + ", "
    insert += "  " + pre_corners_over_under_under_1050 + ", "
    insert += "  " + pre_corners_over_under_over_1075 + ", "
    insert += "  " + pre_corners_over_under_under_1075 + ", "
    insert += "  " + pre_corners_over_under_over_1100 + ", "
    insert += "  " + pre_corners_over_under_under_1100 + ", "
    insert += "  " + pre_corners_over_under_over_1125 + ", "
    insert += "  " + pre_corners_over_under_under_1125 + ", "
    insert += "  " + pre_corners_over_under_over_1150 + ", "
    insert += "  " + pre_corners_over_under_under_1150 + ", "
    insert += "  " + pre_corners_over_under_over_1175 + ", "
    insert += "  " + pre_corners_over_under_under_1175 + ", "
    insert += "  " + pre_corners_over_under_over_1200 + ", "
    insert += "  " + pre_corners_over_under_under_1200 + ", "
    insert += "  " + pre_corners_over_under_over_1225 + ", "
    insert += "  " + pre_corners_over_under_under_1225 + ", "
    insert += "  " + pre_corners_over_under_over_1250 + ", "
    insert += "  " + pre_corners_over_under_under_1250 + ", "
    insert += "  " + pre_corners_over_under_over_1275 + ", "
    insert += "  " + pre_corners_over_under_under_1275 + ", "
    insert += "  " + end_corners_over_under_over_700 + ", "
    insert += "  " + end_corners_over_under_under_700 + ", "
    insert += "  " + end_corners_over_under_over_725 + ", "
    insert += "  " + end_corners_over_under_under_725 + ", "
    insert += "  " + end_corners_over_under_over_750 + ", "
    insert += "  " + end_corners_over_under_under_750 + ", "
    insert += "  " + end_corners_over_under_over_775 + ", "
    insert += "  " + end_corners_over_under_under_775 + ", "
    insert += "  " + end_corners_over_under_over_800 + ", "
    insert += "  " + end_corners_over_under_under_800 + ", "
    insert += "  " + end_corners_over_under_over_825 + ", "
    insert += "  " + end_corners_over_under_under_825 + ", "
    insert += "  " + end_corners_over_under_over_850 + ", "
    insert += "  " + end_corners_over_under_under_850 + ", "
    insert += "  " + end_corners_over_under_over_875 + ", "
    insert += "  " + end_corners_over_under_under_875 + ", "
    insert += "  " + end_corners_over_under_over_900 + ", "
    insert += "  " + end_corners_over_under_under_900 + ", "
    insert += "  " + end_corners_over_under_over_925 + ", "
    insert += "  " + end_corners_over_under_under_925 + ", "
    insert += "  " + end_corners_over_under_over_950 + ", "
    insert += "  " + end_corners_over_under_under_950 + ", "
    insert += "  " + end_corners_over_under_over_975 + ", "
    insert += "  " + end_corners_over_under_under_975 + ", "
    insert += "  " + end_corners_over_under_over_1000 + ", "
    insert += "  " + end_corners_over_under_under_1000 + ", "
    insert += "  " + end_corners_over_under_over_1025 + ", "
    insert += "  " + end_corners_over_under_under_1025 + ", "
    insert += "  " + end_corners_over_under_over_1050 + ", "
    insert += "  " + end_corners_over_under_under_1050 + ", "
    insert += "  " + end_corners_over_under_over_1075 + ", "
    insert += "  " + end_corners_over_under_under_1075 + ", "
    insert += "  " + end_corners_over_under_over_1100 + ", "
    insert += "  " + end_corners_over_under_under_1100 + ", "
    insert += "  " + end_corners_over_under_over_1125 + ", "
    insert += "  " + end_corners_over_under_under_1125 + ", "
    insert += "  " + end_corners_over_under_over_1150 + ", "
    insert += "  " + end_corners_over_under_under_1150 + ", "
    insert += "  " + end_corners_over_under_over_1175 + ", "
    insert += "  " + end_corners_over_under_under_1175 + ", "
    insert += "  " + end_corners_over_under_over_1200 + ", "
    insert += "  " + end_corners_over_under_under_1200 + ", "
    insert += "  " + end_corners_over_under_over_1225 + ", "
    insert += "  " + end_corners_over_under_under_1225 + ", "
    insert += "  " + end_corners_over_under_over_1250 + ", "
    insert += "  " + end_corners_over_under_under_1250 + ", "
    insert += "  " + end_corners_over_under_over_1275 + ", "
    insert += "  " + end_corners_over_under_under_1275 + ", "
    insert += "  " + pre_home_corners_overunder_over_25 + ", "
    insert += "  " + pre_home_corners_overunder_under_25 + ", "
    insert += "  " + pre_home_corners_overunder_over_35 + ", "
    insert += "  " + pre_home_corners_overunder_under_35 + ", "
    insert += "  " + pre_home_corners_overunder_over_45 + ", "
    insert += "  " + pre_home_corners_overunder_under_45 + ", "
    insert += "  " + pre_home_corners_overunder_over_55 + ", "
    insert += "  " + pre_home_corners_overunder_under_55 + ", "
    insert += "  " + pre_home_corners_overunder_over_65 + ", "
    insert += "  " + pre_home_corners_overunder_under_65 + ", "
    insert += "  " + pre_home_corners_overunder_over_75 + ", "
    insert += "  " + pre_home_corners_overunder_under_75 + ", "
    insert += "  " + pre_home_corners_overunder_over_85 + ", "
    insert += "  " + pre_home_corners_overunder_under_85 + ", "
    insert += "  " + end_home_corners_overunder_over_25 + ", "
    insert += "  " + end_home_corners_overunder_under_25 + ", "
    insert += "  " + end_home_corners_overunder_over_35 + ", "
    insert += "  " + end_home_corners_overunder_under_35 + ", "
    insert += "  " + end_home_corners_overunder_over_45 + ", "
    insert += "  " + end_home_corners_overunder_under_45 + ", "
    insert += "  " + end_home_corners_overunder_over_55 + ", "
    insert += "  " + end_home_corners_overunder_under_55 + ", "
    insert += "  " + end_home_corners_overunder_over_65 + ", "
    insert += "  " + end_home_corners_overunder_under_65 + ", "
    insert += "  " + end_home_corners_overunder_over_75 + ", "
    insert += "  " + end_home_corners_overunder_under_75 + ", "
    insert += "  " + end_home_corners_overunder_over_85 + ", "
    insert += "  " + end_home_corners_overunder_under_85 + ", "
    insert += "  " + pre_away_corners_overunder_over_25 + ", "
    insert += "  " + pre_away_corners_overunder_under_25 + ", "
    insert += "  " + pre_away_corners_overunder_over_35 + ", "
    insert += "  " + pre_away_corners_overunder_under_35 + ", "
    insert += "  " + pre_away_corners_overunder_over_45 + ", "
    insert += "  " + pre_away_corners_overunder_under_45 + ", "
    insert += "  " + pre_away_corners_overunder_over_55 + ", "
    insert += "  " + pre_away_corners_overunder_under_55 + ", "
    insert += "  " + pre_away_corners_overunder_over_65 + ", "
    insert += "  " + pre_away_corners_overunder_under_65 + ", "
    insert += "  " + pre_away_corners_overunder_over_75 + ", "
    insert += "  " + pre_away_corners_overunder_under_75 + ", "
    insert += "  " + pre_away_corners_overunder_over_85 + ", "
    insert += "  " + pre_away_corners_overunder_under_85 + ", "
    insert += "  " + end_away_corners_overunder_over_25 + ", "
    insert += "  " + end_away_corners_overunder_under_25 + ", "
    insert += "  " + end_away_corners_overunder_over_35 + ", "
    insert += "  " + end_away_corners_overunder_under_35 + ", "
    insert += "  " + end_away_corners_overunder_over_45 + ", "
    insert += "  " + end_away_corners_overunder_under_45 + ", "
    insert += "  " + end_away_corners_overunder_over_55 + ", "
    insert += "  " + end_away_corners_overunder_under_55 + ", "
    insert += "  " + end_away_corners_overunder_over_65 + ", "
    insert += "  " + end_away_corners_overunder_under_65 + ", "
    insert += "  " + end_away_corners_overunder_over_75 + ", "
    insert += "  " + end_away_corners_overunder_under_75 + ", "
    insert += "  " + end_away_corners_overunder_over_85 + ", "
    insert += "  " + end_away_corners_overunder_under_85 + ", "
    insert += "  " + pre_first_corner_home + ", "
    insert += "  " + pre_first_corner_away + ", "
    insert += "  " + end_first_corner_home + ", "
    insert += "  " + end_first_corner_away + ", "
    insert += "  " + pre_last_corner_home + ", "
    insert += "  " + pre_last_corner_away + ", "
    insert += "  " + end_last_corner_home + ", "
    insert += "  " + end_last_corner_away + ", "
    insert += "  " + pre_cards_asian_handicap_home_min_05 + ", "
    insert += "  " + pre_cards_asian_handicap_away_min_05 + ", "
    insert += "  " + pre_cards_asian_handicap_home_plus_0 + ", "
    insert += "  " + pre_cards_asian_handicap_away_plus_0 + ", "
    insert += "  " + pre_cards_asian_handicap_home_plus_05 + ", "
    insert += "  " + pre_cards_asian_handicap_away_plus_05 + ", "
    insert += "  " + end_cards_asian_handicap_home_min_05 + ", "
    insert += "  " + end_cards_asian_handicap_away_min_05 + ", "
    insert += "  " + end_cards_asian_handicap_home_plus_0 + ", "
    insert += "  " + end_cards_asian_handicap_away_plus_0 + ", "
    insert += "  " + end_cards_asian_handicap_home_plus_05 + ", "
    insert += "  " + end_cards_asian_handicap_away_plus_05 + ", "
    insert += "  " + pre_cards_overunder_over_25 + ", "
    insert += "  " + pre_cards_overunder_under_25 + ", "
    insert += "  " + pre_cards_overunder_over_35 + ", "
    insert += "  " + pre_cards_overunder_under_35 + ", "
    insert += "  " + pre_cards_overunder_over_45 + ", "
    insert += "  " + pre_cards_overunder_under_45 + ", "
    insert += "  " + pre_cards_overunder_over_55 + ", "
    insert += "  " + pre_cards_overunder_under_55 + ", "
    insert += "  " + pre_cards_overunder_over_65 + ", "
    insert += "  " + pre_cards_overunder_under_65 + ", "
    insert += "  " + pre_cards_overunder_over_75 + ", "
    insert += "  " + pre_cards_overunder_under_75 + ", "
    insert += "  " + end_cards_overunder_over_25 + ", "
    insert += "  " + end_cards_overunder_under_25 + ", "
    insert += "  " + end_cards_overunder_over_35 + ", "
    insert += "  " + end_cards_overunder_under_35 + ", "
    insert += "  " + end_cards_overunder_over_45 + ", "
    insert += "  " + end_cards_overunder_under_45 + ", "
    insert += "  " + end_cards_overunder_over_55 + ", "
    insert += "  " + end_cards_overunder_under_55 + ", "
    insert += "  " + end_cards_overunder_over_65 + ", "
    insert += "  " + end_cards_overunder_under_65 + ", "
    insert += "  " + end_cards_overunder_over_75 + ", "
    insert += "  " + end_cards_overunder_under_75 + ", "
    insert += "  " + pre_home_team_total_cards_over_15 + ", "
    insert += "  " + pre_home_team_total_cards_under_15 + ", "
    insert += "  " + pre_home_team_total_cards_over_25 + ", "
    insert += "  " + pre_home_team_total_cards_under_25 + ", "
    insert += "  " + pre_home_team_total_cards_over_35 + ", "
    insert += "  " + pre_home_team_total_cards_under_35 + ", "
    insert += "  " + end_home_team_total_cards_over_15 + ", "
    insert += "  " + end_home_team_total_cards_under_15 + ", "
    insert += "  " + end_home_team_total_cards_over_25 + ", "
    insert += "  " + end_home_team_total_cards_under_25 + ", "
    insert += "  " + end_home_team_total_cards_over_35 + ", "
    insert += "  " + end_home_team_total_cards_under_35 + ", "
    insert += "  " + pre_away_team_total_cards_over_15 + ", "
    insert += "  " + pre_away_team_total_cards_under_15 + ", "
    insert += "  " + pre_away_team_total_cards_over_25 + ", "
    insert += "  " + pre_away_team_total_cards_under_25 + ", "
    insert += "  " + pre_away_team_total_cards_over_35 + ", "
    insert += "  " + pre_away_team_total_cards_under_35 + ", "
    insert += "  " + end_away_team_total_cards_over_15 + ", "
    insert += "  " + end_away_team_total_cards_under_15 + ", "
    insert += "  " + end_away_team_total_cards_over_25 + ", "
    insert += "  " + end_away_team_total_cards_under_25 + ", "
    insert += "  " + end_away_team_total_cards_over_35 + ", "
    insert += "  " + end_away_team_total_cards_under_35 + ", "
    insert += "  " + pre_total_goals_under_2 + ", "
    insert += "  " + pre_total_goals_2_or_3 + ", "
    insert += "  " + pre_total_goals_over_3 + ", "
    insert += "  " + end_total_goals_under_2 + ", "
    insert += "  " + end_total_goals_2_or_3 + ", "
    insert += "  " + end_total_goals_over_3 + ", "
    insert += "  " + pre_first_goal_method_shot + ", "
    insert += "  " + pre_first_goal_method_header + ", "
    insert += "  " + pre_first_goal_method_penalty + ", "
    insert += "  " + pre_first_goal_method_freekick + ", "
    insert += "  " + pre_first_goal_method_owngoal + ", "
    insert += "  " + pre_first_goal_method_draw + ", "
    insert += "  " + end_first_goal_method_shot + ", "
    insert += "  " + end_first_goal_method_header + ", "
    insert += "  " + end_first_goal_method_penalty + ", "
    insert += "  " + end_first_goal_method_freekick + ", "
    insert += "  " + end_first_goal_method_owngoal + ", "
    insert += "  " + end_first_goal_method_draw + ", "
    insert += "  " + pre_to_score_a_penalty_home + ", "
    insert += "  " + pre_to_score_a_penalty_away + ", "
    insert += "  " + end_to_score_a_penalty_home + ", "
    insert += "  " + end_to_score_a_penalty_away + ", "
    insert += "  " + pre_to_miss_a_penalty_home + ", "
    insert += "  " + pre_to_miss_a_penalty_away + ", "
    insert += "  " + end_to_miss_a_penalty_home + ", "
    insert += "  " + end_to_miss_a_penalty_away + ", "
    insert += "  " + pre_player_to_be_booked + ", "
    insert += "  " + end_player_to_be_booked + ", "
    insert += "  " + pre_ah_pattern + ", "
    insert += "  " + pre_ah_pattern_mirror + ", "
    insert += "  " + pre_gou_pattern + ", "
    insert += "  " + end_ah_pattern + ", "
    insert += "  " + end_ah_pattern_mirror + ", "
    insert += "  " + end_gou_pattern + " "
    # ------------------------------------------------------ 
    insert += " ) "
    # ------------------------------------------------------  
    # print(insert, flush=True)
    print("---------------------------------------- insert", flush=True)
    mycursor.execute(insert)
    mydb.commit()  
        
# ----------------------------------------------------------
# Out:
# __Total Row(s) : 125748
# ____ [125747/125748] #'208393' #'1' - '2010'
# ---------------------------------------- insert
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Column count doesn't match value count at row 1
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# ...
