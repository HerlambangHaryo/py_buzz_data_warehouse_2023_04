# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += " fixtureapi_id "
query += " , leagueapi_id "
query += " , season "
query += " , fixture_status "
query += " , teams_homeapi_id "
query += " , teams_awayapi_id "
query += " , goals_home "
query += " , goals_away "
query += " , score_halftime_home "
query += " , score_halftime_away "
query += " , score_fulltime_home "
query += " , score_fulltime_away "
query += " , score_extratime_home "
query += " , score_extratime_away "
query += " , score_penalty_home "
query += " , score_penalty_away "
# query += " , lineups_coach_homeapi_id "
# query += " , lineups_coach_awayapi_id "
# query += " , lineups_formation_home "
# query += " , lineups_formation_away "
# query += " , shots_on_goal_home "
# query += " , shots_on_goal_away "
# query += " , shots_off_goal_home "
# query += " , shots_off_goal_away "
# query += " , total_shots_home "
# query += " , total_shots_away "
# query += " , blocked_shots_home "
# query += " , blocked_shots_away "
# query += " , shots_inside_box_home "
# query += " , shots_inside_box_away "
# query += " , shots_outside_box_home "
# query += " , shots_outside_box_away "
# query += " , fouls_home "
# query += " , fouls_away "
# query += " , corner_kicks_home "
# query += " , corner_kicks_away "
# query += " , offsides_home "
# query += " , offsides_away "
# query += " , ball_possession_home "
# query += " , ball_possession_away "
# query += " , yellow_cards_home "
# query += " , yellow_cards_away "
# query += " , red_cards_home "
# query += " , red_cards_away "
# query += " , goalkeeper_saves_home "
# query += " , goalkeeper_saves_away "
# query += " , total_passess_home "
# query += " , total_passess_away "
# query += " , passess_accurate_home "
# query += " , passess_accurate_away "
# query += " , passess_home "
# query += " , passess_away "
# ---------------------------------------------------------- 
query += " from football_odds "  
query += " where fixtureapi_id not in (select fixtureapi_id from football_statistics) "  
query += " order by date asc "  
# ----------------------------------------------------------  
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
total_rows = len(result)
countdown = total_rows
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------   
    fixtureapi_id = "Null"
    leagueapi_id = "Null"
    season = "Null"
    fixture_status = "Null"
    teams_homeapi_id = "Null"
    teams_awayapi_id = "Null"
    goals_home = "Null"
    goals_away = "Null"
    score_halftime_home = "Null"
    score_halftime_away = "Null"
    score_fulltime_home = "Null"
    score_fulltime_away = "Null"
    score_extratime_home = "Null"
    score_extratime_away = "Null"
    score_penalty_home = "Null"
    score_penalty_away = "Null"
    # lineups_coach_homeapi_id = "Null"
    # lineups_coach_awayapi_id = "Null"
    # lineups_formation_home = "Null"
    # lineups_formation_away = "Null"
    # shots_on_goal_home = "Null"
    # shots_on_goal_away = "Null"
    # shots_off_goal_home = "Null"
    # shots_off_goal_away = "Null"
    # total_shots_home = "Null"
    # total_shots_away = "Null"
    # blocked_shots_home = "Null"
    # blocked_shots_away = "Null"
    # shots_inside_box_home = "Null"
    # shots_inside_box_away = "Null"
    # shots_outside_box_home = "Null"
    # shots_outside_box_away = "Null"
    # fouls_home = "Null"
    # fouls_away = "Null"
    # corner_kicks_home = "Null"
    # corner_kicks_away = "Null"
    # offsides_home = "Null"
    # offsides_away = "Null"
    # ball_possession_home = "Null"
    # ball_possession_away = "Null"
    # yellow_cards_home = "Null"
    # yellow_cards_away = "Null"
    # red_cards_home = "Null"
    # red_cards_away = "Null"
    # goalkeeper_saves_home = "Null"
    # goalkeeper_saves_away = "Null"
    # total_passess_home = "Null"
    # total_passess_away = "Null"
    # passess_accurate_home = "Null"
    # passess_accurate_away = "Null"
    # passess_home = "Null"
    # passess_away = "Null"
    # ------------------------------------------------------ 
    
    
    col_counter = 0
    if(x[col_counter] is not None):
        fixtureapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        leagueapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        season = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        fixture_status = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        teams_homeapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        teams_awayapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_halftime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_halftime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_fulltime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_fulltime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_extratime_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_extratime_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_penalty_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    col_counter += 1
    if(x[col_counter] is not None): 
        score_penalty_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     lineups_coach_homeapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     lineups_coach_awayapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     lineups_formation_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     lineups_formation_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_on_goal_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_on_goal_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_off_goal_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_off_goal_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     total_shots_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     total_shots_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     blocked_shots_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     blocked_shots_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_inside_box_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_inside_box_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_outside_box_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     shots_outside_box_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     fouls_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     fouls_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     corner_kicks_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     corner_kicks_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     offsides_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     offsides_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     ball_possession_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     ball_possession_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     yellow_cards_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     yellow_cards_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     red_cards_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     red_cards_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     goalkeeper_saves_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     goalkeeper_saves_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     total_passess_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     total_passess_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     passess_accurate_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     passess_accurate_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     passess_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"	
    
    # col_counter += 1
    # if(x[col_counter] is not None): 
    #     passess_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    # ------------------------------------------------------  
    countdown -= 1
    word = space + " [" + str(countdown) + "/" + str(total_rows) + "] "
    word += "#" + fixtureapi_id
    word += " #" + leagueapi_id
    word += " - " + season 
    word += " - " + season  

    
    print(word, flush=True)
    # ------------------------------------------------------  
    insert = "INSERT INTO `football_statistics`( "
    # ------------------------------------------------------  
    insert += " `fixtureapi_id`, "
    insert += " `leagueapi_id`, "
    insert += " `season`, "
    insert += " `fixture_status`, "
    insert += " `teams_homeapi_id`, "
    insert += " `teams_awayapi_id`, "
    insert += " `goals_home`, "
    insert += " `goals_away`, "
    insert += " `score_halftime_home`, "
    insert += " `score_halftime_away`, "
    insert += " `score_fulltime_home`, "
    insert += " `score_fulltime_away`, "
    insert += " `score_extratime_home`, "
    insert += " `score_extratime_away`, "
    insert += " `score_penalty_home`, "
    insert += " `score_penalty_away`, "
#     insert += " `lineups_coach_homeapi_id`, "
#     insert += " `lineups_coach_awayapi_id`, "
    # insert += " `lineups_formation_home`, "
    # insert += " `lineups_formation_away`, "
    # insert += " `shots_on_goal_home`, "
    # insert += " `shots_on_goal_away`, "
    # insert += " `shots_off_goal_home`, "
    # insert += " `shots_off_goal_away`, "
    # insert += " `total_shots_home`, "
    # insert += " `total_shots_away`, "
    # insert += " `blocked_shots_home`, "
    # insert += " `blocked_shots_away`, "
    # insert += " `shots_inside_box_home`, "
    # insert += " `shots_inside_box_away`, "
    # insert += " `shots_outside_box_home`, "
    # insert += " `shots_outside_box_away`, "
    # insert += " `fouls_home`, "
    # insert += " `fouls_away`, "
    # insert += " `corner_kicks_home`, "
    # insert += " `corner_kicks_away`, "
    # insert += " `offsides_home`, "
    # insert += " `offsides_away`, "
    # insert += " `ball_possession_home`, "
    # insert += " `ball_possession_away`, "
    # insert += " `yellow_cards_home`, "
    # insert += " `yellow_cards_away`, "
    # insert += " `red_cards_home`, "
    # insert += " `red_cards_away`, "
    # insert += " `goalkeeper_saves_home`, "
    # insert += " `goalkeeper_saves_away`, "
    # insert += " `total_passess_home`, "
    # insert += " `total_passess_away`, "
    # insert += " `passess_accurate_home`, "
    # insert += " `passess_accurate_away`, "
    # insert += " `passess_home`, "
    # insert += " `passess_away`, "
    # ------------------------------------------------------  
    insert += " `created_at` "
    insert += "  ) VALUES ( " 
    # ------------------------------------------------------  
    insert += "  " + fixtureapi_id + ", "
    insert += "  " + leagueapi_id + ", "
    insert += "  " + season + ", "
    insert += "  " + fixture_status + ", "
    insert += "  " + teams_homeapi_id + ", "
    insert += "  " + teams_awayapi_id + ", "
    insert += "  " + goals_home + ", "
    insert += "  " + goals_away + ", "
    insert += "  " + score_halftime_home + ", "
    insert += "  " + score_halftime_away + ", "
    insert += "  " + score_fulltime_home + ", "
    insert += "  " + score_fulltime_away + ", "
    insert += "  " + score_extratime_home + ", "
    insert += "  " + score_extratime_away + ", "
    insert += "  " + score_penalty_home + ", "
    insert += "  " + score_penalty_away + ", "
#     insert += "  " + lineups_coach_homeapi_id + ", "
#     insert += "  " + lineups_coach_awayapi_id + ", "
    # insert += "  " + lineups_formation_home + ", "
    # insert += "  " + lineups_formation_away + ", "
    # insert += "  " + shots_on_goal_home + ", "
    # insert += "  " + shots_on_goal_away + ", "
    # insert += "  " + shots_off_goal_home + ", "
    # insert += "  " + shots_off_goal_away + ", "
    # insert += "  " + total_shots_home + ", "
    # insert += "  " + total_shots_away + ", "
    # insert += "  " + blocked_shots_home + ", "
    # insert += "  " + blocked_shots_away + ", "
    # insert += "  " + shots_inside_box_home + ", "
    # insert += "  " + shots_inside_box_away + ", "
    # insert += "  " + shots_outside_box_home + ", "
    # insert += "  " + shots_outside_box_away + ", "
    # insert += "  " + fouls_home + ", "
    # insert += "  " + fouls_away + ", "
    # insert += "  " + corner_kicks_home + ", "
    # insert += "  " + corner_kicks_away + ", "
    # insert += "  " + offsides_home + ", "
    # insert += "  " + offsides_away + ", "
    # insert += "  " + ball_possession_home + ", "
    # insert += "  " + ball_possession_away + ", "
    # insert += "  " + yellow_cards_home + ", "
    # insert += "  " + yellow_cards_away + ", "
    # insert += "  " + red_cards_home + ", "
    # insert += "  " + red_cards_away + ", "
    # insert += "  " + goalkeeper_saves_home + ", "
    # insert += "  " + goalkeeper_saves_away + ", "
    # insert += "  " + total_passess_home + ", "
    # insert += "  " + total_passess_away + ", "
    # insert += "  " + passess_accurate_home + ", "
    # insert += "  " + passess_accurate_away + ", "
    # insert += "  " + passess_home + ", "
    # insert += "  " + passess_away + ", "
    insert += " current_timestamp ) "
    # ------------------------------------------------------   
    print("---------------------------------------- insert", flush=True)
    mycursor.execute(insert)
    mydb.commit()  
# ----------------------------------------------------------
# Out:
# __Total Row(s) : 19
# ____ [18/19] #'997237' #'293' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [17/19] #'997238' #'293' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [16/19] #'997239' #'293' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [15/19] #'997240' #'293' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [14/19] #'998964' #'245' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [13/19] #'998963' #'245' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [12/19] #'998962' #'245' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [11/19] #'998960' #'245' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [10/19] #'998961' #'245' - '2023' - '2023'
# ---------------------------------------- insert
# ____ [9/19] #'998965' #'245' - '2023' - '2023'
# ...
