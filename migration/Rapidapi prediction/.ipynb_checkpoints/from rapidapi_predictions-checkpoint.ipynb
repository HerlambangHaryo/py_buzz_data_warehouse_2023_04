# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += " fixtureapi_id "
# query += " , leagueapi_id "
# query += " , season "
query += " , prediction_winner_name "
query += " , prediction_winner_comment "
query += " , prediction_underover "
query += " , prediction_goals_home "
query += " , prediction_goals_away "
query += " , prediction_advice "
query += " , prediction_percent_home "
query += " , prediction_percent_draw "
query += " , prediction_percent_away "
query += " , comparison_form_home "
query += " , comparison_form_away "
query += " , comparison_att_home "
query += " , comparison_att_away "
query += " , comparison_def_home "
query += " , comparison_def_away "
query += " , comparison_h2h_home "
query += " , comparison_h2h_away "
query += " , comparison_goals_home "
query += " , comparison_goals_away "
query += " , comparison_poisson_distribution_home "
query += " , comparison_poisson_distribution_away "
query += " , comparison_total_home "
query += " , comparison_total_away " 
# ---------------------------------------------------------- 
query += " from rapidapi_predictions "  
query += " where prediction_winner_name is not null "  
query += " order by id asc "  
# ----------------------------------------------------------  
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------  
    fixtureapi_id = "Null"
    leagueapi_id = "Null"
    season = "Null"
    prediction_winner_name = "Null"
    prediction_winner_comment = "Null"
    prediction_underover = "Null"
    prediction_goals_home = "Null"
    prediction_goals_away = "Null"
    prediction_advice = "Null"
    prediction_percent_home = "Null"
    prediction_percent_draw = "Null"
    prediction_percent_away = "Null"
    comparison_form_home = "Null"
    comparison_form_away = "Null"
    comparison_att_home = "Null"
    comparison_att_away = "Null"
    comparison_def_home = "Null"
    comparison_def_away = "Null"
    comparison_hh_home = "Null"
    comparison_hh_away = "Null"
    comparison_goals_home = "Null"
    comparison_goals_away = "Null"
    comparison_poisson_distribution_home = "Null"
    comparison_poisson_distribution_away = "Null"
    comparison_total_home = "Null"
    comparison_total_away = "Null" 
    # ------------------------------------------------------ 
    col_counter = 0 
    if(x[col_counter] is not None):
        fixtureapi_idx = str(x[col_counter])
        fixtureapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        # -------------------------------------------------- 
        query2 = " Select "
        query2 += " leagueapi_id "
        query2 += " , season "
        query2 += " from football_fixtures "
        query2 += " where fixtureapi_id = '"+fixtureapi_idx+"' "
        # --------------------------------------------------
        mycursor = mydb.cursor()
        mycursor.execute(query2)
        result2 =  mycursor.fetchall()
        # --------------------------------------------------
        total_rows2 = len(result2)
        print(space + "total_rows2 (s) : " + str(total_rows2), flush=True) 
        # --------------------------------------------------
        for y in result2:  
            # ----------------------------------------------
            leagueapi_id = str(y[0])
            season = str(y[1]) 
            # ----------------------------------------------
            word2 = space + "__#" + leagueapi_id
            word2 +=  " - " + season
            # ----------------------------------------------
            print(word2, flush=True) 
        # --------------------------------------------------
    
#     col_counter += 1
#     if(x[col_counter] is not None): 
#         leagueapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
#     col_counter += 1
#     if(x[col_counter] is not None):
#         season = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_winner_name = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_winner_comment = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_underover = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_advice = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_draw = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_form_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_form_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_att_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_att_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_def_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_def_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_hh_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_hh_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_poisson_distribution_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_poisson_distribution_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_total_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_total_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'" 
    # ------------------------------------------------------  
    word = space + "#" + fixtureapi_id
    word += " #" + leagueapi_id
    word += " - " + season
    word += " => " + prediction_winner_name 
    print(word, flush=True)
    # ------------------------------------------------------  
    # ------------------------------------------------------  
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    # ------------------------------------------------------  
    query3 = " Select "
    query3 += " fixtureapi_id " 
    query3 += " from prediction_api_fixtures "
    query3 += " where fixtureapi_id = '"+fixtureapi_idx+"' "
    query3 += " and leagueapi_id = '"+leagueapi_id+"' "
    query3 += " and season = '"+season+"' "
    # ------------------------------------------------------  
    mycursor = mydb.cursor()
    mycursor.execute(query3)
    result3 =  mycursor.fetchall()
    # ------------------------------------------------------
    total_rows3 = len(result3)
    print(space + "total_rows3 (s) : " + str(total_rows3), flush=True) 
    # ------------------------------------------------------
    if(total_rows3 == 0):
        # --------------------------------------------------  
        insert = "INSERT INTO `prediction_api_fixtures`( "
        insert += " `fixtureapi_id`, "
        insert += "  `leagueapi_id`, "
        insert += "  `season`, "
        insert += "  `prediction_winner_name`, "
        insert += "  `prediction_winner_comment`, "
        insert += "  `prediction_underover`, "
        insert += "  `prediction_goals_home`, "
        insert += "  `prediction_goals_away`, "
        insert += "  `prediction_advice`, "
        insert += "  `prediction_percent_home`, "
        insert += "  `prediction_percent_draw`, "
        insert += "  `prediction_percent_away`, "
        insert += "  `comparison_form_home`, "
        insert += "  `comparison_form_away`, "
        insert += "  `comparison_att_home`, "
        insert += "  `comparison_att_away`, "
        insert += "  `comparison_def_home`, "
        insert += "  `comparison_def_away`, "
        insert += "  `comparison_hh_home`, "
        insert += "  `comparison_hh_away`, "
        insert += "  `comparison_goals_home`, "
        insert += "  `comparison_goals_away`, "
        insert += "  `comparison_poisson_distribution_home`, "
        insert += "  `comparison_poisson_distribution_away`, "
        insert += "  `comparison_total_home`, "
        insert += "  `comparison_total_away` "
        insert += "  ) VALUES ( " 
        insert += " " + fixtureapi_id + ", "
        insert += "  " + leagueapi_id + ", "
        insert += "  " + season + ", "
        insert += "  " + prediction_winner_name + ", "
        insert += "  " + prediction_winner_comment + ", "
        insert += "  " + prediction_underover + ", "
        insert += "  " + prediction_goals_home + ", "
        insert += "  " + prediction_goals_away + ", "
        insert += "  " + prediction_advice + ", "
        insert += "  " + prediction_percent_home + ", "
        insert += "  " + prediction_percent_draw + ", "
        insert += "  " + prediction_percent_away + ", "
        insert += "  " + comparison_form_home + ", "
        insert += "  " + comparison_form_away + ", "
        insert += "  " + comparison_att_home + ", "
        insert += "  " + comparison_att_away + ", "
        insert += "  " + comparison_def_home + ", "
        insert += "  " + comparison_def_away + ", "
        insert += "  " + comparison_hh_home + ", "
        insert += "  " + comparison_hh_away + ", "
        insert += "  " + comparison_goals_home + ", "
        insert += "  " + comparison_goals_away + ", "
        insert += "  " + comparison_poisson_distribution_home + ", "
        insert += "  " + comparison_poisson_distribution_away + ", "
        insert += "  " + comparison_total_home + ", "
        insert += "  " + comparison_total_away + " "
        insert += " ) "
        # --------------------------------------------------  
        print("---------------------------------------- insert", flush=True)
        mycursor.execute(insert)
        mydb.commit()  
    # ------------------------------------------------------ 
    # ------------------------------------------------------  
# ----------------------------------------------------------
# Out:
# __Total Row(s) : 3165
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710708' #39 - 2021 => 'Tottenham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710738' #39 - 2021 => 'Everton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710745' #39 - 2021 => 'Wolves'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710750' #39 - 2021 => 'Newcastle'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710751' #39 - 2021 => 'Aston Villa'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710762' #39 - 2021 => 'Leicester'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'710764' #39 - 2021 => 'Newcastle'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#39 - 2021
# ____#'

# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717227' #40 - 2021 => 'Swansea'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717228' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717229' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717230' #40 - 2021 => 'Hull City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717231' #40 - 2021 => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717232' #40 - 2021 => 'Blackpool'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717233' #40 - 2021 => 'Cardiff'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717234' #40 - 2021 => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717235' #40 - 2021 => 'Luton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717236' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717237' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717238' #40 - 2021 => 'Stoke City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717239' #40 - 2021 => 'Huddersfield'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717240' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717241' #40 - 2021 => 'Bristol City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717242' #40 - 2021 => 'Birmingham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717243' #40 - 2021 => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717244' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717245' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717246' #40 - 2021 => 'Blackpool'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717247' #40 - 2021 => 'Cardiff'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717248' #40 - 2021 => 'Coventry'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717249' #40 - 2021 => 'Luton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717250' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717251' #40 - 2021 => 'Swansea'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717252' #40 - 2021 => 'West Brom'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717253' #40 - 2021 => 'Coventry'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717254' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717255' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717256' #40 - 2021 => 'Luton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717257' #40 - 2021 => 'Cardiff'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717258' #40 - 2021 => 'Blackpool'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717259' #40 - 2021 => 'QPR'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717260' #40 - 2021 => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717261' #40 - 2021 => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717262' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717263' #40 - 2021 => 'Swansea'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717264' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717265' #40 - 2021 => 'Reading'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717266' #40 - 2021 => 'West Brom'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717267' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717268' #40 - 2021 => 'Cardiff'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717269' #40 - 2021 => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717270' #40 - 2021 => 'Preston'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717271' #40 - 2021 => 'Huddersfield'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717272' #40 - 2021 => 'Luton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717273' #40 - 2021 => 'Middlesbrough'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717274' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717275' #40 - 2021 => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717300' #40 - 2021 => 'Barnsley'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717306' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717308' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717309' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717312' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717313' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717314' #40 - 2021 => 'Bristol City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717315' #40 - 2021 => 'Huddersfield'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717318' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717319' #40 - 2021 => 'Preston'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717320' #40 - 2021 => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717321' #40 - 2021 => 'Stoke City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717322' #40 - 2021 => 'Swansea'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717323' #40 - 2021 => 'West Brom'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717329' #40 - 2021 => 'Huddersfield'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717330' #40 - 2021 => 'Fulham'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717331' #40 - 2021 => 'Middlesbrough'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717332' #40 - 2021 => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717336' #40 - 2021 => 'Bournemouth'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717337' #40 - 2021 => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717338' #40 - 2021 => 'Derby'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717340' #40 - 2021 => 'Nottingham Forest'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717341' #40 - 2021 => 'Luton'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717346' #40 - 2021 => 'QPR'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#40 - 2021
# ____#'717347' #40 - 2021 => 'West Brom'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#41 - 2021
# ____#'715690' #41 - 2021 => 'Sheffield Wednesday'
# ____total_rows3 (s) : 0
