# %%
# Import
import mysql.connector 
# ---------------------------------------------------------- 
# Connect to DB
# ---------------------------------------------------------- 
space = "__"
# ---------------------------------------------------------- 
host="localhost"
user="root" 
database="pr_mmbuzz_2022_06"
mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
mycursor = mydb.cursor()
# ---------------------------------------------------------- 
query = " Select "
# ---------------------------------------------------------- 
query += " fixtureapi_id "
# query += " , leagueapi_id "
# query += " , season "
query += " , prediction_winner_name "
query += " , prediction_winner_comment "
query += " , prediction_underover "
query += " , prediction_goals_home "
query += " , prediction_goals_away "
query += " , prediction_advice "
query += " , prediction_percent_home "
query += " , prediction_percent_draw "
query += " , prediction_percent_away "
query += " , comparison_form_home "
query += " , comparison_form_away "
query += " , comparison_att_home "
query += " , comparison_att_away "
query += " , comparison_def_home "
query += " , comparison_def_away "
query += " , comparison_h2h_home "
query += " , comparison_h2h_away "
query += " , comparison_goals_home "
query += " , comparison_goals_away "
query += " , comparison_poisson_distribution_home "
query += " , comparison_poisson_distribution_away "
query += " , comparison_total_home "
query += " , comparison_total_away " 
# ---------------------------------------------------------- 
query += " from rapidapi_predictions "  
query += " where prediction_winner_name is not null "  
query += " and fixtureapi_id not in (select fixtureapi_id from prediction_api_fixtures) "  
query += " order by id asc "  
# ----------------------------------------------------------  
mycursor = mydb.cursor()
mycursor.execute(query)
result =  mycursor.fetchall()
# ----------------------------------------------------------  
total_rows = len(result)
print(space + "Total Row(s) : " + str(total_rows), flush=True) 
# ----------------------------------------------------------  
counter = 0
# ----------------------------------------------------------  
space += "__"
# ---------------------------------------------------------- 
for x in result:   
    # ------------------------------------------------------  
    fixtureapi_id = "Null"
    leagueapi_id = "Null"
    season = "Null"
    prediction_winner_name = "Null"
    prediction_winner_comment = "Null"
    prediction_underover = "Null"
    prediction_goals_home = "Null"
    prediction_goals_away = "Null"
    prediction_advice = "Null"
    prediction_percent_home = "Null"
    prediction_percent_draw = "Null"
    prediction_percent_away = "Null"
    comparison_form_home = "Null"
    comparison_form_away = "Null"
    comparison_att_home = "Null"
    comparison_att_away = "Null"
    comparison_def_home = "Null"
    comparison_def_away = "Null"
    comparison_hh_home = "Null"
    comparison_hh_away = "Null"
    comparison_goals_home = "Null"
    comparison_goals_away = "Null"
    comparison_poisson_distribution_home = "Null"
    comparison_poisson_distribution_away = "Null"
    comparison_total_home = "Null"
    comparison_total_away = "Null" 
    # ------------------------------------------------------ 
    col_counter = 0 
    if(x[col_counter] is not None):
        fixtureapi_idx = str(x[col_counter])
        fixtureapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
        # -------------------------------------------------- 
        query2 = " Select "
        query2 += " leagueapi_id "
        query2 += " , season "
        query2 += " from football_fixtures "
        query2 += " where fixtureapi_id = '"+fixtureapi_idx+"' "
        # --------------------------------------------------
        mycursor = mydb.cursor()
        mycursor.execute(query2)
        result2 =  mycursor.fetchall()
        # --------------------------------------------------
        total_rows2 = len(result2)
        print(space + "total_rows2 (s) : " + str(total_rows2), flush=True) 
        # --------------------------------------------------
        for y in result2:  
            # ----------------------------------------------
            leagueapi_id = str(y[0])
            season = str(y[1]) 
            # ----------------------------------------------
            word2 = space + "__#" + leagueapi_id
            word2 +=  " - " + season
            # ----------------------------------------------
            print(word2, flush=True) 
        # --------------------------------------------------
    
#     col_counter += 1
#     if(x[col_counter] is not None): 
#         leagueapi_id = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
#     col_counter += 1
#     if(x[col_counter] is not None):
#         season = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_winner_name = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_winner_comment = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_underover = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_advice = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_draw = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        prediction_percent_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_form_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_form_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_att_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_att_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_def_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_def_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_hh_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_hh_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_goals_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_goals_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_poisson_distribution_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_poisson_distribution_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_total_home = "'" + str(x[col_counter]).replace("'", "\\'") + "'"
    
    col_counter += 1
    if(x[col_counter] is not None):
        comparison_total_away = "'" + str(x[col_counter]).replace("'", "\\'") + "'" 
    # ------------------------------------------------------  
    word = space + "#" + fixtureapi_id
    word += " #" + leagueapi_id
    word += " - " + season
    word += " => " + prediction_winner_name 
    print(word, flush=True)
    # ------------------------------------------------------  
    # ------------------------------------------------------  
    host="localhost"
    user="root" 
    database="pr_mmbuzz_2022_06"
    mydb = mysql.connector.connect(host=host,user=user,password="",database=database)
    mycursor = mydb.cursor()
    # ------------------------------------------------------  
    query3 = " Select "
    query3 += " fixtureapi_id " 
    query3 += " from prediction_api_fixtures "
    query3 += " where fixtureapi_id = '"+fixtureapi_idx+"' "
    query3 += " and leagueapi_id = '"+leagueapi_id+"' "
    query3 += " and season = '"+season+"' "
    # ------------------------------------------------------  
    mycursor = mydb.cursor()
    mycursor.execute(query3)
    result3 =  mycursor.fetchall()
    # ------------------------------------------------------
    total_rows3 = len(result3)
    print(space + "total_rows3 (s) : " + str(total_rows3), flush=True) 
    # ------------------------------------------------------
    if(total_rows3 == 0 and total_rows2 != 0):
        # --------------------------------------------------  
        insert = "INSERT INTO `prediction_api_fixtures`( "
        insert += " `fixtureapi_id`, "
        insert += "  `leagueapi_id`, "
        insert += "  `season`, "
        insert += "  `prediction_winner_name`, "
        insert += "  `prediction_winner_comment`, "
        insert += "  `prediction_underover`, "
        insert += "  `prediction_goals_home`, "
        insert += "  `prediction_goals_away`, "
        insert += "  `prediction_advice`, "
        insert += "  `prediction_percent_home`, "
        insert += "  `prediction_percent_draw`, "
        insert += "  `prediction_percent_away`, "
        insert += "  `comparison_form_home`, "
        insert += "  `comparison_form_away`, "
        insert += "  `comparison_att_home`, "
        insert += "  `comparison_att_away`, "
        insert += "  `comparison_def_home`, "
        insert += "  `comparison_def_away`, "
        insert += "  `comparison_hh_home`, "
        insert += "  `comparison_hh_away`, "
        insert += "  `comparison_goals_home`, "
        insert += "  `comparison_goals_away`, "
        insert += "  `comparison_poisson_distribution_home`, "
        insert += "  `comparison_poisson_distribution_away`, "
        insert += "  `comparison_total_home`, "
        insert += "  `comparison_total_away` "
        insert += "  ) VALUES ( " 
        insert += " " + fixtureapi_id + ", "
        insert += "  " + leagueapi_id + ", "
        insert += "  " + season + ", "
        insert += "  " + prediction_winner_name + ", "
        insert += "  " + prediction_winner_comment + ", "
        insert += "  " + prediction_underover + ", "
        insert += "  " + prediction_goals_home + ", "
        insert += "  " + prediction_goals_away + ", "
        insert += "  " + prediction_advice + ", "
        insert += "  " + prediction_percent_home + ", "
        insert += "  " + prediction_percent_draw + ", "
        insert += "  " + prediction_percent_away + ", "
        insert += "  " + comparison_form_home + ", "
        insert += "  " + comparison_form_away + ", "
        insert += "  " + comparison_att_home + ", "
        insert += "  " + comparison_att_away + ", "
        insert += "  " + comparison_def_home + ", "
        insert += "  " + comparison_def_away + ", "
        insert += "  " + comparison_hh_home + ", "
        insert += "  " + comparison_hh_away + ", "
        insert += "  " + comparison_goals_home + ", "
        insert += "  " + comparison_goals_away + ", "
        insert += "  " + comparison_poisson_distribution_home + ", "
        insert += "  " + comparison_poisson_distribution_away + ", "
        insert += "  " + comparison_total_home + ", "
        insert += "  " + comparison_total_away + " "
        insert += " ) "
        # --------------------------------------------------  
        print("---------------------------------------- insert", flush=True)
        mycursor.execute(insert)
        mydb.commit()  
    # ------------------------------------------------------ 
    # ------------------------------------------------------  
# ----------------------------------------------------------
# Out:
# __Total Row(s) : 494
# ____total_rows2 (s) : 0
# ____#'869542' #Null - Null => 'Barcelona'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870404' #Null - Null => 'WSG Wattens'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870407' #Null - Null => 'Lokomotiv Moscow'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870435' #Null - Null => 'Alloa Athletic'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870438' #Null - Null => 'Wigan'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870455' #Null - Null => 'Sigma Olomouc'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870459' #Null - Null => 'Slask Wroclaw'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870488' #Null - Null => 'Ried'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870490' #Null - Null => 'Lyngby'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870498' #Null - Null => 'Floridsdorfer AC'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870501' #Null - Null => 'Ried'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870506' #Null - Null => 'FC Winterthur'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870674' #Null - Null => 'Woking'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870686' #Null - Null => 'Yeovil Town'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870692' #Null - Null => 'Salford City'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870873' #Null - Null => 'Celtic'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870893' #Null - Null => 'Heart OF Midlothian'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870895' #Null - Null => 'Minnesota United FC'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870902' #Null - Null => 'Excelsior'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870904' #Null - Null => 'PEC Zwolle'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870906' #Null - Null => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870941' #Null - Null => 'Blackburn'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870943' #Null - Null => 'Oxford United'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870944' #Null - Null => 'Southend'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870946' #Null - Null => 'Swansea'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870949' #Null - Null => 'Stockport County'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870954' #Null - Null => 'Bradford'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870955' #Null - Null => 'Millwall'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870964' #Null - Null => 'Stevenage'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'870974' #Null - Null => 'Peterborough'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'871012' #Null - Null => 'Chesterfield'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 0
# ____#'871013' #Null - Null => 'Newcastle'
# ____total_rows3 (s) : 0
# ____total_rows2 (s) : 1
# ______#493 - 2021
# ____#'879506' #493 - 2021 => 'France U19'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#328 - 2022
# ____#'842126' #328 - 2022 => 'Laagri'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#387 - 2022
# ____#'864444' #387 - 2022 => 'Sahab'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#387 - 2022
# ____#'864473' #387 - 2022 => 'Al Hussein'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868542' #263 - 2022 => 'Alebrijes de Oaxaca'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868543' #263 - 2022 => 'Celaya'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868544' #263 - 2022 => 'Tepatitlán'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868550' #263 - 2022 => 'Leones Negros UDG'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868552' #263 - 2022 => 'Alebrijes de Oaxaca'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868553' #263 - 2022 => 'Celaya'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868557' #263 - 2022 => 'Venados FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868563' #263 - 2022 => 'Atlante FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'868564' #263 - 2022 => 'Alebrijes de Oaxaca'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#263 - 2022
# ____#'

# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#295 - 2022
# ____#'845351' #295 - 2022 => 'Cheonan City'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#295 - 2022
# ____#'845353' #295 - 2022 => 'Dangjin Citizen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837794' #99 - 2022 => 'Vegalta Sendai'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837795' #99 - 2022 => 'Tokyo Verdy'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837798' #99 - 2022 => 'Albirex Niigata'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837799' #99 - 2022 => 'Kanazawa'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837800' #99 - 2022 => 'Fagiano Okayama'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837801' #99 - 2022 => 'Oita Trinita'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837802' #99 - 2022 => 'V-varen Nagasaki'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837803' #99 - 2022 => 'Tokushima Vortis'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837820' #99 - 2022 => 'Montedio Yamagata'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837821' #99 - 2022 => 'V-varen Nagasaki'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837822' #99 - 2022 => 'Yokohama FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837824' #99 - 2022 => 'FC Ryukyu'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837825' #99 - 2022 => 'Renofa Yamaguchi'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837828' #99 - 2022 => 'JEF United Chiba'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837829' #99 - 2022 => 'Albirex Niigata'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837832' #99 - 2022 => 'Montedio Yamagata'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837834' #99 - 2022 => 'Omiya Ardija'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837862' #99 - 2022 => 'Ventforet Kofu'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#99 - 2022
# ____#'837865' #99 - 2022 => 'Fagiano Okayama'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844809' #100 - 2022 => 'Matsumoto Yamaga'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844810' #100 - 2022 => 'Ehime FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844811' #100 - 2022 => 'Kitakyushu'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844814' #100 - 2022 => 'Matsumoto Yamaga'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844818' #100 - 2022 => 'Kagoshima United'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#100 - 2022
# ____#'844821' #100 - 2022 => 'Parceiro Nagano'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#194 - 2022
# ____#'842454' #194 - 2022 => 'Adelaide Comets'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#194 - 2022
# ____#'842456' #194 - 2022 => 'Croydon Kings'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#299 - 2022
# ____#'841189' #299 - 2022 => 'Deportivo Lara'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'933614' #848 - 2022 => 'Maccabi Tel Aviv'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867262' #848 - 2022 => 'Guimaraes'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867274' #848 - 2022 => 'Riga'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867276' #848 - 2022 => 'Alashkert'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867278' #848 - 2022 => 'Lechia Gdansk'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867288' #848 - 2022 => 'Gjilani'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867290' #848 - 2022 => 'Mura'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867292' #848 - 2022 => 'KuPS'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867294' #848 - 2022 => 'Ružomberok'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867296' #848 - 2022 => 'Buducnost Podgorica'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867300' #848 - 2022 => 'Borac Banja Luka'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867306' #848 - 2022 => 'Breidablik'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867308' #848 - 2022 => 'Dunajska Streda'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867310' #848 - 2022 => 'Vikingur Gota'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867314' #848 - 2022 => 'Tre Fiori'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867322' #848 - 2022 => 'Shkendija'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867328' #848 - 2022 => 'HB'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867332' #848 - 2022 => 'Flora Tallinn'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'866852' #2 - 2022 => 'Shkupi 1927'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'866850' #2 - 2022 => 'Lech Poznan'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'866836' #2 - 2022 => 'F91 Dudelange'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'866848' #2 - 2022 => 'Shamrock Rovers'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'878837' #2 - 2022 => 'Malmo FF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'866846' #2 - 2022 => 'The New Saints'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#743 - 2021
# ____#'809911' #743 - 2021 => 'Italy W'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#743 - 2021
# ____#'809912' #743 - 2021 => 'France W'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#743 - 2021
# ____#'809917' #743 - 2021 => 'Sweden W'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______

# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#80 - 2022
# ____#'879145' #80 - 2022 => 'SV Elversberg'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#80 - 2022
# ____#'879149' #80 - 2022 => 'VfB Oldenburg'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#80 - 2022
# ____#'879175' #80 - 2022 => 'Rot-weiss Essen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#207 - 2022
# ____#'872539' #207 - 2022 => 'BSC Young Boys'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#207 - 2022
# ____#'872540' #207 - 2022 => 'FC ST. Gallen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#207 - 2022
# ____#'872563' #207 - 2022 => 'Grasshoppers'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#208 - 2022
# ____#'869282' #208 - 2022 => 'Yverdon Sport'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#208 - 2022
# ____#'869283' #208 - 2022 => 'Lausanne'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#208 - 2022
# ____#'869301' #208 - 2022 => 'Yverdon Sport'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#208 - 2022
# ____#'869302' #208 - 2022 => 'Lausanne'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878844' #219 - 2022 => 'First Vienna'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878846' #219 - 2022 => 'FC Liefering'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878848' #219 - 2022 => 'SKU Amstetten'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878850' #219 - 2022 => 'SV Horn'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878851' #219 - 2022 => 'SKN ST. Polten'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878852' #219 - 2022 => 'Grazer AK'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878854' #219 - 2022 => 'Austria Vienna (Am)'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878857' #219 - 2022 => 'SV Lafnitz'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878860' #219 - 2022 => 'SKN ST. Polten'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878862' #219 - 2022 => 'First Vienna'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#219 - 2022
# ____#'878887' #219 - 2022 => 'Admira Wacker'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#83 - 2022
# ____#'904085' #83 - 2022 => 'Eichstätt'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897745' #2 - 2022 => 'Maribor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897747' #2 - 2022 => 'F91 Dudelange'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897753' #2 - 2022 => 'Ludogorets'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897755' #2 - 2022 => 'Shkupi 1927'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897749' #2 - 2022 => 'FK Zalgiris Vilnius'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'897741' #2 - 2022 => 'Slovan Bratislava'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'897631' #848 - 2022 => 'FK Tobol Kostanay'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'897635' #848 - 2022 => 'Vikingur Reykjavik'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'897627' #848 - 2022 => 'CFR 1907 Cluj'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867265' #848 - 2022 => 'Vorskla Poltava'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867236' #848 - 2022 => 'Videoton FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867246' #848 - 2022 => 'Kisvarda FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898004' #848 - 2022 => 'Paide'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'897996' #848 - 2022 => 'Radnicki NIS'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898012' #848 - 2022 => 'Lillestrom'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867264' #848 - 2022 => 'Djurgardens IF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867252' #848 - 2022 => 'Viborg'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867260' #848 - 2022 => 'Levski Sofia'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898000' #848 - 2022 => 'Saburtalo'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898036' #848 - 2022 => 'Shkendija'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898022' #848 - 2022 => 'Pogon Szczecin'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867248' #848 - 2022 => 'Konyaspor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898002' #848 - 2022 => 'Hapoel Beer Sheva'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'897998' #848 - 2022 => 'Hamrun Spartans'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898014' #848 - 2022 => 'Breidablik'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'867250' #848 - 2022 => 'NK Osijek'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898024' #848 - 2022 => 'AZ Alkmaar'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'898020' #848 - 2022 => 'Dunajska Streda'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'933595' #848 - 2022 => 'Antwerp'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'933579' #848 - 2022 => 'Rīgas FS'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'874683' #40 - 2022 => 'Birmingham'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'874690' #40 - 2022 => 'Cardiff'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'874705' #40 - 2022 => 'Burnley'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'874715' #40 - 2022 => 'Swansea'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'874717' #40 - 2022 => 'Middlesbrough'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'880767' #40 - 2022 => 'Birmingham'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ...
# ____total_rows2 (s) : 1
# ______#183 - 2022
# ____#'873694' #183 - 2022 => 'Peterhead'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#183 - 2022
# ____#'873699' #183 - 2022 => 'Montrose'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#184 - 2022
# ____#'873506' #184 - 2022 => 'Dumbarton'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#184 - 2022
# ____#'873509' #184 - 2022 => 'Stranraer'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#184 - 2022
# ____#'873510' #184 - 2022 => 'Elgin City'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'933591' #848 - 2022 => 'Djurgardens IF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'924403' #2 - 2022 => 'Ferencvarosi TC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'924405' #2 - 2022 => 'Dynamo Kyiv'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924457' #848 - 2022 => 'Riga'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924433' #848 - 2022 => 'Dunajska Streda'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924425' #848 - 2022 => 'CSKA Sofia'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'923190' #848 - 2022 => 'CFR 1907 Cluj'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924419' #848 - 2022 => 'Lillestrom'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924447' #848 - 2022 => 'Aris Thessalonikis'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924443' #848 - 2022 => 'Hamrun Spartans'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924437' #848 - 2022 => 'Konyaspor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924449' #848 - 2022 => 'Cukaricki'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'923188' #848 - 2022 => 'Ballkani'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924451' #848 - 2022 => 'FK Tobol Kostanay'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924464' #848 - 2022 => 'Hapoel Beer Sheva'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924446' #848 - 2022 => 'Videoton FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924440' #848 - 2022 => 'Djurgardens IF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924462' #848 - 2022 => 'Zorya Luhansk'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'924454' #848 - 2022 => 'Slavia Praha'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#11 - 2022
# ____#'885355' #11 - 2022 => 'FBC Melgar'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'933547' #3 - 2022 => 'Fenerbahce'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#88 - 2022
# ____#'872248' #88 - 2022 => 'AZ Alkmaar'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#88 - 2022
# ____#'872270' #88 - 2022 => 'NEC Nijmegen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#89 - 2022
# ____#'867604' #89 - 2022 => 'PEC Zwolle'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#89 - 2022
# ____#'867605' #89 - 2022 => 'Almere City FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#89 - 2022
# ____#'867606' #89 - 2022 => 'NAC Breda'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#89 - 2022
# ____#'867607' #89 - 2022 => 'De Graafschap'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#89 - 2022
# ____#'867613' #89 - 2022 => 'FC OSS'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#203 - 2022
# ____#'884392' #203 - 2022 => 'Konyaspor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#204 - 2022
# ____#'884778' #204 - 2022 => 'Adanaspor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#204 - 2022
# ____#'884817' #204 - 2022 => 'Bandırmaspor'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#95 - 2022
# ____#'898936' #95 - 2022 => 'Moreirense'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#95 - 2022
# ____#'898947' #95 - 2022 => 'Farense'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#95 - 2022
# ____#'898960' #95 - 2022 => 'FC Porto B'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#94 - 2022
# ____#'898626' #94 - 2022 => 'FC Porto'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#94 - 2022
# ____#'898643' #94 - 2022 => 'Estoril'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#94 - 2022
# ____#'898648' #94 - 2022 => 'Benfica'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#94 - 2022
# ____#'898654' #94 - 2022 => 'Benfica'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#141 - 2022
# ____#'878325' #141 - 2022 => 'Zaragoza'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#141 - 2022
# ____#'878360' #141 - 2022 => 'Eibar'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#140 - 2022
# ____#'877979' #140 - 2022 => 'Celta Vigo'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#408 - 2022
# ____#'877367' #408 - 2022 => 'Coleraine FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#408 - 2022
# ____#'877379' #408 - 2022 => 'Crusaders FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#145 - 2022
# ____#'875394' #145 - 2022 => 'Deinze'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#145 - 2022
# ____#'875397' #145 - 2022 => 'KRC Genk II'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'923169' #3 - 2022 => 'HJK helsinki'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'923171' #3 - 2022 => 'AEK Larnaca'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'923194' #3 - 2022 => 'Malmo FF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'923200' #3 - 2022 => 'Fenerbahce'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'933173' #2 - 2022 => 'Dynamo Kyiv'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'933175' #2 - 2022 => 'FK Crvena Zvezda'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'933171' #2 - 2022 => 'Plzen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#46 - 2022
# ____#'886577' #46 - 2022 => 'Derby'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#745 - 2022
# ____#'907646' #745 - 2022 => 'Curslack-Neuengamme'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933619' #48 - 2022 => 'Aston Villa'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933621' #48 - 2022 => 'Leeds'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933622' #48 - 2022 => 'Fleetwood Town'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933623' #48 - 2022 => 'Sheffield Wednesday'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933624' #48 - 2022 => 'Tranmere'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#48 - 2022
# ____#'933625' #48 - 2022 => 'Rotherham'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#271 - 2022
# ____#'883242' #271 - 2022 => 'Ferencvarosi TC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946850' #2 - 2022 => 'FC Copenhagen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946849' #2 - 2022 => 'Dinamo Zagreb'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946854' #2 - 2022 => 'Manchester City'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946855' #2 - 2022 => 'Juventus'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946868' #2 - 2022 => 'Rangers'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#2 - 2022
# ____#'946878' #2 - 2022 => 'FC Copenhagen'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946755' #3 - 2022 => 'AEK Larnaca'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946756' #3 - 2022 => 'Dynamo Kyiv'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946759' #3 - 2022 => 'Malmo FF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946762' #3 - 2022 => 'Omonia Nicosia'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946761' #3 - 2022 => 'Manchester United'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946668' #848 - 2022 => 'Molde'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946673' #848 - 2022 => 'Apollon Limassol'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946674' #848 - 2022 => 'AZ Alkmaar'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946776' #3 - 2022 => 'Ferencvarosi TC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946675' #848 - 2022 => 'Djurgardens IF'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946778' #3 - 2022 => 'FC Zurich'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946677' #848 - 2022 => 'Slavia Praha'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946680' #848 - 2022 => 'Slovan Bratislava'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946780' #3 - 2022 => 'Fenerbahce'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946688' #848 - 2022 => 'Slovácko'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946686' #848 - 2022 => 'Villarreal'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#3 - 2022
# ____#'946781' #3 - 2022 => 'Ludogorets'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946684' #848 - 2022 => 'West Ham'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946681' #848 - 2022 => 'Rīgas FS'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#848 - 2022
# ____#'946685' #848 - 2022 => 'Lech Poznan'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#166 - 2022
# ____#'822297' #166 - 2022 => 'Magni'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#90 - 2022
# ____#'942458' #90 - 2022 => 'Staphorst'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#5 - 2022
# ____#'854707' #5 - 2022 => 'Turkey'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#383 - 2022
# ____#'865887' #383 - 2022 => 'Maccabi Bnei Raina'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#141 - 2022
# ____#'878442' #141 - 2022 => 'Zaragoza'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#563 - 2022
# ____#'833062' #563 - 2022 => 'Vasalund'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#563 - 2022
# ____#'833058' #563 - 2022 => 'Sandviken'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#116 - 2022
# ____#'850472' #116 - 2022 => 'FC Slutsk'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#408 - 2022
# ____#'877416' #408 - 2022 => 'Crusaders FC'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#183 - 2022
# ____#'873733' #183 - 2022 => 'Kelty Hearts'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
# ____total_rows2 (s) : 1
# ______#40 - 2022
# ____#'880896' #40 - 2022 => 'Sheffield Utd'
# ____total_rows3 (s) : 0
# ---------------------------------------- insert
