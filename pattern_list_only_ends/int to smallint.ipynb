# %%
import mysql.connector

pre = [ 
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_65_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_6_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_6_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_6_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_6_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_65_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_65_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_40_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_40_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_45_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_50_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_50_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_55_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_60_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_60_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_65_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_65_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_70_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_70_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_75_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_75_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_85_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_85_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_95_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_95_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_05_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_10_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_15_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_20_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_30_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `homeaway_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `homeaway_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_first_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_second_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_home_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_home_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_draw_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_home_draw_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_home_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_draw_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `oddeven_odd_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `oddeven_even_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_home_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_draw_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_away_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_home_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_draw_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_away_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_over_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_under_35_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_over_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_under_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__home_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__home_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__away_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__away_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_both_halves_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_both_halves_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score__first_half_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score__first_half_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score__second_half_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score__second_half_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_to_nil_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_to_nil_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_6_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_more_7_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_win_either_half_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_win_either_half_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_more_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_more_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_more_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_0_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_1_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_2_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_3_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_4_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_more_5_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_score_in_both_halves_by_teams_home_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_score_in_both_halves_by_teams_away_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_over_yes_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_over_no_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_under_yes_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_under_no_25_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_home_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_draw_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_away_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_home_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_draw_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_away_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_yes_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_yes_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_no_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_no_no_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `rcard_yes_data` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `rcard_no_data` ", 
]

end = [
    " `asian_handicap_away_min_65_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_6_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_6_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_55_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_55_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_5_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_5_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_45_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_45_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_4_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_4_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_35_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_35_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_3_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_3_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_25_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_25_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_2_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_2_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_min_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_min_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_0_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_0_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_2_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_2_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_25_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_25_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_3_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_3_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_35_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_35_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_4_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_4_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_45_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_45_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_5_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_5_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_55_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_55_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_6_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_6_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_65_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_65_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_40_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_40_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_45_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_45_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_50_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_50_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_55_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_55_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_60_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_60_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_65_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_65_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_70_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_70_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_75_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_75_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_85_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_85_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_over_95_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_under_95_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_0_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_0_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_05_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_1_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_15_data` SMALLINT NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_05_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_10_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_15_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_20_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_30_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `match_winner_home_data` SMALLINT NULL DEFAULT NULL;",
    " `match_winner_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `match_winner_away_data` SMALLINT NULL DEFAULT NULL;",
    " `homeaway_home_data` SMALLINT NULL DEFAULT NULL;",
    " `homeaway_away_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_winner_home_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_winner_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_winner_away_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_home_home_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_home_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_home_away_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_draw_home_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_draw_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_draw_away_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_away_home_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_away_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `htft_double_away_away_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_score_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_score_no_data` SMALLINT NULL DEFAULT NULL;",
    " `highest_scoring_half_first_data` SMALLINT NULL DEFAULT NULL;",
    " `highest_scoring_half_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `highest_scoring_half_second_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance_home_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance_home_away_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance_draw_away_data` SMALLINT NULL DEFAULT NULL;",
    " `first_half_winner_home_data` SMALLINT NULL DEFAULT NULL;",
    " `first_half_winner_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `first_half_winner_away_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance__first_half_home_draw_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance__first_half_home_away_data` SMALLINT NULL DEFAULT NULL;",
    " `double_chance__first_half_draw_away_data` SMALLINT NULL DEFAULT NULL;",
    " `oddeven_odd_data` SMALLINT NULL DEFAULT NULL;",
    " `oddeven_even_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_home_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_draw_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_away_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_home_no_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_draw_no_data` SMALLINT NULL DEFAULT NULL;",
    " `results_both_teams_score_away_no_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_home_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_draw_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_away_over_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_home_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_draw_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_away_under_35_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_home_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_draw_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_away_over_25_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_home_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_draw_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `result_total_goals_away_under_25_data` SMALLINT NULL DEFAULT NULL;",
    " `clean_sheet__home_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `clean_sheet__home_no_data` SMALLINT NULL DEFAULT NULL;",
    " `clean_sheet__away_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `clean_sheet__away_no_data` SMALLINT NULL DEFAULT NULL;",
    " `win_both_halves_home_data` SMALLINT NULL DEFAULT NULL;",
    " `win_both_halves_away_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_score__first_half_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_score__first_half_no_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score__second_half_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score__second_half_no_data` SMALLINT NULL DEFAULT NULL;",
    " `win_to_nil_home_data` SMALLINT NULL DEFAULT NULL;",
    " `win_to_nil_away_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_0_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_1_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_2_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_3_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_4_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_5_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_6_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number_more_7_data` SMALLINT NULL DEFAULT NULL;",
    " `to_win_either_half_home_data` SMALLINT NULL DEFAULT NULL;",
    " `to_win_either_half_away_data` SMALLINT NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_0_data` SMALLINT NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_1_data` SMALLINT NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_2_data` SMALLINT NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_more_3_data` SMALLINT NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_0_data` SMALLINT NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_1_data` SMALLINT NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_2_data` SMALLINT NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_more_3_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_0_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_1_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_2_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_3_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_4_data` SMALLINT NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_more_5_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_0_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_1_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_2_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_3_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_4_data` SMALLINT NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_more_5_data` SMALLINT NULL DEFAULT NULL;",
    " `to_score_in_both_halves_by_teams_home_data` SMALLINT NULL DEFAULT NULL;",
    " `to_score_in_both_halves_by_teams_away_data` SMALLINT NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_over_yes_25_data` SMALLINT NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_over_no_25_data` SMALLINT NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_under_yes_25_data` SMALLINT NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_under_no_25_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_home_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_draw_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_away_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_home_no_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_draw_no_data` SMALLINT NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_away_no_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_yes_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_yes_no_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_no_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_no_no_data` SMALLINT NULL DEFAULT NULL;",
    " `rcard_yes_data` SMALLINT NULL DEFAULT NULL;",
    " `rcard_no_data` SMALLINT NULL DEFAULT NULL;",
]

# %%
# -----------------------------------------------------------------
total_rows = len(pre) 
# -----------------------------------------------------------------
host = "localhost"
user = "root"
database = "pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database ) 
# -----------------------------------------------------------------
mycursor = mydb.cursor() 
# -----------------------------------------------------------------
print(total_rows) 
counter = 0
# ----------------------------------------------------------------- 
while counter < total_rows: 
    pre_0 =  pre[counter]
    end_0 =  end[counter]
    word = pre_0 + end_0
    print(word)
    counter += 1 
    mycursor.execute(word)
    mydb.commit()
# Out:
# 240
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_65_data`  `asian_handicap_away_min_65_data` SMALLINT NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_6_data`  `asian_handicap_home_min_6_data` SMALLINT NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_6_data`  `asian_handicap_away_min_6_data` SMALLINT NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_55_data`  `asian_handicap_home_min_55_data` SMALLINT NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_55_data`  `asian_handicap_away_min_55_data` SMALLINT NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_5_data`  `asian_handicap_home_min_5_data` SMALLINT NULL DEFAULT NULL;
# ...
