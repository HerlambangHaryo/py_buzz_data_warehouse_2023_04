# %%
import mysql.connector

pre = [ 
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_65_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_6_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_6_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_6_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_6_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_plus_65_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_plus_65_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_40_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_40_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_45_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_50_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_50_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_55_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_60_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_60_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_65_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_65_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_70_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_70_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_75_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_75_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_85_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_85_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_over_95_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_under_95_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder_first_half_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_min_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_min_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_home_plus_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_first_half_away_plus_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_05_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_10_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_15_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_20_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_30_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `goals_overunder__second_half_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `match_winner_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `homeaway_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `homeaway_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_winner_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_home_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_draw_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `htft_double_away_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_first_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `highest_scoring_half_second_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_home_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_home_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance_draw_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `first_half_winner_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_home_draw_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_home_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `double_chance__first_half_draw_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `oddeven_odd_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `oddeven_even_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_home_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_draw_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_away_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_home_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_draw_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `results_both_teams_score_away_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_over_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_under_35_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_over_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_home_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_draw_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `result_total_goals_away_under_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__home_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__home_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__away_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `clean_sheet__away_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_both_halves_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_both_halves_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score__first_half_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_score__first_half_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score__second_half_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score__second_half_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_to_nil_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `win_to_nil_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_6_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number_more_7_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_win_either_half_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_win_either_half_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `home_team_exact_goals_number_more_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `away_team_exact_goals_number_more_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `second_half_exact_goals_number_more_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_0_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_1_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_2_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_3_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_4_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `exact_goals_number__first_half_more_5_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_score_in_both_halves_by_teams_home_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `to_score_in_both_halves_by_teams_away_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_over_yes_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_over_no_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_under_yes_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `total_goals_both_teams_to_score_under_no_25_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_home_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_draw_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_away_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_home_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_draw_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `halftime_result_both_teams_score_away_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_yes_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_yes_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_no_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `both_teams_to_score_1st_half__2nd_half_no_no_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `rcard_yes_perc` ",
     " ALTER TABLE `pattern_lists_only_ends` CHANGE `rcard_no_perc` ", 
]

end = [
    " `asian_handicap_away_min_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_min_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_min_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_home_plus_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_away_plus_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_40_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_40_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_45_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_50_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_50_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_60_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_60_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_70_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_70_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_75_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_75_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_85_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_85_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_over_95_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_under_95_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder_first_half_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_min_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_min_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_home_plus_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `asian_handicap_first_half_away_plus_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_05_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_10_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_15_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_20_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_30_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `goals_overunder__second_half_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `match_winner_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `match_winner_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `match_winner_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `homeaway_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `homeaway_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_winner_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_winner_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_winner_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_home_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_home_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_home_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_draw_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_draw_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_draw_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_away_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_away_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `htft_double_away_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_score_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_score_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `highest_scoring_half_first_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `highest_scoring_half_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `highest_scoring_half_second_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance_home_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance_home_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance_draw_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `first_half_winner_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `first_half_winner_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `first_half_winner_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance__first_half_home_draw_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance__first_half_home_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `double_chance__first_half_draw_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `oddeven_odd_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `oddeven_even_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_home_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_draw_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_away_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_home_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_draw_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `results_both_teams_score_away_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_home_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_draw_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_away_over_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_home_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_draw_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_away_under_35_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_home_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_draw_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_away_over_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_home_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_draw_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `result_total_goals_away_under_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `clean_sheet__home_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `clean_sheet__home_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `clean_sheet__away_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `clean_sheet__away_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `win_both_halves_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `win_both_halves_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_score__first_half_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_score__first_half_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score__second_half_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score__second_half_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `win_to_nil_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `win_to_nil_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number_more_7_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `to_win_either_half_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `to_win_either_half_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `home_team_exact_goals_number_more_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `away_team_exact_goals_number_more_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `second_half_exact_goals_number_more_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_0_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_1_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_2_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_3_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_4_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `exact_goals_number__first_half_more_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `to_score_in_both_halves_by_teams_home_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `to_score_in_both_halves_by_teams_away_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_over_yes_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_over_no_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_under_yes_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `total_goals_both_teams_to_score_under_no_25_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_home_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_draw_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_away_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_home_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_draw_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `halftime_result_both_teams_score_away_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_yes_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_yes_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_no_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `both_teams_to_score_1st_half__2nd_half_no_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `rcard_yes_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
    " `rcard_no_perc` DECIMAL(5,3) NULL DEFAULT NULL;",
]

# %%
# -----------------------------------------------------------------
total_rows = len(pre) 
# -----------------------------------------------------------------
host = "localhost"
user = "root"
database = "pr_mmbuzz_2022_06" 
mydb = mysql.connector.connect( host=host, user=user, password="", database=database ) 
# -----------------------------------------------------------------
mycursor = mydb.cursor() 
# -----------------------------------------------------------------
print(total_rows) 
counter = 0
# ----------------------------------------------------------------- 
while counter < total_rows: 
    pre_0 =  pre[counter]
    end_0 =  end[counter]
    word = pre_0 + end_0
    print(word)
    counter += 1 
    mycursor.execute(word)
    mydb.commit()
# Out:
# 240
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_65_perc`  `asian_handicap_away_min_65_perc` DECIMAL(5,3) NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_6_perc`  `asian_handicap_home_min_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_6_perc`  `asian_handicap_away_min_6_perc` DECIMAL(5,3) NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_55_perc`  `asian_handicap_home_min_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_away_min_55_perc`  `asian_handicap_away_min_55_perc` DECIMAL(5,3) NULL DEFAULT NULL;
#  ALTER TABLE `pattern_lists_only_ends` CHANGE `asian_handicap_home_min_5_perc`  `asian_handicap_home_min_5_perc` DECIMAL(5,3) NULL DEFAULT NULL;
# ...
